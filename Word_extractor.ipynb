# %%
import google.colab
import googleapiclient.discovery
import googleapiclient.http

# %%
google.colab.auth.authenticate_user()
drive_service = googleapiclient.discovery.build('drive', 'v3')

# %%
# Google driveにcolabのファイルを保存する。
# https://qiita.com/kakinaguru_zo/items/33dbe24276915124f545

upload_filename = 'dictionary-of-legal-terms.pdf'

file_list = drive_service.files().list(q="name='" + upload_filename + "'").execute().get('files')

# ファイル ID を取得します。
file_id = None
for file in file_list:
  if file.get('name') == upload_filename:
    file_id = file.get('id')
    break

if file_id is None:
  # ファイル ID を取得できなかった場合はエラーメッセージを出力します。
  print(upload_filename + ' が見つかりません.')
else:
  # colab 環境へファイルをアップロードします。
  with open(upload_filename, 'wb') as f:
    request = drive_service.files().get_media(fileId=file_id)
    media = googleapiclient.http.MediaIoBaseDownload(f, request)

    done = False
    while not done:
      progress_status, done = media.next_chunk()
      print(100*progress_status.progress(), end="")
      print("%完了")

  print('GoogleドライブからColab環境へのファイル取り込みが完了しました.')
# Out:
# 100.0%完了
# GoogleドライブからColab環境へのファイル取り込みが完了しました.

# %% [markdown]
# #Import all libraries

# %%
# https://towardsdatascience.com/how-to-extract-keywords-from-pdfs-and-arrange-in-order-of-their-weights-using-python-841556083341
import pandas as pd
import numpy as np
import re

# %%
# !pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading https://files.pythonhosted.org/packages/b4/01/68fcc0d43daf4c6bdbc6b33cc3f77bda531c86b174cac56ef0ffdb96faab/PyPDF2-1.26.0.tar.gz (77kB)
#      |████████████████████████████████| 81kB 2.7MB/s
# Building wheels for collected packages: PyPDF2
#   Building wheel for PyPDF2 (setup.py) ... done
#   Created wheel for PyPDF2: filename=PyPDF2-1.26.0-cp36-none-any.whl size=61085 sha256=7c46f8605bc29162d016e53b7f3ab23f4c0365939043bf2c797eb6f6ad405119
#   Stored in directory: /root/.cache/pip/wheels/53/84/19/35bc977c8bf5f0c23a8a011aa958acd4da4bbd7a229315c1b7
# Successfully built PyPDF2
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-1.26.0

# %%
# !pip install textract
# Out:
# Collecting textract
#   Downloading https://files.pythonhosted.org/packages/32/31/ef9451e6e48a1a57e337c5f20d4ef58c1a13d91560d2574c738b1320bb8d/textract-1.6.3-py3-none-any.whl
# Collecting EbookLib==0.17.1 (from textract)
#   Downloading https://files.pythonhosted.org/packages/00/38/7d6ab2e569a9165249619d73b7bc6be0e713a899a3bc2513814b6598a84c/EbookLib-0.17.1.tar.gz (111kB)
#      |████████████████████████████████| 112kB 7.4MB/s
# Collecting argcomplete==1.10.0 (from textract)
#   Downloading https://files.pythonhosted.org/packages/4d/82/f44c9661e479207348a979b1f6f063625d11dc4ca6256af053719bbb0124/argcomplete-1.10.0-py2.py3-none-any.whl
# Collecting xlrd==1.2.0 (from textract)
#   Downloading https://files.pythonhosted.org/packages/b0/16/63576a1a001752e34bf8ea62e367997530dc553b689356b9879339cf45a4/xlrd-1.2.0-py2.py3-none-any.whl (103kB)
#      |████████████████████████████████| 112kB 46.3MB/s
# Collecting docx2txt==0.8 (from textract)
#   Downloading https://files.pythonhosted.org/packages/7d/7d/60ee3f2b16d9bfdfa72e8599470a2c1a5b759cb113c6fe1006be28359327/docx2txt-0.8.tar.gz
# Collecting pdfminer.six==20181108 (from textract)
#   Downloading https://files.pythonhosted.org/packages/8a/fd/6e8746e6965d1a7ea8e97253e3d79e625da5547e8f376f88de5d024bacb9/pdfminer.six-20181108-py2.py3-none-any.whl (5.6MB)
#      |████████████████████████████████| 5.6MB 43.1MB/s
# Collecting python-pptx==0.6.18 (from textract)
#   Downloading https://files.pythonhosted.org/packages/bf/86/eb979f7b0333ec769041aae36df8b9f1bd8bea5bbad44620663890dce561/python-pptx-0.6.18.tar.gz (8.9MB)
#      |████████████████████████████████| 8.9MB 14.6MB/s
# Requirement already satisfied: chardet==3.0.4 in /usr/local/lib/python3.6/dist-packages (from textract) (3.0.4)
# Collecting SpeechRecognition==3.8.1 (from textract)
#   Downloading https://files.pythonhosted.org/packages/26/e1/7f5678cd94ec1234269d23756dbdaa4c8cfaed973412f88ae8adf7893a50/SpeechRecognition-3.8.1-py2.py3-none-any.whl (32.8MB)
#      |████████████████████████████████| 32.8MB 1.4MB/s
# Requirement already satisfied: six==1.12.0 in /usr/local/lib/python3.6/dist-packages (from textract) (1.12.0)
# Collecting extract-msg==0.23.1 (from textract)
#   Downloading https://files.pythonhosted.org/packages/a1/90/84485a914ed90adb5e87df17e626be04162fbba146dfecf34643659a4633/extract_msg-0.23.1-py2.py3-none-any.whl (45kB)
#      |████████████████████████████████| 51kB 18.8MB/s
# Collecting beautifulsoup4==4.8.0 (from textract)
#   Downloading https://files.pythonhosted.org/packages/1a/b7/34eec2fe5a49718944e215fde81288eec1fa04638aa3fb57c1c6cd0f98c3/beautifulsoup4-4.8.0-py3-none-any.whl (97kB)
#      |████████████████████████████████| 102kB 30.1MB/s
# Requirement already satisfied: lxml in /usr/local/lib/python3.6/dist-packages (from EbookLib==0.17.1->textract) (4.2.6)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.6/dist-packages (from pdfminer.six==20181108->textract) (2.1.0)
# Collecting pycryptodome (from pdfminer.six==20181108->textract)
#   Downloading https://files.pythonhosted.org/packages/c1/f1/0ba99559391621280ce24adea245d31bf2eb2f20ac72270eead1813e8d2b/pycryptodome-3.9.0-cp36-cp36m-manylinux1_x86_64.whl (9.7MB)
#      |████████████████████████████████| 9.7MB 26.9MB/s
# Requirement already satisfied: Pillow>=3.3.2 in /usr/local/lib/python3.6/dist-packages (from python-pptx==0.6.18->textract) (4.3.0)
# Collecting XlsxWriter>=0.5.7 (from python-pptx==0.6.18->textract)
#   Downloading https://files.pythonhosted.org/packages/25/88/a38f35b00ce4dd166a20e1a0a25e438e19e332e680df52af4aeac0df0f03/XlsxWriter-1.2.2-py2.py3-none-any.whl (140kB)
#      |████████████████████████████████| 143kB 42.3MB/s
# Requirement already satisfied: tzlocal==1.5.1 in /usr/local/lib/python3.6/dist-packages (from extract-msg==0.23.1->textract) (1.5.1)
# Collecting imapclient==2.1.0 (from extract-msg==0.23.1->textract)
#   Downloading https://files.pythonhosted.org/packages/dc/39/e1c2c2c6e2356ab6ea81fcfc0a74b044b311d6a91a45300811d9a6077ef7/IMAPClient-2.1.0-py2.py3-none-any.whl (73kB)
#      |████████████████████████████████| 81kB 27.2MB/s
# Requirement already satisfied: olefile==0.46 in /usr/local/lib/python3.6/dist-packages (from extract-msg==0.23.1->textract) (0.46)
# Collecting soupsieve>=1.2 (from beautifulsoup4==4.8.0->textract)
#   Downloading https://files.pythonhosted.org/packages/5d/42/d821581cf568e9b7dfc5b415aa61952b0f5e3dede4f3cbd650e3a1082992/soupsieve-1.9.4-py2.py3-none-any.whl
# Requirement already satisfied: pytz in /usr/local/lib/python3.6/dist-packages (from tzlocal==1.5.1->extract-msg==0.23.1->textract) (2018.9)
# Building wheels for collected packages: EbookLib, docx2txt, python-pptx
#   Building wheel for EbookLib (setup.py) ... done
#   Created wheel for EbookLib: filename=EbookLib-0.17.1-cp36-none-any.whl size=38164 sha256=7a771878af051d90b326eea866db36518e5c4947956bd99af80291b3bfa03b5d
#   Stored in directory: /root/.cache/pip/wheels/84/11/01/951369cbbf8f96878786a1f4da68bd7ac19a5d945b38e03d54
#   Building wheel for docx2txt (setup.py) ... done
#   Created wheel for docx2txt: filename=docx2txt-0.8-cp36-none-any.whl size=3965 sha256=5fe49745511c86269f5c37cba95965b561502afd8960752b0b829b47047f135d
#   Stored in directory: /root/.cache/pip/wheels/b2/1f/26/a051209bbb77fc6bcfae2bb7e01fa0ff941b82292ab084d596
#   Building wheel for python-pptx (setup.py) ... done
#   Created wheel for python-pptx: filename=python_pptx-0.6.18-cp36-none-any.whl size=275707 sha256=08065c1375e719c810a581c5d16d46e227f03039b303e2b34aa9acbff1c3e10d
#   Stored in directory: /root/.cache/pip/wheels/1f/1f/2c/29acca422b420a0b5210bd2cd7e9669804520d602d2462f20b
# Successfully built EbookLib docx2txt python-pptx
# Installing collected packages: EbookLib, argcomplete, xlrd, docx2txt, pycryptodome, pdfminer.six, XlsxWriter, python-pptx, SpeechRecognition, imapclient, extract-msg, soupsieve, beautifulsoup4, textract
#   Found existing installation: xlrd 1.1.0
#     Uninstalling xlrd-1.1.0:
#       Successfully uninstalled xlrd-1.1.0
#   Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed EbookLib-0.17.1 SpeechRecognition-3.8.1 XlsxWriter-1.2.2 argcomplete-1.10.0 beautifulsoup4-4.8.0 docx2txt-0.8 extract-msg-0.23.1 imapclient-2.1.0 pdfminer.six-20181108 pycryptodome-3.9.0 python-pptx-0.6.18 soupsieve-1.9.4 textract-1.6.3 xlrd-1.2.0

# %% [markdown]
# #Extract words from a dictionary
#
# convert a pdf file to txt and read data
#
# extract keywords
#
# save extracted keywords

# %%
import PyPDF2
import textract

# %% [markdown]
# ようやくできた！！！！インストールだけでは足りず、インポートもしないといけないらしい！！！

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#google drive 
filename ='/content/drive/My Drive/Colab Notebooks/dictionary-of-legal-terms.pdf' 

pdfFileObj = open(filename,'rb') #why B?
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)   #The pdfReader variable is a readable object that will be parsed
num_pages = pdfReader.numPages                 #discerning the number of pages will allow us to parse through all the pages


count = 150 # only for test to read pages from 12 to 14
text = ""
                                                            
while count < 200:                      #CHANGE PAGE NUM TO 626 WHEN USE
    pageObj = pdfReader.getPage(count)
    count +=1
    text += pageObj.extractText()
    
#Below if statement exists to check if the above library returned #words. It's done because PyPDF2 cannot read scanned files.

if text != "":
    text = text 
    
#If the above returns as False, we run the OCR library textract to #convert scanned/image based PDF files into text

else:
    text = textract.process('http://bit.ly/epo_keyword_extraction_document', method='tesseract', language='eng')

    # Now we have a text variable which contains all the text derived from our PDF file.

# %%
print(text)
# Out:
# < previous page
# page_121next page >
# Page 121
# prietary, or penal interest that a reasonable person would not have made the statement unless he or she believed it
# to be true. Further, the declarant must have personal knowledge and, in some jurisdictions, must be unavailable at
#
# the time of trial. Because of its special trustworthiness, a declaration against interest is an exception to the hearsay
#
# rule.EXAMPLE: A statement by a juvenile that he had thrown a bicycle frame out an eighth floor stairwell window of
# the defendant's building is admissible hearsay in an action against the defendant housing authority for failure to
# repair the stairwell window.
# ADMISSIONS BY A PARTY-OPPONENT
# distinguishable from declarations against interest in that admissions of
# a party-opponent are per se admissible and thus do not have to satisfy the above requirements for a declaration
# against interest and they do not have to, although they may, be against interest when made. Further, the party
#
# making the admission need not be unavailable and need not have personal knowledge.
# EXAMPLE: A statement by a defendant, questioned in Nebraska about a homicide committed in New Jersey, that
# he had never been to New Jersey is admissible as an admission by a party (along with proof of his ten-year
# residency in New Jersey) to show that the defendant lied to throw off the investigation.
# DECLARATION OF ESTIMATED TAX see return [
# DECLARATION OF ESTIMATED TAX
# ].DECLARATION OF TRUST see trust [
# DECLARATION OF TRUST
# ].DECLARATORY JUDGMENT
# a judgment of the court to establish the rights of the parties or express the opinion of the court on a question of
# law, without ordering anything to be done or granting any remedy.
# EXAMPLE: A state legislature passes a taxing measure that will have a widespread effect on corporations doing
# interstate business within that state. A payment of the tax with a subsequent refund if the tax is found invalid
# would result in administrative difficulties. Therefore, one of the affected corporations asks a court for a
# declaratory
# judgment
# on the validity of the tax.
# Compare advisory opinion; injunction.
# DECLARATORY STATUTE
# a statute that merely declares the existing law without proposing changes, for the purpose of resolving conflicts
# concerning the meaning of a previous statute or portion of the common law.
#  < previous page
# page_121next page >
# < previous page
# page_122next page >
# Page 122
# DECREE1. the judicial decision in a litigated cause rendered by a court of equity; 2. the determination of a cause in courts
# of admiralty and probate. It is accurate to use the word judgment for a decision of a court of law, and decree from
#
# a court of equity, although the former term now includes both.
# CONSENT DECREE
# an agreement of the parties made under sanction of the court, not the result of a judicial
# determination, but merely agreement to be bound by certain stipulated facts.
#
# DECREE NISI
# in English law, a provisional decree of divorce, which becomes absolute only after a specified
# interval, usually six months, during which parties have the opportunity to show cause why the decree should not
# become absolute.
# FINAL DECREE
# one that ultimately disposes of every matter of contention between the parties and constitutes a
# bar to another action on the same subject matter between the same parties.
#
# INTERLOCUTORY DECREE
# one made upon some point arising during the progress of the suit that does not
# determine finally the merits of the entire suit.
# DECREE NISI see decree [
# DECREE NISI
# ]; nisi [
# DECREE NISI
# ].DECRIMINALIZATIONthe adoption or repeal of legislation, the effect of which is that acts or omissions formerly considered criminal are
# no longer so characterized, and penal sanctions for such acts or omissions are removed.
# DEDICATIONa conveyance of land as a grant to the public by a private owner and an acceptance of that land on behalf of the
# public.EXAMPLE: A company buys a large area of land, on which it plans to locate its national headquarters. To promote
# goodwill between the company and the surrounding communities, the company
# dedicates
# a portion of land to the
# county parks committee, who accept permanent ownership of the land.
# DEDUCTIONSamounts allowed to taxpayers under the Internal Revenue Code as offsets against
# GROSS INCOME
# or
# ADJUSTEDGROSS INCOME
# (see income).
# ITEMIZED DEDUCTIONS
# specific individualized deductions, allowed under provisions of the Code for specific
# expenses incurred by the taxpayer during the taxable year. These deductions are allowed in computing
# TAXABLEINCOME(see income) to the extent they exceed the
# ZERO BRACKET AMOUNT
# .MARITAL DEDUCTION
# a deductible amount under the unified estate and gift tax for certain interests in property
# transferred to a spouse.
#  < previous page
# page_122next page >
# < previous page
# page_123next page >
# Page 123
# PERSONAL EXPENSES DEDUCTION
# personal expenses as opposed to expenses for income-producing or
# business expenses. Personal expenses are not allowed as deductions except as specifically enumerated in the
# Internal Revenue Code
# STANDARD DEDUCTION
# a provision allowing a taxpayer to deduct, in lieu of itemized deductions, a percentage
# of gross income up to certain specified amounts, repealed and replaced by the
# ZERO BRACKET AMOUNT
# .ZERO BRACKET AMOUNT DEDUCTION
# an amount of income below the amounts at which, according to the
# tax tables, income taxes must be paid.
# DEEDan instrument in writing that conveys an interest in land (realty) from the grantor to the grantee. Its main function
# is to pass title to land. See bargain and sale; quitclaim deed; warranty.
# DEED OF TRUST
# a transfer of legal title to property from owner to a trustee, so that the trustee may hold the title as security for the
# performance of certain obligations, monetary or otherwise, by the owner of a third party. Compare mortgage.
# DEED POLL
# a deed made by and obligatory upon one party alone.
# DEEP ROCK DOCTRINE
# a doctrine that makes available a remedy for improper conduct in connection with a loan to a corporation by a
# controlling shareholder. Though generally loans to a corporation by a shareholder are entitled to equal priority with
#
# loans made by outside creditors, the doctrine allows, when there are bankruptcy proceedings involving the
#
# corporation, subordination of the shareholder loans to the claims of other creditors where it would be manifestly
#
# unfair to permit a controlling shareholder to participate equally with these other creditors.
# The unfairness occurs most commonly where the corporation is undercapitalized and frequently involves a parent
# corporation as the controlling shareholder of a subsidiary.
# DE FACTO
#  Lat.: in fact. By virtue of the deed or accomplishment; actually. Used to refer to a situation in which
# a condition or institution is operating as though it were official or pursuant to law, but that is not legally
# authorized. Such situations may arise where, for example, an authorizing law is declared invalid, or because
#
# required legal formalities have not been satisfied.
# EXAMPLE: Nursing homes were established throughout a particular state under the authority of a newly enacted
# state law. Now, two years later, portions of the law are found to be unconstitutional. Instead of closing all the
# homes that were set up, the state permits
#  < previous page
# page_123next page >
# < previous page
# page_124next page >
# Page 124
# them to continue to operate under its
# de facto
# authority until the law is amended and legal.
# The de facto acts of a person or entity may for some purposes be regarded as legally binding. Compare de jure.
# DEFALCATIONfailure of one entrusted with money to pay over the money when it is due to another. The term is like
# misappropriation and embezzlement, but is wider in scope because it does not imply criminal fraud.
# DEFAMATIONthe publication of anything injurious to the reputation of another. Defamation designed to be read is libel; oral
# defamation is slander.
# EXAMPLE: A reporter publishes an article that Ryan is being investigated for misapplication of public funds. The
# article has no basis in fact, but, as a result of it, Ryan is forced to temporarily leave his position as director. Ryan
# has been libeled and probably has a
# defamation action against the reporter.
# DEFAULTfailure to discharge a duty. The term is often used in the context of mortgages to describe failure of the mortgagor
# to pay installments when due, and in the context of judicial proceedings to describe failure of one of the parties to
#
# take procedural steps to prevent entry of a judgment against him (called a default judgment). See delict.
# DEFAULT JUDGMENT
# 1. a judgment against defendant who has failed to respond to plaintiff's action or to appear at the trial or hearing.
#
# EXAMPLE: A carpenter files a suit against a homeowner, claiming that the homeowner failed to pay the carpenter
# for work performed six months ago. Under the state's court rules, the homeowner has twenty days to file an answer
# to the carpenter's claim. If the homeowner fails to do so within twenty days, the court will enter a
# default judgment
#
# against him declaring that the homeowner must pay the carpenter what is claimed.
# 2. judgment given without the defendant being heard in his own defense. Compare confession of judgment; ex
# parte.DEFEASANCEan instrument that negates the effectiveness of a deed or of a will; a collateral deed that defeats the force of another
# deed upon the performance of certain conditions.
# DEFEASIBLEsubject to revocation if certain conditions are not met; capable of being avoided or annulled, or liable to such
# avoidance or annulment.
#  < previous page
# page_124next page >
# < previous page
# page_125next page >
# Page 125
# DEFEASIBLE FEE see determinable fee.
# DEFECT see latent defect; patent defect.
#
# DEFECTIVE1. incomplete, faulty; 2. not reasonably safe for a use that can be reasonably anticipated. See also products liability;
# warranty.DEFECTIVE PLEADING
# any pleading [complaint, answer, cross-claim, etc.] which fails to conform in form or substance to minimum
# standards of accuracy or sufficiency. Under strict common law pleading rules, a defective pleading was often fatal
#
# to the lawsuit. Under modern relaxed standards, such occurrences are rare and are curable by amendment.
# DEFECTIVE TITLE
# unmarketable right of ownership. 1. With reference to land, it means that the title held by the person making the
# conveyance, claiming to own good title, is or might be subject to partial or complete ownership by someone else.
# EXAMPLE: Ruth wants to sell her house to a friend who is moving into the state. Prior to purchasing the house,
# the friend has a title search done to determine if anyone else has claimed ownership of the house besides Ruth.
# That search discloses a bank note that has never been paid but that the bank has never acted upon. Still, the
#
# outstanding bank note gives rise to a
# defective title,
# which now makes the friend reluctant to buy the house.
# 2. As to negotiable instruments, the term denotes title obtained through fraud or other illegal means.
# DEFENDANT1. in civil proceedings, the party responding to the complaint; one who is sued and called upon to make satisfaction
# for a wrong complained of by another; 2. in criminal proceedings, the accused. See also respondent.
# DEFENDENT IN ERROR
# the prevailing party in the lower court who is the adverse party in the appellate
# proceeding where review has been sought on a writ of error. The person who brings the action at the appellate
# level is called the
# PLAINTIFF IN ERROR
# . See also appellee.
# DEFENSEa denial, answer or plea disputing the validity of plaintiff's case, or making some further contention that renders the
# defendant not liable upon the facts alleged by the plaintiff.
# AFFIRMATIVE DEFENSE
# one that serves as a basis for proving some new fact, whereby defendant does not
# simply deny a charge but offers new evidence to avoid judgment against him or her.
#  < previous page
# page_125next page >
# < previous page
# page_126next page >
# Page 126
# EQUITABLE DEFENSE
# a defense that is recognized by courts of equity acting solely upon rules of equity. Such
# defenses can now be asserted in courts of law as well.
# DEFERMENTpostponing or putting off to a future time. May apply to the vesting or enjoyment of an estate, or to the calling of a
# person to serve in the armed forces. To defer does not mean to abolish or omit.
# DEFERRED COMPENSATION see retirement plans [
# DEFERRED COMPENSATION
# ].DEFERRED PAYMENTS
# payments extended over a period of time or put off to a future date.
# DEFICIENCYthe excess of a taxpayer's correct tax liability for the taxable year over the amount of taxes previously paid for such
# year. The Internal Revenue Service is authorized to assess deficiencies during an audit of the taxpayer's return, and
#
# a deficiency may be used to assess penalties for the underpayment of tax, such as for negligence or fraud in filing
#
# the return.
# DEFICITinsufficiency in an account or number, whether as the result of defaults and misappropriations or of mistake or
# shrinkage in value.
# DEFINITE FAILURE OF ISSUE see failure of issue.
#
# DEFRAUDto deprive a person of property or interest, estate or right by fraud or deceit.
# DEGREEa measure. Also, the certificate of achievement that a school, college, or university gives to a student who
# completes a specified course of study or curriculum.
# DEGREE OF CONSANGUINITY [KINSHIP] see consanguinity.
#
# DEGREE OF CRIME
# the measure of the seriousness of a criminal act that determines the range of criminal sanctions that may be
# imposed for the crime. For instance, under the Model Penal Code, assault can be classified into any of four degrees
#
# depending upon the victim or the manner of commission. A simple assault could be a petty misdemeanor carrying
#
# a sentence of not more than 30 days, or a misdemeanor carrying a sentence of not more than one year; an
#
# aggravated assault could be a crime of the third degree exposing the defendant to five years, or a crime of the
#
# second degree carrying a maximum sentence of ten years.
# DEGREE OF NEGLIGENCE
# the measure of negligence necessary for liability to result. Parties under an obligation to exercise great care, such
# as common carriers, may be liable for slight negligence,
#  < previous page
# page_126next page >
# < previous page
# page_127next page >
# Page 127
# whereas parties only required to exercise slight care, such as the driver of an automobile in a state that has a guest
# statute, will be liable to a passenger only for gross negligence.
# DEGREE OF PROOF
# the measure of probability necessary in order for a court or other fact finder to render a decision or a verdict with
# regard to the evidence presented to it. See preponderance of the evidence; clear and convincing; reasonable doubt.
# DE JURE
#  Lat.: by right; lawful; legitimate.
# EXAMPLE: a new corporation is set up exactly according to both state and federal incorporation laws. The
# corporation is therefore a
# de jure
# (i.e., legal) corporation.
# Generally used in contrast to de facto; de jure connotes "as a matter of law," whereas de facto connotes "as a
# matter of practice not founded upon law."
# DELEGABLE DUTY
# a duty that an obligor is able to transfer to another. The term does not imply a giving up of authority but, rather, the
# conferring of authority to another to do things that otherwise must be done by the obligor. When delegation occurs,
#
# it does not free the obligor from his or her duty to see to it that performance is properly complied with. Only by
#
# novation may the original obligor totally discharge his or her responsibilities and liabilities.
# Where performance by the delegate would vary materially from the performance of the obligor, the duty is
# NONDELEGABLE. Thus, under a contract to paint a portrait or where a contract is premised on the unique
# abilities of the obligor, the duties are nondelegable. Construction contracts, however, are generally held to be
#
# delegable because it is contemplated by the parties that the work will be performed by persons other than the
#
# obligor.DELEGATEl. to appoint, authorize or commission; the transfer of authority by one person to another. 2. a person commissioned
# to act instead of another.
# DELEGATED POWER
# power conferred by one person on another who will act for his or her benefit.
# DELIBERATEto consider all of the evidence and arguments presented in regard to a particular matter. For instance, after the
# evidence has been presented, the parties to a lawsuit have made their closing arguments, and the judge has given
#
# the jury its instructions, the jury will retire to deliberate and render its verdict.
# DELIBERATE SPEED
# forthwith, immediate. In certain instances, such as the desegregation of public facilities, the term implies that
#  < previous page
# page_127next page >
# < previous page
# page_128next page >
# Page 128
# desegregation should occur as quickly as the maintenance of law and order and the welfare of all citizens will
# allow.DELIBERATIONthe process by which the reasons for and against a verdict are weighed by jurors. While such verdict should be the
# consensus of the judgments of each juror, the purpose of deliberation is to allow opinions to be changed by
#
# conference in the jury room.
# DELICTa tort; a wrong or injury; any statutory violation; sometimes used in the sense of a default on a monetary
# obligation.DELICTUMLatin for tort. An action
# EX DELICTO
# is an action in tort as distinguished from one
# EXCONTRACTU, in contract.
# DELICTUM
# Latin for tort. An
# ACTION EX DELICTO
# is an action in tort as opposed to one
# EX CONTRACTU
# , in contract.
# This distinction was significant when the early forms of code pleading were very strict. If, for example, one alleged
# a cause of action ex delicto for fraud but the proof established a breach of warranty (an action ex contractu) the
#
# case would be dismissed for variance.
# DELINQUENTin a monetary context, payable but overdue and unpaid. See default. See also juvenile delinquent.
# DELISTINGremoval of an issue from trading on an organized exchange such as the New York Stock Exchange. Organized
# exchanges have minimum listing requirements that must be met before listed trading is allowed. If the issuer fails
#
# to maintain the minimum requirements, trading in its listed securities can be suspended or eliminated.
# DELIVERYa voluntary transfer of title or possession from one party to another; a legally recognized handing over to another
# one's possessory rights. Where actual delivery is cumbersome or impossible, the courts may find constructive
#
# delivery sufficient if the intention is clearly to transfer title. Thus, one may deliver the contents of a safety deposit
#
# box by handing over the key together with any necessary authorization. Such action is also called
# SYMBOLIC
# DELIVERY. Compare bailment.
# DELUSIONa false belief that is produced by a mental disorder and that people of the same age, class, and education would
# find incredible. A delusion can be the basis for the insanity defense to a crime.
# DEMAND see on demand.
#
# DEMAND NOTE
# 1. an instrument that by its express terms is payable immediately on an agreed-upon date of maturity without
#  < previous page
# page_128next page >
# < previous page
# page_129next page >
# Page 129
# further demand for payment; 2. an instrument payable at sight, or upon presentation, or one in which no time for
# payment is stated.
# DEMESNE Fr: domain. Something owned; held in one's own right, and not of a superior; not allotted to tenants. In
# the language of pleading, own, proper, or original. See ancient demesne.
#
# DE MINIMIS
#  Lat.: trifling. Of insufficient significance to warrant judicial attention.
# DE MINIMIS NON CURAT LEX
# Lat.: the law does not care for small things; the law does not bother with trifles.
# EXAMPLE: Tom is arrested for possession of one marijuana cigarette. Although marijuana possession has not been
# decriminalized in the state where Tom is arrested, the prosecutor decides not to prosecute Tom for the possession
# since it is only a
# de minimis
# infraction.DEMISEterm used to describe a conveyance of an estate in real property; to let, especially pursuant to a lease for a term of
# years.DEMONSTRATIVE EVIDENCE
# evidence consisting of an object or thing, such as a weapon used in a crime, a stolen item, or a photograph or X-
# ray, that may aid the jury in understanding the crime before it but has no effect on the question of guilt; evidence
#
# other than a person's oral testimony but that may help to explain that testimony.
# DEMURto present a demurrer. More broadly, to take an exception to a point of law or an allegation of facts on the basis
# that even if it is so it does not advance the interests of the party making the statement.
# DEMURRERformal allegation that facts as stated in the pleadings, even if true, are not legally sufficient for the case to proceed
# further. It does not admit anything but tests whether the complaint is sufficient to state a cause of action. In modern
#
# procedure, a motion to dismiss for failure to state a claim upon which relief may be granted replaces the demurrer.
#
# Compare summary judgment.
# DENIALa contradiction or traverse; in practice, a refutation of affirmative allegations contained in the pleading of an
# adversary. A defendant's answer must admit, deny, or state there is insufficient information upon which to admit or
#
# deny the plaintiff's allegations. Any allegation in a complaint to which a responsive pleading is required, other than
#
# for amount of damages, is admitted when not denied in the responsive pleading. Averments in a pleading to which
#
# no responsive pleading is required or permitted shall be taken as denied or avoided. See also confession and
#
# avoidance; negative pregnant.
#  < previous page
# page_129next page >
# < previous page
# page_130next page >
# Page 130
# CONJUNCTIVE DENIAL
# a denial that denies all of the allegations as wholly untrue.
# DISJUNCTIVE DENIAL
# a denial that denies the allegations as untrue in the alternative.
# GENERAL DENIAL
# a denial of all of the plaintiff's allegations.
# SPECIFIC DENIAL
# a denial of one or several, but not all, of the plaintiff's allegations.
# DE NOVO
#  Lat.: anew. A second time, as though the first had never taken place.
# DE NOVO HEARING
# a new hearing, in which the judgment of the first hearing is suspended and the case proceeds
# as if it had originated in the reviewing tribunal.
# EXAMPLE: A state statute gives a defendant convicted in a municipal court the right to appeal that conviction
# denovo
# in a higher court. That right means that the defendant will have a new trial in which the facts and issues will
# be retried as though the first trial never took place.
# DEODAND see forfeiture.
#
# DEPENDENCYa territory or possession not within the boundaries of the country that has jurisdiction to govern it. Dependencies of
# the United States include Puerto Rico, the Virgin Islands, Guam, and various other islands located in the Pacific
#
# Ocean.DEPENDENTany person with respect to whom a taxpayer can claim a dependency exemption; defined by the Internal Revenue
# Code as any individual supported by the taxpayer who is related to the taxpayer in specified ways or who makes
#
# his principal abode in the taxpayer's household.
# DEPENDENT CARE see child and dependent care credit.
#
# DEPENDENT COVENANTS see covenant [
# DEPENDENT COVENANTS
# ].DEPENDENT RELATIVE REVOCATION
# the doctrine that provides that when a will revokes an earlier will executed by the same person, the earlier will is
# only revoked if the latter will is effective; otherwise, the earlier will remains in full effect and force.
# DEPLETIONthe exhaustion of a natural resource, the amount of the original deposit being hidden and thus necessarily
# unknown. Depletion is most often referred to in federal income tax deduction provisions that deal with exhaustion
#
# of natural resources.
#  < previous page
# page_130next page >
# < previous page
# page_131next page >
# Page 131
# The
# DEPLETION ALLOWANCE
# is a formula for computing and excluding from the proceeds of natural resource
# operations that part of the operations' proceeds that is in effect a return of capital.
# EXAMPLE: Petro Corporation purchases several leases of land on which it plans to drill oil. If oil is extracted from
# any of those leased lands, the value of the lease is reduced. The
# depletion allowance
# determines a figure based on
# that reduction in value. Petro then uses that figure to reduce its tax obligation.
# Depletion allowance should be contrasted with depreciation deduction provisions that deal with deterioration of
# tangible physical property incident to its use that shortens its period of service.
# DEPONENTa witness; especially one who gives information under oath, in a deposition concerning facts known to him or her.
# DEPORTATIONthe transfer of an alien to a foreign country because the deporting government refuses to harbor a person whose
# presence is deemed inconsistent with the public welfare. Compare extradition.
# DEPOSE1. to give evidence or testimony, especially in response to interrogation during a deposition. 2. the act of
# interrogating and eliciting testimony during a deposition, typically conducted by a lawyer.
# DEPOSITIONa method of pretrial discovery that consists of a stenographically transcribed statement of a witness under oath, in
# response to an attorney's questions, with opportunity for the opposing party or his or her attorney to be present and
#
# to cross-examine. Such a statement is the most common form of discovery and may be taken of any witness
#
# (whether or not a party to the action). When taken in the form described, it is called an oral deposition. Depositions
#
# may also be taken upon written interrogatories, where the questions are read to the witness by the officer who is
#
# taking the deposition.
# DEPOSITION DE BENE ESSE see de bene esse.
#
# DEPRECIATIONa deduction allowed to a taxpayer representing a reasonable allowance for the exhaustion of property used in a
# trade or business, or property held for the production of income. The purpose of charging depreciation against
#
# equipment is to generate a tax-free stream of income equal to the portion of the asset that has been ''used up" and
#
# to distinguish the portion of income that is a return of capital. Compare depletion.
# ACCELERATED DEPRECIATION
# any one of a number of allowed methods of calculating depreciation that
# permit greater amounts of
#  < previous page
# page_131next page >
# < previous page
# page_132next page >
# Page 132
# deductions in earlier years than are permitted under the straight line method, which assumes equal depreciation
# during each year of the asset's useful life.
# STRAIGHT LINE DEPRECIATION
# a method that calculates the depreciation deduction available by subtracting
# the asset's
# SALVAGE VALUE
# from its total value and dividing the difference by the number of years of the asset's
# useful life.
#
# SALVAGE VALUE
# the estimated value of the property when the taxpayer completes his or her use of the property.
# In determining the amount of depreciation allowable, salvage value must be subtracted from basis.
#
# USEFUL LIFE
# the reasonable estimate of the term of an asset's usefulness to the taxpayer in his or her business.
# DEPRECIATION RESERVE [
# ACCUMULATED DEPRECIATION
# ]the total depreciation charged against all productive assets as stated on the balance sheet. The charge is made to
# allow realistic reduction in the value of productive assets and to allow tax-free recovery of the original investment
#
# in assets.
# DEPREDATION see piracy.
#
# DEPRESSANTS see controlled substances.
#
# DERELICTIONa recession of waters of the sea, a navigable river or other stream, by which land that had been covered with water
# is left dry. If the alteration is sudden and noticeable, ownership remains according to former bounds; but if
#
# recession is gradual and imperceptible, the derelict or dry land belongs to the riparian owner from whose shore the
#
# water has so receded. The term may also refer to the land that is thus left uncovered. For contiguous landowners to
#
# gain ownership of the newly uncovered land, the withdrawal of the water must appear permanent, not merely
#
# seasonal. Compare accretion; avulsion.
# DERIVATIVE ACTION
# 1. an action based upon a primary right of a corporation, but asserted on its behalf by the shareholder because of
# the corporation's failure, deliberate or otherwise, to assert the right; 2. a cause of action founded upon an injury to
#
# another, as when a husband sues for loss of consortium or services of his wife on account of injury to her by the
#
# defendant, or when a father sues for loss of services of children. See stockholders' derivative action.
# DERIVATIVE TORT
# an action in tort based on the criminal conduct of defendant that resulted in injury to plaintiff for which he
#  < previous page
# page_132next page >
# < previous page
# page_133next page >
# Page 133
# seeks compensation. The action is distinct from any criminal prosecution that may result from the same conduct by
# defendant.DEROGATIONpartial taking away of the effectiveness of a law; partially repealing or abolishing a law.
# DESCENTa method of acquiring property, usually real property, through the laws of descent and distribution from a decedent
# without the use of a will; generally applied to inheritance only by intestate succession. Compare devise. See
#
# worthier title, doctrine of.
# DESCENT AND DISTRIBUTION
# the transmission of an intestate's property to his heirs.
# DESEGREGATION see segregation.
#
# DESERTIONact of abandonment of a relation or service in which one owes duties. In matrimonial law, an unjustified cessation
# from cohabitation, with intent not to resume it and without the consent of the other spouse, is desertion and is
#
# grounds for divorce. In military law,
# ABSENT WITHOUT LEAVE
#  [AWOL] signifies an intention by a member
# of the armed forces not to return to service. It is punishable under the Code of Military Justice.
# DESIST see cease and desist order.
#
# DESTINATION CONTRACT see tender [
# TENDER OF DELIVERY
# ].DESTRUCTIBILITYrefers to a common-law rule that when a contingent remainder does not vest at or before the termination of the
# preceding freehold estate, the remainder interest is destroyed. Thus, the termination of the preceding estate,
#
# because of its inherent limitation, or as a result of forfeiture or merger, destroys the nonvested contingent
#
# remainder.DESUETUDEa term applied to obsolete laws and practices that may therefore be regarded as no longer in effect.
# DETAINER1. keeping a person from goods or land to which he or she has a legal right; 2. a writ or instrument, issued by a
# competent officer, authorizing a prison warden to keep in his or her custody a person therein named. See also
#
# detention.UNLAWFUL DETAINER
# refusal to deliver on demand, as where the tenant, after termination of the lease, refuses
# to deliver possession to the landlord. Compare tenancy [
# TENANCY AT SUFFERANCE
# ].DETENTION
# holding of a person charged with crime following the person's arrest on that charge.
#  < previous page
# page_133next page >
# < previous page
# page_134next page >
# Page 134
# DETERMINABLE FEE [FEE SIMPLE DETERMINABLE]
# an interest in property that may last forever, but that will automatically terminate upon the happening or
# nonhappening of a specified event. Also called a
# DEFEASIBLE FEEor a
# FEE SIMPLE DEFEASIBLE
# .EXAMPLE: A brother conveys a large office building to his sister provided she remains unmarried. If she is
# unmarried at her death, she can dispose of it as she pleases in her will. But once she marries, the ownership of the
#
# building reverts to the brother. The sister's interest in the building after the brother's conveyance is a
# determinable
# fee.DETERMINATIONa decision by a court or other adjudicative body. See holding; judgment; verdict.
# DETINUEin common law, an action for the wrongful detention of personal property; a legal claim provided for the recovery
# of a specific thing, and for obtaining damages for its detention. Compare detainer [
# UNLAWFUL DETAINER
# ].DEVISEa gift of real property made by will. In modern usage, the term may also embrace testamentary gifts of personal
# property. Compare bequest; legacy.
# DEVOLVEto pass property from one person to another by operation of law, without any voluntary act of the previous owner.
# DICTAplural form of dictum.
# DICTUMa statement in a judicial opinion not necessary for the decision of the case. Dictum differs from the holding in that
# it does not establish a rule binding on the courts in subsequent cases.
# EXAMPLE: Sandy claims that the issue of his liability for damage on his sidewalk resulting in injury to another
# was settled in a previous case. The judge reminds Sandy that the previous case concerned the city's obligation to
# keep the sidewalks in good repair and the city's liability for injury to a person. The part of the case addressed to a
#
# private citizen's liability was not necessary to the decision and hence was only
# dictum
# and is not binding on this
#
# judge.CONSIDERED DICTUM
# refers to a discussion of a point of law that, although it is dictum, is nevertheless so well
# developed that it is later incorporated into an opinion of a court as though it were authority.
# DIE WITHOUT ISSUE see failure of issue.
#
# DILATORY PLEA [PLEA IN ABATEMENT]
# in common law, a plea not responsive to the merits of a controversy, but a defense that
#  < previous page
# page_134next page >
# < previous page
# page_135next page >
# Page 135
# simply delays or defeats the present action, leaving the cause of action unsettled. If a defendant, by establishing the
# facts, can defeat the plaintiff's cause of action in whole or in part, or can obtain substantial relief against the
#
# plaintiff, the plea is not dilatory, but on the merits. This kind of plea has largely disappeared under modern
#
# practice. Instead these defenses are now raised by motion or in an answer.
# DILIGENCEattention to the matter at hand.
# DUE DILIGENCE
# or
# REASONABLE DILIGENCE
# is that level of attention
# required by the circumstances in order to avoid liability in negligence.
# DILUTING THE SHARES see watered stock.
#
# DIMINISHED CAPACITY
# in criminal law, the inability to have the state of mind, or mens rea, required for the commission of a particular
# crime. A successful defense of diminished capacity will usually result in conviction of a lesser offense, not an
#
# acquittal. Compare insanity
# DIMINISHED RESPONSIBILITY see diminished capacity.
#
# DIMINUTION IN VALUE
# a measure of damages for breach of contract that reflects a decrease, occasioned by the breach, in the value of
# property with which the contract was concerned. In a building contract, for example, it is the difference between
#
# the value of the building as constructed and its value had it been constructed in conformance with the contract.
#
# Compare cost of completion; damages [
# EXPECTATION DAMAGES
# ].DIRECT AFFINITY see affinity [
# DIRECT AFFINITY
# ].DIRECT ATTACK
# a proceeding instituted to amend, vacate or enjoin execution of a judgment; an attempt by appellants to avoid or
# correct a judgment in a manner provided by law, as by an appeal. Compare collateral [
# COLLATERAL ATTACK
# ].DIRECT CAUSE see cause [
# DIRECT CAUSE
# ].DIRECT CONTEMPT see contempt of court.
# DIRECTED VERDICT
# a verdict returned by the jury at the direction of the trial judge, by whose direction the jury is bound. In civil
# proceedings either party may receive a directed verdict in its favor if the opposing party fails to present a prima
#
# facie case or a necessary defense. In criminal proceedings, there may be a directed verdict of acquittal, but not a
#
# directed verdict of conviction, which would violate the defendant's constitutional right to a jury determination of
#
# his guilt or innocence.
# DIRECT ESTOPPEL see estoppel [
# DIRECT ESTOPPEL
# ]. < previous page
# page_135next page >
# < previous page
# page_136next page >
# Page 136
# DIRECT EXAMINATION see cross-examination [
# DIRECT EXAMINATION
# ].DIRECTORa member of a board of directors of a company or corporation, who shares with others directors the legal
# responsibility of control over the officers and affairs of the company or corporation. A director has a fiduciary duty
#
# to the corporation and to its shareholders to manage the corporation in a manner consistent with their interests.
# DIRECT ORDER OF ALIENATION see marshaling [marshalling] [
# DIRECT ORDER OF ALIENATION
# ].DISABILITYtate of being not fully capable of performing all functions, whether mental or physical; want of legal capacity such
# as infancy, insanity or past criminal conviction that renders a person legally incompetent; one person's inability to
#
# alter a given legal relation with another person. Compare Durham Rule.
# DISBARto rescind an attorney's license to practice law because of illegal or unethical conduct.
# DISCHARGE1. to satisfy or dismiss the obligations of contract or debt; 2. the method by which a legal duty is extinguished.
# Compare performance; rescission.
# DISCHARGE IN BANKRUPTCY
# the release of the bankrupt from all his or her provable debts, whether then
# payable or not, and debts founded on a contract, express or implied; but not a release from debts specifically
# excepted from discharge by the bankruptcy statute.
# 3. to release from custody, acquit. See sentence [
# SUSPENDED SENTENCE; CONDITIONAL DISCHARGE;
# UNCONDITIONAL DISCHARGE
# ].
# Compare reprieve.
# DISCLAIMER
# l. denial of a person's claim to a thing, though previously that person insisted on such a claim or right; 2.
# renunciation of the right to possess and of claim of title; 3. denial of a right of another, e.g., where an insurer
#
# disclaims an allegation of liability against its insured and thereby refuses to indemnify or defend the insured in a
#
# lawsuit [
# DISCLAIMER OF LIABILITY
# ].DISCONTINUANCEcessation of proceedings in an action where the plaintiff voluntarily puts an end to it, with or without judicial
# approval. Judicial approval may be required, depending upon each jurisdiction's rules of practice. Compare
#
# dismissal; nonsuit.
# DISCOUNTa deduction from a specified sum; often used with transactions in negotiable commercial paper in which the
# instrument is
#  < previous page
# page_136next page >
# < previous page
# page_137next page >
# Page 137
# bought at a price below its face amount to reflect the fact that the debt it represents is not due until a future date.
# EXAMPLE: Sidney regularly enters into contracts where he is not to be paid until the work is completed. But
# Sidney needs the money before he starts the work to purchase work materials and pay other debts. Because the
# contracts represent obligations to pay by other parties, a bank is willing to give Sidney the money that the contracts
#
# call for less a
# discount.
# That discount mainly covers the difference in the value of the money given to Sidney now
#
# versus what the money will be worth when the bank is paid by the other parties, as well as a small profit margin
#
# for the bank. The discount will also factor in that percentage of the contracts which are not likely to be collected.
# DISCOUNT BOND see bond [
# BOND DISCOUNT
# ].DISCOUNTED CASH FLOW
# measure of the present value of a future income stream generated by a capital investment.
#
# DISCOVERY
# modern pretrial procedure by which one party gains information held by the adverse party, concerning the case; the
# disclosure by the adverse party of facts, deeds and documents that are exclusively within his or her possession or
#
# knowledge and that are necessary to support the other party's position. Common types of discovery are depositions,
#
# interrogatories, production of documents and requests for admissions.
# EXAMPLE: Sally gets into an accident when her rear wheels stop for no reason, causing the car to skid into a
# highway divider. In her lawsuit against the car manufacturer, Sally uses the
# discovery
# procedure to obtain memos
# and test-run results that the manufacturer used in designing the car. Without discovery, Sally may not be able to
#
# acquire that information.
# DISCRETIONthe freedom of a public officer to make choices, within the limits of his or her authority, among possible courses of
# action.ABUSE OF DISCRETION
# see abuse of discretion.
# JUDICIAL DISCRETION
# the reasonable use of judicial power, i.e., the court's freedom to decide within the bounds
# of law and fact.
#
# EXAMPLE: Jason, a juvenile, is charged with an assault upon another teenager. In Jason's state, the law provides
# the juvenile judge with the judicial discretion to have the case heard in the juvenile court or to transfer the case to
# an adult court. Previous cases and the law itself establish certain standards to use in determining whether a transfer
#
# is appropriate, but the judge has the discretion to decide which court shall hear the matter. The decision, though,
#
# may be appealed to a higher court.
#  < previous page
# page_137next page >
# < previous page
# page_138next page >
# Page 138
# LEGAL DISCRETION
# the use of one of several equally satisfactory provisions of law.
# PROSECUTORIAL DISCRETION
# the wide range of alternatives for a prosecutor in criminal cases, including
# decision to prosecute, particular charges to be brought, bargaining, mode of trial conduct, recommendations for
# sentencing, parole, etc.
# DISCRETIONARY ACCOUNT
# in the securities trade, one in which the customer gives the broker or a third party
# complete or partial discretion to buy and sell securities. Such discretion typically extends to selection, price, timing,
# and amount purchased.
# DISCRIMINATIONthe unequal treatment of parties who are similarly situated. Federal law prohibits discrimination on the basis of
# race, sex, nationality, religion, and age in matters of employment, housing, education, voting rights, and access to
#
# public facilities.DISHONORto refuse, rightly or wrongly, to make payment on a negotiable instrument when such an instrument is duly
# presented for payment.
# DISINHERITANCEthe act by the donor that dissolves the right of a person to inherit that property to which he or she previously had
# such right.
# DISINTERMEDIATIONmovement of savings from banks and savings and loan associations into money market instruments, such as
# treasury bills and notes.
# DISJUNCTIVE ALLEGATIONS
# those that charge the defendant with either one act or another. The word "or" may not leave the averment uncertain
# as to which of two or more things is meant. An allegation that charges the commission of a crime by one act "or"
#
# another is defective if it does not clearly inform the defendant of the charge so that a defense can be prepared to
#
# meet it. The same standard is applied to pleadings in civil cases, where both disjunctive allegations and disjunctive
#
# denials generally constitute defective pleadings and are therefore inadmissible.
# DISMISSto terminate a case or some part of it. Before or during the trial of a civil action, the suit may be dismissed
# voluntarily by the plaintiff, or involuntarily by the court upon defendant's motion to dismiss the complaint or any
#
# count thereof. See demurrer.
# DISMISSALa cancellation. Dismissal of a motion is a denial of the motion. Dismissal of a complaint or a related count
# terminates proceedings on the claim asserted in the complaint. Dismissal of an
#  < previous page
# page_138next page >
# < previous page
# page_139next page >
# Page 139
# appeal places the parties in the condition as if there had been no appeal, confirming the judgment of the lower
# court.DISMISSAL WITH PREJUDICE
# usually an adjudication upon the merits that operates as a bar to future action by
# preventing plaintiff from making further attempts at a claim based upon the same facts.
#
# EXAMPLE: George brings a lawsuit against a company, claiming that it never refunded his money for an item he
# returned. The company shows the judge a check made payable to George and cashed by him, with a large notation
# on the check that it was payment for the return of the item. George then tries to make an additional claim that the
#
# company owes him more money for other reasons. The judge will usually dismiss with prejudice George's claim for
#
# the refund price alone and instruct him to file a separate claim if he is seeking more money. The "with prejudice"
#
# aspect of the court's decision means that George can never again sue on the same claim unless he successfully
#
# appeals the decision.
# DISMISSAL WITHOUT PREJUDICE
# such a dismissal is not on the merits and does not bar a subsequent suit on
# the same cause of action, nor affect any right or remedy of the parties.
# DISORDERLY CONDUCT
# generic term embracing minor offenses that are generally below the grade of misdemeanor, but that nevertheless
# are somewhat criminal; broadly signifies conduct that tends to breach the peace or endanger the morals, safety or
#
# health of the community.
# DISPARAGEMENT see bait and switch.
#
# DISPOSITION1. the giving up of anything; often used in reference to a testamentary proceeding, as in "the disposition of the
# estate." 2. courts "dispose of " cases, i.e., determine the rights of the parties or otherwise terminate the proceedings.
#
# 3. In criminal law, the sentence of the defendant is the disposition.
# DISPOSSESSto oust, eject or exclude another from the possession of lands or premises, whether by legal process (as where a
# landlord lawfully evicts a tenant) or wrongfully. Compare disseisin.
# DISPUTABLE PRESUMPTION see presumption [
# REBUTTABLE PRESUMPTION].DISQUALIFICATIONthe inability to perform some act due to the existence of factors rendering the performance improper or
# inappropriate. For instance, a judge may be disqualified from hearing a particular case because of having
#
# previously represented one of the parties involved.
#  < previous page
# page_139next page >
# < previous page
# page_140next page >
# Page 140
# DISSEISINl. the act of wrongfully depriving a person of seisin of land; the taking of possession of land under claim or color
# of title; 2. any act, with or without the owner's consent, the necessary effect of which is to divest him of the estate.
# DISSENT1. to disagree; 2. a reasoned opinion that differs from that of the majority of the court.
# DISSENTING OPINION see opinion [
# DISSENTING OPINION
# ].DISSOLUTIONin corporation law, the end of the legal existence of a corporation, whether by expiration of charter, decree of
# court, act of legislature, vote of shareholders, or other means.
# DISTINGUISHto demonstrate that an apparently similar case is so sufficiently different from the case at hand that it is of limited
# value as precedent.
# DISTRAINT see distress.
#
# DISTRESSthe act or process of
# DISTRAINT, by which a person (the
# DISTRAINER), without prior court approval, seizes the
# personal property of another in satisfaction of a claim, as a pledge for performance of a duty or in reparation of an
# injury. Where goods are seized in satisfaction of a claim, the distrainer may hold the goods until the claim is paid
#
# and, failing payment, may sell them in satisfaction. The person whose goods are distrained has recourse against the
#
# wrongful distrainer in replevin.
# EXAMPLE: A warehouseman stores goods for a farmer. When the farmer fails to pay the storage costs for over a
# year, the warehouseman seizes in
# distress
# whatever goods the farmer presently has in the warehouse. If the farmer
# does not then pay for the storage charges that are past due, the warehouseman can sell the goods, take out what he
#
# is owed and refund the amount remaining to the farmer.
# Originally, distress was a landlord's remedy; see lien [
# LANDLORD' S LIEN
# ],
# distinguishable from attachment,
# which is a court-ordered seizure of property. See also impounding; garnishment.
# DISTRESS, EMOTIONAL see emotional distress.
#
# DISTRIBUTIONa payment of yield in cash or in property to one entitled to such payment.
#
# EXAMPLE: At the end of every three months, a corporation distributes dividends to all of its shareholders. A
# distribution
# takes place whether the dividends represent checks, an increase in the number of shares each
# shareholder has, or any other method of payment.
#  < previous page
# page_140next page >
# < previous page
# page_141next page >
# Page 141
# DISTRICT ATTORNEYan officer of the governmental body under which he or she is operating, such as a state, county, or municipality,
# ...
#
# Larry accepts, acquires the drugs and is then arrested. The officer's conduct in continually pressing Larry after he
#
# refused on several occasions may constitute
# entrapment.ENTRY, FORCIBLE see forcible entry.
#
# ENTRY, UNLAWFUL see unlawful entry.
#  < previous page
# page_157next page >
# < previous page
# page_158next page >
# Page 158
# ENUMERATED POWERS
# express powers specifically granted by the Constitution such as the taxing power and the spending power granted to
# Congress. See inherent powers. Compare implied powers.
# ENURE see inure.
#
# EN VENTRE SA MERE
# in gestation; in the womb of one's mother. In the law of property, a person who is en ventre sa mere has the same
# rights as, and is entitled to the same protections as, a person who has been born.
# ENVIRONMENTAL IMPACT STATEMENT [REPORT]
# requirement under federal and state laws for developers to file documents and receive approval where projects may
# affect the environment. Such documents must detail efforts to minimize adverse polution, disruption to wildlife or
#
# traffic, or use of protected areas such as wetlands.
# ENVIRONMENTAL PROTECTION AGENCY [EPA]
# an agency of the federal government charged with a variety of responsibilities relating to protection of the quality
# of the natural environment, including research and monitoring, promulgation of standards for air and water quality,
#
# control of the introduction of pesticides and other hazardous materials into the environment, and the like. See
#
# police power.
# EO INSTANTI
# immediately; instantly.
# EPA see Environmental Protection Agency.
#
# EQUAL EMPLOYMENT OPPORTUNITY COMMISSION [EEOC] see equal opportunity.
#
# EQUALITYpossessing the same rights under the same circumstances. Achieving a balance; uniformity. See equal protection of
# the laws.
# EQUAL OPPORTUNITY
# a term to signify an employer's adoption of employment practices that do not discriminate on the basis of race,
# color, religion, sex or national origin. Such discrimination was outlawed by Title VII of the Civil Rights Act of
#
# 1964.Title VII also created the
# EQUAL EMPLOYMENT OPPORTUNITY COMMISSION
#  [EEOC] to implement equal
# opportunity policy by working with local agencies.
# EQUAL PROTECTION OF THE LAWS
# constitutional guarantee embodied in the Fourteenth Amendment to the U.S. Constitution, which states in relevant
# part that "No State shall . . . deny to any person
#  < previous page
# page_158next page >
# < previous page
# page_159next page >
# Page 159
# within its jurisdiction the equal protection of the laws." The essential purpose of this constitutional doctrine is to
# ensure that the laws and the government treat all persons alike, unless there is some substantial reason why certain
#
# persons or classes of persons should be treated differently.
# EXAMPLE: Women and men who perform equal tasks in their jobs for the state receive unequal pay. In a lawsuit
# seeking equal pay, the fact that a question based on gender is raised forces the state to demonstrate a compelling
# government interest to justify the distinction.
# EQUAL RIGHTS AMENDMENT [E.R.A.]
# a proposed amendment hoping to eliminate sex as a basis for any decisions made by a state of the United States.
# This amendment was never ratified by a sufficient number of states to qualify as a constitutional amendment, but
#
# the basic premise underlying the proposal has become an accepted standard in many statutes and court decisions.
# EQUAL TIME ACT [RULE]
# broadcast requirement that if a candidate for public office is permitted air time, the station must afford equal
# opportunities to all other candidates for that office. Compare fairness doctrine.
# EQUITABLEaccording to natural right or natural justice; marked by due consideration for what is fair and impartial,
# unhampered by technical rules the law may have devised that limit recovery or defense.
# EQUITABLE DISTRIBUTION
# see equitable distribution.
# See equity.
# EQUITABLE DEFENSE see defense.
#
# EQUITABLE DISTRIBUTION
# 1. a just division of property among interested parties; 2. the process by which, as part of a dissolution of marriage
# proceeding under a no-fault divorce statute, the court apportions between husband and wife all assets acquired by
#
# either or both of them, whether owned jointly or individually, during the marriage See alimony, community
#
# property.EQUITABLE EASEMENT see equitable servitude.
#
# EQUITABLE ESTATE see estate.
#
# EQUITABLE ESTOPPEL see estoppel [
# ESTOPPEL IN PAIS
# ].EQUITABLE RECOUPMENT
# in certain situations in which a taxpayer erroneously pays taxes in one taxable year when they are properly payable
# in a later year, this doctrine allows the taxpayer to
#  < previous page
# page_159next page >
# < previous page
# page_160next page >
# Page 160
# recoup the additional taxes paid by reducing his or her taxes payable in the later year.
# EQUITABLE RELIEF see relief.
#
# EQUITABLE SEISIN see seisin.
#
# EQUITABLE SERVITUDE
# a covenant that is enforceable only in equity. For a covenant to be valid at law, as to remote grantees of the
# affected property there must exist
# PRIVITY OF ESTATE
# (see privity) between the covenantor and covenantee, but
# such a relationship is not necessary to create an enforceable equitable servitude so long as the subsequent grantee
#
# has either actual or
# CONSTRUCTIVE NOTICE
# (see notice) of the covenant.
# EQUITABLE TITLE see title.
# EQUITYgenerally, justice or fairness Historically, equity refers to a separate body of law developed in England in reaction
# to the inability of the common law courts, in their strict adherence to rigid writs and forms of action, to consider or
#
# provide a remedy for every injury. The king therefore established the court of chancery, to do justice between
#
# parties in cases where the common law would give inadequate redress. The principle of this jurisprudence is that
#
# equity will find a way to achieve a lawful result when legal procedure is inadequate. Equity and law courts are now
#
# merged in most jurisdictions, though equity jurisprudence and equitable doctrines are still independently viable.
# Equity also refers to the value of property minus liens or other encumbrances. For example, one's equity in a home
# with a mortgage is the value of the property beyond the amount of the mortgage debt.
# In accounting, equity refers to the ownership interest in a company as determined by subtracting liabilities from
# assets. See balance sheet. For incorporated business enterprises, equity is owned by the common and preferred
#
# shareholders. If the corporation is publicly held, the shares will be traded on a stock exchange or over-the-counter
#
# market which together comprise the
# EQUITY MARKET
# .EQUITY CAPITAL see security.
# EQUITY OF REDEMPTION
# right of mortgagor to redeem his or her property (save it from foreclosure) after default in the payment of the
# mortgage debt, by subsequent payment of all costs and interest, in addition to the mortgage debt, to the mortgagee.
# E.R.A. see Equal Rights Amendment [E.R.A.].
#  < previous page
# page_160next page >
# < previous page
# page_161next page >
# Page 161
# ERGO Lat.: therefore; consequently; hence; because.
# ERISA [EMPLOYMENT RETIREMENT INCOME SECURITY ACT OF 1974]
# a Congressional attempt to attack a multitude of problems that were affecting employee benefit plans, especially
# the lack of employee information and adequate safeguards concerning their operation. Through various statutes and
#
# regulations, the act creates minimum standards to assure the equitable character and financial soundness of these
#
# plans.ERRONEOUSinvolving a mistake; signifies a deviation from the requirements of the law, but it does not connote a lack of legal
# authority, and is thus distinguished from illegal. If, while having the power to act, one commits error in the
#
# exercise of that power, he acts erroneously.
# ERRONEOUS JUDGMENT
# one rendered according to practice of court, but contrary to law, upon a mistaken view
# of law, or upon erroneous application of legal principles.
# ERRORa mistake; an act involving a departure from truth or accuracy. In a legal proceeding such as a trial, an
# ERROROF LAW
# furnishes grounds for the appellate court to reverse a judgment.
# ESCALATOR CLAUSE
# that part of a lease or contract that provides for an increase in the rent or contract price upon the occurrence of
# certain conditions beyond the parties' control, such as an increase in the cost of labor or of a necessary commodity,
#
# or the fixing of maximum prices by a government agency. Escalator clauses in leases may permit an increase in
#
# rent whenever real estate taxes or interest rates rise. In a divorce decree one's alimony payments may increase as
#
# the cost of living rises or when the ex-spouse who is paying alimony has a higher income.
# ESCAPE CLAUSE
# a clause in a contract permitting a party to renege on its obligations under certain conditions without incurring a
# penalty or other liability.
# EXAMPLE: Stilton Harvest Corporation agrees to provide a bread company with all the wheat it needs for one
# year. The agreement includes a provision that, if the annual harvest for a group of states falls below an established
# level, Stilton is relieved of its obligation.
# ESCHEATassignment of property to the state because there is no verifiable legal owner.
# ESCROWa written instrument, such as a deed, temporarily deposited with a neutral third party (the
# ESCROW AGENT
# ), by
# the agreement of two parties to a valid contract. The escrow agent will
#  < previous page
# page_161next page >
# < previous page
# page_162next page >
# Page 162
# deliver the document to the benefited party when the conditions of the contract have been met. The depositor has
# no control over the instrument in escrow. In common law, escrow applied to the deposits only of instruments for
#
# conveyance of land, but it now applies to all instruments so deposited. Money or other property so deposited is also
#
# loosely referred to as escrow.
# ESOP see Employee Share Ownership Plan [ESOP].
#
# ESQUIRE [ESQ.]
# a title for lawyers.
# ESSENCE see time is of the essence.
#
# ESTABLISHMENT CLAUSE
# provision in the First Amendment of the U.S. Constitution prohibiting enactment of laws pertaining to "the
# establishment of religion." It has been said that the establishment clause means that neither a state nor the federal
#
# government may set up a church; neither may pass laws that aid one religion, aid all religions or prefer one religion
#
# over another. In the words of Jefferson, the clause was intended to erect a "wall of separation between church and
#
# state."ESTATE1. technically, the nature and extent of a person's interest in or ownership of land; 2. broadly, estate applies to all
# that a person owns, whether real or personal property.
# CONTINGENT ESTATE
# see contingent estate.
# DOMINANT ESTATE
# see dominant estate.
# EQUITABLE ESTATE
# an estate or interest that can be enforced only in equity; applies especially to every trust,
# express or implied, that is not converted to a legal estate by the Statute of Uses.
#
# FUTURE ESTATE
# an estate in land that is not possessory but that will or may become so in the future. Future
# estates are either vested or contingent, and include remainders and reversions.
#
# LEGAL ESTATE
# originally, an interest in land that was enforced by courts of common law, as opposed to an
# equitable estate, enforced by courts of equity.
#
# PRECEDING ESTATE
# see preceding estate.
# SERVIENT ESTATE
# see servient estate.
# VESTED ESTATE
# one either presently in possession or owned by a presently existing person to whom (or to
# whose successors in interest) the property interest will automatically accrue upon the termination of a
# PRECEDING ESTATE
# Such an estate thus represents a present interest and as such is neither subject to any
# contingency nor otherwise capable of being defeated.
#  < previous page
# page_162next page >
# < previous page
# page_163next page >
# Page 163
# ESTATE AT SUFFERANCE see tenancy [
# TENANCY AT SUFFERANCE
# ].ESTATE AT WILL see tenancy [
# TENANCY AT WILL
# ].ESTATE BY THE ENTIRETY see tenancy [
# TENANCY BY THE ENTIRETY
# ].ESTATE FOR LIFE see life estate.
# ESTATE FOR YEARS see tenancy [
# TENANCY FOR YEARS
# ].ESTATE FROM YEAR TO YEAR see tenancy [
# PERIODIC TENANCY
# ].ESTATE IN COMMON see tenancy [
# TENANCY IN COMMON
# ].ESTATE IN COPARCENARY see coparcenary.
#
# ESTATE OF INHERITANCE
# a common law species of land ownership that could descend to heirs; a type of freehold estate that the owner can
# both enjoy during his or her life and bequeath according to an established order of descent. Estate of inheritance
#
# include estates in fee simple absolute, fee simple conditional, fee simple determinable and estates in fee tail.
# ESTATE PER AUTRE VIE see per autre vie.
#
# ESTATE TAX see tax.
#
# ESTOPPELa restraint; a bar; arises where a person has done some act that the policy of the law will not permit him or her to
# deny, or where circumstances are such that the law will not permit a certain argument because it would lead to an
#
# unjust result. In the context of contract law, for example, one is estopped from denying existence of a binding
#
# contract where he or she has done something intending that another rely on his or her conduct, and the result of the
#
# reliance is detrimental to that other person. Compare waiver.
# EXAMPLE: Nelson convinces an associate to sign what appears to be a valid contract which gives the associate the
# right to buy certain items from Nelson. When the contract turns out to harm Nelson more than the associate,
# Nelson tries to deny the validity of the instrument. A court will find that Nelson is
# estopped
# (i.e., prevented) from
#
# raising that claim since it was Nelson who initiated the offer.
# AUTHORITY BY ESTOPPEL
# see authority by estoppel.
# COLLATERAL ESTOPPEL
# see collateral estoppel.
# DIRECT ESTOPPEL
#  the prohibition of the relitigation of an issue by two parties who have previously litigated the
# issue and had it decided by the courts. See collateral estoppel; res judicata.
#  < previous page
# page_163next page >
# < previous page
# page_164next page >
# Page 164
# ESTOPPEL BY DEED
# a bar that precludes a party from denying the truth and legitimacy of the conveyance
# represented by a deed he or she has given. It may be invoked only in a suit on the deed or concerning a right
# arising out of it.
# ESTOPPEL BY JUDGMENT
# see judgment [
# ESTOPPEL BY JUDGMENT
# ].ESTOPPEL BY LACHES
# see laches.
# ESTOPPEL IN PAIS
#  Old Fr: the country, the neighborhood. An estoppel that arises out of a person's
# statement of fact, or out of his or her silence, acts or omissions, rather than from a deed or record or written
# contract; also called an
# EQUITABLE ESTOPPEL
# .MUTUALITY OF ESTOPPEL
# the doctrine that prohibits one party from raising an issue or a matter which the
# other party is prohibited from raising.
# PROMISSORY ESTOPPEL
# see promissory estoppel.
# ESTOVERS
# the right of the tenant, during the period of his or her lease, to use timber on the leased premises for proper
# maintenance of the property.
# ET AL.
#  Lat.: and others; abbreviation of et allii.
# ETHICAL see unethical.
#
# ET NON
#  Lat.: and not.
# ET SEQ.
#  Lat.: and the following; abbreviation of et sequentes or et sequentia. Most commonly used in
# denominating page reference numbers: page 13 et seq.
#
# ET UX.
#  Lat.: and wife; abbreviation of et uxor. Used in old legal documents such as wills or deeds; for example,
# ''This will made by John Doe
# et ux
# ."EURODOLLARa U.S. dollar held as a deposit in a European commercial bank. Eurodollars were created after World War II by
# United States foreign defense and aid expenditures. Since the dollar was backed by gold, it became a popular
#
# reserve currency in Europe and among all the trading partners of the United States.
# EUTHANASIAthe putting to death, as an act of mercy, of someone in considerable pain as the result of disease or other physical
# malady, for whom there is no hope of recovery. While routinely permitted for animals, it has not been permitted in
#
# this country for human beings, although some states have authorized removal of extraordinary life support systems
# in individual cases. See brain death.
#  < previous page
# page_164next page >

# %% [markdown]
# ↑の処理：全単語をテキスト化した。これに加えて、
# ##見出語のみ抽出
# をしたい。but how?
#
# - 12-626 pages
# - 見出し語＝WORDS whose letters are more than 2 and ALL IN CAPITAL
#
# - take out the first two letter and check if they are both capital, capital and period or capital and a space.
# - if true,
#  - add the two letters to [word1] #listの要素を区分けする処理はどうすれば？
# - if Capital and lower case,
#  - add the first letter to word1
# - increase "letter_num" by 1

# %%
#words = [] #追加していく
#letter_length = 1#増やしていく
#word_num =11 1
#word_length = 1
#i=0
#words.insert(i,"")

#for t in text:
#  word = text[t:t+word_length]
#  while text[t:t+word_length].isupper==True: 
#    words[i]+word
#    word_length=+1
#  else:
#    i=+1

# %%
import pprint

# %%
#正規表現でやる
capital = r'[A-Z]+[.?(A-Z)+| ?(A-Z)+]+[A-Z.]'
words=re.findall(capital,text)
pprint.pprint(words)
# Out:
# ['AA.B.A.',
#  'ABANDONED CHILD',
#  'SPOUSE',
#  'ABANDONMENT',
#  'EXAMPLE',
#  'ABATABLE NUISANCE',
#  'ABATEMENT',
#  'ABATEMENT OF A LEGACY',
#  'ABATEMENT OF TAXES',
#  'ABDUCTION',
#  'ABET',
#  'ABEYANCE',
#  'ABILITY TO STAND TRIAL',
#  'AB INITIO',
#  'ABNORMALLY DANGEROUS ACTIVITY',
#  'ABOLISH',
#  'ABORIGINAL TITLE',
#  'INDIAN TITLE',
#  'ABORTION',
#  'ABRIDGE',
#  'ABROGATE',
#  'ABSCOND',
#  'ABSENTIA',
#  'ABSOLUTE LIABILITY',
#  'ABSQUE HOC',
#  'ABSTENTION',
#  'DOCTRINE',
#  'EXAMPLE',
#  'ABSTRACT OF RECORD',
#  'ABSTRACT OF TITLE',
#  'EXAMPLE',
#  'ABUSE OF DISCRETION',
#  'ABUSE OF PROCESS',
#  'EXAMPLE',
#  'ABUT',
#  'ACCELERATION',
#  'ACCELERATION CLAUSE',
#  'EXAMPLE',
#  'ACCEPTANCE',
#  'EXAMPLE',
#  'ACCESS',
#  'ACCESSION',
#  'EXAMPLE',
#  'ACCESSORY',
#  'ACCESSORY AFTER THE FACT',
#  'ACCESSORY BEFORE THE FACT',
#  'ACCIDENT',
#  'UNAVOIDABLE ACCIDENT',
#  'ACCOMMODATION INDORSEMENT',
#  'ACCOMMODATION MAKER',
#  'OR PARTY',
#  'ACCOMPLICE',
#  'ACCORD',
#  'ACCORD AND SATISFACTION',
#  'ACCOUNT',
#  'ACCOUNT DEBTOR',
#  'ACCOUNT PAYABLE',
#  'ACCOUNTS RECEIVABLE',
#  'ACCOUNTING',
#  'ACTION FOR',
#  'ACCOUNTING METHOD',
#  'ACCRUAL METHOD',
#  'CASH METHOD',
#  'ACCOUNTS PAYABLE',
#  'ACCOUNTS RECEIVABLE',
#  'ACCREDITED INVESTOR',
#  'ACCRETION',
#  'EXAMPLE',
#  'ACCRUE',
#  'ACCRUED INTEREST',
#  'ACCUSATION',
#  'ACCUSATORY INSTRUMENT',
#  'ACCUSE',
#  'ACCUSED',
#  'ACKNOWLEDGMENT',
#  'A.C.L.U.',
#  'ACQUIESCENCE',
#  'ACQUIRE',
#  'ACQUIT',
#  'ACQUITTAL',
#  'ACT',
#  'ACTIO L',
#  'ACTION',
#  'ACTIONABLE',
#  'ACTIONABLE TORT',
#  'ACTION EX CONTRACTU',
#  'ACTION EX DELICTO',
#  'ACTION FOR ACCOUNTING',
#  'ACTION FOR POSSESSION',
#  'ACTION IN CASE',
#  'TRESSPASS ON THE CASE',
#  'ACTIO NON',
#  'ACTIONS IN PERSONAM',
#  'ACTIONS IN REM',
#  'ACTIONS QUASI IN REM',
#  'ACTIVE EUTHANASIA',
#  'ACTIVE EUTHANASIA',
#  'ACTIVISM',
#  'ACT OF GOD',
#  'ACTUAL AUTHORITY',
#  'ACTUAL CASH VALUE',
#  'ACTUAL DAMAGES',
#  'ACTUAL DAMAGES',
#  'ACTUAL EVICTION',
#  'ACTUAL EVICTION',
#  'ACTUAL NOTICE',
#  'ACTUAL NOTICE',
#  'ACTUAL POSSESSION',
#  'ACTUAL POSSESSION',
#  'ACTUAL VALUE',
#  'ACTUARY',
#  'ACTUS REUS',
#  'AD DAMNUM',
#  'ADDENDUM',
#  'ADDITUR L',
#  'ADEEM',
#  'ADEMPTION',
#  'ADHESION CONTRACT',
#  'AD HOC',
#  'ADJECTIVE LAW',
#  'ADJOURN',
#  'ADJOURNMENT SINE DIE',
#  'ADJUDICATION',
#  'ADJUSTED BASIS',
#  'ADJUSTED BASIS',
#  'ADJUSTER',
#  'AD LITEM',
#  'GUARDIAN AD',
#  'LITEM',
#  'ADMINISTRATION FOR NATIVE AMERICANS',
#  'ADMINISTRATION FOR NATIVE',
#  'AMERICANS',
#  'ADMINISTRATIVE AGENCY',
#  'ADMINISTRATIVE HEARING',
#  'ADMINISTRATIVE LAW',
#  'ADMINISTRATIVE LAW JUDGE',
#  'ADMINISTRATIVE PROCEDURE ACT',
#  'APA',
#  'ADMINISTRATOR',
#  'ADMIRALTY AND MARITIME JURISDICTION',
#  'U.S.',
#  'ADMIRALTY COURTS',
#  'ADMIRALTY LAW',
#  'ADMISSIBLE EVIDENCE',
#  'ADMISSION',
#  'ADMISSION BY A PARTY',
#  'OPPONENT',
#  'ADMIT',
#  'ADMIT TO BAIL',
#  'ADMIT TO PRACTICE',
#  'ADMIT TO THE BAR',
#  'ADMIT TO PRACTICE',
#  'ADOPT',
#  'ADOPTION',
#  'ADR',
#  'AD TESTIFICANDUM',
#  'AD TESTIFICANDUM',
#  'ADULT',
#  'ADULTERY',
#  'CORRESPONDENT',
#  'AD VALOREM',
#  'AD VALOREM TAX',
#  'VALUE ADDED TAX',
#  'ADVANCE',
#  'ADVANCEMENT',
#  'EXAMPLE',
#  'ADVANCE SHEETS',
#  'SLIP OPINION',
#  'ADVERSARY',
#  'ADVERSARY PROCEEDING',
#  'ADVERSE INTEREST',
#  'ADVERSE PARTY',
#  'ADVERSE POSSESSION',
#  'EXAMPLE',
#  'ADVERSE WITNESS',
#  'ADVERSE',
#  'HOSTILE',
#  'WITNESS',
#  'ADVICE AND CONSENT',
#  'ADVISORY OPINION',
#  'ADVOCACY',
#  'A.F.D.C.',
#  'AID TO FAMILIES WITH DEPENDENT CHILDREN',
#  'AFFECTED WITH A PUBLIC INTEREST',
#  'AFFECTED WITH A PUBLIC INTEREST',
#  'AFFIANT',
#  'AFFIDAVIT',
#  'EXAMPLE',
#  'AFFINITY',
#  'DIRECT AFFINITY',
#  'SECONDARY AFFINITY',
#  'COLLATERAL AFFINITY',
#  'AFFIRM',
#  'AFFIRMATION',
#  'AFFIRMATIVE ACTION',
#  'AFFIRMATIVE ACTION PROGRAMS',
#  'AFFIRMATIVE DEFENSE',
#  'AFFIRMATIVE EASEMENT',
#  'AFFIRMATIVE EASEMENT',
#  'AFFIRMATIVE RELIEF',
#  'AFFIX',
#  'AFIS',
#  'AFIS',
#  'AFORETHOUGHT',
#  'A FORTIORI',
#  'EXAMPLE',
#  'AFTER',
#  'ACQUIRED PROPERTY',
#  'AFTER',
#  'ACQUIRED TITLE',
#  'AFTER',
#  'THE',
#  'FACT',
#  'ACCESSORY AFTER',
#  'THE',
#  'FACT',
#  'AGAINST PUBLIC POLICY',
#  'AGAINST PUBLIC POLICY',
#  'AGAINST THE',
#  'MANIFEST',
#  'WEIGHT OF THE',
#  'EVIDENCE',
#  'AGE DISCRIMINATION',
#  'AGENCY',
#  'AGENT',
#  'EXAMPLE',
#  'AGE OF CONSENT',
#  'EXAMPLE',
#  'AGE OF MAJORITY',
#  'AGGRAVATED ASSAULT',
#  'AGGRAVATING CIRCUMSTANCES',
#  'AGGREGATE',
#  'AGGRIEVED PARTY',
#  'AGREEMENT',
#  'AID AND ABET',
#  'AID TO FAMILIES WITH DEPENDENT CHILDREN',
#  'AID TO FAMILIES WITH',
#  'DEPENDENT CHILDREN',
#  'AIR PIRACY',
#  'AIR RIGHTS',
#  'AIRSPACE',
#  'A.J.',
#  'A.K.A.',
#  'ALEATORY',
#  'ALEATORY CONTRACT',
#  'ALIAS',
#  'AKA',
#  'ALIBI',
#  'ALIEN',
#  'RESIDENT ALIEN',
#  'ILLEGAL ALIEN',
#  'ALIENATION',
#  'ALIENATION OF AFFECTIONS',
#  'CRIMINAL',
#  'CONVERSATION. H',
#  'ALIENATION',
#  'ORDER OF',
#  'ALIEN REGISTRATION',
#  'ALIMONY',
#  'CHILD SUPPORT',
#  'ALIQUOT L',
#  'ALI TEST',
#  'ALI TEST',
#  'ALIUNDE L',
#  'ALIUNDE RULE',
#  'ALLEGATION',
#  'ALLEN CHARGE',
#  'ALLOCUTION',
#  'ALLODIAL',
#  'ALLOWANCE',
#  'DEPLETION ALLOWANCE',
#  'ALLUVION',
#  'ALTERATION',
#  'ALTER EGO',
#  'ALTERNATIVE DISPUTE RESOLUTION',
#  'ADR',
#  'ALTERNATIVE PLEADING',
#  'EXAMPLE',
#  'ALTERNATIVE WRIT OF MANDAMUS',
#  'AMELIORATING WASTE',
#  'AMELIORATING WASTE',
#  'AMEND',
#  'EXAMPLE',
#  'AMENDMENTS',
#  'A MENSA ET THORO',
#  'SEPARATION',
#  'AMERICAN BAR ASSOCIATION',
#  'A.B.A.',
#  'AMERICAN BAR FOUNDATION',
#  'A.B.A.',
#  'AMERICAN BAR FOUNDATION',
#  'AMERICAN BAR FOUNDATION',
#  'AMERICAN CIVIL LIBERTIES UNION',
#  'ACLU',
#  'AMERICAN DEPOSITORY RECEIPT',
#  'ADR',
#  'ADR',
#  'ADR',
#  'AMERICAN INDIAN LAW',
#  'AMERICAN STOCK EXCHANGE',
#  'NEW YORK CURB EXCHANGE',
#  'AMEX',
#  'ASE.AMEX',
#  'AMICUS CURIAE',
#  'AMICUS CURIAE BRIEF',
#  'AMICUS BRIEF',
#  'AMNESTY',
#  'EXAMPLE',
#  'AMORTIZATION',
#  'EXAMPLE',
#  'AMOUNT REALIZED',
#  'GAIN OR LOSS REALIZED',
#  'ANCIENT DEMESNE',
#  'ANCILLARY JURISDICTION',
#  'AND HIS HEIRS',
#  'ANIMO L',
#  'AMINO TESTANDI',
#  'AMINO REVOCANDI',
#  'AMINO REVERTENDI',
#  'ANIMUS',
#  'ANNOTATION',
#  'U.S.C.A.',
#  'N.J.S.A.',
#  'A.L.R.',
#  'A.L.R.',
#  'A.L.R. F',
#  'ANNUAL REPORT',
#  'SEC',
#  'ANNUITANT',
#  'ANNUITY',
#  'ANNUL',
#  'ANSWER',
#  'ANTENUPTIAL AGREEMENT',
#  'ANTICIPATORY BREACH',
#  'EXAMPLE',
#  'VOLUNTARYDISABLEMENT.ANTI',
#  'DISCRIMINATION ACT',
#  'ANTI',
#  'DUMPING LAW',
#  'ANTILAPSE STATUTES',
#  'ANTITRUST LAWS',
#  'U.S.',
#  'SHERMAN ACT',
#  'CLAYTON ACT',
#  'A POSTERIORI',
#  'APPARENT AUTHORITY',
#  'EXAMPLE',
#  'APPEAL',
#  'APPEARANCE',
#  'PRO SE',
#  'EXAMPLE',
#  'GENERAL APPEARANCE',
#  'SPECIAL APPEARANCE',
#  'EXAMPLE',
#  'COMPULSORY APPEARANCE',
#  'VOLUNTARY APPEARANCE',
#  'APPEARANCE DE BENE ESSE',
#  'APPELLANT',
#  'PLAINTIFF IN ERROR',
#  'APPELLATE COURT',
#  'APPEALS COURT',
#  'APPELLATE JURISDICTION',
#  'APPELLEE',
#  'DEFENDANT IN ERROR',
#  'APPOINTED COUNSEL',
#  'APPOINTMENT OF RECEIVER',
#  'APPOINTMENT',
#  'POWER OF',
#  'APPORTION',
#  'APPRAISAL RIGHTS',
#  'SHAREHOLDERS',
#  'APPRAISE',
#  'APPRECIATE',
#  'APPRECIATION',
#  'UNREALIZED APPRECIATION',
#  'APPROPRIATE',
#  'APPROPRIATION',
#  'APPURTENANT',
#  'EASEMENT APPURTENANT',
#  'A PRIORI',
#  'ARBITER L',
#  'ARBITRAGE',
#  'HEDGED',
#  'ARBITRARY AND CAPRICIOUS',
#  'ARBITRATION',
#  'BINDING ARBITRATION',
#  'COMPULSORY ARBITRATION',
#  'ARBITRATION CLAUSE',
#  'ARBITRATOR',
#  'ARGUENDO L',
#  'EXAMPLE',
#  'ARGUMENT',
#  'ARM',
#  'S LENGTH',
#  'ARRAIGN',
#  'ARRAIGNMENT',
#  'ARRANGEMENTS',
#  'CHAPTER',
#  'REORGANIZATION',
#  'ARRAY',
#  'CHALLENGE TO JURY ARRAY',
#  'ARREARS',
#  'ARREST',
#  'ARREST OF JUDGMENT',
#  'ARREST RECORD',
#  'ARSON',
#  'ARTICLES OF IMPEACHMENT',
#  'ARTICLES OF INCORPORATION',
#  'ARTIFICE',
#  'ARTIFICIAL PERSON',
#  'ART',
#  'WORDS OF',
#  'AS A MATTER OF LAW',
#  'ASE',
#  'AS IS',
#  'ASPORTATION',
#  'TRESPASS DE BONIS ASPORTATIS',
#  'ASSAULT',
#  'AGGRAVATED ASSAULT',
#  'ASSEMBLY',
#  'UNLAWFUL',
#  'ASSESS',
#  'ASSESSMENT OF DEFICIENCY',
#  'JEOPARDY ASSESSMENT',
#  'ASSET',
#  'EXAMPLE',
#  'CURRENT ASSETS',
#  'FIXED ASSETS',
#  'ASSET VALUE',
#  'ASSIGN',
#  'ASSIGNED COUNSEL',
#  'ASSIGNED RISK',
#  'FINANCIAL RESPONSIBILITY',
#  'LAWS',
#  'ASSIGNMENT',
#  'ASSIGNMENT FOR BENEFIT OF CREDITORS',
#  'ASSIGNMENT OF A LEASE',
#  'ASSIGNMENT OF ERROR',
#  'ASSIGNMENT OF INCOME',
#  'ASSIGNS',
#  'ASSIGNEES',
#  'ASSISTED SUICIDE',
#  'ACTIVE EUTHANASIA',
#  'ASSIZE',
#  'ASSOCIATE JUSTICE',
#  'ASSOCIATION',
#  'ASSUMPSIT L',
#  'ASSUMPTION OF MORTGAGE',
#  'ASSUMPTION OF RISK',
#  'ASSURANCE',
#  'COVENANT OF FURTHER ASSURANCE',
#  'ASSURED',
#  'ASYLUM',
#  'POLITICAL ASYLUM',
#  'AT BAR',
#  'AT EQUITY',
#  'AT ISSUE',
#  'AT LAW',
#  'ATROCIOUS',
#  'ATTACHMENT',
#  'ATTAINDER',
#  'ATTAINDER',
#  'BILL OF',
#  'ATTAINT',
#  'ATTEMPT',
#  'ATTENDANT CIRCUMSTANCES',
#  'ATTEST',
#  'EXAMPLE',
#  'ATTESTATION',
#  'ATTORNEY',
#  'ATTORNEY IN FACT',
#  'ATTORNEY AT LAW',
#  'COUNSELLOR',
#  'ATTORNEY',
#  'CLIENT PRIVILEGE',
#  'ATTORNEY GENERAL',
#  'ATTORNEY OF RECORD',
#  'ATTORNEY OF RECORD',
#  'ATTORNEY',
#  'POWER OF',
#  'ATTORNEY',
#  'S FEE',
#  'ATTRACTIVE NUISANCE',
#  'AUCTION',
#  'AUCTION SALE',
#  'AUDIT',
#  'EXAMPLE',
#  'AUDIT OF RETURN',
#  'AUDITOR',
#  'AUTHENTICATE',
#  'AUTHORITY',
#  'DE FACTO',
#  'AUTHORITY',
#  'IMPLIEDAUTHORITY',
#  'EXPRESS AUTHORITY',
#  'AUTHORITY COUPLED WITH AN INTEREST',
#  'AUTHORITY',
#  'BY ESTOPPEL',
#  'ACTUAL AUTHORITY',
#  'AUTHORIZED ISSUE',
#  'AUTOMOBILE',
#  'DEATH BY',
#  'DEATH BY AUTOMOBILE',
#  'AUTOMOBILE GUEST STATUTE',
#  'AUTOPSY',
#  'AVERMENT',
#  'AVOID',
#  'AVOIDANCE',
#  'AVOIDANCE OF TAX',
#  'AVULSION',
#  'AWOL',
#  'ABSENT WITHOUT LEAVE',
#  'BBAD CHECK',
#  'NSF',
#  'BAD DEBT',
#  'GROSS INCOME',
#  'ORDINARY INCOME',
#  'SHORT',
#  'TERM CAPITAL GAINS OR LOSSES',
#  'BAD DEBT RESERVE',
#  'BAD FAITH',
#  'BADGES OF FRAUD',
#  'BAD TITLE',
#  'BAIL',
#  'R.O.R.',
#  'BAIL BOND',
#  'BAIL BONDSMAN',
#  'BAILEE',
#  'EXAMPLE',
#  'BAILIFF',
#  'BAIL JUMPING',
#  'BAILMENT',
#  'CONSTRUCTIVE BAILMENT',
#  'GRATUITOUS BAILMENT',
#  'INVOLUNTARY BAILMENT',
#  'BAILOR',
#  'EXAMPLE',
#  'BAIT AND SWITCH',
#  'DISPARAGEMENT. S',
#  'BALANCE SHEET',
#  'BALANCING (TEST',
#  'BALANCING OF EQUITIES',
#  'BALANCING OF INTERESTS',
#  'BALLOON NOTE',
#  'BANC',
#  'BANK',
#  'COMMERCIAL BANK',
#  'SAVINGS BANK',
#  'SAVINGS AND LOAN ASSOCIATION',
#  'BUILDING AND LOAN ASSOCIATION',
#  'NOW',
#  'BANKER',
#  'S LIEN',
#  'BANKRUPTCY',
#  'INSOLVENCY PRECEEDINGS',
#  'TRUSTEE IN BANKRUPTCY',
#  'VOLUNTARY PROCEEDING',
#  'INVOLUNTARY PROCEEDING',
#  'CHAPTER',
#  'REORGANIZATION',
#  'BANKRUPTCY COURT',
#  'BANKRUPTCY PETITION',
#  'BAR',
#  'COLLATERAL ESTOPPEL',
#  'AT BAR',
#  'CASE AT BAR',
#  'BARGAIN',
#  'EXAMPLE',
#  'BARGAIN AND SALE',
#  'COVENANT',
#  'AGAINST GRANTOR',
#  'S ACTS',
#  'BARGAINING UNIT',
#  'BARRATRY',
#  'BARRISTER',
#  'SOLICITOR',
#  'BARTER',
#  'BASIS',
#  'ADJUSTED BASIS',
#  'CAPITAL EXPENDITURE',
#  'CARRYOVER OR SUBSTITUTED BASIS',
#  'RECOVERY OF BASIS',
#  'STEP',
#  'UP BASIS',
#  'BASTARD',
#  'BASTARDY PROCEEDING',
#  'BATTERY',
#  'BEARER',
#  'BEARER BOND',
#  'BEARER BOND',
#  'BEARER PAPER',
#  'PAYABLE TO BEARER',
#  'EXAMPLE',
#  'BED AND BOARD',
#  'BEFORE',
#  'THE',
#  'FACT',
#  'ACCESSORY BEFORE',
#  'THE',
#  'FACT',
#  'BELIEF',
#  'BENCH',
#  'BENCH TRIAL',
#  'BENCH TRIAL',
#  'BENCH WARRANT',
#  'EXAMPLE',
#  'BENEFICIAL INTEREST',
#  'BENEFICIAL USE',
#  'BENEFICIARY',
#  'EXAMPLE',
#  'INCIDENTAL BENEFICIARY',
#  'BENEFIT',
#  'FRINGE BENEFITS',
#  'BENEFIT OF THE BARGAIN (RULE',
#  'LOSS OF BARGAIN',
#  'BEQUEATH',
#  'BEQUEST',
#  'CONDITIONAL BEQUEST',
#  'EXECUTORY BEQUEST',
#  'RESIDUARY BEQUEST',
#  'SPECIFIC BEQUEST',
#  'BEST EVIDENCE RULE',
#  'BESTIALITY',
#  'BEYOND A REASONABLE DOUBT',
#  'B.F.O.Q. S',
#  'B.F.O.Q.',
#  'B.F.P.',
#  'BIAS',
#  'EXAMPLE',
#  'BIAS CRIME',
#  'F.B.I.',
#  'BID',
#  'BID SHOPPING',
#  'BIGAMY',
#  'BILATERAL CONTRACT',
#  'BILATERAL MISTAKE',
#  'MUTUAL (BILATERAL) MISTAKE',
#  'BILL',
#  'BILL FOR A NEW TRIAL',
#  'BILL OF CERTIORARI',
#  'BILL OF DISCOVERY',
#  'BILL OF EXCEPTIONS',
#  'BILL OF EXCHANGE',
#  'BILL OF INTERPLEADER',
#  'BILL OF REVIEW',
#  'BILL OF SALE',
#  'CROSS BILL',
#  'TREASURY BILL',
#  'U.S.',
#  'BILL OF ATTAINDER',
#  'BILL OF EXCHANGE',
#  'BILL OF LADING',
#  'EXAMPLE',
#  'ORDER BILL OF LADING',
#  'STRAIGHT BILL OF LADING',
#  'BILL OF PARTICULARS',
#  'BILL OF REVIEW',
#  'BILL OF RIGHTS',
#  'BIND',
#  'BINDER',
#  'BINDER RECEIPT',
#  'BINDING',
#  'BINDING AGREEMENT',
#  'BINDING INSTRUCTION',
#  'BIND OVER',
#  'BLACKACRE',
#  'BLACK LETTER LAW',
#  'BLACKMAIL',
#  'EXAMPLE',
#  'BLACKMAIL SUITS',
#  'BLANK INDORSEMENT',
#  'BLASPHEMY',
#  'BLIND TRUST',
#  'BLIND TRUST',
#  'BLOOD',
#  'CORRUPTION OF THE',
#  'BLUEBOOK',
#  'BLUE BOOK',
#  'BLUE CHIP STOCK',
#  'BLUE LAWS',
#  'EXAMPLE',
#  'BLUE RIBBON JURY',
#  'BLUE RIBBON JURY',
#  'BLUE SKY LAWS',
#  'SEC',
#  'BOARD OF DIRECTORS',
#  'BOARD ROOM',
#  'SEC',
#  'BOILERPLATE',
#  'EXAMPLE',
#  'BOILER ROOM',
#  'OR SHOP',
#  'BONA L',
#  'BONA FIDE',
#  'BONA FIDE OCCUPATIONAL QUALIFICATION',
#  'B.F.O.Q.',
#  'B.F.O.Q.',
#  'B.F.O.Q.',
#  'B.F.O.Q.',
#  'B.F.O.Q.',
#  'B.F.O.Q.',
#  'BONA FIDE PURCHASER',
#  'B.F.P.',
#  'EXAMPLE',
#  'BOND',
#  'REGISTERED BONDS',
#  'BEARER BONDS',
#  'BONDED DEBT',
#  'BOND FOR DEED',
#  'TITLE',
#  'BOND DISCOUNT',
#  'BOND FOR GENERAL PURPOSES',
#  'BOND ISSUE',
#  'BOND PREMIUM',
#  'BOND YIELD',
#  'PERFORMANCE BOND',
#  'SERIAL',
#  'SERIES',
#  'BONDS',
#  'SURETY BOND',
#  'BONDSMAN',
#  'BONUS STOCK',
#  'BOOK VALUE',
#  'EXAMPLE',
#  'BOOT',
#  'BORDELLO',
#  'BORDELLO',
#  'BOROUGH ENGLISH',
#  'BOYCOTT',
#  'BRAIN DEATH',
#  'BREACH',
#  'ANTICIPATORY BREACH',
#  'BREACH OF CONTRACT',
#  'BREACH OF THE PEACE',
#  'BREACH OF PROMISE',
#  'BREACH OF TRUST',
#  'BREACH OF WARRANTY',
#  'MATERIAL BREACH',
#  'PARTIAL BREACH',
#  'BREAKING A CLOSE',
#  'BREAKING AND ENTERING',
#  'BREAKING BULK',
#  'BREATHALYZER',
#  'BRETHREN',
#  'BRIBERY',
#  'EXAMPLE',
#  'COMMERCIAL BRIBERY',
#  'BRIEF',
#  'MEMORANDUM OF LAW',
#  'BROKER',
#  'BRUTUM FULMEN',
#  'BUGGERY',
#  'BUGGING',
#  'BUILDING AND LOAN ASSOCIATION',
#  'SAVINGS AND LOAN ASSOCIATION',
#  'BUILDING PERMIT',
#  'BULK SALES ACTS',
#  'BULK TRANSFER',
#  'UCC',
#  'BUNCHING',
#  'BURDEN',
#  'BURDEN OF PROOF',
#  'EXAMPLE',
#  'DUTY OF PRODUCING EVIDENCE',
#  'BURDEN OF EVIDENCE',
#  'PRODUCTION BURDEN',
#  'AFFIRMATIVE DEFENSE',
#  'PLEADING BURDEN',
#  'BUREAU OF INDIAN AFFAIRS',
#  'BUREAU OF INDIAN AFFAIRS',
#  'BURGLARY',
#  'BUSINESS',
#  'COURSE OF',
#  'BUSINESS CYCLE',
#  'U.S. N',
#  'BUSINESS GUEST',
#  'BUSINESS INVITEE',
#  'BUSINESS JUDGMENT RULE',
#  'BUSINESS RECORDS EXCEPTION',
#  'BUSINESS RECORDS EXCEPTION',
#  'BUSINESS TRUST',
#  'BUT FOR',
#  'PROXIMATE CAUSE',
#  'CAUSA SINE QUA NON',
#  'BUYER IN ORDINARY COURSE OF BUSINESS',
#  'EXAMPLE',
#  'BUY',
#  'SELL AGREEMENT',
#  'BYLAWS',
#  'BY OPERATION OF LAW',
#  'BY THE ENTIRETY',
#  'TENANCY BY THE ENTIRETY',
#  'CCAB',
#  'CAB',
#  'CADAVER',
#  'CALENDAR CALL',
#  'CALL',
#  'CALLABLE BOND',
#  'CALL OPTION',
#  'CALL OPTION',
#  'CALUMNY',
#  'CAMERA',
#  'CANNABIS',
#  'CANNABIS',
#  'CANON',
#  'PROFESSIONAL CANON',
#  'CAPACITY',
#  'CAPACITY TO SUE',
#  'CAPIAS L',
#  'CAPIAS AD AUDIENDUM JUDICIUM',
#  'CAPIAS AD RESPONDENDUM',
#  'CAPIAS AD SATISFACIENDUM',
#  'CAPITA',
#  'CAPITAL',
#  'CAPITAL ASSETS',
#  'U.S.',
#  'CAPITAL EXPENDITURE',
#  'EXAMPLE',
#  'CAPITAL INVESTMENT',
#  'CAPITAL STOCK',
#  'CAPITAL ACCOUNT',
#  'CAPITAL ASSET',
#  'CAPITAL ASSETS',
#  'CAPITAL EXPENDITURE',
#  'CAPITAL EXPENDITURE',
#  'CAPITAL GAINS OR LOSSES',
#  'CAPITAL ASSETS',
#  'LONG',
#  'TERM CAPITAL GAIN OR LOSS',
#  'SHORT',
#  'TERM CAPITAL GAIN OR LOSS',
#  'CAPITAL INTENSIVE',
#  'CAPITAL INVESTMENT',
#  'CAPITAL INVESTMENT',
#  'CAPITALIZATION',
#  'CAPITALIZED VALUE',
#  'CAPITAL MARKET',
#  'EQUITY MARKET',
#  'CAPITAL OFFENSE',
#  'CAPITAL PUNISHMENT',
#  'CAPITAL STOCK',
#  'CAPITAL STOCK',
#  'CAPITAL SURPLUS',
#  'CAPITAL SURPLUS',
#  'CAPITE',
#  'CAPTION',
#  'ASPORTATION',
#  'CAPTURE',
#  'CARE',
#  'DUTY OF',
#  'CARE',
#  'GREAT CARE',
#  'ORDINARY CARE',
#  'REASONABLE CARE',
#  'SLIGHT CARE',
#  'CA. RESP.',
#  'CAPIAS AD RESPONDENDUM',
#  'CARJACKING',
#  'CARJACKING',
#  'CARNAL KNOWLEDGE',
#  'CARRIER',
#  'COMMON CARRIER',
#  'CARRYBACK',
#  'CARRYOVER',
#  'CARRYOVER BASIS',
#  'CARRYOVER SUBSTITUTED BASIS',
#  'CARTEL',
#  'CARVE OUT',
#  'CA. SA',
#  'CAPIAS AD SATISFACIENDUM',
#  'CASE',
#  'CASE AT BAR',
#  'CASE LAW',
#  'CASE OF FIRST IMPRESSION',
#  'CASE',
#  'ON THE',
#  'TRESPASS ON THE CASE',
#  'CASE OR CONTROVERSY',
#  'CASE REPORTS',
#  'CASH EQUIVALENT DOCTRINE',
#  'CASH EQUIVALENT DOCTRINE',
#  'CASHIER',
#  'S CHECK',
#  'CASH SALE',
#  'CASH SALE DOCTRINE',
#  'CASH SURRENDER VALUE',
#  'CASH VALUE',
#  'CASUALTY LOSS',
#  'TAXABLE INCOME',
#  'CAUSA L',
#  'CAUSA MORTIS',
#  'CAUSA PROXIMA',
#  'PROXIMATECAUSE',
#  'DIRECT CAUSE',
#  'CAUSA SINE QUA NON',
#  'CAUSE',
#  'DIRECT CAUSE',
#  'PROXIMATE CAUSE',
#  'IMMEDIATE CAUSE',
#  'INTERVENING',
#  'SUPERVENING',
#  'CAUSE',
#  'PROXIMATE CAUSE',
#  'SUPERSEDING CAUSE',
#  'EXAMPLE',
#  'SUPERVENING CAUSE',
#  'INTERVENING CAUSE',
#  'CAUSE OF ACTION',
#  'BREACH OF CONTRACT',
#  'A RIGHTOF ACTION',
#  'CAUTIONARY INSTRUCTION',
#  'CAVEAT L',
#  'CAVEAT EMPTOR',
#  'CEASE AND DESIST ORDER',
#  'EXAMPLE',
#  'CELL PARDE',
#  'CELL PAROLE',
#  'CENSURE',
#  'CENTER OF GRAVITY',
#  'CERTIFICATE OF DEPOSIT',
#  'CERTIFICATE OF INCORPORATION',
#  'CERTIFICATE OF OCCUPANCY',
#  'CERTIFICATE OF TITLE',
#  'BILL OF SALE',
#  'CERTIFICATION',
#  'CERTIFIED CHECK',
#  'CERTIORARI L',
#  'CESTUI QUE',
#  'CESTUIS QUE) O',
#  'CESTUI QUE TRUST',
#  'CESTUI QUE USE',
#  'CESTUI QUE VIE',
#  'C.F.I.',
#  'C.I.F.',
#  'CHAIN OF TITLE',
#  'TRACT',
#  'INDEX',
#  'GRANTOR',
#  'GRANTEE INDEX',
#  'CHALLENGE',
#  'CHALLENGE FOR CAUSE',
#  'PEREMPTORY CHALLENGE',
#  'CHALLENGED FOR CAUSE',
#  'CHAMBERS',
#  'CHAMPERTY',
#  'CHANCELLOR',
#  'CHANCERY',
#  'CHAPTER',
#  'CHAPTER',
#  'REORGANIZATION',
#  'CHARACTER WITNESS',
#  'CHARGE',
#  'EXAMPLE',
#  'CHARITABLE CONTRIBUTION',
#  'CHARITABLE DEDUCTION',
#  'CHARITY',
#  'TAXABLE INCOME',
#  'PUBLIC CHARITY',
#  'PRIVATE FOUNDATIONS',
#  'CHARTER',
#  'CHATTEL',
#  'CHATTEL MORTGAGE',
#  'CHATTEL PAPER',
#  'CHECK',
#  'CASHIER',
#  'S CHECK',
#  'CERTIFIED CHECK',
#  'MEMORANDUM CHECK',
#  'CHECK KITING',
#  'B. T',
#  'A.) S',
#  'CHECKS AND BALANCES',
#  'CHIEF JUSTICE',
#  'U.S.',
#  'CHILD AND DEPENDENT CARE CREDIT',
#  'CHILD CUSTODY',
#  'CHILD SUPPORT',
#  'CHILL',
#  'CHILLING EFFECT',
#  'EXAMPLE',
#  'CHOATE',
#  'CHOICE OF LAW',
#  'CHOICE OF LAW',
#  'CHOSE F',
#  'CHOSE IN ACTION',
#  'CHOSE IN POSSESSION',
#  'CHURNING',
#  'C.I.F.',
#  'C.F.I. I',
#  'C.I.F.',
#  'CIRCUIT',
#  'CIRCUIT COURT',
#  'U. S.',
#  'CIRCUMSTANTIAL EVIDENCE',
#  'EXAMPLE',
#  'CITATION',
#  'CITE',
#  'CITIZEN',
#  'CITIZEN',
#  'NATURALIZED',
#  'CIVIL',
#  'CIVIL ACTION',
#  'CIVIL AERONAUTICS BOARD',
#  'CAB',
#  'FAA',
#  'CIVIL CONTEMPT',
#  'CIVIL DAMAGE ACTS',
#  'CIVIL DEATH',
#  'CIVIL DISOBEDIENCE',
#  'EXAMPLE',
#  'CIVIL DISORDER',
#  'CIVIL LAW',
#  'CIVIL LIABILITY',
#  'CIVIL LIBERTIES',
#  'CIVIL PENALTIES',
#  'CIVIL PROCEDURE',
#  'CIVIL RIGHTS',
#  'CIVIL',
#  'LIBERTIES',
#  'EXAMPLE',
#  'CIVIL RIGHTS ACT OF',
#  'CIVIL SERVICE COMMISSIONS',
#  'CIVIL SERVICE COMMISSIONS',
#  'CIVITAS L',
#  'C.J.',
#  'CLA',
#  'CLA',
#  'CLAIM',
#  'CLAIMANT',
#  'CLAIM FOR REFUND',
#  'IRS',
#  'IRS',
#  'CLAIM OF RIGHT',
#  'CLASS ACTION',
#  'EXAMPLE',
#  'CLASS GIFT',
#  'CLASSIFIED STOCK',
#  'CLAUSE',
#  'CLAYTON ACT',
#  'CLEAN HANDS',
#  'CLEAR',
#  'CLEAR AND CONVINCING',
#  'CLEAR AND PRESENT DANGER',
#  'CLEARINGHOUSE',
#  'XYZ',
#  'CLEAR TITLE',
#  'CLEMENCY',
#  'CLERGYMEN',
#  'S PRIVILEGE',
#  'CLERICAL ERROR',
#  'JUDICIAL ERROR',
#  'CLERIC',
#  'S PRIVILEGE',
#  'CLERK',
#  'COURT CLERK',
#  'LAW CLERK',
#  'CLOSE',
#  'CLOSE CORPORATION',
#  'CLOSED END FUNDS',
#  'TRUST',
#  'CLOSED',
#  'END MANAGEMENT COMPANY',
#  'MUTUAL FUND',
#  'CLOSED SHOP',
#  'CLOSELY HELD CORPORATION',
#  'CLOSE CORPORATIONS',
#  'CLOSING',
#  'CLOSING AGREEMENT',
#  'IRS',
#  'CLOSING LAWS',
#  'CLOSING STATEMENT',
#  'CLOSING STATEMENT',
#  'CLOTURE',
#  'FILIBUSTER',
#  'U.S. S',
#  'CLOUD ON TITLE',
#  'EXAMPLE',
#  'CODE',
#  'CODEFENDANT',
#  'CODE OF MILITARY JUSTICE',
#  'CODE OF MILITARY JUSTICE',
#  'CODE OF PROFESSIONAL RESPONSIBILITY',
#  'CODE PLEADING',
#  'CODICIL',
#  'EXAMPLE',
#  'COERCION',
#  'COGENT',
#  'COGNIZABLE',
#  'COGNOVIT JUDGMENT',
#  'COGNOVIT NOTE',
#  'COHABITATION',
#  'COHEIR',
#  'COIF',
#  'COINSURANCE',
#  'COLLATERAL',
#  'COLLATERAL AFFINITY',
#  'COLLATERAL AFFINITY',
#  'COLLATERAL ATTACK',
#  'COLLATERAL CONSANGUINITY',
#  'LINE',
#  'COLLATERAL CONSANGUINITY',
#  'COLLATERAL LINE',
#  'COLLATERAL ESTOPPEL',
#  'EXAMPLE',
#  'ALIBI',
#  'COLLATERAL FRAUD',
#  'EXTRINSIC',
#  'COLLATERAL',
#  'FRAUD',
#  'COLLATERAL SOURCE RULE',
#  'COLLATION',
#  'COLLECTIVE BARGAINING',
#  'COLLOQUIUM',
#  'COLLUSION',
#  'COLLUSIVE ACTION',
#  'COLOR',
#  'COLORABLE',
#  'COLOR OF LAW',
#  'COLOR OF TITLE',
#  'COMITY',
#  'COMITAS',
#  'EXAMPLE',
#  'COMMENT',
#  'COMMERCE CLAUSE',
#  'COMMERCE POWER',
#  'COMMERCE POWER',
#  'COMMERCIAL BANK',
#  'COMMERCIAL BANK',
#  'COMMERCIAL BRIBERY',
#  'COMMERCIAL FRUSTRATION',
#  'COMMERCIAL LAW',
#  'COMMERCIAL NAME',
#  'COMMERCIAL PAPER',
#  'COMMERCIAL PREFERENCE',
#  'COMMERCIAL UNIT',
#  'COMMINGLING OF FUNDS',
#  'EXAMPLE',
#  'COMMISSION',
#  'COMMISSION',
#  'MILITARY',
#  'MILITARY COMMISSION',
#  'COMMITMENT',
#  'COMMITTEE',
#  'COMMODITY',
#  'COMMON AREA',
#  'COMMON CARRIER',
#  'COMMON CARRIER',
#  'COMMON LAW',
#  'COMMON',
#  'LAWCOPYRIGHT',
#  'COMMON',
#  'LAW MARRIAGE',
#  'COMMON',
#  'LAWTRUST',
#  'COMMON NUISANCE',
#  'PUBLIC',
#  'COMMON',
#  'NUISANCE',
#  'COMMON PROPERTY',
#  'COMMONS',
#  'COMMON STOCK',
#  'COMMUNITY NOTIFICATION',
#  'COMMUNITY NOTIFICATION',
#  'COMMUNITY PROPERTY',
#  'SEPARATE PROPERTY',
#  'EXAMPLE',
#  'EQUITABLE DISTRIBUTION',
#  'TENANCY BY THE ENTIRETY',
#  'JOINTTENANCY',
#  'COMMUTATION',
#  'EXAMPLE',
#  'COMPACT CLAUSE',
#  'INTERSTATE COMPACTS',
#  'COMPANY',
#  'HOLDING COMPANY',
#  'JOINT STOCK COMPANY',
#  'CAPITAL STOCK',
#  'COMPARATIVE NEGLIGENCE',
#  'COMPELLING INTEREST',
#  'COMPENSATION',
#  'COMPENSATORY DAMAGES',
#  'ACTUAL DAMAGES',
#  'COMPETENT',
#  'COMPETENT EVIDENCE',
#  'COMPETENT COURT',
#  'EXAMPLE',
#  'COMPLAINANT',
#  'COMPLAINT',
#  'COMPOS MENTIS',
#  'COMPOUND CONCLUSION',
#  'COMPOUND CONCLUSION',
#  'COMPOUNDING A FELONY',
#  'COMPOUND INTEREST',
#  'COMPROMISE VERDICT',
#  'COMPROMISE VERDICT',
#  'COMPULSORY ARBITRATION',
#  'COMPULSORY ARBITRATION',
#  'COMPULSORY APPEARANCE',
#  'COMPULSORY APPEARANCE',
#  'COMPULSORY COUNTERCLAIM',
#  'COMPULSORY COUNTERCLAIM',
#  'COMPULSORY JOINDER',
#  'COMPULSORY JOINDER',
#  'COMPULSORY PROCESS',
#  'COMPURAGATOR',
#  'CONCEALMENT',
#  'CONCERTED ACTION',
#  'CONCERT OF ACTION',
#  'CONCILIATION',
#  'CONCILIATOR',
#  'CONCILIATOR',
#  'CONCILIATOR',
#  'CONCLUSION OF FACT',
#  'EXAMPLE',
#  'CONCLUSION OF LAW',
#  'EXAMPLE',
#  'CONCLUSIVE EVIDENCE',
#  'CONCLUSIVE PRESUMPTION',
#  'CONCUR',
#  'CONCURRENT',
#  'CONCURRENT SENTENCE',
#  'CONCURRENT CONDITION',
#  'CONCURRENT CONDITION',
#  'CONCURRENT COVENANTS',
#  'CONCURRENT COVENANTS',
#  'CONCURRENT JURISDICTION',
#  'CONCURRENT JURISDICTION',
#  'CONCURRENT NEGLIGENCE',
#  'CONCURRENT NEGLIGENCE',
#  'CONCURRENT SENTENCES',
#  'CONCURRENT SENTENCES',
#  'CONCURRING OPINION',
#  'CONCURRING OPINION',
#  'CONDEMN',
#  'CONDITION',
#  'CONDITION PRECEDENT',
#  'CONDITION SUBSEQUENT',
#  'BREACH OF',
#  'CONTRACT',
#  'CONCURRENT CONDITION',
#  'CONDITIONAL',
#  'CONDITIONAL BEQUEST',
#  'CONDITIONAL BEQUEST',
#  'CONDITIONAL CONTRACT',
#  'CONDITIONAL CONTRACT',
#  'CONDITIONAL DISCHARGE',
#  'SUSPENDED SENTENCE',
#  'CONDITIONAL FEE',
#  'OR ESTATE',
#  'EXAMPLE',
#  'CONDITION PRECEDENT',
#  'CONDITION PRECEDENT',
#  'CONDITION SUBSEQUENT',
#  'CONDITION SUBSEQUENT',
#  'CONDOMINIUM',
#  'COOPERATIVE',
#  'CONFERENCE',
#  'PRE',
#  'TRIAL',
#  'CONFESSION',
#  'CONFESSION AND AVOIDANCE',
#  'AFFIRMATIVE DEFENSE',
#  'CONFESSION OF JUDGMENT',
#  'CONFIDENCE GAME',
#  'CONFIDENTIAL COMMUNICATION',
#  'CONFIRMATION',
#  'CONFIRMATION',
#  'CONFISCATE',
#  'CONFLICT OF INTERESTS',
#  'CONFLICT OF LAW',
#  'CHOICE OF LAW',
#  'EXAMPLE',
#  'CONFORMED COPY',
#  'EXAMPLE',
#  'CONFORMING USE',
#  'CONFRONTATION CLAUSE',
#  'CONFUSION OF GOODS',
#  'CONGLOMERATE',
#  'CONGRESS',
#  'CONGRESSIONAL REFERENCE CASES',
#  'CONJECTURE',
#  'CONJUGAL RIGHTS',
#  'CONJUGAL',
#  'VISITATION',
#  'CONJUNCTIVE DENIAL',
#  'CONJUNCTIVE DENIAL',
#  'CONSANGUINITY',
#  'LINEAL CONSANGUINITY',
#  'COLLATERAL CONSANGUINITY',
#  'CONSCIENCE OF THE COURT',
#  'CONSCIENTIOUS OBJECTOR',
#  'U.S. S',
#  'CONSCIOUS PARALLELISM',
#  'EXAMPLE',
#  'CONSECUTIVE SENTENCE',
#  'CONSECUTIVE',
#  'CUMULATIVE',
#  'SENTENCE',
#  'CONSENT',
#  'CONSENT DECREE',
#  'CONSENT',
#  'INFORMED',
#  'CONSENT JUDGMENT',
#  'CONSENT ORDER',
#  'FTC',
#  'CONSENT DECREE',
#  'CONSENT ORDER',
#  'CONSENT ORDER',
#  'CONSENT SEARCH',
#  'CONSEQUENTIAL DAMAGES',
#  'CONSERVATOR',
#  'CONSIDERATION',
#  'FAILURE OF CONSIDERATION',
#  'WANT OF CONSIDERATION',
#  'EXAMPLE',
#  'CONSIDERED DICTUM',
#  'CONSIDERED DICTUM',
#  'CONSIGNMENT',
#  'CONSIGNEE',
#  'COMMON CARRIER',
#  'CONSIGNOR',
#  'CONSOLIDATED APPEAL',
#  'CONSOLIDATION',
#  'CONSORTIUM',
#  'CONSPIRACY',
#  'CONSPIRATOR',
#  'COCONSPIRATOR',
#  'CONSTITUTION',
#  'CONSTITUTIONAL RIGHTS',
#  'CONSTRUCTION',
#  'STRICT CONSTRUCTION',
#  'CONSTRUCTIVE',
#  'CONSTRUCTIVE BAILMENT',
#  'CONSTRUCTIVE BAILMENT',
#  'CONSTRUCTIVE CONTEMPT',
#  'CONSTRUCTIVE CONTEMPT',
#  'CONSTRUCTIVE DELIVERY',
#  'CONSTRUCTIVE DELIVERY',
#  'CONSTRUCTIVE EVICTION',
#  'CONSTRUCTIVE EVICTION',
#  'CONSTRUCTIVE FRAUD',
#  'CONSTRUCTIVE FRAUD',
#  'CONSTRUCTIVE NOTICE',
#  'CONSTRUCTIVE NOTICE',
#  'CONSTRUCTIVE POSSESSION',
#  'CONSTRUCTIVE POSSESSION',
#  'CONSTRUCTIVE SERVICE',
#  'CONSTRUCTIVE TRUST',
#  'CONSTRUCTIVE',
#  'INVOLUNTARY',
#  'TRUST',
#  'CONSTRUE',
#  'CONSUMER',
#  'CONSUMER GOODS',
#  'EQUIPMENT',
#  'FARM PRODUCTS',
#  'INVENTORY',
#  'CONSUMER PROTECTION',
#  'EXAMPLE',
#  'CONTACTS APPROACH',
#  'CONTEMPLATION OF DEATH',
#  'CAUSA MORTIS',
#  'CONTEMPT OF COURT',
#  'DIRECT CONTEMPT',
#  'CONSTRUCTIVE CONTEMPT',
#  'CIVIL CONTEMPT',
#  'RELIEF TO LITIGANTS',
#  'CRIMINAL CONTEMPT',
#  'EXAMPLE',
#  'CONTIGUOUS',
#  'CONTINGENT BENEFICIARY',
#  'EXAMPLE',
#  'CONTINGENT ESTATE',
#  'OR INTEREST',
#  'EXAMPLE',
#  'CONTINGENT FEE',
#  'CONTINGENT LIABILITY',
#  'CONTINUANCE',
#  'CONTRA L',
#  'CONTRABAND',
#  'CONTRA BONOS MORES',
#  'CONTRACT',
#  'BILATERAL CONTRACT',
#  'CONDITIONAL CONTRACT',
#  'EXAMPLE',
#  'COST',
#  'PLUS CONTRACT',
#  'ORAL CONTRACT',
#  'OUTPUT CONTRACT',
#  'QUASI CONTRACT',
#  'QUASI CONTRACT',
#  'REQUIREMENTS CONTRACT',
#  'UNILATERAL CONTRACT',
#  'CONTRACT OFADHESION',
#  'CONTRACT OF HAZARD',
#  'SALE IN GROSS',
#  'CONTRACTOR',
#  'INDEPENDENT CONTRACTOR',
#  'GENERAL BUILDING',
#  'CONTRACTOR',
#  'SUBCONTRACTOR',
#  'CONTRACTUAL BREACH',
#  'CONTRACT UNDER SEAL',
#  'CONTRA PACEM',
#  'CONTRIBUTION',
#  'DONATION.',
#  'CHARITABLE CONTRIBUTION',
#  'NOT',
#  'FOR',
#  'PROFIT',
#  'CORPORATION',
#  'CONTRIBUTORY NEGLIGENCE',
#  'CONTROLLED SUBSTANCE',
#  'CONTROVERSY',
#  'CONTUMACY',
#  'CONVERSATION',
#  'CRIMINAL',
#  'CONVERSION',
#  'EXAMPLE',
#  'CONVERTIBLE SECURITIES',
#  'CONVEY',
#  'CONVEYANCE',
#  'CONVICT',
#  'CONVICTION',
#  'COOPERATIVE',
#  'COOPERATIVE ASSOCIATION',
#  'COORDINATE JURISDICTION',
#  'CONCURRENT JURISDICTION',
#  'COPARCENARY',
#  'COPARCENERS',
#  'EXAMPLE',
#  'COPARTNER',
#  'COPY',
#  'CONFORMED',
#  'COPYHOLD',
#  'COPYRIGHT',
#  'COMMON',
#  'LAW COPYRIGHT',
#  'RIGHT OF FIRST',
#  'PUBLICATION.COPYRIGHT INFRINGEMENT',
#  'CORAM NOBIS',
#  'WRIT OF',
#  'CORESPONDENT',
#  'CORONER',
#  'CORPORAL PUNISHMENT',
#  'CORPORATE OPPORTUNITY',
#  'CONSTRUCTIVE TRUST',
#  'CORPORATE POWER',
#  'CORPORATION',
#  'ARTIFICAL PERSON',
#  'CLOSE CORPORATIONS',
#  'EXAMPLE',
#  'SUBCHAPTER S CORPORATION',
#  'DE FACTO CORPORATION',
#  'EXAMPLE',
#  'NOT',
#  'FOR',
#  'PROFIT CORPORATION',
#  'PUBLIC',
#  'OR POLITICAL',
#  'CORPORATIONS',
#  'PRIVATE CORPORATION',
#  'QUASI CORPORATION',
#  'CORPOREAL',
#  'INCORPOREAL',
#  'CORPOREAL HEREDITAMENT',
#  'CORPUS L',
#  'EXAMPLE',
#  'CORPUS DELICTI',
#  'EXAMPLE',
#  'CORPUS JURIS',
#  'CORRECTIONAL INSTITUTION',
#  'CORRESPONDENT',
#  'CORROBORATING EVIDENCE',
#  'CORRUPTION OF THE BLOOD',
#  'COSIGN',
#  'COST',
#  'INSURANCE',
#  'AND FREIGHT',
#  'C.I.F.',
#  'COST OF COMPLETION',
#  'COST OF LIVING CLAUSE',
#  'COST',
#  'PLUS CONTRACT',
#  'COST OF COMPLETION',
#  'COSTS',
#  'COSTS TO ABIDE THE EVENT',
#  'TENANCY',
#  'TENANCY IN',
#  'COMMON',
#  'JOINT TENANCY',
#  'TENANCY BY THE ENTIRETY',
#  'COUNSEL',
#  'COUNT',
#  'COUNTERCLAIM',
#  'EXAMPLE',
#  'COMPULSORY COUNTERCLAIM',
#  'PERMISSIVE COUNTERCLAIM',
#  'COUNTERFEIT',
#  'COUPLED WITH AN INTEREST',
#  'AUTHORITY COUPLED WITH AN INTEREST',
#  'COUPONS',
#  'BEARER BOND',
#  'COURSE OF BUSINESS',
#  'COURSE OF DEALING',
#  'COURSE OF DEALING',
#  'COURT',
#  'COURT CALENDAR',
#  'TRIAL LIST',
#  'COURTDOCKET.COURT EN BANC',
#  'COURT',
#  'MARTIAL',
#  'GENERAL COURT',
#  'MARTIAL',
#  'SPECIAL COURT',
#  'MARTIAL',
#  'SUMMARY COURT',
#  'MARTIAL',
#  'COURT OF APPEALS',
#  'COURT OF ASSIZE AND NISI PRIUS',
#  'COURT OF CLAIMS',
#  'COURT OF CUSTOMS AND PATENT APPEALS',
#  'COURT OF EQUITY',
#  'COURT OF EXCHEQUER',
#  'THE COURT OF EXCHEQUER CHAMBER',
#  'COURT OF INQUIRY',
#  'MILITARY COURT OF INQUIRY',
#  'COURT OF KING',
#  'QUEEN',
#  'BENCH',
#  'COURT OF LAW',
#  'COURT OF MILITARY APPEAL',
#  'COURT OF MILITARY APPEAL',
#  'COURT OF MILITARY REVIEW',
#  'COURT OF MILITARY REVIEW',
#  'COURT OF RECORD',
#  'COURT OF STAR CHAMBER',
#  'COURT REPORTERS',
#  'REAL TIME',
#  'LIVE VIEW',
#  'COURT REPORTS',
#  'COVENANT',
#  'EXAMPLE',
#  'CONCURRENT COVENANTS',
#  'COVENANT NOT TO COMPETE',
#  'DEPENDENT COVENANTS',
#  'INDEPENDENT',
#  'OR MUTUAL',
#  'COVENANTS',
#  'COVENANTS OF TITLE',
#  'COVENANT AGAINST ACTS OF THE GRANTOR',
#  'COVENANT AGAINST ENCUMBRANCES',
#  'COVENANT OF FURTHER ASSURANCE',
#  'COVENANT OF QUIET ENJOYMENT',
#  'COVENANT OF SEISIN AND RIGHT TO CONVEY',
#  'COVENANT OF WARRANTY AND QUIET ENJOYMENT',
#  'RESTRICTIVE COVENANT',
#  'COVENANTEE',
#  'COVENANT NOT TO COMPETE',
#  'EXAMPLE',
#  'COVENANTOR',
#  'COVER',
#  'EXAMPLE',
#  'COVERTURE',
#  'CREDIBILITY',
#  'CREDIT',
#  'CREDIT CARD',
#  'CREDITOR',
#  'CREDITOR BENEFICIARY',
#  'CREDITOR BENEFICIARY',
#  'CREDITOR',
#  'S BILL',
#  'OR SUIT',
#  'CRIME',
#  'CRIME AGAINST NATURE',
#  'CRIMEN FALSI',
#  'CRIME OF PASSION',
#  'EXAMPLE',
#  'CRIME',
#  'ORGANIZED',
#  'CRIMINAL',
#  'HABITUAL OFFENDER',
#  'CRIMINAL CODE',
#  'CRIMINAL COERCION',
#  'CRIMINAL CONTEMPT',
#  'CRIMINAL CONVERSATION',
#  'CRIMINAL MAINTENANCE',
#  'CRIMINAL MISCHIEF',
#  'CRIMINAL NEGLIGENCE',
#  'CRIMINAL POSSESSION',
#  'CRIMINAL PROCEDURE',
#  'CRIMINAL PROCEDURE',
#  'CRIMINAL RECORD',
#  'NCIC. A',
#  'RAP SHEET',
#  'CROSS',
#  'BILL',
#  'CROSS',
#  'BILL',
#  'CROSS',
#  'CLAIM',
#  'CROSS',
#  'EXAMINATION',
#  'DIRECT EXAMINATION',
#  'DIRECT EXAMINATION',
#  'REDIRECT EXAMINATION',
#  'CRUEL AND UNUSUAL PUNISHMENT',
#  'U.S. C',
#  'CTA',
#  'CTA',
#  'CUCKOLD',
#  'CULPA L',
#  'DOLUS',
#  'CULPABLE',
#  'CULPABLE MENTAL STATE',
#  'EXAMPLE',
#  'CRIMINAL',
#  'CULPABLE',
#  'NEGLIGENCE',
#  'CUM TESTAMENTO ANNEXO',
#  'CUM TESTAMENTO ANNEXO',
#  'CUMULATIVE DIVIDEND',
#  'CUMULATIVE DIVIDEND',
#  'CUMULATIVE SENTENCE',
#  'CONSECUTIVE',
#  'CUMULATIVE',
#  'SENTENCE',
#  'CUMULATIVE VOTING',
#  'CURATIVE',
#  'CURIA REGIS',
#  'CURRENT ASSETS',
#  'CURRENT LIABILITIES',
#  'CURTESY',
#  'CURTILAGE',
#  'CUSTODY',
#  'CUSTODY OF CHILDREN',
#  'JOINT CUSTODY',
#  'CUSTOM DUTIES',
#  'CUSTOMS COURT',
#  'EXAMPLE',
#  'DD.A.',
#  'DAILY',
#  'DAMAGE',
#  'DAMAGE',
#  'HARM',
#  'DAMAGES',
#  'ACTUAL DAMAGES',
#  'CONSEQUENTIAL',
#  'SPECIAL',
#  'DAMAGES',
#  'EXAMPLE',
#  'DOUBLE',
#  'TREBLE',
#  'DAMAGES',
#  'EXEMPLARY',
#  'PUNITIVE',
#  'DAMAGES',
#  'EXAMPLE',
#  'EXPECTATION DAMAGES',
#  'INCIDENTAL DAMAGES',
#  'LIQUIDATED DAMAGES',
#  'NOMINAL DAMAGES',
#  'DAMNUM ABSQUE INJURIA',
#  'DANGEROUS WEAPON',
#  'OR INSTRUMENTALITY',
#  'DAY IN COURT',
#  'D.B.A.',
#  'EXAMPLE',
#  'D.B.A. S',
#  'DBN',
#  'DBN',
#  'DEAD HAND',
#  'DEADLY FORCE',
#  'DEADLY FORCE',
#  'DEADLY WEAPON',
#  'DEALER',
#  'DEATH',
#  'DEATH BY AUTOMOBILE',
#  'DEATH BY AUTOMOBILE',
#  'DEATH PENALTY',
#  'U.S. S',
#  'DEBAUCHERY',
#  'DE BENE ESSE',
#  'APPEARANCE DE BENE ESSE',
#  'DEPOSITIONS DE BENE ESSE',
#  'EVIDENCE DE BENE ESSE',
#  'DEBENTURE',
#  'DEBIT',
#  'DE BONIS NON',
#  'DE BONIS NON',
#  'DEBT',
#  'DEBT CAPITAL',
#  'DEBT CAPITAL',
#  'DEBTOR',
#  'DECEASED',
#  'DECEDENT',
#  'DECEDENT',
#  'DECEIT',
#  'DECISION',
#  'DECISION ON THE MERITS',
#  'JUDGMENT ON THE MERITS',
#  'DECLARANT',
#  'DECLARATION',
#  'DECLARATION AGAINST INTEREST',
#  'EXAMPLE',
#  'ADMISSIONS BY A PARTY',
#  'OPPONENT',
#  'EXAMPLE',
#  'DECLARATION OF ESTIMATED TAX',
#  'DECLARATION OF ESTIMATED TAX',
#  'DECLARATION OF TRUST',
#  'DECLARATION OF TRUST',
#  'DECLARATORY JUDGMENT',
#  'EXAMPLE',
#  'DECLARATORY STATUTE',
#  'DECREE',
#  'CONSENT DECREE',
#  'DECREE NISI',
#  'FINAL DECREE',
#  'INTERLOCUTORY DECREE',
#  'DECREE NISI',
#  'DECREE NISI',
#  'DECREE NISI',
#  'DECRIMINALIZATION',
#  'DEDICATION',
#  'EXAMPLE',
#  'DEDUCTIONS',
#  'GROSS INCOME',
#  'ADJUSTEDGROSS INCOME',
#  'ITEMIZED DEDUCTIONS',
#  'TAXABLEINCOME',
#  'ZERO BRACKET AMOUNT',
#  'MARITAL DEDUCTION',
#  'PERSONAL EXPENSES DEDUCTION',
#  'STANDARD DEDUCTION',
#  'ZERO BRACKET AMOUNT',
#  'ZERO BRACKET AMOUNT DEDUCTION',
#  'DEED',
#  'DEED OF TRUST',
#  'DEED POLL',
#  'DEEP ROCK DOCTRINE',
#  'DE FACTO',
#  'EXAMPLE',
#  'DEFALCATION',
#  'DEFAMATION',
#  'EXAMPLE',
#  'DEFAULT',
#  'DEFAULT JUDGMENT',
#  'EXAMPLE',
#  'DEFEASANCE',
#  'DEFEASIBLE',
#  'DEFEASIBLE FEE',
#  'DEFECT',
#  'DEFECTIVE',
#  'DEFECTIVE PLEADING',
#  'DEFECTIVE TITLE',
#  'EXAMPLE',
#  'DEFENDANT',
#  'DEFENDENT IN ERROR',
#  'PLAINTIFF IN ERROR',
#  'DEFENSE',
#  'AFFIRMATIVE DEFENSE',
#  'EQUITABLE DEFENSE',
#  'DEFERMENT',
#  'DEFERRED COMPENSATION',
#  'DEFERRED COMPENSATION',
#  'DEFERRED PAYMENTS',
#  'DEFICIENCY',
#  'DEFICIT',
#  'DEFINITE FAILURE OF ISSUE',
#  'DEFRAUD',
#  'DEGREE',
#  'DEGREE OF CONSANGUINITY',
#  'KINSHIP',
#  'DEGREE OF CRIME',
#  'DEGREE OF NEGLIGENCE',
#  'DEGREE OF PROOF',
#  'DE JURE',
#  'EXAMPLE',
#  'DELEGABLE DUTY',
#  'NONDELEGABLE. T',
#  'DELEGATE',
#  'DELEGATED POWER',
#  'DELIBERATE',
#  'DELIBERATE SPEED',
#  'DELIBERATION',
#  'DELICT',
#  'DELICTUML',
#  'EX DELICTO',
#  'EXCONTRACTU',
#  'DELICTUM',
#  'ACTION EX DELICTO',
#  'EX CONTRACTU',
#  'DELINQUENT',
#  'DELISTING',
#  'DELIVERY',
#  'SYMBOLIC',
#  'DELIVERY. C',
#  'DELUSION',
#  'DEMAND',
#  'DEMAND NOTE',
#  'DEMESNE F',
#  'DE MINIMIS',
#  'DE MINIMIS NON CURAT LEX',
#  'EXAMPLE',
#  'DEMISE',
#  'DEMONSTRATIVE EVIDENCE',
#  'DEMUR',
#  'DEMURRER',
#  'DENIAL',
#  'CONJUNCTIVE DENIAL',
#  'DISJUNCTIVE DENIAL',
#  'GENERAL DENIAL',
#  'SPECIFIC DENIAL',
#  'DE NOVO',
#  'DE NOVO HEARING',
#  'EXAMPLE',
#  'DEODAND',
#  'DEPENDENCY',
#  'DEPENDENT',
#  'DEPENDENT CARE',
#  'DEPENDENT COVENANTS',
#  'DEPENDENT COVENANTS',
#  'DEPENDENT RELATIVE REVOCATION',
#  'DEPLETION',
#  'DEPLETION ALLOWANCE',
#  'EXAMPLE',
#  'DEPONENT',
#  'DEPORTATION',
#  'DEPOSE',
#  'DEPOSITION',
#  'DEPOSITION DE BENE ESSE',
#  'DEPRECIATION',
#  'ACCELERATED DEPRECIATION',
#  'STRAIGHT LINE DEPRECIATION',
#  'SALVAGE VALUE',
#  'SALVAGE VALUE',
#  'USEFUL LIFE',
#  'DEPRECIATION RESERVE',
#  'ACCUMULATED DEPRECIATION',
#  'DEPREDATION',
#  'DEPRESSANTS',
#  'DERELICTION',
#  'DERIVATIVE ACTION',
#  'DERIVATIVE TORT',
#  'DEROGATION',
#  'DESCENT',
#  'DESCENT AND DISTRIBUTION',
#  'DESEGREGATION',
#  'DESERTION',
#  'ABSENT WITHOUT LEAVE',
#  'AWOL',
#  'DESIST',
#  'DESTINATION CONTRACT',
#  'TENDER OF DELIVERY',
#  'DESTRUCTIBILITY',
#  'DESUETUDE',
#  'DETAINER',
#  'UNLAWFUL DETAINER',
#  'TENANCY AT SUFFERANCE',
#  'DETENTION',
#  'DETERMINABLE FEE',
#  'FEE SIMPLE DETERMINABLE',
#  'DEFEASIBLE FEE',
#  'FEE SIMPLE DEFEASIBLE',
#  'EXAMPLE',
#  'DETERMINATION',
#  'DETINUE',
#  'UNLAWFUL DETAINER',
#  'DEVISE',
#  'DEVOLVE',
#  'DICTA',
#  'DICTUM',
#  'EXAMPLE',
#  'CONSIDERED DICTUM',
#  'DIE WITHOUT ISSUE',
#  'DILATORY PLEA',
#  'PLEA IN ABATEMENT',
#  'DILIGENCE',
#  'DUE DILIGENCE',
#  'REASONABLE DILIGENCE',
#  'DILUTING THE SHARES',
#  'DIMINISHED CAPACITY',
#  'DIMINISHED RESPONSIBILITY',
#  'DIMINUTION IN VALUE',
#  'EXPECTATION DAMAGES',
#  'DIRECT AFFINITY',
#  'DIRECT AFFINITY',
#  'DIRECT ATTACK',
#  'COLLATERAL ATTACK',
#  'DIRECT CAUSE',
#  'DIRECT CAUSE',
#  'DIRECT CONTEMPT',
#  'DIRECTED VERDICT',
#  'DIRECT ESTOPPEL',
#  'DIRECT ESTOPPEL',
#  'DIRECT EXAMINATION',
#  'DIRECT EXAMINATION',
#  'DIRECTOR',
#  'DIRECT ORDER OF ALIENATION',
#  'DIRECT ORDER OF ALIENATION',
#  'DISABILITY',
#  'DISBAR',
#  'DISCHARGE',
#  'DISCHARGE IN BANKRUPTCY',
#  'SUSPENDED SENTENCE',
#  'CONDITIONAL DISCHARGE',
#  'UNCONDITIONAL DISCHARGE',
#  'DISCLAIMER',
#  'DISCLAIMER OF LIABILITY',
#  'DISCONTINUANCE',
#  'DISCOUNT',
#  'EXAMPLE',
#  'DISCOUNT BOND',
#  'BOND DISCOUNT',
#  'DISCOUNTED CASH FLOW',
#  'DISCOVERY',
#  'EXAMPLE',
#  'DISCRETION',
#  'ABUSE OF DISCRETION',
#  'JUDICIAL DISCRETION',
#  'EXAMPLE',
#  'LEGAL DISCRETION',
#  'PROSECUTORIAL DISCRETION',
#  'DISCRETIONARY ACCOUNT',
#  'DISCRIMINATION',
#  'DISHONOR',
#  'DISINHERITANCE',
#  'DISINTERMEDIATION',
#  'DISJUNCTIVE ALLEGATIONS',
#  'DISMISS',
#  'DISMISSAL',
#  'DISMISSAL WITH PREJUDICE',
#  'EXAMPLE',
#  'DISMISSAL WITHOUT PREJUDICE',
#  'DISORDERLY CONDUCT',
#  'DISPARAGEMENT',
#  'DISPOSITION',
#  'DISPOSSESS',
#  'DISPUTABLE PRESUMPTION',
#  'REBUTTABLE PRESUMPTION',
#  'DISQUALIFICATION',
#  'DISSEISIN',
#  'DISSENT',
#  'DISSENTING OPINION',
#  'DISSENTING OPINION',
#  'DISSOLUTION',
#  'DISTINGUISH',
#  'DISTRAINT',
#  'DISTRESS',
#  'DISTRAINT',
#  'DISTRAINER',
#  'EXAMPLE',
#  'LANDLORD',
#  'S LIEN',
#  'DISTRESS',
#  'EMOTIONAL',
#  'DISTRIBUTION',
#  'EXAMPLE',
#  'DISTRICT ATTORNEY',
#  'UNITED STATES ATTORNEYS',
#  'DISTRICT COURT',
#  'U.S. C',
#  'DISTURBANCE OF THE PEACE',
#  'DIVERS',
#  'DIVERSIONARY PROGRAMS',
#  'P.T.I.',
#  'DIVERSIONARY PROGRAMS',
#  'DIVERSITY JURISDICTION',
#  'DIVERSITY OF CITIZENSHIP',
#  'DIVESTITURE',
#  'EXAMPLE',
#  'DIVIDEND',
#  'CUMULATIVE DIVIDEND',
#  'DIVIDEND ADDITION',
#  'EXTRAORDINARY DIVIDENDS',
#  'LIQUIDATION DIVIDEND',
#  'PREFERRED DIVIDEND',
#  'SCRIP DIVIDEND',
#  'STOCK DIVIDEND',
#  'DIVISIBLE CONTRACT',
#  'DIVORCE',
#  'FAULT DIVORCE',
#  'SEPARATION',
#  'OR DIVORCE A MENSA ET THORO',
#  'DNA TESTING',
#  'DNA',
#  'DNA',
#  'DNA',
#  'DNA',
#  'DNA',
#  'DNA. DNA',
#  'DNA',
#  'DNA',
#  'DNA',
#  'DNA',
#  'RFLP',
#  'PCR. RFLP',
#  'DNA',
#  'DNA',
#  'PCR',
#  'RFLP. PCR',
#  'PCR',
#  'DNA',
#  'HLA DQ ALPHA',
#  'DQ A',
#  'PCR',
#  'HLA',
#  'DQ A',
#  'DNA',
#  'DOB',
#  'DOCKET',
#  'DOCTOR',
#  'PATIENT PRIVILEGE',
#  'DOCTRINE OF WORTHIER TITLE',
#  'DOCUMENT',
#  'DOCUMENTARY EVIDENCE',
#  'DOCUMENT OF TITLE',
#  'DOCUMENT',
#  'ORIGINAL',
#  'DOLUS',
#  'DOMAIN',
#  'DOMESDAY BOOK',
#  'DOMICILE',
#  'EXAMPLE',
#  'DOMICILIARY',
#  'DOMINANT ESTATE',
#  'OR TENEMENT',
#  'DOMINION',
#  'DONATED SURPLUS',
#  'DONATED SURPLUS',
#  'DONATIO L',
#  'DONATION',
#  'DONATIVE INTENT',
#  'DONEE',
#  'DONEE BENEFICIARY',
#  'DONEE BENEFICIARY',
#  'DONOR',
#  'DOUBLE DAMAGES',
#  'DOUBLE',
#  'TREBLE',
#  'DAMAGES',
#  'DOUBLE JEOPARDY',
#  'U.S. C',
#  'EXAMPLE',
#  'COLLATERAL ESTOPPEL',
#  'DOUBT',
#  'DOWAGER',
#  'DOWER',
#  'DOWRY',
#  'DQ ALPHA',
#  'DNA',
#  'HLA DQ ALPHA',
#  'DRAFT',
#  'BILL OF EXCHANGE',
#  'DRAWING',
#  'SIGHT DRAFT',
#  'DRAM SHOPACT',
#  'EXAMPLE',
#  'DRAW',
#  'DRAWEE',
#  'BILL OF EXCHANGE',
#  'DRAWER',
#  'BILL OF EXCHANGE',
#  'DRIVING WHILE INTOXICATED',
#  'D.W.I.',
#  'DROIT F',
#  'DRUG ABUSE',
#  'DRUG LAW',
#  'GENERIC DRUG LAW',
#  'DRUGS',
#  'DUAL CITIZENSHIP',
#  'DUCES TECUM',
#  'SUBPOENA DUCES TECUM',
#  'DUE CARE',
#  'EXAMPLE',
#  'DUE COURSE',
#  'DUE DATE',
#  'DUE PROCESS OF LAW',
#  'U.S. C',
#  'SUBSTANTIVE',
#  'DUE PROCESS',
#  'PROCEDURAL DUE PROCESS',
#  'EXAMPLE',
#  'D.U.I.',
#  'D.W.I.',
#  'DUMMY',
#  'DUMMY CORPORATION',
#  'DUMMY DIRECTOR',
#  'DUMMY SHAREHOLDER',
#  'DUMPING',
#  'ANTIDUMPING LAW',
#  'DUPLICITOUS',
#  'DUPLICITY',
#  'DURESS',
#  'EXAMPLE',
#  'DURHAM RULE',
#  'DUTY',
#  'DUTY OF CARE',
#  'DELEGABLE DUTY',
#  'DUTY',
#  'LEGAL',
#  'DUTY OF PRODUCING EVIDENCE',
#  'DUTY TO MITIGATE DAMAGES',
#  'DWELLING HOUSE',
#  'D.W.I.',
#  'DYING DECLARATIONS',
#  'DYING DECLARATIONS',
#  'EEARNEST',
#  'EARNINGS AND PROFITS',
#  'ACCUMULATED EARNINGS AND PROFITS',
#  'CURRENT EARNINGS AND PROFITS',
#  'EARNINGS REPORT',
#  'EASEMENT',
#  'EASEMENT APPURTENANT',
#  'EASEMENT IN',
#  'GROSS',
#  'EASEMENT IN GROSS',
#  'EASEMENT OF NECESSITY',
#  'IMPLIED EASEMENT',
#  'QUASI EASEMENT',
#  'NEGATIVE EASEMENT',
#  'PRESCRIPTIVE EASEMENT',
#  'EASEMENT BY PRESCRIPTION',
#  'PUBLIC EASEMENT',
#  'RECIPROCAL NEGATIVE EASEMENTS',
#  'EXAMPLE',
#  'EAVESDROPPING',
#  'ECCLESIASTICAL LAW',
#  'ECU',
#  'E.E.O.C.',
#  'EFFECTS',
#  'PERSONAL',
#  'EGRESS',
#  'EIGHTH AMENDMENT',
#  'EIS',
#  'EIR',
#  'EJECTMENT',
#  'EJUSDEM GENERIS',
#  'EXAMPLE',
#  'ELECTION',
#  'ELECTION OF REMEDIES',
#  'ELECTION UNDER THE WILL',
#  'ELECTION',
#  'WIDOW',
#  'ELECTIVE FRANCHISE',
#  'ELECTIVE FRANCHISE',
#  'ELECTIVE SHARE',
#  'ELEGIT',
#  'ELEGIT',
#  'ELEMENT',
#  'ELEMENTS',
#  'ELEVENTH AMENDMENT',
#  'U.S. C',
#  'EMANCIPATION',
#  'EMBEZZLEMENT',
#  'EXAMPLE',
#  'EMBLEMENTS',
#  'EMBRACERY',
#  'JURYTAMPERING. S',
#  'EMINENT DOMAIN',
#  'EMOLUMENT',
#  'EMOTIONAL DISTRESS',
#  'INTENTIONAL INFLICTION OF EMOTIONAL',
#  'DISTRESS',
#  'NEGLIGENT INFLICTION OF EMOTIONAL DISTRESS',
#  'HIV',
#  'EMPLOYEE SHARE OWNERSHIP PLAN',
#  'ESOP',
#  'EMPLOYEE STOCK OPTION',
#  'EMPLOYER',
#  'S LIABILITY ACTS',
#  'EMPLOYMENT RETIREMENT INCOME SECURITYACT OF',
#  'ERISA',
#  'ENABLING CLAUSE',
#  'EXAMPLE',
#  'ENACTING CLAUSE',
#  'EN BANC',
#  'REHEARING EN BANC',
#  'ENCLOSURE',
#  'CLOSE.ENCROACH',
#  'ENCUMBRANCE',
#  'EXAMPLE',
#  'ENDORSEMENT',
#  'ENDOWMENT',
#  'ENFEOFF',
#  'EN GROS',
#  'ENJOIN',
#  'EXAMPLE',
#  'ENJOYMENT',
#  'COVENANT OF QUIET ENJOYMENT',
#  'ENLARGEMENT',
#  'ENRICHMENT',
#  'ENTAIL',
#  'ENTIRETY',
#  'TENANCY BY THE ENTIRETY',
#  'ENTITY',
#  'ENTRAPMENT',
#  'AFFIRMATIVE DEFENSE',
#  'EXAMPLE',
#  'ENTRY',
#  'FORCIBLE',
#  'ENTRY',
#  'UNLAWFUL',
#  'ENUMERATED POWERS',
#  'ENURE',
#  'EN VENTRE SA MERE',
#  'ENVIRONMENTAL IMPACT STATEMENT',
#  'REPORT',
#  'ENVIRONMENTAL PROTECTION AGENCY',
#  'EPA',
#  'EO INSTANTI',
#  'EPA',
#  'EQUAL EMPLOYMENT OPPORTUNITY COMMISSION',
#  'EEOC',
#  'EQUALITY',
#  'EQUAL OPPORTUNITY',
#  'VII',
#  'VII',
#  'EQUAL EMPLOYMENT OPPORTUNITY COMMISSION',
#  'EEOC',
#  'EQUAL PROTECTION OF THE LAWS',
#  'U.S. C',
#  'EXAMPLE',
#  'EQUAL RIGHTS AMENDMENT',
#  'E.R.A.',
#  'EQUAL TIME ACT',
#  'RULE',
#  'EQUITABLE',
#  'EQUITABLE DISTRIBUTION',
#  'EQUITABLE DEFENSE',
#  'EQUITABLE DISTRIBUTION',
#  'EQUITABLE EASEMENT',
#  'EQUITABLE ESTATE',
#  'EQUITABLE ESTOPPEL',
#  'ESTOPPEL IN PAIS',
#  'EQUITABLE RECOUPMENT',
#  'EQUITABLE RELIEF',
#  'EQUITABLE SEISIN',
#  'EQUITABLE SERVITUDE',
#  'PRIVITY OF ESTATE',
#  'CONSTRUCTIVE NOTICE',
#  'EQUITABLE TITLE',
#  'EQUITY',
#  'EQUITY MARKET',
#  'EQUITY CAPITAL',
#  'EQUITY OF REDEMPTION',
#  'E.R.A.',
#  'E.R.A.',
#  'ERGO L',
#  'ERISA',
#  'EMPLOYMENT RETIREMENT INCOME SECURITY ACT OF',
#  'ERRONEOUS',
#  'ERRONEOUS JUDGMENT',
#  'ERROR',
#  'ERROROF LAW',
#  'ESCALATOR CLAUSE',
#  'ESCAPE CLAUSE',
#  'EXAMPLE',
#  'ESCHEAT',
#  'ESCROW',
#  'ESCROW AGENT',
#  'ESOP',
#  'ESOP',
#  'ESQUIRE',
#  'ESQ.',
#  'ESSENCE',
#  'ESTABLISHMENT CLAUSE',
#  'U.S. C',
#  'ESTATE',
#  'CONTINGENT ESTATE',
#  'DOMINANT ESTATE',
#  'EQUITABLE ESTATE',
#  'FUTURE ESTATE',
#  'LEGAL ESTATE',
#  'PRECEDING ESTATE',
#  'SERVIENT ESTATE',
#  'VESTED ESTATE',
#  'PRECEDING ESTATE',
#  'ESTATE AT SUFFERANCE',
#  'TENANCY AT SUFFERANCE',
#  'ESTATE AT WILL',
#  'TENANCY AT WILL',
#  'ESTATE BY THE ENTIRETY',
#  'TENANCY BY THE ENTIRETY',
#  'ESTATE FOR LIFE',
#  'ESTATE FOR YEARS',
#  'TENANCY FOR YEARS',
#  'ESTATE FROM YEAR TO YEAR',
#  'PERIODIC TENANCY',
#  'ESTATE IN COMMON',
#  'TENANCY IN COMMON',
#  'ESTATE IN COPARCENARY',
#  'ESTATE OF INHERITANCE',
#  'ESTATE PER AUTRE VIE',
#  'ESTATE TAX',
#  'ESTOPPEL',
#  'EXAMPLE',
#  'AUTHORITY BY ESTOPPEL',
#  'COLLATERAL ESTOPPEL',
#  'DIRECT ESTOPPEL',
#  'ESTOPPEL BY DEED',
#  'ESTOPPEL BY JUDGMENT',
#  'ESTOPPEL BY JUDGMENT',
#  'ESTOPPEL BY LACHES',
#  'ESTOPPEL IN PAIS',
#  'EQUITABLE ESTOPPEL',
#  'MUTUALITY OF ESTOPPEL',
#  'PROMISSORY ESTOPPEL',
#  'ESTOVERS',
#  'ET AL.',
#  'ETHICAL',
#  'ET NON',
#  'ET SEQ.',
#  'ET UX.',
#  'EURODOLLAR',
#  'U.S.',
#  'EUTHANASIA',
#  'EVASION OF TAX',
#  'EXAMPLE',
#  'EVASIVE ANSWER',
#  'EVICTION',
#  'CONSTRUCTIVE EVICTION',
#  'PARTIAL ACTUAL EVICTION',
#  'EVIDENCE',
#  'EVIDENCE ALIUNDE',
#  'EVIDENCE DE BENE ESSE',
#  'EX AEQUO ET BONO',
#  'EXAMINATION',
#  'DIRECT EXAMINATION',
#  'EXCEPTION',
#  'EXCESSIVE BAIL',
#  'EXCHANGE',
#  'BARTER.EXCHANGE',
#  'LIKE',
#  'KIND',
#  'EXCHEQUER',
#  'EXCISE',
#  'EXAMPLE',
#  'EXCLUSION',
#  'GROSS INCOME',
#  'EXCLUSIONARY RULE',
#  'EXAMPLE',
#  'EXCLUSIVE USE',
#  'EXCLUSIVE USE',
#  'EX CONTRACTU',
#  'EXCULPATORY',
#  'EXCULPATORY CLAUSE',
#  'EXCUSABLE NEGLECT',
#  'DATE',
#  'DIVIDEND DATE',
#  'EX DELICTO',
#  'DIVIDEND',
#  'PAYMENT DATE',
#  'DIVIDEND DATE',
#  'DATE',
#  'EXECUTE',
#  'EXECUTED',
#  'EXECUTED INTEREST',
#  'EXECUTED INTEREST',
#  'EXECUTION',
#  'EXECUTION OF INSTRUMENT',
#  'EXECUTION SALE',
#  'JUDICIAL SALE',
#  'EXECUTIVE AGREEMENT',
#  'EXECUTIVE CLEMENCY',
#  'EXECUTIVE ORDER',
#  'EXECUTIVE PARDON',
#  'EXECUTIVE PRIVILEGE',
#  'EXECUTIVE PROCLAMATION',
#  'PRESIDENTIAL PROCLAMATION',
#  'EXECUTOR',
#  'OR EXECUTRIX',
#  'EXAMPLE',
#  'EXECUTORY',
#  'EXECUTORY CONTRACT',
#  'EXECUTORY BEQUEST',
#  'EXECUTORY BEQUEST',
#  'EXECUTORY INTEREST',
#  'EXECUTORY INTEREST',
#  'EXECUTORY WAIVER',
#  'EXECUTORY WAIVER',
#  'EXEMPLAR',
#  'EXEMPLARY DAMAGES',
#  'EXEMPLARY',
#  'PUNITIVE',
#  'DAMAGES',
#  'EXEMPT',
#  'EXEMPTION',
#  'EXAMPLE',
#  'EX GRATIA',
#  'EXHAUSTION OF REMEDIES',
#  'EXHAUSTION OF ADMINISTRATIVE REMEDIES',
#  'EXHAUSTION OF STATE REMEDIES',
#  'EXHIBIT',
#  'EXIGENCY',
#  'EXIGENT CIRCUMSTANCES',
#  'EXIGIBLE',
#  'EXILE',
#  'OFFENDER',
#  'EX OFFICIO',
#  'EX OFFICIO MEMBER',
#  'EX OFFICIO SERVICES',
#  'EX PARTE',
#  'EXAMPLE',
#  'EXPECTANCY',
#  'EXPECTATION DAMAGES',
#  'EXPECTATION DAMAGES',
#  'EXPENSE',
#  'CAPITAL EXPENDITURES',
#  'EXPERT TESTIMONY',
#  'OR EVIDENCE',
#  'EXPERT WITNESS',
#  'EXPERT EVIDENCE',
#  'EXPERT TESTIMONY',
#  'EXPORT',
#  'EX POST FACTO',
#  'EXAMPLE',
#  'EXPRESS',
#  'EXPRESSIO UNIUS EST EXCLUSIO ALTERIUS',
#  'EXPRESS POWERS',
#  'EXPRESS WARRANTY',
#  'EXPRESS WARRANTIES',
#  'EXPROPRIATION',
#  'EXPULSION',
#  'EXPULSION',
#  'EXPUNGEMENT OF RECORDS',
#  'EX REL',
#  'RELATOR. T',
#  'RIGHTS',
#  'EXTENSION',
#  'EXTENUATING CIRCUMSTANCES',
#  'EXTINGUISHMENT',
#  'EXAMPLE',
#  'EXTORTION',
#  'EXAMPLE',
#  'EXTRADITION',
#  'EXTRAJUDICIAL',
#  'EXTRAORDINARY DIVIDENDS',
#  'EXTRAORDINARY DIVIDENDS',
#  'EXTRAORDINARY REMEDY',
#  'EXTRAORDINARY REMEDY',
#  'EXTREMIS',
#  'EXTRINSIC EVIDENCE',
#  'EXTRINSIC FRAUD',
#  'EXTRINSIC',
#  'COLLATERAL',
#  'FRAUD',
#  'EX TURPI CAUSA NON ORITUR ACTIO',
#  'EYEWITNESS',
#  'FFAA',
#  'FAA',
#  'FACE VALUE',
#  'FACIAL INVALIDITY',
#  'FACILITATION',
#  'EXAMPLE',
#  'FACINUS QUOS INQUINAT AEQUAT',
#  'FACT',
#  'FACTA SUNT PROTENTIORI VERBIS',
#  'FACT FINDER',
#  'TRIER OF FACT',
#  'FACTO L',
#  'FACTOR',
#  'FACTORAGE). H',
#  'FACTOR',
#  'S ACTS',
#  'FACT',
#  'QUESTION OF',
#  'FACTS',
#  'PROBATIVE',
#  'PROBATIVE FACTS',
#  'FACTUAL IMPOSSIBILITY',
#  'FACTUM L',
#  'FACTUM PROBANDUM',
#  'FAILURE OF CONSIDERATION',
#  'FAILURE OF ISSUE',
#  'INDEFINITE',
#  'FAILURE OF ISSUE',
#  'DEFINITE FAILURE OF ISSUE',
#  'FAILURE TO PROSECUTE',
#  'FAIR COMMENT',
#  'FAIR COMPETITION',
#  'FAIR HEARING',
#  'FAIR LABOR PRACTICE',
#  'FAIR MARKET VALUE',
#  'FAIRNESS DOCTRINE',
#  'FAIR TRADE LAWS',
#  'FAIR USE',
#  'EXAMPLE',
#  'FALSE ARREST',
#  'FALSE IMPRISONMENT',
#  'FALSE OATH',
#  'FALSE PRETENSE',
#  'MISREPRESENTATION.EXAMPLE',
#  'FALSE RETURN',
#  'FALSE SWEARING',
#  'FALSE VERDICT',
#  'FALSI CRIMEN',
#  'FAMILY',
#  'WIDOW',
#  'ALLOWANCE',
#  'FAMILY',
#  'CRIMINAL',
#  'FAMILY PURPOSE DOCTRINE',
#  'EXAMPLE',
#  'FAMOSUS LIBELLUS',
#  'FANNIE MAE',
#  'FANNIE MAE',
#  'F.A.S.',
#  'FATAL VARIANCE',
#  'FAULT',
#  'FAVORED BENEFICIARY',
#  'FBI',
#  'FBI',
#  'F.C.I.',
#  'FEDERAL CORRECTIONAL INSTITUTION (F.C.I.',
#  'F.D.A.',
#  'F.D.A.',
#  'FEALTY',
#  'FEATHERBEDDING',
#  'FEDERAL AVIATION ADMINISTRATION',
#  'FAA',
#  'U.S. D',
#  'FEDERAL BUREAU OF INVESTIGATION',
#  'FBI',
#  'U.S. D',
#  'U.S.',
#  'FEDERAL COMMON LAW',
#  'U.S.',
#  'FEDERAL CORRECTIONAL FACILITY',
#  'FEDERAL CORRECTIONAL INSTITUTION',
#  'FEDERAL COURTS',
#  'COURT OF',
#  'CUSTOMS AND PATENT APPEALS',
#  'CUSTOMS COURT',
#  'FEDERAL EMPLOYERS',
#  'LIABILITY ACT',
#  'FEDERAL INSURANCE CONTRIBUTION ACT',
#  'F.I.C.A.',
#  'FEDERALISM',
#  'EXAMPLE',
#  'FEDERAL MAGISTRATE',
#  'UNITED STATES',
#  'FEDERAL',
#  'MAGISTRATE',
#  'FEDERAL MAGISTRATE',
#  'S ACT OF',
#  'FEDERAL MAGISTRATE',
#  'S ACT OF',
#  'FEDERAL QUESTION JURISDICTION',
#  'FEDERAL RESERVE SYSTEM',
#  'FEDERAL TORT CLAIMS ACT',
#  'FEDERAL TRADE COMMISSION',
#  'FTC',
#  'FEDERAL TRADE COMMISSION IMPROVEMENT ACT',
#  'FEE',
#  'FEE SIMPLE ABSOLUTE',
#  'EXAMPLE',
#  'FEE SIMPLE',
#  'FEE SIMPLE ABSOLUTE',
#  'FEE SIMPLE CONDITIONAL',
#  'FEE SIMPLE DEFEASIBLE',
#  'FEE SIMPLE DETERMINABLE',
#  'FEE TAIL',
#  'FEE TAIL MALE',
#  'FEE TAIL FEMALE',
#  'FELA',
#  'FELLOW SERVANTS',
#  'FELLOW SERVANT RULE',
#  'FELONY',
#  'FELONY',
#  'MISPRISION OF',
#  'FELONY MURDER',
#  'EXAMPLE',
#  'FENCE',
#  'FEOFFMENT',
#  'FERAE NATURAE',
#  'FERTILE OCTOGENARIAN',
#  'FEUDALISM',
#  'FIAT JUSTITIA',
#  'F.I.C.A.',
#  'FEDERAL INSURANCE CONTRIBUTION ACT',
#  'FICTION',
#  'LEGAL',
#  'FIDUCIARY',
#  'FIERI FACIAS L',
#  'ELEGIT L',
#  'EXTENDI FACIAS',
#  'LEVARI FACIAS',
#  'FIFO',
#  'FIFTEENTH AMENDMENT',
#  'FIFTH AMENDMENT',
#  'U.S. C',
#  'FIGHTING WORDS',
#  'FIGURE',
#  'FILE',
#  'FILIBUSTER',
#  'FILIBUSTER',
#  'FILING',
#  'FILING',
#  'FINAL DECISION',
#  'OR DECREE OR JUDGMENT',
#  'FINAL DECREE',
#  'FINAL DECREES',
#  'FINAL HEARING',
#  'FINAL HEARING',
#  'FINAL JUDGMENT',
#  'FINAL ORDER',
#  'FINANCE CHARGES',
#  'FINANCIAL INTERMEDIARY',
#  'REIT',
#  'FINANCIAL RESPONSIBILITY LAWS',
#  'FINANCIAL STATEMENT',
#  'FINDER OF FACT',
#  'FINDER',
#  'S FEE',
#  'FINDING',
#  'FINE',
#  'FINGERPRINT',
#  'AFIS (A',
#  'DNA',
#  'DNA',
#  'DNA',
#  'FIRM OFFER',
#  'EXAMPLE',
#  'FIRST AMENDMENT',
#  'FIRST',
#  'DEGREE MURDER',
#  'FIRST',
#  'DEGREE MURDER',
#  'FIRST DEVISEE',
#  'FIRST IMPRESSION',
#  'FIRST',
#  'FIRST',
#  'OUT',
#  'FIFO',
#  'FIFO',
#  'LAST',
#  'FIRST',
#  'OUT',
#  'LIFO',
#  'FISC',
#  'FISCAL',
#  'FISC).FISCAL POLICY',
#  'FISCAL YEAR',
#  'FIT',
#  'FITNESS',
#  'WARRANTY OF FITNESS',
#  'FIXED ASSETS',
#  'FIXED CAPITAL',
#  'FIXED INCOME',
#  'FIXED INVESTMENT TRUST',
#  'FIXED SALARY',
#  'FIXING',
#  'PRICE',
#  'FIXTURE',
#  'EXAMPLE',
#  'TRADE FIXTURE',
#  'FLIGHT',
#  'FLOAT',
#  'FLOATING DEBT',
#  'FUNDED DEBT',
#  'F.O.B.',
#  'F.O.I.A.',
#  'FOOD AND DRUG ADMINISTRATION',
#  'FDA',
#  'FORBEAR',
#  'FORBEARANCE',
#  'EXAMPLE',
#  'FORCE',
#  'DEADLY FORCE',
#  'UNLAWFUL FORCE',
#  'FORCED HEIRS',
#  'FORCED SALE',
#  'FORCIBLE DETAINER',
#  'UNLAWFUL DETAINER',
#  'FORCIBLE ENTRY',
#  'UNLAWFUL DETAINER',
#  'FORCIBLE ENTRYAND DETAINER',
#  'FORECLOSURE',
#  'JUDICIAL SALE',
#  'FORCEDSALE',
#  'FOREMAN',
#  'FOREPERSON',
#  'OF JURY',
#  'FORENSIC',
#  'FORENSIC MEDICINE',
#  'FORESEEABILITY',
#  'FORESEEABLE RISK',
#  'EXAMPLE',
#  'FORFEITURE',
#  'FORGERY',
#  'FORM',
#  'FORMAL CONTRACT',
#  'FORMA PAUPERIS',
#  'FORMS OF ACTION',
#  'FORNICATION',
# ...
#  'SUBSIDIARY',
#  'SUBSIDIARY CORPORATION',
#  'PARENT CORPORATION',
#  'SUB SILENTIO',
#  'EXAMPLE',
#  'SUBSTANTIAL COMPLIANCE',
#  'SUBSTANTIAL PERFORMANCE',
#  'COMPLIANCE',
#  'EXAMPLE',
#  'BREACH OF CONTRACT',
#  'SUBSTANTIVE DUE PROCESS',
#  'SUBSTANTIVE LAW',
#  'SUBSTITUTED BASIS',
#  'SUBSTITUTED BASIS',
#  'SUBSTITUTED SERVICE',
#  'SUBSTITUTED SERVICE',
#  'SUBSTITUTION',
#  'SUBTENANT',
#  'EXAMPLE',
#  'ASSIGNMENT OF A LEASE',
#  'SUCCESSION',
#  'SUCCESSIVE TERMS',
#  'SUCCESSOR',
#  'SUCCESSOR ADMINISTRATOR',
#  'SUCCESSOR ADMINISTRATOR',
#  'SUE OUT',
#  'SUICIDE',
#  'EXAMPLE',
#  'SUI GENERIS',
#  'SUI JURIS',
#  'SUIT',
#  'CLASS SUIT',
#  'STOCKHOLDERS',
#  'DERIVATIVE SUIT',
#  'SUITOR',
#  'SUM CERTAIN',
#  'EXAMPLE',
#  'SUMMARY COURT',
#  'MARTIAL',
#  'COURT',
#  'MARTIAL',
#  'SUMMARY JUDGMENT',
#  'EXAMPLE',
#  'SUMMARY PROCEEDING',
#  'SUMMATION',
#  'SUMMING UP',
#  'CLOSING ARGUMENTS',
#  'PROSECUTORIAL',
#  'MISCONDUCT',
#  'SUMMONS',
#  'EXAMPLE',
#  'SUNDAY CLOSING LAWS',
#  'SUNSHINE LAWS',
#  'OPEN PUBLIC MEETING LAWS',
#  'SUO NOMINE',
#  'SUPERIOR COURT',
#  'SUPERIOR COURT',
#  'SUPERSEDEAS L',
#  'SUPERSEDING CAUSE',
#  'SUPERSEDING CAUSE',
#  'SUPERVENING CAUSE',
#  'INTERVENING',
#  'SUPERVENING',
#  'CAUSE',
#  'SUPPLEMENTAL',
#  'SUPPLEMENTAL ACT',
#  'SUPPLEMENTAL AFFIDAVIT',
#  'SUPPLEMENTAL ANSWER',
#  'SUPPLEMENTAL BILL',
#  'SUPPLEMENTAL CLAIM',
#  'SUPPLEMENTAL PLEADING',
#  'COMPLAINT',
#  'SUPPLEMENTAL PLEADING',
#  'SUPPLEMENTAL PROCEEDING',
#  'SUPPLEMENTARY SECURITY INCOME',
#  'SUPPLEMENTARY SECURITY INCOME',
#  'SUPPORT',
#  'SUPPRESS',
#  'SUPPRESSION OF EVIDENCE',
#  'U.S. S',
#  'SUPRA L',
#  'SUPREMACY CLAUSE',
#  'EXAMPLE',
#  'SUPREME COURT',
#  'U.S.',
#  'SUPREME COURT OF APPEALS',
#  'SUPREME COURT OF ERRORS',
#  'SUPREME JUDICIAL COURT',
#  'SURCHARGE',
#  'SURTAX',
#  'SURETY',
#  'EXAMPLE',
#  'SURETY BOND',
#  'SURETY BOND',
#  'SURPLUS',
#  'EARNED SURPLUS',
#  'PAID',
#  'IN SURPLUS',
#  'PAR VALUE',
#  'SURREBUTTER',
#  'SURREJOINDER',
#  'SURRENDER',
#  'TENANCY FOR YEARS',
#  'SURROGATE',
#  'EXAMPLE',
#  'SURROGATE MOTHER',
#  'SURROGATE PARENT',
#  'SURROGATE',
#  'S COURT',
#  'SURROGATE',
#  'S COURT',
#  'SURTAX',
#  'SURVEILLANCE',
#  'SURVIVAL STATUTE',
#  'SURVIVORSHIP',
#  'JOINT TENANCY',
#  'EXAMPLE',
#  'SUSPECT',
#  'SUSPECT CLASSIFICATION',
#  'SUSPENDED SENTENCE',
#  'SUSTAIN',
#  'SWEARING',
#  'FALSE',
#  'SWEEPSTAKES',
#  'SWEEPSTAKES',
#  'SWITCH',
#  'SYLLABUS',
#  'SYMBOLIC DELIVERY',
#  'SYMBOLIC DELIVERY',
#  'SYMBOLIC SPEECH',
#  'SYNDICATE',
#  'EXAMPLE',
#  'TTACIT',
#  'TACKING',
#  'TAFT',
#  'HARTLEY ACT',
#  'EXAMPLE',
#  'TAIL',
#  'TAIL',
#  'ESTATE IN',
#  'TAINTED EVIDENCE',
#  'TAINT',
#  'TAKING THE FIFTH',
#  'TANGIBLE PROPERTY',
#  'TARGET CORPORATION',
#  'TARGET CORPORATION',
#  'TARGETED JOBS CREDIT',
#  'TARGETED JOBS CREDIT',
#  'TAX',
#  'AD VALOREM TAX',
#  'VALUE ADDED TAX',
#  'CAPITAL GAINS TAX',
#  'CAPITAL ASSETS',
#  'ESTATE TAX',
#  'TRANSFER TAX',
#  'ESTIMATED TAX',
#  'EXCISE TAX',
#  'FRANCHISE TAX',
#  'EXAMPLE',
#  'INCOME TAX',
#  'POLL TAX',
#  'PROGRESSIVE TAX',
#  'PROPERTY TAX',
#  'REGRESSIVE TAX',
#  'SALES TAX',
#  'UNIFIED ESTATE AND GIFT TAX',
#  'USE TAX',
#  'EXAMPLE',
#  'VALUE ADDED TAX',
#  'AD VALOREM TAX',
#  'WITHHOLDING TAX',
#  'TAXABLE ESTATE',
#  'ESTATE TAX',
#  'TAXABLE GIFT',
#  'TAXABLE INCOME',
#  'ZERO BRACKET AMOUNT',
#  'TAXABLE YEAR',
#  'TAX BENEFIT DOCTRINE',
#  'GROSS INCOME',
#  'TAX COURT',
#  'D.C.',
#  'TAX CREDIT',
#  'INVESTMENT TAX CREDIT',
#  'TAX DEDUCTION',
#  'TAX EVASION',
#  'TAX EXEMPT',
#  'TAX EXPENDITURE',
#  'TAX EXPENDITURE BUDGET',
#  'TAXING POWER',
#  'U.S. C',
#  'TAXPAYER',
#  'TAX PREFERENCE ITEMS',
#  'GROSS INCOME',
#  'TAX RATE',
#  'MARGINAL TAX RATE',
#  'EFFECTIVE TAX RATE',
#  'PROGRESSIVE TAX',
#  'TAX RETURN',
#  'TAX SALE',
#  'TAX SALE',
#  'TAX SHELTER',
#  'EXAMPLE',
#  'TEMPORARY',
#  'TEMPORARY INJUNCTION',
#  'TEMPORARY RESTRAINING ORDER',
#  'TEMPORE L',
#  'TENANCY',
#  'HOLDOVER TENANCY',
#  'TENANCY AT SUFFERANCE',
#  'JOINT TENANCY',
#  'PERIODIC TENANCY',
#  'TENANCY FOR',
#  'YEARS',
#  'TENANCY AT',
#  'WILL',
#  'TENANCY AT SUFFERANCE',
#  'HOLDOVER TENANCY',
#  'TENANCY AT WILL',
#  'EXAMPLE',
#  'TENANCY AT WILL',
#  'TENANCY BY THE ENTIRETY',
#  'MARRIED WOMAN',
#  'S ACTS',
#  'TENANCY FOR YEARS',
#  'TENANCY AT SUFFERANCE',
#  'TENANCY AT WILL',
#  'PERIODIC TENANCY',
#  'TENANCY FROM MONTH TO MTH',
#  'PERIODIC TENANCY',
#  'TENANCY FROM YEAR TO YEAR',
#  'PERIODIC TENANCY',
#  'TENANCY IN COMMON',
#  'TENANT',
#  'TENANTABLE REPAIR',
#  'TENANT FOR LIFE',
#  'TENANT IN FEE (SIMPLE',
#  'TENANTS IN TAIL',
#  'TENANTS IN TAIL',
#  'TENDER',
#  'LEGAL TENDER',
#  'TENDER OFFER',
#  'TENDER OF DELIVERY',
#  'EXAMPLE',
#  'TENDER OFFER',
#  'TENEMENT',
#  'TENTH AMENDMENT',
#  'U.S. C',
#  'RESERVED POWERS AMENDMENT',
#  'TENURE',
#  'TENURIAL OWNERSHIP',
#  'TERMINABLE INTEREST',
#  'TERMINER',
#  'TERM INSURANCE',
#  'TERM INSURANCE',
#  'TERM OF ART',
#  'TERM OF COURT',
#  'TERRITORIAL COURT',
#  'TERRITORIAL JURISDICTION',
#  'TERRITORIAL WATERS',
#  'TERROREM',
#  'TESTACY',
#  'TESTAMENT',
#  'TESTAMENTARY CAPACITY',
#  'TESTAMENTARY DISPOSITION',
#  'EXAMPLE',
#  'TESTAMENTARY INTENT',
#  'TESTATRIX',
#  'TESTAMENTARY TRUST',
#  'TESTATOR',
#  'TESTATRIX',
#  'TEST CASE',
#  'ACTION',
#  'CASE OR CONTROVERSY',
#  'TESTIFY',
#  'TESTIMONIAL IMMUNITY',
#  'TESTIMONIAL',
#  'USE',
#  'IMMUNITY',
#  'TESTIMONY',
#  'THEFT',
#  'THING IN ACTION',
#  'CHOSE IN ACTION',
#  'THIRD PARTY',
#  'THIRD PARTY BENEFICIARY',
#  'DONEE BENEFICIARY',
#  'CREDITOR BENEFICIARY',
#  'THIRD PARTYPLAINTIFF',
#  'THIRD PARTY PLAINTIFF',
#  'THIRTEENTH AMENDMENT',
#  'PEONAGE',
#  'THREAT',
#  'THRIFT INSTITUTIONS',
#  'TIDE LAND',
#  'TIME',
#  'TIME ARBITRAGE',
#  'TIME ARBITRAGE',
#  'TIME DRAFT',
#  'TIME DRAFT',
#  'TIME IS OF THE ESSENCE',
#  'TIME SHARING',
#  'INTERVAL OWNERSHIP',
#  'EXAMPLE',
#  'TIME',
#  'UNITY OF',
#  'UNITY OF TIME',
#  'TITHE',
#  'TITLE',
#  'EXAMPLE',
#  'ADVERSE TITLE',
#  'CLEAR TITLE',
#  'CLEAR TITLE OF RECORD',
#  'COLOR OF TITLE',
#  'EQUITABLE TITLE',
#  'MARKETABLE TITLE',
#  'QUIET TITLE',
#  'TITLE',
#  'OF A STATUTE',
#  'TITLE JURISDICTION',
#  'TITLE SEARCH',
#  'TITLE THEORY',
#  'TOLL',
#  'EXAMPLE',
#  'TOMBSTONE AD',
#  'TONNAGE',
#  'TONNAGE DUTY',
#  'TORT',
#  'EXAMPLE',
#  'TORT CLAIMS ACT',
#  'TORTFEASOR',
#  'JOINT TORTFEASORS',
#  'TORTIOUS',
#  'TOTAL DISABILITY',
#  'TOTAL INCORPORATION',
#  'TOTAL INCORPORATION APPROACH',
#  'TOTALITY OF THE CIRCUMSTANCES TEST',
#  'TOTAL LOSS',
#  'TOTO',
#  'TOUCH AND CONCERN',
#  'TO WIT',
#  'TRACT INDEX',
#  'TRADE',
#  'FAIR',
#  'TRADE FIXTURE',
#  'TRADEMARK',
#  'TRADE NAME',
#  'TRADE',
#  'RESTRAINT OF',
#  'TRADE SECRETS',
#  'EXAMPLE',
#  'TRADE USAGE',
#  'USAGE OF',
#  'TRADE',
#  'A COURSE OF DEALING',
#  'TRADITIONARY EVIDENCE',
#  'TRANSACTION',
#  'CLOSED TRANSACTION',
#  'OPEN TRANSACTION',
#  'SHAM TRANSACTION',
#  'STEP TRANSACTION',
#  'TRANSACTIONAL IMMUNITY',
#  'TRANSACTIONS OR OCCURRENCE TEST',
#  'COMPULSORY COUNTERCLAIM',
#  'TRANSCRIPT',
#  'TRANSFER',
#  'TRANSFER AGENT',
#  'TRANSFEREE LIABILITY',
#  'TRANSFER IN CONTEMPLATION OF DEATH',
#  'CAUSA MORTIS',
#  'GIFT IN',
#  'CONTEMPLATION OF DEATH',
#  'TRANSFERRED INTENT',
#  'TRAVERSE',
#  'GENERAL TRAVERSE',
#  'SPECIAL TRAVERSE',
#  'TREASON',
#  'EXAMPLE',
#  'A U.S.',
#  'TREASURE TROVE',
#  'TREASURY',
#  'TREASURY BILL',
#  'U.S.',
#  'U.S. T',
#  'TREASURY BOND',
#  'U.S. G',
#  'U.S. G',
#  'TREASURY NOTE',
#  'U.S. G',
#  'U.S. G',
#  'TREASURY STOCK',
#  'TREATY',
#  'EXECUTIVE AGREEMENT',
#  'TREATY CLAUSE',
#  'TREBLE DAMAGES',
#  'DOUBLE',
#  'TREBLE) DAMAGES',
#  'TRESPASS',
#  'EXAMPLE',
#  'CONTINUING TRESPASS',
#  'TRESPASS DE BONIS ASPORTATIS',
#  'TRESPASS ON THE CASE',
#  'TRESPASS QUARE CLAUSUM FREGIT',
#  'TRESPASS VI ET ARMIS',
#  'TRESPASSER',
#  'TRESPASS ON THE CASE',
#  'TRESPASS ON THE CASE',
#  'TRIAL',
#  'TRIAL DE NOVO',
#  'TRIAL COURT',
#  'TRIBUNAL',
#  'TRIER OF FACT',
#  'TRIPARTITE',
#  'T.R.O.',
#  'TROVER',
#  'TENANCY AT',
#  'SUFFERANCE',
#  'TRUE BILL',
#  'TRUST',
#  'CESTUI QUE TRUST',
#  'EQUITABLE TITLE',
#  'SIMPLE TRUST',
#  'COMPLEX TRUST',
#  'CHARITABLE TRUST',
#  'PUBLIC TRUST',
#  'CONSTRUCTIVE TRUST',
#  'INVOLUNTARY TRUST',
#  'EXPRESS TRUST',
#  'DIRECT TRUST',
#  'GRANTOR TRUST',
#  'IMPLIED TRUST',
#  'EXPRESS TRUST',
#  'CONSTRUCTIVE',
#  'RESULTING.INVESTMENT TRUST',
#  'LIVING TRUST',
#  'TESTAMENTARY TRUST',
#  'PRECATORY TRUST',
#  'RESULTING TRUST',
#  'EXPRESS TRUST',
#  'EXAMPLE',
#  'TESTAMENTARY TRUST',
#  'SPENDTHRIFT TRUST',
#  'UNIT INVESTMENT TRUST',
#  'VOTING TRUST',
#  'TRUST CERTIFICATE',
#  'TRUST COMPANY',
#  'TRUST DEED',
#  'TRUSTEE',
#  'EXAMPLE',
#  'TRUSTEE IN BANKRUPTCY',
#  'TRUST FUND',
#  'TRUST INDENTURE',
#  'TRUST INDENTURE ACT OF',
#  'TRUST INDENTURE ACT OF',
#  'TRUSTOR',
#  'TRUTH IN LENDING ACT',
#  'EXAMPLE',
#  'TRY TITLE',
#  'TUCKER ACT',
#  'TURNTABLE DOCTRINE',
#  'TURPITUDE',
#  'TWO FUNDS DOCTRINE',
#  'TWO FUNDS DOCTRINE',
#  'TWO PARTY CONSENT',
#  'TWO PARTY CONSENT',
#  'TYING ARRANGEMENT',
#  'UUBI L',
#  'UBI SUPRA',
#  'U.C.C.',
#  'U.C.C.',
#  'U.C.C.C.',
#  'U.C.C.C.',
#  'ULTIMATE FACTS',
#  'ULTRAHAZARDOUS ACTIVITY',
#  'EXAMPLE',
#  'ULTRAVIRES L',
#  'UNAVOIDABLE ACCIDENT',
#  'UNAVOIDABLE ACCIDENT',
#  'UNCLEAN HANDS',
#  'UNCONDITIONAL DISCHARGE',
#  'SUSPENDED SENTENCE',
#  'UNCONSCIONABLE',
#  'EXAMPLE',
#  'UNCONSTITUTIONAL',
#  'UNDER COLOR OF LAW',
#  'UNDER COLOR OF TITLE',
#  'UNDERLEASE',
#  'UNDER PROTEST',
#  'UNDER SEAL',
#  'UNDER THE INFLUENCE',
#  'D.W.I.',
#  'UNDER THE WILL',
#  'ELECTION',
#  'UNDERWRITE',
#  'EXAMPLE',
#  'UNDISCLOSED PRINCIPAL',
#  'UNDIVIDED INTEREST',
#  'TENANTS IN COMMON',
#  'JOINT TENANTS',
#  'TENANTS BY THE',
#  'ENTIRETY',
#  'UNDUE INFLUENCE',
#  'EXAMPLE',
#  'UNEARNED SURPLUS',
#  'REVALUATION SURPLUS',
#  'DONATED SURPLUS',
#  'UNETHICAL',
#  'UNEXECUTED USE',
#  'UNEXECUTED USE',
#  'UNFAIR COMPETITION',
#  'UNFAIR LABOR PRACTICE',
#  'UNFIT',
#  'WARRANTY OF',
#  'FITNESS',
#  'UNIFIED ESTATE AND GIFT TAX',
#  'UNIFIED ESTATE AND GIFT TAX',
#  'UNIFORM ARBITRATION ACT',
#  'UNIFORM ARBITRATION ACT',
#  'UNIFORM CODE OF MILITARY JUSTICE',
#  'UNIFORM) CODE OF MILITARY JUSTICE',
#  'UNIFORM COMMERCIAL CODE',
#  'U.C.C.',
#  'UNIFORM CONSUMER CREDIT CODE',
#  'U.C.C.C.',
#  'U.C.C.C.',
#  'UNIFORM GIFTS TO MINORS ACT',
#  'U.G.M.A.',
#  'UNIFORM LAWS',
#  'EXAMPLE',
#  'U.C.C.',
#  'UNIFORM SYSTEM OF CITATION',
#  'BLUE BOOK',
#  'UNILATERAL CONTRACT',
#  'UNILATERAL MISTAKE',
#  'UNION',
#  'UNION',
#  'UNION SHOP',
#  'UNIT',
#  'UNITED STATES ATTORNEY',
#  'UNITED STATES CLAIMS COURT',
#  'UNITED STATES CODE',
#  'UNITED STATES CODE ANNOTATED',
#  'U.S.C.A.',
#  'UNITED STATES COURTS',
#  'UNITED STATES MAGISTRATE',
#  'UNITED STATES',
#  'FEDERAL',
#  'MAGISTRATE',
#  'UNITED STATES TRUSTEE',
#  'UNITED STATES TRUSTEE',
#  'UNITIES',
#  'JOINT TENANCY',
#  'TENANCY BY THE ENTIRETY',
#  'UNITY OF INTEREST',
#  'TENANCY IN COMMON',
#  'UNITY OF POSSESSION',
#  'UNITY OF TIME',
#  'UNITY OF TITLE',
#  'UNITY OF PERSON',
#  'UNIT INVESTMENT TRUST',
#  'UNIVERSAL AGENT',
#  'UNJUST ENRICHMENT',
#  'EXAMPLE',
#  'UNLAWFUL ACT MANSLAUGHTER',
#  'UNLAWFUL ACT MANSLAUGHTER',
#  'UNLAWFUL ASSEMBLY',
#  'BREACH',
#  'OF THE PEACE',
#  'UNLAWFUL DETAINER',
#  'UNLAWFULDETAINER STATUTES',
#  'TENANCY AT SUFFERANCE',
#  'UNLAWFUL ENTRY',
#  'UNLAWFUL FORCE',
#  'UNLAWFUL FORCE',
#  'UNLIQUIDATED',
#  'UNLIQUIDATED',
#  'UNLISTED SECURITY',
#  'UNNATURAL ACT',
#  'UNNECESSARY HARDSHIP',
#  'UNREALIZED APPRECIATION',
#  'UNREALIZED APPRECIATION',
#  'UNREASONABLE',
#  'UNREASONABLE PUNISHMENT',
#  'UNREASONABLE RESTRAINT OF TRADE',
#  'UNREASONABLE SEARCH AND SEIZURE',
#  'EXAMPLE',
#  'UNUSUAL PUNISHMENT',
#  'UP TICK',
#  'OR PLUS TICK',
#  'ZERO',
#  'PLUS TICK',
#  'USAGE OF TRADE',
#  'USE',
#  'RESULTING USE',
#  'SHIFTING USE',
#  'SPRINGING USE',
#  'PUBLIC USE',
#  'USEFUL LIFE',
#  'USEFUL LIFE',
#  'USE IMMUNITY',
#  'USE',
#  'PUBLIC',
#  'USUFRUCT',
#  'USURIOUS CONTRACT',
#  'USURY',
#  'EXAMPLE',
#  'UTILITY',
#  'UTMOST CARE',
#  'UTMOST RESISTANCE',
#  'UTTER',
#  'UXOR',
#  'VVACATE',
#  'VAGRANCY',
#  'VAGUENESS',
#  'VALUABLE CONSIDERATION',
#  'VALUABLE CONSIDERATION',
#  'VALUATION',
#  'VALUE',
#  'REPLACEMENT VALUE',
#  'PROBATIVE VALUE',
#  'VALUE ADDED TAX',
#  'AD ALOREM TAX',
#  'VANDALISM',
#  'VARIANCE',
#  'FATAL VARIANCE',
#  'EXAMPLE',
#  'VASSAL',
#  'VEIL',
#  'PIERCING',
#  'VEL NON',
#  'VENAL',
#  'VEND',
#  'VENDEE',
#  'VENDOR',
#  'VENDOR',
#  'S LIEN',
#  'VENIRE L',
#  'VENIRE DE NOVO',
#  'VENUE',
#  'CHANGE OF VENUE',
#  'VERACITY',
#  'CHARACTER WITNESS',
#  'VERDICT',
#  'COMPROMISE VERDICT',
#  'DIRECTED VERDICT',
#  'GENERAL VERDICT',
#  'PARTIAL VERDICT',
#  'QUOTIENT VERDICT',
#  'SPECIAL VERDICT',
#  'VERIFICATION',
#  'VERTICAL PRICE FIXING',
#  'VERTICAL PRICE FIXING',
#  'VERTICAL PRIVITY',
#  'VERTICAL PRIVITY',
#  'VESTED',
#  'CONDITION PRECEDENT',
#  'VESTED ESTATE',
#  'EXAMPLE',
#  'VESTED INTEREST',
#  'VESTED REMAINDER',
#  'VESTED RIGHTS',
#  'VETO',
#  'VEXATIOUS LITIGATION',
#  'VICARIOUS LIABILITY',
#  'IMPUTED',
#  'LIABILITY.EXAMPLE',
#  'EXAMPLE',
#  'VICE CRIMES',
#  'VICINAGE',
#  'VICTUALS',
#  'VICTUALER',
#  'VICTUALLER',
#  'VIDELICET',
#  'VIDUITATE',
#  'VIDUITY',
#  'VI  ET ARMIS',
#  'TRESPASS VI ET ARMIS',
#  'VIEW',
#  'VILLEIN SOCAGE',
#  'VILLENAGE',
#  'VIOLATION OF PROBATION',
#  'VIOLATION OF PROBATION',
#  'VIOLENCE',
#  'VIOLENT',
#  'VIR L',
#  'VIRTUAL REPRESENTATION',
#  'VISA',
#  'VISITATION',
#  'CONJUGAL',
#  'CONJUGAL VISITATION',
#  'VISITATION RIGHTS',
#  'VIS MAJOR',
#  'VITALIZED',
#  'VITIATE',
#  'VIZ L',
#  'VOICE EXEMPLAR',
#  'VOID',
#  'VOIDABLE',
#  'VOIDABLE PREFERENCE',
#  'VOIDABLE PREFERENCE',
#  'VOID FOR VAGUENESS',
#  'VOID',
#  'NULL AND',
#  'VOID ON ITS FACE',
#  'VOIR DIRE',
#  'VOIR DIRE EXAMINATION',
#  'EXAMPLE',
#  'VOLENTI NON FIT INJURIA',
#  'VOLUNTARY APPEARANCE',
#  'VOLUNTARY DISABLEMENT',
#  'VOLUNTARY DISSOLUTION',
#  'VOLUNTARY DISSOLUTION',
#  'VOLUNTARY MANSLAUGHTER',
#  'VOLUNTARY MANSLAUGHTER',
#  'VOLUNTARY NONSUIT',
#  'VOLUNTARY NONSUIT',
#  'VOLUNTARY WASTE',
#  'VOLUNTARY WASTE',
#  'VOTING',
#  'VOTING RIGHT',
#  'VOTING RIGHTS ACT',
#  'U.S. C',
#  'U.S.',
#  'VOTING TRUST',
#  'WWAGE EARNER',
#  'S PLAN',
#  'WAGE EARNER',
#  'S PLAN',
#  'WAGE',
#  'MINIMUM',
#  'WAGER OF LAW',
#  'COMPURGATORS',
#  'WAGNER ACT',
#  'UNION',
#  'NATIONAL LABOR RELATIONS ACT',
#  'WAIT',
#  'WAITING PERIOD',
#  'WAITING PERIOD',
#  'WAIVER',
#  'EXAMPLE',
#  'EXECUTORY WAIVER',
#  'WANT OF CONSIDERATION',
#  'WANT OF PROSECUTION',
#  'WANT OF PROSECUTION',
#  'WANTON',
#  'WARD',
#  'WARDSHIP',
#  'WAREHOUSEMAN',
#  'S LIEN',
#  'WAREHOUSEMAN',
#  'S LIEN',
#  'WAREHOUSE RECEIPT',
#  'WARRANT',
#  'WARRANT TO SATISFY JUDGMENT',
#  'STOCK WARRANT',
#  'WARRENTLESS ARREST',
#  'ARREST WARRANT',
#  'WARRANTY',
#  'EXPRESS WARRANTIES',
#  'IMPLIED WARRANTIES',
#  'A COVENANT OF WARRANTY',
#  'WARRANTY OF FITNESS',
#  'EXAMPLE',
#  'WARRANTY OF HABITABILITY',
#  'WARRANTY OF MERCHANTABILITY',
#  'WARRANTY ACT',
#  'WARRANTY DEED',
#  'WASH SALE',
#  'WASTE',
#  'AMELIORATING WASTE',
#  'EQUITABLE WASTE',
#  'PERMISSIVE WASTE',
#  'VOLUNTARY WASTE',
#  'PHYSICAL WASTE',
#  'ECONOMIC WASTE',
#  'WASTING ASSET',
#  'WATERED STOCK',
#  'WATERS',
#  'WAY',
#  'RIGHT OF',
#  'WEAPON',
#  'INSTRUMENTALITY',
#  'WEIGHT OF THE EVIDENCE',
#  'WESTLAW',
#  'WHEN ISSUED',
#  'WHEN ISSUED SECURITIES',
#  'WHIPLASH INJURY',
#  'WHITE',
#  'COLLAR CRIME',
#  'EXAMPLE',
#  'WHITE SLAVE TRAFFIC ACT',
#  'WHOLE LIFE INSURANCE',
#  'WHOLE LIFE INSURANCE',
#  'WHOLESALER',
#  'WIDOW',
#  'S ALLOWANCE',
#  'WIDOW',
#  'WIDOWER',
#  'ELECTION',
#  'WILDCAT STRIKE',
#  'EXAMPLE',
#  'WILD',
#  'S CASE',
#  'RULE IN',
#  'WILL',
#  'CAUSA MORTIS',
#  'WILLFUL',
#  'WILLFUL NEGLIGENCE',
#  'WANTON NEGLIGENCE',
#  'WILLIAMS ACT',
#  'WILLS',
#  'STATUTE OF',
#  'WINDING UP',
#  'WIRETAP',
#  'WITHDRAWAL',
#  'WITHHOLDING',
#  'WITHHOLDING TAX',
#  'WITHHOLDING TAX',
#  'WITHHOLDING TAX',
#  'WITHOUT FAULT',
#  'LIABILITY',
#  'WITHOUT PREJUDICE',
#  'DISMISSAL WITHOUT PREJUDICE',
#  'WITHOUT RECOURSE',
#  'WITH PREJUDICE',
#  'DISMISSAL WITH PREJUDICE',
#  'WITH RESERVATION',
#  'WITNESS',
#  'ADVERSE',
#  'HOSTILE',
#  'WITNESS',
#  'CHARACTER WITNESS',
#  'EXAMPLE',
#  'MATERIAL WITNESS',
#  'WITNESS AGAINST ONESELF',
#  'WORDS OF ART',
#  'WORDS OF FIGHTING',
#  'WORDS OF LIMITATION',
#  'WORDS OF PURCHASE',
#  'WORKERS',
#  'COMPENSATION ACTS',
#  'WORKHOUSE',
#  'WORKHOUSE',
#  'WORK PRODUCT',
#  'EXAMPLE',
#  'IRS.',
#  'WORK RELEASE PROGRAM',
#  'WORTH',
#  'WORTHIER TITLE',
#  'DOCTRINE OF',
#  'WRAPAROUND MORTGAGE',
#  'WRIT',
#  'WRIT OF ASSISTANCE',
#  'WRIT OF CAPIAS',
#  'WRIT OF CERTIORARI',
#  'WRIT OF CORAM NOBIS',
#  'WRIT OF ERROR CORAMNOBIS',
#  'CORAM NOBIS',
#  'WRIT OF ERROR',
#  'WRIT OF EXECUTION',
#  'WRIT OF HABEAS CORPUS',
#  'WRIT OF MANDAMUS',
#  'WRIT OF NE EXEAT',
#  'WRIT OF POSSESSION',
#  'WRIT OF PROHIBITION',
#  'PROHIBITION.WRIT OF QUO WARRANTO',
#  'WRIT OF RIGHT',
#  'WRIT OF SUPERSEDEAS',
#  'WRIT',
#  'PEREMPTORY',
#  'WRIT',
#  'PREROGATIVE',
#  'WRITTEN INSTRUMENT',
#  'WRONG',
#  'WRONGFUL ACT',
#  'WRONGFUL DEATH STATUTE',
#  'U.S.',
#  'WRONGFUL LIFE',
#  'YYEAR AND A DAY RULE',
#  'YEARLY',
#  'YELLOW DOG CONTRACT',
#  'YIELD',
#  'YIELD',
#  'MATURITY',
#  'YTM',
#  'YTM',
#  'YOUTHFUL OFFENDERS',
#  'ZZONE OF EMPLOYMENT',
#  'ZONING']

# %%
answer=["AA.B.A.","ABANDONED CHILD","ABANDONMENT","ABATABLE NUISANCE","ABATEMENT","ABATEMENT OF A LEGACY","ABATEMENT OF TAXES","ABDUCTION","ABET","ABEYANCE",
"ABILITY TO STAND TRIAL",
"AB INITIO","ABNORMALLY DANGEROUS ACTIVITY","ABOLISH",
"ABORIGINAL TITLE",
"ABORTION",
"ABRIDGE",
"ABROGATE",
"ABSCOND",
"ABSENTIA",
"ABSOLUTE LIABILITY",
"ABSQUE HOC",
"ABSTENTION",
"ABSTRACT OF RECORD"]

#def check():
#  if len(answer)==len(words):
#    print(yepee)
#  else:
#    for i in answer[:]:
#      if i in words:
#        missing_words = answer.remove(i)
#        redandunt_words = words.remove(i)
#        print("False",missing_words,redandunt_words)
#check()


def check2():
  if len(answer)==len(words):
    print("yiepee")
  else:
    print("missing words are:")
    pprint.pprint(set(answer)-set(words))
    print("redundant words are:")
    pprint.pprint(set(words)-set(answer))
check2()
# Out:
# missing words are:
# set()
# redundant words are:
# {'A COURSE OF DEALING',
#  'A COVENANT OF WARRANTY',
#  'A FORTIORI',
#  'A JOINT TENANCY',
#  'A MENSA ET THORO',
#  'A POSTERIORI',
#  'A PRIORI',
#  'A RIGHTOF ACTION',
#  'A U.S.',
#  'A.) S',
#  'A.B.A.',
#  'A.C.L.U.',
#  'A.F.D.C.',
#  'A.J.',
#  'A.K.A.',
#  'A.L.R.',
#  'A.L.R. F',
#  'ABATEMENT OF A NUISANCE',
#  'ABSENT WITHOUT LEAVE',
#  'ABSOLUTE SALE',
#  'ABSTRACT OF TITLE',
#  'ABUSE OF DISCRETION',
#  'ABUSE OF PROCESS',
#  'ABUT',
#  'ACCELERATED DEPRECIATION',
#  'ACCELERATION',
#  'ACCELERATION CLAUSE',
#  'ACCELERATION DEPRECIATION',
#  'ACCEPTANCE',
#  'ACCESS',
#  'ACCESSION',
#  'ACCESSORY',
#  'ACCESSORY AFTER',
#  'ACCESSORY AFTER THE FACT',
#  'ACCESSORY BEFORE',
#  'ACCESSORY BEFORE THE FACT',
#  'ACCIDENT',
#  'ACCOMMODATION INDORSEMENT',
#  'ACCOMMODATION MAKER',
#  'ACCOMPLICE',
#  'ACCORD',
#  'ACCORD AND SATISFACTION',
#  'ACCOUNT',
#  'ACCOUNT DEBTOR',
#  'ACCOUNT PAYABLE',
#  'ACCOUNTING',
#  'ACCOUNTING METHOD',
#  'ACCOUNTS PAYABLE',
#  'ACCOUNTS RECEIVABLE',
#  'ACCREDITED INVESTOR',
#  'ACCREDITED INVESTORS',
#  'ACCRETION',
#  'ACCRUAL METHOD',
#  'ACCRUE',
#  'ACCRUED INTEREST',
#  'ACCUMULATED DEPRECIATION',
#  'ACCUMULATED EARNINGS AND PROFITS',
#  'ACCUSATION',
#  'ACCUSATORY INSTRUMENT',
#  'ACCUSE',
#  'ACCUSED',
#  'ACKNOWLEDGMENT',
#  'ACLU',
#  'ACQUIESCENCE',
#  'ACQUIRE',
#  'ACQUIRED PROPERTY',
#  'ACQUIRED TITLE',
#  'ACQUIT',
#  'ACQUITTAL',
#  'ACT',
#  'ACT OF GOD',
#  'ACTIO L',
#  'ACTIO NON',
#  'ACTION',
#  'ACTION EX CONTRACTU',
#  'ACTION EX DELICTO',
#  'ACTION FOR',
#  'ACTION FOR ACCOUNTING',
#  'ACTION FOR POSSESSION',
#  'ACTION IN CASE',
#  'ACTIONABLE',
#  'ACTIONABLE TORT',
#  'ACTIONS IN PERSONAM',
#  'ACTIONS IN REM',
#  'ACTIONS QUASI IN REM',
#  'ACTIVE EUTHANASIA',
#  'ACTIVISM',
#  'ACTUAL',
#  'ACTUAL AUTHORITY',
#  'ACTUAL CASH VALUE',
#  'ACTUAL DAMAGES',
#  'ACTUAL EVICTION',
#  'ACTUAL NOTICE',
#  'ACTUAL POSSESSION',
#  'ACTUAL VALUE',
#  'ACTUARY',
#  'ACTUS REUS',
#  'AD ALOREM TAX',
#  'AD DAMNUM',
#  'AD HOC',
#  'AD LITEM',
#  'AD TESTIFICANDUM',
#  'AD VALOREM',
#  'AD VALOREM TAX',
#  'ADDENDUM',
#  'ADDITUR L',
#  'ADEEM',
#  'ADEMPTION',
#  'ADHESION CONTRACT',
#  'ADJECTIVE LAW',
#  'ADJOURN',
#  'ADJOURNMENT SINE DIE',
#  'ADJUDICATION',
#  'ADJUSTED BASIS',
#  'ADJUSTED GROSS INCOME',
#  'ADJUSTEDGROSS INCOME',
#  'ADJUSTER',
#  'ADMINISTRATION DBN',
#  'ADMINISTRATION FOR NATIVE',
#  'ADMINISTRATION FOR NATIVE AMERICANS',
#  'ADMINISTRATIVE AGENCIES',
#  'ADMINISTRATIVE AGENCY',
#  'ADMINISTRATIVE HEARING',
#  'ADMINISTRATIVE LAW',
#  'ADMINISTRATIVE LAW JUDGE',
#  'ADMINISTRATIVE PROCEDURE ACT',
#  'ADMINISTRATOR',
#  'ADMIRALTY AND MARITIME JURISDICTION',
#  'ADMIRALTY COURTS',
#  'ADMIRALTY LAW',
#  'ADMISSIBLE EVIDENCE',
#  'ADMISSION',
#  'ADMISSION BY A PARTY',
#  'ADMISSIONS BY A PARTY',
#  'ADMIT',
#  'ADMIT TO BAIL',
#  'ADMIT TO PRACTICE',
#  'ADMIT TO THE BAR',
#  'ADOPT',
#  'ADOPTION',
#  'ADR',
#  'ADULT',
#  'ADULTERY',
#  'ADVANCE',
#  'ADVANCE SHEETS',
#  'ADVANCEMENT',
#  'ADVERSARY',
#  'ADVERSARY PROCEEDING',
#  'ADVERSE',
#  'ADVERSE INTEREST',
#  'ADVERSE PARTY',
#  'ADVERSE POSSESSION',
#  'ADVERSE TITLE',
#  'ADVERSE WITNESS',
#  'ADVICE AND CONSENT',
#  'ADVISORY OPINION',
#  'ADVOCACY',
#  'AFFECTED WITH A PUBLIC INTEREST',
#  'AFFIANT',
#  'AFFIDAVIT',
#  'AFFINITY',
#  'AFFIRM',
#  'AFFIRMATION',
#  'AFFIRMATIVE ACTION',
#  'AFFIRMATIVE ACTION PROGRAMS',
#  'AFFIRMATIVE DEFENSE',
#  'AFFIRMATIVE EASEMENT',
#  'AFFIRMATIVE RELIEF',
#  'AFFIX',
#  'AFIS',
#  'AFIS (A',
#  'AFORETHOUGHT',
#  'AFTER',
#  'AGAINST GRANTOR',
#  'AGAINST PUBLIC POLICY',
#  'AGAINST THE',
#  'AGE DISCRIMINATION',
#  'AGE OF',
#  'AGE OF CONSENT',
#  'AGE OF MAJORITY',
#  'AGENCY',
#  'AGENT',
#  'AGGRAVATED ASSAULT',
#  'AGGRAVATING CIRCUMSTANCES',
#  'AGGREGATE',
#  'AGGRIEVED PARTY',
#  'AGREEMENT',
#  'AID AND ABET',
#  'AID TO FAMILIES WITH',
#  'AID TO FAMILIES WITH DEPENDENT CHILDREN',
#  'AIR PIRACY',
#  'AIR RIGHTS',
#  'AIRSPACE',
#  'AKA',
#  'ALEATORY',
#  'ALEATORY CONTRACT',
#  'ALI TEST',
#  'ALIAS',
#  'ALIBI',
#  'ALIEN',
#  'ALIEN REGISTRATION',
#  'ALIENATION',
#  'ALIENATION OF AFFECTIONS',
#  'ALIMONY',
#  'ALIQUOT L',
#  'ALIUNDE L',
#  'ALIUNDE RULE',
#  'ALLEGATION',
#  'ALLEN CHARGE',
#  'ALLOCUTION',
#  'ALLODIAL',
#  'ALLODIAL OWNERSHIP',
#  'ALLOWANCE',
#  'ALLUVION',
#  'ALTER EGO',
#  'ALTERATION',
#  'ALTERNATE PAYEE',
#  'ALTERNATIVE DISPUTE RESOLUTION',
#  'ALTERNATIVE PLEADING',
#  'ALTERNATIVE WRIT OF MANDAMUS',
#  'AMELIORATING WASTE',
#  'AMEND',
#  'AMENDED RETURN',
#  'AMENDMENTS',
#  'AMERICAN BAR ASSOCIATION',
#  'AMERICAN BAR FOUNDATION',
#  'AMERICAN CIVIL LIBERTIES UNION',
#  'AMERICAN DEPOSITORY RECEIPT',
#  'AMERICAN INDIAN LAW',
#  'AMERICAN STOCK EXCHANGE',
#  'AMERICANS',
#  'AMEX',
#  'AMICUS BRIEF',
#  'AMICUS CURIAE',
#  'AMICUS CURIAE BRIEF',
#  'AMINO REVERTENDI',
#  'AMINO REVOCANDI',
#  'AMINO TESTANDI',
#  'AMNESTY',
#  'AMORTIZATION',
#  'AMOUNT REALIZED',
#  'ANCIENT DEMESNE',
#  'ANCILLARY JURISDICTION',
#  'AND',
#  'AND FREIGHT',
#  'AND HIS HEIRS',
#  'AND QUARTERED',
#  'ANIMO L',
#  'ANIMUS',
#  'ANNOTATION',
#  'ANNUAL REPORT',
#  'ANNUITANT',
#  'ANNUITY',
#  'ANNUL',
#  'ANSWER',
#  'ANTENUPTIAL AGREEMENT',
#  'ANTI',
#  'ANTICIPATORY BREACH',
#  'ANTIDISCRIMINATION ACT',
#  'ANTIDUMPING LAW',
#  'ANTILAPSE STATUTES',
#  'ANTITRUST LAWS',
#  'APA',
#  'APPARENT AUTHORITY',
#  'APPEAL',
#  'APPEALS COURT',
#  'APPEARANCE',
#  'APPEARANCE DE BENE ESSE',
#  'APPELLANT',
#  'APPELLATE COURT',
#  'APPELLATE JURISDICTION',
#  'APPELLATEJURISDICTION',
#  'APPELLEE',
#  'APPOINTED COUNSEL',
#  'APPOINTMENT',
#  'APPOINTMENT OF RECEIVER',
#  'APPORTION',
#  'APPRAISAL RIGHTS',
#  'APPRAISE',
#  'APPRECIATE',
#  'APPRECIATION',
#  'APPROPRIATE',
#  'APPROPRIATION',
#  'APPURTENANT',
#  'ARBITER L',
#  'ARBITRAGE',
#  'ARBITRARY AND CAPRICIOUS',
#  'ARBITRATION',
#  'ARBITRATION CLAUSE',
#  'ARBITRATOR',
#  'ARGUENDO L',
#  'ARGUMENT',
#  'ARM',
#  'ARM STATUTES',
#  'ARMED ROBBERY',
#  'ARRAIGN',
#  'ARRAIGNMENT',
#  'ARRANGEMENTS',
#  'ARRAY',
#  'ARREARS',
#  'ARREST',
#  'ARREST OF JUDGMENT',
#  'ARREST RECORD',
#  'ARREST WARRANT',
#  'ARSON',
#  'ART',
#  'ARTICLES OF IMPEACHMENT',
#  'ARTICLES OF INCORPORATION',
#  'ARTIFICAL PERSON',
#  'ARTIFICE',
#  'ARTIFICIAL PERSON',
#  'AS A MATTER OF LAW',
#  'AS IS',
#  'ASE',
#  'ASE.AMEX',
#  'ASPORTATION',
#  'ASSAULT',
#  'ASSEMBLY',
#  'ASSESS',
#  'ASSESSABLE STOCK',
#  'ASSESSMENT OF DEFICIENCY',
#  'ASSET',
#  'ASSET VALUE',
#  'ASSIGN',
#  'ASSIGNED COUNSEL',
#  'ASSIGNED RISK',
#  'ASSIGNEES',
#  'ASSIGNMENT',
#  'ASSIGNMENT FOR BENEFIT OF CREDITORS',
#  'ASSIGNMENT OF A LEASE',
#  'ASSIGNMENT OF ERROR',
#  'ASSIGNMENT OF INCOME',
#  'ASSIGNS',
#  'ASSISTED SUICIDE',
#  'ASSIZE',
#  'ASSOCIATE JUSTICE',
#  'ASSOCIATION',
#  'ASSUMPSIT L',
#  'ASSUMPTION OF MORTGAGE',
#  'ASSUMPTION OF RISK',
#  'ASSURANCE',
#  'ASSURED',
#  'ASYLUM',
#  'AT BAR',
#  'AT EQUITY',
#  'AT ISSUE',
#  'AT LAW',
#  'ATROCIOUS',
#  'ATTACHMENT',
#  'ATTAINDER',
#  'ATTAINT',
#  'ATTEMPT',
#  'ATTENDANT CIRCUMSTANCES',
#  'ATTEST',
#  'ATTESTATION',
#  'ATTORNEY',
#  'ATTORNEY AT LAW',
#  'ATTORNEY GENERAL',
#  'ATTORNEY IN FACT',
#  'ATTORNEY OF RECORD',
#  'ATTRACTIVE NUISANCE',
#  'AUCTION',
#  'AUCTION SALE',
#  'AUDIT',
#  'AUDIT OF RETURN',
#  'AUDITOR',
#  'AUTHENTICATE',
#  'AUTHORITY',
#  'AUTHORITY BY ESTOPPEL',
#  'AUTHORITY COUPLED WITH AN INTEREST',
#  'AUTHORIZED ISSUE',
#  'AUTOMOBILE',
#  'AUTOMOBILE GUEST',
#  'AUTOMOBILE GUEST STATUTE',
#  'AUTOPSY',
#  'AUTRE VIE',
#  'AVERMENT',
#  'AVERMENT OF NOTICE',
#  'AVOID',
#  'AVOIDANCE',
#  'AVOIDANCE OF TAX',
#  'AVULSION',
#  'AWOL',
#  'B. T',
#  'B.F.O.Q.',
#  'B.F.O.Q. S',
#  'B.F.P.',
#  'BAD DEBT',
#  'BAD DEBT RESERVE',
#  'BAD FAITH',
#  'BAD TITLE',
#  'BADGES OF FRAUD',
#  'BAIL',
#  'BAIL BOND',
#  'BAIL BONDSMAN',
#  'BAIL JUMPING',
#  'BAILEE',
#  'BAILIFF',
#  'BAILMENT',
#  'BAILOR',
#  'BAIT AND SWITCH',
#  'BALANCE SHEET',
#  'BALANCING (TEST',
#  'BALANCING OF EQUITIES',
#  'BALANCING OF INTERESTS',
#  'BALLOON NOTE',
#  'BALM STATUTE',
#  'BANC',
#  'BANK',
#  'BANKER',
#  'BANKRUPTCY',
#  'BANKRUPTCY COURT',
#  'BANKRUPTCY PETITION',
#  'BAR',
#  'BARGAIN',
#  'BARGAIN AND SALE',
#  'BARGAINING UNIT',
#  'BARRATRY',
#  'BARRISTER',
#  'BARTER',
#  'BARTER.EXCHANGE',
#  'BASIS',
#  'BASTARD',
#  'BASTARDY PROCEEDING',
#  'BASTARDY PROCEEDINGS',
#  'BATTERY',
#  'BBAD CHECK',
#  'BEARER',
#  'BEARER BOND',
#  'BEARER BONDS',
#  'BEARER PAPER',
#  'BED AND BOARD',
#  'BEFORE',
#  'BELIEF',
#  'BENCH',
#  'BENCH TRIAL',
#  'BENCH WARRANT',
#  'BENEFICIAL INTEREST',
#  'BENEFICIAL USE',
#  'BENEFICIARY',
#  'BENEFIT',
#  'BENEFIT OF THE BARGAIN (RULE',
#  'BEQUEATH',
#  'BEQUEST',
#  'BEST EVIDENCE RULE',
#  'BESTIALITY',
#  'BEYOND A REASONABLE DOUBT',
#  'BIA',
#  'BIAS',
#  'BIAS CRIME',
#  'BID',
#  'BID SHOPPING',
#  'BIGAMY',
#  'BILATERAL',
#  'BILATERAL CONTRACT',
#  'BILATERAL MISTAKE',
#  'BILL',
#  'BILL FOR A NEW TRIAL',
#  'BILL OF',
#  'BILL OF ATTAINDER',
#  'BILL OF CERTIORARI',
#  'BILL OF DISCOVERY',
#  'BILL OF EXCEPTIONS',
#  'BILL OF EXCHANGE',
#  'BILL OF INTERPLEADER',
#  'BILL OF LADING',
#  'BILL OF PARTICULARS',
#  'BILL OF REVIEW',
#  'BILL OF RIGHTS',
#  'BILL OF SALE',
#  'BIND',
#  'BIND OVER',
#  'BINDER',
#  'BINDER RECEIPT',
#  'BINDING',
#  'BINDING AGREEMENT',
#  'BINDING ARBITRATION',
#  'BINDING INSTRUCTION',
#  'BLACK LETTER LAW',
#  'BLACKACRE',
#  'BLACKMAIL',
#  'BLACKMAIL SUITS',
#  'BLANK INDORSEMENT',
#  'BLASPHEMY',
#  'BLIND TRUST',
#  'BLOOD',
#  'BLUE BOOK',
#  'BLUE CHIP STOCK',
#  'BLUE LAWS',
#  'BLUE RIBBON JURY',
#  'BLUE SKY LAWS',
#  'BLUEBOOK',
#  'BOARD OF DIRECTORS',
#  'BOARD ROOM',
#  'BOILER ROOM',
#  'BOILERPLATE',
#  'BONA FIDE',
#  'BONA FIDE OCCUPATIONAL QUALIFICATION',
#  'BONA FIDE PURCHASER',
#  'BONA L',
#  'BOND',
#  'BOND DISCOUNT',
#  'BOND FOR DEED',
#  'BOND FOR GENERAL PURPOSES',
#  'BOND ISSUE',
#  'BOND PREMIUM',
#  'BOND YIELD',
#  'BONDED DEBT',
#  'BONDS',
#  'BONDSMAN',
#  'BONUS STOCK',
#  'BOOK VALUE',
#  'BOOT',
#  'BORDELLO',
#  'BOROUGH ENGLISH',
#  'BOYCOTT',
#  'BRAIN DEATH',
#  'BREACH',
#  'BREACH OF',
#  'BREACH OF CONTRACT',
#  'BREACH OF PROMISE',
#  'BREACH OF THE PEACE',
#  'BREACH OF TRUST',
#  'BREACH OF WARRANTY',
#  'BREAKING A CLOSE',
#  'BREAKING AND ENTERING',
#  'BREAKING BULK',
#  'BREATHALYZER',
#  'BRETHREN',
#  'BRIBERY',
#  'BRIEF',
#  'BROKER',
#  'BRUTUM FULMEN',
#  'BUGGERY',
#  'BUGGING',
#  'BUILDING AND LOAN ASSOCIATION',
#  'BUILDING PERMIT',
#  'BULK SALES ACTS',
#  'BULK TRANSFER',
#  'BUNCHING',
#  'BURDEN',
#  'BURDEN OF EVIDENCE',
#  'BURDEN OF PROOF',
#  'BUREAU OF INDIAN AFFAIRS',
#  'BURGLARY',
#  'BUSINESS',
#  'BUSINESS CYCLE',
#  'BUSINESS GUEST',
#  'BUSINESS INVITEE',
#  'BUSINESS JUDGMENT RULE',
#  'BUSINESS RECORDS EXCEPTION',
#  'BUSINESS TRUST',
#  'BUT FOR',
#  'BUY',
#  'BUYER IN ORDINARY COURSE OF BUSINESS',
#  'BY ESTOPPEL',
#  'BY OPERATION OF LAW',
#  'BY THE ENTIRETY',
#  'BYLAWS',
#  'C. C',
#  'C.F.I.',
#  'C.F.I. I',
#  'C.I.F.',
#  'C.J.',
#  'CA. RESP.',
#  'CA. SA',
#  'CAB',
#  'CADAVER',
#  'CALENDAR CALL',
#  'CALL',
#  'CALL OPTION',
#  'CALLABLE BOND',
#  'CALUMNY',
#  'CAMERA',
#  'CANNABIS',
#  'CANON',
#  'CAPACITY',
#  'CAPACITY TO SUE',
#  'CAPIAS AD AUDIENDUM JUDICIUM',
#  'CAPIAS AD RESPONDENDUM',
#  'CAPIAS AD SATISFACIENDUM',
#  'CAPIAS L',
#  'CAPITA',
#  'CAPITAL',
#  'CAPITAL ACCOUNT',
#  'CAPITAL ASSET',
#  'CAPITAL ASSETS',
#  'CAPITAL EXPENDITURE',
#  'CAPITAL EXPENDITURES',
#  'CAPITAL GAINS OR LOSSES',
#  'CAPITAL GAINS TAX',
#  'CAPITAL INTENSIVE',
#  'CAPITAL INVESTMENT',
#  'CAPITAL MARKET',
#  'CAPITAL OFFENSE',
#  'CAPITAL PUNISHMENT',
#  'CAPITAL STOCK',
#  'CAPITAL SURPLUS',
#  'CAPITAL. S',
#  'CAPITALIZATION',
#  'CAPITALIZED VALUE',
#  'CAPITE',
#  'CAPTION',
#  'CAPTURE',
#  'CARE',
#  'CARJACKING',
#  'CARNAL KNOWLEDGE',
#  'CARRIER',
#  'CARRYBACK',
#  'CARRYOVER',
#  'CARRYOVER BASIS',
#  'CARRYOVER OR SUBSTITUTED BASIS',
#  'CARRYOVER SUBSTITUTED BASIS',
#  'CARTEL',
#  'CARVE OUT',
#  'CASE',
#  'CASE AT BAR',
#  'CASE LAW',
#  'CASE OF FIRST IMPRESSION',
#  'CASE OR CONTROVERSY',
#  'CASE REPORTS',
#  'CASH EQUIVALENT DOCTRINE',
#  'CASH METHOD',
#  'CASH SALE',
#  'CASH SALE DOCTRINE',
#  'CASH SURRENDER VALUE',
#  'CASH VALUE',
#  'CASHIER',
#  'CASUALTY LOSS',
#  'CAUSA L',
#  'CAUSA MORTIS',
#  'CAUSA PROXIMA',
#  'CAUSA SINE QUA NON',
#  'CAUSAMORTIS',
#  'CAUSE',
#  'CAUSE OF ACTION',
#  'CAUTIONARY INSTRUCTION',
#  'CAVEAT EMPTOR',
#  'CAVEAT L',
#  'CCAB',
#  'CEASE AND DESIST ORDER',
#  'CELL PARDE',
#  'CELL PAROLE',
#  'CENSURE',
#  'CENTER OF GRAVITY',
#  'CERTIFICATE OF DEPOSIT',
#  'CERTIFICATE OF INCORPORATION',
#  'CERTIFICATE OF OCCUPANCY',
#  'CERTIFICATE OF TITLE',
#  'CERTIFICATION',
#  'CERTIFIED CHECK',
#  'CERTIORARI L',
#  'CESTUI QUE',
#  'CESTUI QUE TRUST',
#  'CESTUI QUE USE',
#  'CESTUI QUE VIE',
#  'CESTUIS QUE) O',
#  'CHAIN OF TITLE',
#  'CHALLENGE',
#  'CHALLENGE FOR CAUSE',
#  'CHALLENGE TO JURY ARRAY',
#  'CHALLENGED FOR CAUSE',
#  'CHAMBERS',
#  'CHAMPERTY',
#  'CHANCELLOR',
#  'CHANCERY',
#  'CHANGE OF VENUE',
#  'CHAPTER',
#  'CHARACTER WITNESS',
#  'CHARGE',
#  'CHARITABLE CONTRIBUTION',
#  'CHARITABLE DEDUCTION',
#  'CHARITABLE TRUST',
#  'CHARITY',
#  'CHARTER',
#  'CHATTEL',
#  'CHATTEL MORTGAGE',
#  'CHATTEL PAPER',
#  'CHECK',
#  'CHECK KITING',
#  'CHECK.NON SUI JURIS',
#  'CHECKS AND BALANCES',
#  'CHIEF JUSTICE',
#  'CHILD AND DEPENDENT CARE CREDIT',
#  'CHILD CUSTODY',
#  'CHILD SUPPORT',
#  'CHILL',
#  'CHILLING EFFECT',
#  'CHOATE',
#  'CHOICE OF',
#  'CHOICE OF LAW',
#  'CHOSE F',
#  'CHOSE IN',
#  'CHOSE IN ACTION',
#  'CHOSE IN POSSESSION',
#  'CHURNING',
#  'CIRCUIT',
#  'CIRCUIT COURT',
#  'CIRCUMSTANTIAL EVIDENCE',
#  'CITATION',
#  'CITE',
#  'CITIZEN',
#  'CIVIL',
#  'CIVIL ACTION',
#  'CIVIL AERONAUTICS BOARD',
#  'CIVIL CONTEMPT',
#  'CIVIL DAMAGE ACTS',
#  'CIVIL DEATH',
#  'CIVIL DISOBEDIENCE',
#  'CIVIL DISORDER',
#  'CIVIL LAW',
#  'CIVIL LIABILITY',
#  'CIVIL LIBERTIES',
#  'CIVIL PENALTIES',
#  'CIVIL PROCEDURE',
#  'CIVIL RIGHTS',
#  'CIVIL RIGHTS ACT OF',
#  'CIVIL SERVICE COMMISSIONS',
#  'CIVITAS L',
#  'CLA',
#  'CLA (C',
#  'CLAIM',
#  'CLAIM FOR REFUND',
#  'CLAIM OF RIGHT',
#  'CLAIMANT',
#  'CLASS ACTION',
#  'CLASS GIFT',
#  'CLASS SUIT',
#  'CLASSIFIED STOCK',
#  'CLAUSE',
#  'CLAYTON ACT',
#  'CLEAN HANDS',
#  'CLEAR',
#  'CLEAR AND CONVINCING',
#  'CLEAR AND PRESENT DANGER',
#  'CLEAR TITLE',
#  'CLEAR TITLE OF RECORD',
#  'CLEARINGHOUSE',
#  'CLEMENCY',
#  'CLERGYMEN',
#  'CLERIC',
#  'CLERICAL ERROR',
#  'CLERK',
#  'CLIENT PRIVILEGE',
#  'CLOSE',
#  'CLOSE CORPORATION',
#  'CLOSE CORPORATIONS',
#  'CLOSE.ENCROACH',
#  'CLOSED',
#  'CLOSED END FUNDS',
#  'CLOSED SHOP',
#  'CLOSED TRANSACTION',
#  'CLOSELY HELD CORPORATION',
#  'CLOSING',
#  'CLOSING AGREEMENT',
#  'CLOSING ARGUMENTS',
#  'CLOSING LAWS',
#  'CLOSING STATEMENT',
#  'CLOTURE',
#  'CLOUD ON TITLE',
#  'COCONSPIRATOR',
#  'CODE',
#  'CODE OF MILITARY JUSTICE',
#  'CODE OF PROFESSIONAL RESPONSIBILITY',
#  'CODE PLEADING',
#  'CODEFENDANT',
#  'CODICIL',
#  'COERCION',
#  'COGENT',
#  'COGNIZABLE',
#  'COGNOVIT JUDGMENT',
#  'COGNOVIT NOTE',
#  'COHABITATION',
#  'COHEIR',
#  'COIF',
#  'COINSURANCE',
#  'COLLAR CRIME',
#  'COLLATERAL',
#  'COLLATERAL AFFINITY',
#  'COLLATERAL ATTACK',
#  'COLLATERAL CONSANGUINITY',
#  'COLLATERAL ESTOPPEL',
#  'COLLATERAL FRAUD',
#  'COLLATERAL LINE',
#  'COLLATERAL PROMISE',
#  'COLLATERAL SOURCE RULE',
#  'COLLATION',
#  'COLLECTIVE BARGAINING',
#  'COLLOQUIUM',
#  'COLLUSION',
#  'COLLUSIVE ACTION',
#  'COLOR',
#  'COLOR OF LAW',
#  'COLOR OF TITLE',
#  'COLORABLE',
#  'COMITAS',
#  'COMITY',
#  'COMMENT',
#  'COMMERCE',
#  'COMMERCE CLAUSE',
#  'COMMERCE POWER',
#  'COMMERCIAL BANK',
#  'COMMERCIAL BRIBERY',
#  'COMMERCIAL FRUSTRATION',
#  'COMMERCIAL LAW',
#  'COMMERCIAL NAME',
#  'COMMERCIAL PAPER',
#  'COMMERCIAL PREFERENCE',
#  'COMMERCIAL UNIT',
#  'COMMINGLING OF FUNDS',
#  'COMMISSION',
#  'COMMITMENT',
#  'COMMITTEE',
#  'COMMODITY',
#  'COMMODITY SHORT SALES',
#  'COMMON',
#  'COMMON AREA',
#  'COMMON CARRIER',
#  'COMMON LAW',
#  'COMMON NUISANCE',
#  'COMMON PROPERTY',
#  'COMMON SEAL',
#  'COMMON STOCK',
#  'COMMONS',
#  'COMMUNITY NOTIFICATION',
#  'COMMUNITY PROPERTY',
#  'COMMUTATION',
#  'COMPACT CLAUSE',
#  'COMPANY',
#  'COMPANY ACT OF',
#  'COMPARATIVE NEGLIGENCE',
#  'COMPELLING INTEREST',
#  'COMPENSATION',
#  'COMPENSATION ACTS',
#  'COMPENSATORY DAMAGES',
#  'COMPETENT',
#  'COMPETENT COURT',
#  'COMPETENT EVIDENCE',
#  'COMPLAINANT',
#  'COMPLAINT',
#  'COMPLEX TRUST',
#  'COMPLIANCE',
#  'COMPOS MENTIS',
#  'COMPOUND CONCLUSION',
#  'COMPOUND INTEREST',
#  'COMPOUNDING A FELONY',
#  'COMPROMISE VERDICT',
#  'COMPULSORY APPEARANCE',
#  'COMPULSORY ARBITRATION',
#  'COMPULSORY COUNTERCLAIM',
#  'COMPULSORY JOINDER',
#  'COMPULSORY PROCESS',
#  'COMPURAGATOR',
#  'COMPURGATORS',
#  'CONCEALMENT',
#  'CONCERT OF ACTION',
#  'CONCERTED ACTION',
#  'CONCILIATION',
#  'CONCILIATOR',
#  'CONCLUSION OF FACT',
#  'CONCLUSION OF LAW',
#  'CONCLUSIVE',
#  'CONCLUSIVE EVIDENCE',
#  'CONCLUSIVE PRESUMPTION',
#  'CONCUR',
#  'CONCURRENT',
#  'CONCURRENT CONDITION',
#  'CONCURRENT COVENANTS',
#  'CONCURRENT JURISDICTION',
#  'CONCURRENT NEGLIGENCE',
#  'CONCURRENT SENTENCE',
#  'CONCURRENT SENTENCES',
#  'CONCURRING OPINION',
#  'CONDEMN',
#  'CONDITION',
#  'CONDITION PRECEDENT',
#  'CONDITION SUBSEQUENT',
#  'CONDITIONAL',
#  'CONDITIONAL BEQUEST',
#  'CONDITIONAL CONTRACT',
#  'CONDITIONAL DISCHARGE',
#  'CONDITIONAL DISCHARGE SENTENCE',
#  'CONDITIONAL FEE',
#  'CONDITIONAL PARDON',
#  'CONDITIONAL SALE',
#  'CONDITIONALDISCHARGE',
#  'CONDOMINIUM',
#  'CONFERENCE',
#  'CONFESSION',
#  'CONFESSION AND AVOIDANCE',
#  'CONFESSION OF JUDGMENT',
#  'CONFIDENCE GAME',
#  'CONFIDENTIAL COMMUNICATION',
#  'CONFIRMATION',
#  'CONFISCATE',
#  'CONFLICT OF INTERESTS',
#  'CONFLICT OF LAW',
#  'CONFORMED',
#  'CONFORMED COPY',
#  'CONFORMING USE',
#  'CONFRONTATION CLAUSE',
#  'CONFUSION OF GOODS',
#  'CONGLOMERATE',
#  'CONGRESS',
#  'CONGRESSIONAL REFERENCE CASES',
#  'CONJECTURE',
#  'CONJUGAL',
#  'CONJUGAL RIGHTS',
#  'CONJUGAL VISITATION',
#  'CONJUNCTIVE DENIAL',
#  'CONSANGUINITY',
#  'CONSCIENCE OF THE COURT',
#  'CONSCIENTIOUS OBJECTOR',
#  'CONSCIOUS PARALLELISM',
#  'CONSECUTIVE',
#  'CONSECUTIVE SENTENCE',
#  'CONSENT',
#  'CONSENT DECREE',
#  'CONSENT FOR',
#  'CONSENT JUDGMENT',
#  'CONSENT ORDER',
#  'CONSENT SEARCH',
#  'CONSEQUENTIAL',
#  'CONSEQUENTIAL DAMAGES',
#  'CONSERVATOR',
#  'CONSIDERATION',
#  'CONSIDERED DICTUM',
#  'CONSIGNEE',
#  'CONSIGNMENT',
#  'CONSIGNMENT.SALE OR EXCHANGE',
#  'CONSIGNOR',
#  'CONSOLIDATED APPEAL',
#  'CONSOLIDATION',
#  'CONSORTIUM',
#  'CONSPIRACY',
#  'CONSPIRATOR',
#  'CONSTITUTION',
#  'CONSTITUTIONAL',
#  'CONSTITUTIONAL RIGHTS',
#  'CONSTRUCTION',
#  'CONSTRUCTIVE',
#  'CONSTRUCTIVE BAILMENT',
#  'CONSTRUCTIVE CONTEMPT',
#  'CONSTRUCTIVE DELIVERY',
#  'CONSTRUCTIVE EVICTION',
#  'CONSTRUCTIVE FRAUD',
#  'CONSTRUCTIVE NOTICE',
#  'CONSTRUCTIVE POSSESSION',
#  'CONSTRUCTIVE RECEIPT OF INCOME',
#  'CONSTRUCTIVE SERVICE',
#  'CONSTRUCTIVE TRUST',
#  'CONSTRUE',
#  'CONSUMER',
#  'CONSUMER GOODS',
#  'CONSUMER PROTECTION',
#  'CONTACTS APPROACH',
#  'CONTEMPLATION OF DEATH',
#  'CONTEMPT OF COURT',
#  'CONTIGUOUS',
#  'CONTINGENT',
#  'CONTINGENT BENEFICIARY',
#  'CONTINGENT ESTATE',
#  'CONTINGENT FEE',
#  'CONTINGENT LIABILITY',
#  'CONTINUANCE',
#  'CONTINUING TRESPASS',
#  'CONTRA BONOS MORES',
#  'CONTRA L',
#  'CONTRA PACEM',
#  'CONTRABAND',
#  'CONTRACT',
#  'CONTRACT OF HAZARD',
#  'CONTRACT OFADHESION',
#  'CONTRACT UNDER SEAL',
#  'CONTRACT. T',
#  'CONTRACTOR',
#  'CONTRACTUAL BREACH',
#  'CONTRIBUTION',
#  'CONTRIBUTORY NEGLIGENCE',
#  'CONTROLLED SUBSTANCE',
#  'CONTROVERSY',
#  'CONTUMACY',
#  'CONVERSATION',
#  'CONVERSATION. H',
#  'CONVERSION',
#  'CONVERTIBLE SECURITIES',
#  'CONVERTIBLE SECURITY',
#  'CONVEY',
#  'CONVEYANCE',
#  'CONVICT',
#  'CONVICTION',
#  'COOPERATIVE',
#  'COOPERATIVE ASSOCIATION',
#  'COORDINATE JURISDICTION',
#  'COPARCENARY',
#  'COPARCENERS',
#  'COPARTNER',
#  'COPY',
#  'COPYHOLD',
#  'COPYRIGHT',
#  'CORAM NOBIS',
#  'CORESPONDENT',
#  'CORONER',
#  'CORPORAL PUNISHMENT',
#  'CORPORATE',
#  'CORPORATE OPPORTUNITY',
#  'CORPORATE POWER',
#  'CORPORATION',
#  'CORPORATIONS',
#  'CORPOREAL',
#  'CORPOREAL HEREDITAMENT',
#  'CORPOREALHEREDITAMENTS',
#  'CORPUS DELICTI',
#  'CORPUS JURIS',
#  'CORPUS L',
#  'CORRECTIONAL FACILITY',
#  'CORRECTIONAL INSTITUTION',
#  'CORRESPONDENT',
#  'CORROBORATING EVIDENCE',
#  'CORRUPTION OF THE',
#  'CORRUPTION OF THE BLOOD',
#  'COSIGN',
#  'COST',
#  'COST OF COMPLETION',
#  'COST OF LIVING CLAUSE',
#  'COSTS',
#  'COSTS TO ABIDE THE EVENT',
#  'COUNSEL',
#  'COUNSELLOR',
#  'COUNT',
#  'COUNTER MARKET',
#  'COUNTERCLAIM',
#  'COUNTERFEIT',
#  'COUPLED WITH AN INTEREST',
#  'COUPONS',
#  'COURSE OF',
#  'COURSE OF BUSINESS',
#  'COURSE OF DEALING',
#  'COURT',
#  'COURT CALENDAR',
#  'COURT CLERK',
#  'COURT OF',
#  'COURT OF APPEALS',
#  'COURT OF ASSIZE AND NISI PRIUS',
#  'COURT OF CLAIMS',
#  'COURT OF CUSTOMS AND PATENT APPEALS',
#  'COURT OF EQUITY',
#  'COURT OF EXCHEQUER',
#  'COURT OF INQUIRY',
#  'COURT OF KING',
#  'COURT OF LAW',
#  'COURT OF MILITARY APPEAL',
#  'COURT OF MILITARY REVIEW',
#  'COURT OF RECORD',
#  'COURT OF STAR CHAMBER',
#  'COURT REPORTERS',
#  'COURT REPORTS',
#  'COURT SETTLEMENT',
#  'COURTDOCKET.COURT EN BANC',
#  'COVENANT',
#  'COVENANT AGAINST ACTS OF THE GRANTOR',
#  'COVENANT AGAINST ENCUMBRANCES',
#  'COVENANT NOT TO COMPETE',
#  'COVENANT OF',
#  'COVENANT OF FURTHER ASSURANCE',
#  'COVENANT OF QUIET ENJOYMENT',
#  'COVENANT OF SEISIN AND RIGHT TO CONVEY',
#  'COVENANT OF WARRANTY AND QUIET ENJOYMENT',
#  'COVENANTEE',
#  'COVENANTOR',
#  'COVENANTS',
#  'COVENANTS OF TITLE',
#  'COVER',
#  'COVERTURE',
#  'CREDIBILITY',
#  'CREDIT',
#  'CREDIT CARD',
#  'CREDITOR',
#  'CREDITOR BENEFICIARY',
#  'CRIME',
#  'CRIME AGAINST NATURE',
#  'CRIME OF PASSION',
#  'CRIMEN FALSI',
#  'CRIMINAL',
#  'CRIMINAL CODE',
#  'CRIMINAL COERCION',
#  'CRIMINAL CONTEMPT',
#  'CRIMINAL CONVERSATION',
#  'CRIMINAL MAINTENANCE',
#  'CRIMINAL MISCHIEF',
#  'CRIMINAL NEGLIGENCE',
#  'CRIMINAL POSSESSION',
#  'CRIMINAL PROCEDURE',
#  'CRIMINAL RECORD',
#  'CROSS',
#  'CROSS BILL',
#  'CRUEL AND UNUSUAL PUNISHMENT',
#  'CTA',
#  'CUCKOLD',
#  'CULPA L',
#  'CULPABLE',
#  'CULPABLE MENTAL STATE',
#  'CUM TESTAMENTO ANNEXO',
#  'CUMULATIVE',
#  'CUMULATIVE DIVIDEND',
#  'CUMULATIVE SENTENCE',
#  'CUMULATIVE VOTING',
#  'CURATIVE',
#  'CURIA REGIS',
#  'CURRENT ASSETS',
#  'CURRENT EARNINGS AND PROFITS',
#  'CURRENT LIABILITIES',
#  'CURTESY',
#  'CURTILAGE',
#  'CUSTODIAL SENTENCE',
#  'CUSTODY',
#  'CUSTODY OF CHILDREN',
#  'CUSTOM DUTIES',
#  'CUSTOMS AND PATENT APPEALS',
#  'CUSTOMS COURT',
#  'D.B.A.',
#  'D.B.A. S',
#  'D.C.',
#  'D.U.I.',
#  'D.W.I.',
#  'DAILY',
#  'DAMAGE',
#  'DAMAGES',
#  'DAMNUM ABSQUE INJURIA',
#  'DANGEROUS WEAPON',
#  'DATE',
#  'DAY IN COURT',
#  'DBN',
#  'DD.A.',
#  'DE BENE ESSE',
#  'DE BONIS NON',
#  'DE FACTO',
#  'DE FACTO CORPORATION',
#  'DE FACTO INCUMBENT',
#  'DE JURE',
#  'DE MINIMIS',
#  'DE MINIMIS NON CURAT LEX',
#  'DE NOVO',
#  'DE NOVO HEARING',
#  'DEAD HAND',
#  'DEADLY FORCE',
#  'DEADLY WEAPON',
#  'DEALER',
#  'DEALING',
#  'DEATH',
#  'DEATH BY',
#  'DEATH BY AUTOMOBILE',
#  'DEATH PENALTY',
#  'DEBAUCHERY',
#  'DEBENTURE',
#  'DEBIT',
#  'DEBT',
#  'DEBT CAPITAL',
#  'DEBTOR',
#  'DECEASED',
#  'DECEDENT',
#  'DECEIT',
#  'DECISION',
#  'DECISION ON THE MERITS',
#  'DECLARANT',
#  'DECLARATION',
#  'DECLARATION AGAINST INTEREST',
#  'DECLARATION OF ESTIMATED TAX',
#  'DECLARATION OF TRUST',
#  'DECLARATORY JUDGMENT',
#  'DECLARATORY STATUTE',
#  'DECREE',
#  'DECREE NISI',
#  'DECRIMINALIZATION',
#  'DEDICATION',
#  'DEDUCTIONS',
#  'DEED',
#  'DEED OF TRUST',
#  'DEED POLL',
#  'DEEP ROCK DOCTRINE',
#  'DEFALCATION',
#  'DEFAMATION',
#  'DEFAULT',
#  'DEFAULT JUDGMENT',
#  'DEFEASANCE',
#  'DEFEASIBLE',
#  'DEFEASIBLE FEE',
#  'DEFECT',
#  'DEFECTIVE',
#  'DEFECTIVE PLEADING',
#  'DEFECTIVE TITLE',
#  'DEFENDANT',
#  'DEFENDANT IN ERROR',
#  'DEFENDENT IN ERROR',
#  'DEFENSE',
#  'DEFENSE OF',
#  'DEFERMENT',
#  'DEFERRED COMPENSATION',
#  'DEFERRED PAYMENTS',
#  'DEFICIENCY',
#  'DEFICIT',
#  'DEFINITE FAILURE OF ISSUE',
#  'DEFRAUD',
#  'DEGREE',
#  'DEGREE MURDER',
#  'DEGREE OF CONSANGUINITY',
#  'DEGREE OF CRIME',
#  'DEGREE OF NEGLIGENCE',
#  'DEGREE OF PROOF',
#  'DEHORS',
#  'DELEGABLE DUTY',
#  'DELEGATE',
#  'DELEGATED POWER',
#  'DELIBERATE',
#  'DELIBERATE SPEED',
#  'DELIBERATION',
#  'DELICT',
#  'DELICTUM',
#  'DELICTUML',
#  'DELINQUENCY. S',
#  'DELINQUENT',
#  'DELISTING',
#  'DELIVERY',
#  'DELIVERY. C',
#  'DELUSION',
#  'DEMAND',
#  'DEMAND NOTE',
#  'DEMESNE F',
#  'DEMISE',
#  'DEMONSTRATIVE EVIDENCE',
#  'DEMUR',
#  'DEMURRER',
#  'DENIAL',
#  'DEODAND',
#  'DEPENDENCY',
#  'DEPENDENT',
#  'DEPENDENT CARE',
#  'DEPENDENT CHILDREN',
#  'DEPENDENT COVENANTS',
#  'DEPENDENT RELATIVE REVOCATION',
#  'DEPLETION',
#  'DEPLETION ALLOWANCE',
#  'DEPONENT',
#  'DEPORTATION',
#  'DEPOSE',
#  'DEPOSITION',
#  'DEPOSITION DE BENE ESSE',
#  'DEPOSITIONS DE BENE ESSE',
#  'DEPRECIATION',
#  'DEPRECIATION RESERVE',
#  'DEPREDATION',
#  'DEPRESSANTS',
#  'DERELICTION',
#  'DERIVATIVE ACTION',
#  'DERIVATIVE SUIT',
#  'DERIVATIVE TORT',
#  'DEROGATION',
#  'DESCENT',
#  'DESCENT AND DISTRIBUTION',
#  'DESEGREGATION',
#  'DESERTION',
#  'DESIST',
#  'DESTINATION CONTRACT',
#  'DESTRUCTIBILITY',
#  'DESUETUDE',
#  'DETAINER',
#  'DETENTION',
#  'DETERMINABLE FEE',
#  'DETERMINATION',
#  'DETINUE',
#  'DETRIMENTAL RELIANCE',
#  'DEVISE',
#  'DEVOLVE',
#  'DICTA',
#  'DICTUM',
#  'DIE WITHOUT ISSUE',
#  'DIFFERENTIAL.ODIOUS',
#  'DILATORY PLEA',
#  'DILIGENCE',
#  'DILUTING THE SHARES',
#  'DIMINISHED',
#  'DIMINISHED CAPACITY',
#  'DIMINISHED RESPONSIBILITY',
#  'DIMINUTION IN VALUE',
#  'DIRECT AFFINITY',
#  'DIRECT ATTACK',
#  'DIRECT CAUSE',
#  'DIRECT CONTEMPT',
#  'DIRECT ESTOPPEL',
#  'DIRECT EXAMINATION',
#  'DIRECT ORDER OF ALIENATION',
#  'DIRECT TRUST',
#  'DIRECTED VERDICT',
#  'DIRECTOR',
#  'DISABILITY',
#  'DISBAR',
#  'DISCHARGE',
#  'DISCHARGE IN BANKRUPTCY',
#  'DISCLAIMER',
#  'DISCLAIMER OF LIABILITY',
#  'DISCLOSED PRINCIPAL',
#  'DISCONTINUANCE',
#  'DISCOUNT',
#  'DISCOUNT BOND',
#  'DISCOUNTED CASH FLOW',
#  'DISCOVERY',
#  'DISCRETION',
#  'DISCRETIONARY ACCOUNT',
#  'DISCRIMINATION',
#  'DISCRIMINATION ACT',
#  'DISHONOR',
#  'DISINHERITANCE',
#  'DISINTERMEDIATION',
#  'DISJUNCTIVE ALLEGATIONS',
#  'DISJUNCTIVE DENIAL',
#  'DISMISS',
#  'DISMISSAL',
#  'DISMISSAL WITH PREJUDICE',
#  'DISMISSAL WITHOUT PREJUDICE',
#  'DISORDERLY CONDUCT',
#  'DISPARAGEMENT',
#  'DISPARAGEMENT. S',
#  'DISPOSITION',
#  'DISPOSSESS',
#  'DISPUTABLE PRESUMPTION',
#  'DISQUALIFICATION',
#  'DISSEISIN',
#  'DISSENT',
#  'DISSENTING OPINION',
#  'DISSOLUTION',
#  'DISTINGUISH',
#  'DISTRAINER',
#  'DISTRAINT',
#  'DISTRESS',
#  'DISTRIBUTION',
#  'DISTRICT ATTORNEY',
#  'DISTRICT COURT',
#  'DISTURBANCE OF THE PEACE',
#  'DIVERS',
#  'DIVERSIONARY PROGRAMS',
#  'DIVERSIONARY PROGRAMS.PREVAILING PARTY',
#  'DIVERSITY JURISDICTION',
#  'DIVERSITY OF CITIZENSHIP',
#  'DIVESTITURE',
#  'DIVIDEND',
#  'DIVIDEND ADDITION',
#  'DIVIDEND DATE',
#  'DIVISIBLE CONTRACT',
#  'DIVISIBLE CONTRACTS',
#  'DIVORCE',
#  'DIVORCE A MENSA ET THORO',
#  'DNA',
#  'DNA TESTING',
#  'DNA. DNA',
#  'DOB',
#  'DOCKET',
#  'DOCTOR',
#  'DOCTRINE',
#  'DOCTRINE OF',
#  'DOCTRINE OF WORTHIER TITLE',
#  'DOCUMENT',
#  'DOCUMENT OF TITLE',
#  'DOCUMENTARY EVIDENCE',
#  'DOLUS',
#  'DOMAIN',
#  'DOMESDAY BOOK',
#  'DOMICILE',
#  'DOMICILIARY',
#  'DOMINANT ESTATE',
#  'DOMINION',
#  'DONATED SURPLUS',
#  'DONATIO L',
#  'DONATION',
#  'DONATION.',
#  'DONATIVE INTENT',
#  'DONEE',
#  'DONEE BENEFICIARY',
#  'DONOR',
#  'DOUBLE',
#  'DOUBLE DAMAGES',
#  'DOUBLE JEOPARDY',
#  'DOUBT',
#  'DOWAGER',
#  'DOWER',
#  'DOWRY',
#  'DQ A',
#  'DQ ALPHA',
#  'DRAFT',
#  'DRAM SHOPACT',
#  'DRAW',
#  'DRAWEE',
#  'DRAWER',
#  'DRAWING',
#  'DRAWN',
#  'DRIVING WHILE INTOXICATED',
#  'DROIT F',
#  'DRUG ABUSE',
#  'DRUG LAW',
#  'DRUGS',
#  'DTC',
#  'DUAL CITIZENSHIP',
#  'DUCES TECUM',
#  'DUE CARE',
#  'DUE COURSE',
#  'DUE DATE',
#  'DUE DILIGENCE',
#  'DUE PROCESS',
#  'DUE PROCESS OF LAW',
#  'DUMMY',
#  'DUMMY CORPORATION',
#  'DUMMY DIRECTOR',
#  'DUMMY SHAREHOLDER',
#  'DUMPING',
#  'DUMPING LAW',
#  'DUPLICITOUS',
#  'DUPLICITY',
#  'DURESS',
#  'DURHAM RULE',
#  'DUTY',
#  'DUTY OF',
#  'DUTY OF CARE',
#  'DUTY OF PRODUCING EVIDENCE',
#  'DUTY TO',
#  'DUTY TO MITIGATE DAMAGES',
#  'DWELLING HOUSE',
#  'DYING DECLARATIONS',
#  'DYINGDECLARATIONS. U',
#  'E.E.O.C.',
#  'E.R.A.',
#  'EARNED SURPLUS',
#  'EARNINGS AND PROFITS',
#  'EARNINGS REPORT',
#  'EASEMENT',
#  'EASEMENT APPURTENANT',
#  'EASEMENT BY',
#  'EASEMENT BY PRESCRIPTION',
#  'EASEMENT IN',
#  'EASEMENT IN GROSS',
#  'EASEMENT OF NECESSITY',
#  'EAVESDROPPING',
#  'ECCLESIASTICAL LAW',
#  'ECONOMIC WASTE',
#  'ECU',
#  'EEARNEST',
#  'EEOC',
#  'EEOC). T',
#  'EFFECTIVE TAX RATE',
#  'EFFECTS',
#  'EGRESS',
#  'EIGHTH AMENDMENT',
#  'EIR',
#  'EIS',
#  'EJECTMENT',
#  'EJUSDEM GENERIS',
#  'ELECTION',
#  'ELECTION OF REMEDIES',
#  'ELECTION UNDER THE WILL',
#  'ELECTIVE',
#  'ELECTIVE FRANCHISE',
#  'ELECTIVE SHARE',
#  'ELEGIT',
#  'ELEGIT L',
#  'ELEMENT',
#  'ELEMENTS',
#  'ELEVENTH AMENDMENT',
#  'EMANCIPATION',
#  'EMBEZZLEMENT',
#  'EMBLEMENTS',
#  'EMBRACERY',
#  'EMINENT DOMAIN',
#  'EMOLUMENT',
#  'EMOTIONAL',
#  'EMOTIONAL DISTRESS',
#  'EMPLOYEE SHARE OWNERSHIP PLAN',
#  'EMPLOYEE STOCK OPTION',
#  'EMPLOYER',
#  'EMPLOYMENT RETIREMENT INCOME SECURITY ACT OF',
#  'EMPLOYMENT RETIREMENT INCOME SECURITYACT OF',
#  'EN BANC',
#  'EN GROS',
#  'EN VENTRE SA MERE',
#  'ENABLING CLAUSE',
#  'ENACTING CLAUSE',
#  'ENCLOSURE',
#  'ENCUMBRANCE',
#  'END LOAD PLAN',
#  'END MANAGEMENT COMPANY',
#  'END MUTUAL FUNDS',
#  'ENDORSEMENT',
#  'ENDOWMENT',
#  'ENDOWMENT INSURANCE',
#  'ENFEOFF',
#  'ENJOIN',
#  'ENJOYMENT',
#  'ENLARGEMENT',
#  'ENRICHMENT',
#  'ENTAIL',
#  'ENTIRETY',
#  'ENTITY',
#  'ENTRAPMENT',
#  'ENTRY',
#  'ENUMERATED',
#  'ENUMERATED POWERS',
#  'ENURE',
#  'ENVIRONMENTAL IMPACT STATEMENT',
#  'ENVIRONMENTAL PROTECTION AGENCY',
#  'EO INSTANTI',
#  'EPA',
#  'EQUAL EMPLOYMENT OPPORTUNITY COMMISSION',
#  'EQUAL OPPORTUNITY',
#  'EQUAL PROTECTION OF THE LAWS',
#  'EQUAL RIGHTS AMENDMENT',
#  'EQUAL TIME ACT',
#  'EQUALITY',
#  'EQUIPMENT',
#  'EQUITABLE',
#  'EQUITABLE DEFENSE',
#  'EQUITABLE DISTRIBUTION',
#  'EQUITABLE EASEMENT',
#  'EQUITABLE ESTATE',
#  'EQUITABLE ESTATES',
#  'EQUITABLE ESTOPPEL',
#  'EQUITABLE LIEN',
#  'EQUITABLE MORTGAGE',
#  'EQUITABLE RECOUPMENT',
#  'EQUITABLE RELIEF',
#  'EQUITABLE SALVAGE',
#  'EQUITABLE SEISIN',
#  'EQUITABLE SERVITUDE',
#  'EQUITABLE TITLE',
#  'EQUITABLE WASTE',
#  'EQUITY',
#  'EQUITY CAPITAL',
#  'EQUITY MARKET',
#  'EQUITY OF REDEMPTION',
#  'EREMPTORYCHALLENGES',
#  'ERGO L',
#  'ERISA',
#  'ERISA.',
#  'ERRONEOUS',
#  'ERRONEOUS JUDGMENT',
#  'ERROR',
#  'ERROROF LAW',
#  'ESCALATOR CLAUSE',
#  'ESCAPE CLAUSE',
#  'ESCHEAT',
#  'ESCROW',
#  'ESCROW AGENT',
#  'ESOP',
#  'ESQ.',
#  'ESQUIRE',
#  'ESSENCE',
#  'ESTABLISHMENT CLAUSE',
#  'ESTATE',
#  'ESTATE AT SUFFERANCE',
#  'ESTATE AT WILL',
#  'ESTATE BY THE ENTIRETY',
#  'ESTATE FOR LIFE',
#  'ESTATE FOR YEARS',
#  'ESTATE FROM YEAR TO YEAR',
#  'ESTATE IN',
#  'ESTATE IN COMMON',
#  'ESTATE IN COPARCENARY',
#  'ESTATE OF INHERITANCE',
#  'ESTATE PER AUTRE VIE',
#  'ESTATE TAX',
#  'ESTIMATED TAX',
#  'ESTOPPEL',
#  'ESTOPPEL BY',
#  'ESTOPPEL BY DEED',
#  'ESTOPPEL BY JUDGMENT',
#  'ESTOPPEL BY LACHES',
#  'ESTOPPEL IN PAIS',
#  'ESTOVERS',
#  'ET AL.',
#  'ET NON',
#  'ET SEQ.',
#  'ET UX.',
#  'ETHICAL',
#  'EURODOLLAR',
#  'EUTHANASIA',
#  'EVASION OF TAX',
#  'EVASIVE ANSWER',
#  'EVICTION',
#  'EVIDENCE',
#  'EVIDENCE ALIUNDE',
#  'EVIDENCE DE BENE ESSE',
#  'EX AEQUO ET BONO',
#  'EX CONTRACTU',
#  'EX DELICTO',
#  'EX GRATIA',
#  'EX OFFICIO',
#  'EX OFFICIO MEMBER',
#  'EX OFFICIO SERVICES',
#  'EX PARTE',
#  'EX POST FACTO',
#  'EX REL',
#  'EX TURPI CAUSA NON ORITUR ACTIO',
#  'EXAMINATION',
#  'EXAMPLE',
#  'EXAMPLE. T',
#  'EXCEPTION',
#  'EXCESSIVE BAIL',
#  'EXCHANGE',
#  'EXCHEQUER',
#  'EXCISE',
#  'EXCISE TAX',
#  'EXCLUSION',
#  'EXCLUSIONARY RULE',
#  'EXCLUSIVE USE',
#  'EXCONTRACTU',
#  'EXCULPATORY',
#  'EXCULPATORY CLAUSE',
#  'EXCUSABLE NEGLECT',
#  'EXECUTE',
#  'EXECUTED',
#  'EXECUTED INTEREST',
#  'EXECUTED REMAINDER',
#  'EXECUTED SALE',
#  'EXECUTION',
#  'EXECUTION OF INSTRUMENT',
#  'EXECUTION SALE',
#  'EXECUTIVE AGREEMENT',
#  'EXECUTIVE CLEMENCY',
#  'EXECUTIVE ORDER',
#  'EXECUTIVE PARDON',
#  'EXECUTIVE PRIVILEGE',
#  'EXECUTIVE PROCLAMATION',
#  'EXECUTOR',
#  'EXECUTORY',
#  'EXECUTORY BEQUEST',
#  'EXECUTORY CONTRACT',
#  'EXECUTORY CONTRACTS',
#  'EXECUTORY INTEREST',
#  'EXECUTORY SALE',
#  'EXECUTORY WAIVER',
#  'EXEMPLAR',
#  'EXEMPLARY',
#  'EXEMPLARY DAMAGES',
#  'EXEMPT',
#  'EXEMPTION',
#  'EXHAUSTION OF ADMINISTRATIVE REMEDIES',
#  'EXHAUSTION OF REMEDIES',
#  'EXHAUSTION OF STATE REMEDIES',
#  'EXHIBIT',
#  'EXIGENCY',
#  'EXIGENT CIRCUMSTANCES',
#  'EXIGIBLE',
#  'EXILE',
#  'EXPECTANCY',
#  'EXPECTATION DAMAGES',
#  'EXPENSE',
#  'EXPERT EVIDENCE',
#  'EXPERT TESTIMONY',
#  'EXPERT WITNESS',
#  'EXPORT',
#  'EXPRESS',
#  'EXPRESS AUTHORITY',
#  'EXPRESS POWERS',
#  'EXPRESS TRUST',
#  'EXPRESS WARRANTIES',
#  'EXPRESS WARRANTY',
#  'EXPRESSIO UNIUS EST EXCLUSIO ALTERIUS',
#  'EXPROPRIATION',
#  'EXPULSION',
#  'EXPUNGEMENT OF RECORDS',
#  'EXTENDI FACIAS',
#  'EXTENSION',
#  'EXTENUATING CIRCUMSTANCES',
#  'EXTINGUISHMENT',
#  'EXTORTION',
#  'EXTRADITION',
#  'EXTRAJUDICIAL',
#  'EXTRAORDINARY DIVIDENDS',
#  'EXTRAORDINARY REMEDY',
#  'EXTREMIS',
#  'EXTRINSIC',
#  'EXTRINSIC EVIDENCE',
#  'EXTRINSIC FRAUD',
#  'EYEWITNESS',
#  'F.A.S.',
#  'F.B.I.',
#  'F.C.I.',
#  'F.D.A.',
#  'F.I.C.A.',
#  'F.I.C.A. U',
#  'F.O.B.',
#  'F.O.I.A.',
#  'F.T.C.',
#  'FAA',
#  'FACE VALUE',
#  'FACIAL INVALIDITY',
#  'FACILITATION',
#  'FACINUS QUOS INQUINAT AEQUAT',
#  'FACT',
#  'FACT FINDER',
#  'FACTA SUNT PROTENTIORI VERBIS',
#  'FACTO L',
#  'FACTOR',
#  'FACTORAGE). H',
#  'FACTS',
#  'FACTUAL IMPOSSIBILITY',
#  'FACTUM L',
#  'FACTUM PROBANDUM',
#  'FAILURE OF CONSIDERATION',
#  'FAILURE OF ISSUE',
#  'FAILURE TO PROSECUTE',
#  'FAIR',
#  'FAIR COMMENT',
#  'FAIR COMPETITION',
#  'FAIR HEARING',
#  'FAIR LABOR PRACTICE',
#  'FAIR MARKET',
#  'FAIR MARKET VALUE',
#  'FAIR TRADE LAWS',
#  'FAIR USE',
#  'FAIR VALUE',
#  'FAIRNESS DOCTRINE',
#  'FALSE',
#  'FALSE ARREST',
#  'FALSE IMPRISONMENT',
#  'FALSE OATH',
#  'FALSE PRETENSE',
#  'FALSE RETURN',
#  'FALSE SWEARING',
#  'FALSE VERDICT',
#  'FALSI CRIMEN',
#  'FAMILY',
#  'FAMILY PURPOSE DOCTRINE',
#  'FAMOSUS LIBELLUS',
#  'FANNIE MAE',
#  'FARM PRODUCTS',
#  'FATAL VARIANCE',
#  'FAULT',
#  'FAULT DIVORCE',
#  'FAVORED BENEFICIARY',
#  'FBI',
#  'FCC',
#  'FDA',
#  'FEALTY',
#  'FEATHERBEDDING',
#  'FEDERAL',
#  'FEDERAL AVIATION ADMINISTRATION',
#  'FEDERAL BUREAU OF INVESTIGATION',
#  'FEDERAL COMMON LAW',
#  'FEDERAL CORRECTIONAL FACILITY',
#  'FEDERAL CORRECTIONAL INSTITUTION',
#  'FEDERAL CORRECTIONAL INSTITUTION (F.C.I.',
#  'FEDERAL COURTS',
#  'FEDERAL EMPLOYERS',
#  'FEDERAL INSURANCE CONTRIBUTION ACT',
#  'FEDERAL MAGISTRATE',
#  'FEDERAL QUESTION JURISDICTION',
#  'FEDERAL RESERVE SYSTEM',
#  'FEDERAL TAX LIEN',
#  'FEDERAL TORT CLAIMS ACT',
#  'FEDERAL TRADE COMMISSION',
#  'FEDERAL TRADE COMMISSION IMPROVEMENT ACT',
#  'FEDERALISM',
#  'FEE',
#  'FEE SIMPLE',
#  'FEE SIMPLE ABSOLUTE',
#  'FEE SIMPLE CONDITIONAL',
#  'FEE SIMPLE DEFEASIBLE',
#  'FEE SIMPLE DETERMINABLE',
#  'FEE TAIL',
#  'FEE TAIL FEMALE',
#  'FEE TAIL MALE',
#  'FELA',
#  'FELLOW SERVANT RULE',
#  'FELLOW SERVANTS',
#  'FELONY',
#  'FELONY MURDER',
#  'FENCE',
#  'FEOFFMENT',
#  'FERAE NATURAE',
#  'FERTILE OCTOGENARIAN',
#  'FEUDALISM',
#  'FFAA',
#  'FIAT JUSTITIA',
#  'FICTION',
#  'FIDUCIARY',
#  'FIERI FACIAS L',
#  'FIFO',
#  'FIFO.',
#  'FIFTEENTH AMENDMENT',
#  'FIFTH AMENDMENT',
#  'FIGHTING WORDS',
#  'FIGURE',
#  'FILE',
#  'FILIBUSTER',
#  'FILING',
#  'FINAL DECISION',
#  'FINAL DECREE',
#  'FINAL DECREES',
#  'FINAL HEARING',
#  'FINAL JUDGMENT',
#  'FINAL ORDER',
#  'FINANCE CHARGES',
#  'FINANCIAL INTERMEDIARY',
#  'FINANCIAL RESPONSIBILITY',
#  'FINANCIAL RESPONSIBILITY LAWS',
#  'FINANCIAL STATEMENT',
#  'FINDER',
#  'FINDER OF FACT',
#  'FINDING',
#  'FINE',
#  'FINGERPRINT',
#  'FIRM OFFER',
#  'FIRST',
#  'FIRST AMENDMENT',
#  'FIRST DEGREE MURDER',
#  'FIRST DEVISEE',
#  'FIRST IMPRESSION',
#  'FISC',
#  'FISC).FISCAL POLICY',
#  'FISCAL',
#  'FISCAL YEAR',
#  'FIT',
#  'FITNESS',
#  'FIXED',
#  'FIXED ASSETS',
#  'FIXED CAPITAL',
#  'FIXED INCOME',
#  'FIXED INVESTMENT TRUST',
#  'FIXED SALARY',
#  'FIXING',
#  'FIXTURE',
#  'FLIGHT',
#  'FLOAT',
#  'FLOATING DEBT',
#  'FLOATING LIEN',
#  'FOOD AND DRUG ADMINISTRATION',
#  'FOR',
#  'FORBEAR',
#  'FORBEARANCE',
#  'FORCE',
#  'FORCED HEIRS',
#  'FORCED SALE',
#  'FORCEDSALE',
#  'FORCIBLE',
#  'FORCIBLE DETAINER',
#  'FORCIBLE ENTRY',
#  'FORCIBLE ENTRYAND DETAINER',
#  'FORECLOSURE',
#  'FOREMAN',
#  'FORENSIC',
#  'FORENSIC MEDICINE',
#  'FOREPERSON',
#  'FORESEEABILITY',
#  'FORESEEABLE',
#  'FORESEEABLE RISK',
#  'FORFEITURE',
#  'FORGERY',
#  'FORM',
#  'FORMA PAUPERIS',
#  'FORMAL CONTRACT',
#  'FORMS OF ACTION',
#  'FORNICATION',
#  'FORUM',
#  'FORUM NON CONVENIENS',
#  'FOUNDATION',
#  'FOUNDER',
#  'FOUR CORNERS',
#  'FOUR UNITIES',
#  'FOURTEENTH AMENDMENT',
#  'FOURTH AMENDMENT',
#  'FRANCHISE',
#  'FRANCHISE TAX',
#  'FRATRICIDE',
#  'FRAUD',
#  'FRAUD IN FACT',
#  'FRAUD IN LAW',
#  'FRAUD IN THE FACTUM',
#  'FRAUD IN THE INDUCEMENT',
#  'FRAUDULENT CONVEYANCE',
#  'FREE',
#  'FREE ALONGSIDE',
#  'FREE AND CLEAR',
#  'FREE AND COMMON SOCAGE',
#  'FREE EXERCISE CLAUSE',
#  'FREE ON BOARD',
#  'FREEDOM',
#  'FREEDOM OF',
#  'FREEDOM OF ASSOCIATION',
#  'FREEDOM OF CONTRACT',
#  'FREEDOM OF EXPRESSION',
#  'FREEDOM OF INFORMATION ACT',
#  'FREEDOM OF PRESS',
#  'FREEDOM OF RELIGION',
#  'FREEDOM OF SPEECH',
#  'FREEDOMOF PRESS',
#  'FREEHOLD',
#  'FREIGHT FORWARDER',
#  'FRESH PURSUIT',
#  'FRIEND',
#  'FRIEND OF THE COURT',
#  'FRIENDLY SUIT',
#  'FRINGE BENEFIT',
#  'FRINGE BENEFITS',
#  'FRISK',
#  'FRIVOLOUS',
#  'FRONT',
#  'FRUCTUS INDUSTRIALES',
#  'FRUCTUS NATURALES',
#  'FRUIT OF THE POISONOUS TREE DOCTRINE',
#  'FRUITS OF CRIME',
#  'FRUSTRATION OF PURPOSE',
#  'FTC',
#  'FUGITIVE FROM JUSTICE',
#  'FULL DISCLOSURE',
#  'FULL FAITH AND CREDIT',
#  'FUND',
#  'FUND IN COURT',
#  'FUNDED DEBT',
#  'FUNGIBLE',
#  'FUTURE ESTATE',
#  'FUTURE INTEREST',
#  'FUTURES',
#  'G.A.T.T.G',
#  'G.N.P.',
#  'G.N.P. S',
#  'GAIN',
#  'GAIN OR LOSS REALIZED',
#  'GAINFUL EMPLOYMENT',
#  'GAINS OR LOSSES',
#  'GAMBLING',
#  'GAME LAWS',
#  'GAOL',
#  'GARAGEMAN',
#  'GARNISH',
#  'GARNISHEE',
#  'GARNISHMENT',
#  'GAVELKIND',
#  'GENERAL APPEARANCE',
#  'GENERAL BUILDING',
#  'GENERAL CONTRACTOR',
#  'GENERAL COURT',
#  'GENERAL DENIAL',
#  'GENERAL FUND',
#  'GENERAL INTENT',
#  'GENERAL PARTNER',
#  'GENERAL POWER',
#  'GENERAL POWER OF APPOINTMENT',
#  'GENERAL TRAVERSE',
#  'GENERAL VERDICT',
#  'GENERAL WARRANTS',
#  'GENERAL WARRANTY DEED',
#  'GENERALPARTNERS',
#  'GENERALWARRANT',
#  'GENERATION SKIPPING TRANSFER',
#  'GENERATION SKIPPING TRUST',
#  'GENERIC',
#  'GENERIC DRUG LAW',
#  'GERRYMANDER',
#  'GGAG ORDER',
#  'GIFT',
#  'GIFT CAUSA MORTIS',
#  'GIFT IN',
#  'GIFT IN CONTEMPLATION OF DEATH',
#  'GIFT OVER',
#  'GIFT TAX',
#  'GINNIE MAE',
#  'GOING CONCERN VALUE',
#  'GOOD CAUSE',
#  'GOOD FAITH',
#  'GOOD SAMARITAN',
#  'GOOD TENANTABLE REPAIR',
#  'GOOD TITLE',
#  'GOOD UNTIL CANCELLED',
#  'GOOD WILL',
#  'GOODS',
#  'GOVERNMENT',
#  'GOVERNMENTAL FUNCTIONS',
#  'GOVERNMENTAL IMMUNITY',
#  'GRACE PERIOD',
#  'GRADED OFFENSE',
#  'GRAFT',
#  'GRAND JURY',
#  'GRAND LARCENY',
#  'GRANDFATHER CLAUSE',
#  'GRANT',
#  'GRANTEE INDEX',
#  'GRANTOR',
#  'GRANTOR TRUST',
#  'GRATIS',
#  'GRATUITOUS BAILMENT',
#  'GRATUITOUS PROMISE',
#  'GRATUITY',
#  'GRAVAMEN',
#  'GREAT CARE',
#  'GREAT CHARTER',
#  'GREAT WRIT',
#  'GREEN CARD',
#  'GRIEVANCE',
#  'GRIFFIN ACT',
#  'GROSS',
#  'GROSS ESTATE',
#  'GROSS INCOME',
#  'GROSS NATIONAL PRODUCT',
#  'GROSS NEGLIGENCE',
#  'GROUND RENT',
#  'GROWTH STOCK',
#  'GTC',
#  'GUARANTEE',
#  'GUARANTEE CLAUSE',
#  'GUARANTEED SECURITY',
#  'GUARANTOR',
#  'GUARANTY',
#  'GUARDIAN',
#  'GUARDIAN AD',
#  'GUARDIAN AD LITEM',
#  'GUEST',
#  'GUEST STATUTE',
#  'GUILD',
#  'GUILTY',
#  'GUN CONTROL LAW',
#  'HABENDUM',
#  'HABITABILITY',
#  'HABITUAL OFFENDER',
#  'HAEC VERBA',
#  'HALFWAY HOUSE',
#  'HALLUCINATION',
#  'HALLUCINOGENS',
#  'HANGED',
#  'HARASSMENT',
#  'HARD CASES',
#  'HARDSHIP',
#  'HARM',
#  'HARMLESS ERROR',
#  'HARTLEY ACT',
#  'HATE CRIME',
#  'HEAD OF HOUSEHOLD',
#  'HEADNOTE',
#  'HEARING',
#  'HEARING DE NOVO',
#  'HEARSAY RULE',
#  'HEART',
#  'HEDGE FUND',
#  'HEDGED',
#  'HEDGING',
#  'HEIR APPARENT',
#  'HEIRS',
#  'HEIRS AT LAW',
#  'HEIRS OF THE BODY',
#  'HELP',
#  'HEREDITAMENTS',
#  'HEREDITARY SUCCESSION',
#  'HHABEAS CORPUS',
#  'HIDDEN ASSET',
#  'HIDDEN DEFECT',
#  'HIDDEN INFLATION',
#  'HIDDEN TAX',
#  'HIGH MISDEMEANORS',
#  'HIJACKING',
#  'HIT',
#  'HIV',
#  'HLA',
#  'HLA DQ ALPHA',
#  'HOARDING',
#  'HOBBY LOSS',
#  'HOLD HARMLESS',
#  'HOLDER',
#  'HOLDER IN DUE COURSE',
#  'HOLDING',
#  'HOLDING CELL',
#  'HOLDING COMPANY',
#  'HOLDING COMPANY TAX',
#  'HOLDING PERIOD',
#  'HOLDOVER TENANCY',
#  'HOLDUP SUIT',
#  'HOLDUP SUITS',
#  'HOLOGRAPHIC WILL',
#  'HOMAGE',
#  'HOME PORT DOCTRINE',
#  'HOME RULE',
#  'HOMESTEAD',
#  'HOMESTEAD EXEMPTION LAWS',
#  'HOMICIDE',
#  'HONORABLE DISCHARGE',
#  'HONORARY',
#  'HORIZONTAL PRICE FIXING',
#  'HORIZONTAL PRIVITY',
#  'HORNBOOK',
#  'HORNBOOK LAW',
#  'HORS F',
#  'HOSTILE',
#  'HOSTILE POSSESSION',
#  'HOSTILE WITNESS',
#  'HOSTILE) WITNESS',
#  'HOT PURSUIT',
#  'HOUSE',
#  'HOUSE OF PROSTITUTION',
#  'HUNG JURY',
#  'HUSBAND',
#  'HYBRIDTHEORY',
#  'HYPNOSIS',
#  'HYPOTHECATE',
#  'HYPOTHETICAL QUESTION',
#  'I.D.B.',
#  'I.R.B.',
#  'I.R.C.',
#  'I.R.S.',
#  'ICC',
#  'ID. L',
#  'IGNORANCE',
#  'IGNORANTIA LEGIS NON EXCUSAT',
#  'IIBID. L',
#  'III',
#  'ILLEGAL',
#  'ILLEGAL ALIEN',
#  'ILLEGALLY OBTAINED EVIDENCE',
#  'ILLEGITIMATE',
#  'ILLINOIS LAND TRUST',
#  'ILLUSORY PROMISE',
#  'IMMATERIAL',
#  'IMMEDIATE CAUSE',
#  'IMMIGRATION',
#  'IMMORAL CONDUCT',
#  'IMMUNITIES',
#  'IMMUNITY',
#  'IMPACT RULE',
#  'IMPAIR THE OBLIGATION OF A CONTRACT',
#  'IMPANEL',
#  'IMPANELING',
#  'IMPEACH',
#  'IMPERTINENT MATTER',
#  'IMPLEADER',
#  'IMPLICATION',
#  'IMPLIED',
#  'IMPLIED CONSENT',
#  'IMPLIED CONTRACT',
#  'IMPLIED EASEMENT',
#  'IMPLIED NOTICE',
#  'IMPLIED POWERS',
#  'IMPLIED TRUST',
#  'IMPLIED WARRANTIES',
#  'IMPLIED WARRANTY',
#  'IMPLIEDAUTHORITY',
#  'IMPORT',
#  'IMPORTATION',
#  'IMPOSSIBILITY',
#  'IMPOST',
#  'IMPOUND',
#  'IMPOUNDING',
#  'IMPOUNDMENT',
#  'IMPRESSION',
#  'IMPRIMATUR',
#  'IMPRISONMENT',
#  'IMPROVEMENT',
#  'IMPUTE',
#  'IMPUTED',
#  'IMPUTED INCOME',
#  'IMPUTED LIABILITY',
#  'IN ABSENTIA',
#  'IN ARTICULO MORTIS',
#  'IN BANC',
#  'IN CAMERA',
#  'IN CAPITE',
#  'IN CHAMBERS',
#  'IN CHIEF',
#  'IN DELICTO',
#  'IN ESCROW',
#  'IN ESSE',
#  'IN EXTREMIS',
#  'IN FEE',
#  'IN FEE SIMPLE',
#  'IN FORMA PAUPERIS',
#  'IN FUTURO',
#  'IN GENERE',
#  'IN GROSS',
#  'IN HAEC VERBA',
#  'IN HOC',
#  'IN INVITUM',
#  'IN JEOPARDY',
#  'IN KIND',
#  'IN LIMINE',
#  'IN LOCO PARENTIS',
#  'IN MORTMAIN',
#  'IN OMNIBUS',
#  'IN PAIS',
#  'IN PARI DELICTO',
#  'IN PARI MATERIA',
#  'IN PERPETUITY',
#  'IN PERSONAM',
#  'IN PERSONAM JURISDICTION',
#  'IN POSSE',
#  'IN PRAESENTI',
#  'IN QUANTUM MERUIT',
#  'IN RE',
#  'IN REM',
#  'IN SE',
#  'IN SPECIE',
#  'IN STATU QUO',
#  'IN STATU QUO ANTE',
#  'IN SURPLUS',
#  'IN TERROREM',
#  'IN TOTO',
#  'IN VACUO',
#  'IN VENTRE SA MERE',
#  'INALIENABLE RIGHTS',
#  'INCAPACITY',
#  'INCARCERATION',
#  'INCENDIARY',
#  'INCEST',
#  'INCHOATE',
#  'INCHOATE DOWER',
#  'INCIDENT OF OWNERSHIP',
#  'INCIDENTAL BENEFICIARY',
#  'INCIDENTAL DAMAGES',
#  'INCLOSURE',
#  'INCLUDED OFFENSE',
#  'INCOME',
#  'INCOME AVERAGING',
#  'INCOME IN RESPECT OF A DECEDENT',
#  'INCOME SPLITTING',
#  'INCOME STATEMENT',
#  'INCOME TAX',
#  'INCOME TAXES',
#  'INCOMPETENCY',
#  'INCOMPETENT EVIDENCE',
#  'INCONSISTENT',
#  'INCONSISTENT STATEMENT',
#  'INCONTESTABILITY CLAUSE',
#  'INCONVENIENT FORUM',
#  'INCORPORATE',
#  'INCORPORATION',
#  'INCORPOREAL',
#  'INCORPOREAL HEREDITAMENT',
#  'INCORPOREAL HEREDITAMENTS',
#  'INCORRIGIBLE',
#  'INCREMENT',
#  'INCRIMINATE',
#  'INCRIMINATION',
#  'INCROACH',
#  'INCULPATORY',
#  'INCUMBENT',
#  'INCUMBRANCE',
#  'INDEBITATUS ASSUMPSIT',
#  'INDEBTEDNESS',
#  'INDECENT',
#  'INDECENT EXPOSURE',
#  'INDEFEASIBLE',
#  'INDEFINITE',
#  'INDEFINITE FAILURE OF ISSUE',
#  'INDEMNIFY',
#  'INDEMNITY',
#  'INDENTURE',
#  'INDEPENDENT',
#  'INDEPENDENT CONTRACTOR',
#  'INDETERMINATE SENTENCE',
#  'INDEX',
#  'INDEX FUND',
#  'INDIAN CLAIMS COMMISSION',
#  'INDIAN LAW',
#  'INDIAN RESERVATION',
#  'INDIAN TITLE',
#  'INDICIA L',
#  'INDICIUM L',
#  'INDICTABLE OFFENSES',
#  'INDICTMENT',
#  'INDIGENT',
#  'INDIGNITY',
#  'INDIRECT ATTACK',
#  'INDIRECT EVIDENCE',
#  'INDISPENSABLE EVIDENCE',
#  'INDISPENSABLE PARTY',
#  'INDIVIDUAL RETIREMENT ACCOUNT',
#  'INDORSEE',
#  'INDORSEMENT',
#  'INDORSER',
#  'INDUSTRIAL DEVELOPMENT BOND',
#  'INDUSTRIAL RESERVE BANK',
#  'INDUSTRIAL RESERVE BOND',
#  'INELIGIBILITY',
#  'INFAMOUS CRIME',
#  'INFANCY',
#  'INFERENCE',
#  'INFERIOR COURT',
#  'INFEUDATION',
#  'INFIRM',
#  'INFLUENCE',
#  'INFORMAL PROCEEDINGS',
#  'INFORMATION',
#  'INFORMATION AND BELIEF',
#  'INFORMATION RETURN',
#  'INFORMED',
#  'INFORMED CONSENT',
#  'INFORMER',
#  'INFRA L',
#  'INFRINGEMENT',
#  'INFRINGEMENT OF COPYRIGHT',
#  'INFRINGEMENT OF PATENT',
#  'INGRESS AND EGRESS',
#  'INHERENT',
#  'INHERENT CONSTITUTIONAL POWERS',
#  'INHERENT DEFECT',
#  'INHERENT POWERS',
#  'INHERENT RIGHT',
#  'INHERIT',
#  'INHERITANCE',
#  'INITIATIVE',
#  'INJUNCTION',
#  'INJURIA ABSQUE DAMNO',
#  'INJURIA NON EXCUSAT INJURIAM',
#  'INJURY',
#  'INMATE',
#  'INNOCENT PURCHASER',
#  'INNS OF COURT',
#  'INNUENDO',
#  'INQUEST',
#  'INQUIRY NOTICE',
#  'INSANE DELUSION',
#  'INSANITY',
#  'INSANITY PLEA',
#  'INSIDER',
#  'INSIDER TRADING',
#  'INSOLVENCY',
#  'INSOLVENCY PRECEEDINGS',
#  'INSOLVENCY PROCEEDINGS',
#  'INSPECTION OF DOCUMENTS',
#  'INSTALLMENT',
#  'INSTALLMENT CONTRACT',
#  'INSTALLMENT SALE',
#  'INSTANT MATTER',
#  'INSTITUTION',
#  'INSTRUCTION',
#  'INSTRUMENT',
#  'INSTRUMENTALITY',
#  'INSUFFICIENT EVIDENCE',
#  'INSURABLE INTEREST',
#  'INSURANCE',
#  'INSURED',
#  'INSURRECTION',
#  'INTANGIBLE ASSET',
#  'INTANGIBLE PROPERTY',
#  'INTEGRATION',
#  'INTENDMENT OF LAW',
#  'INTENT',
#  'INTENTIONAL INFLICTION OF EMOTIONAL',
#  'INTER ALIA',
#  'INTER PARES',
#  'INTER PARTES',
#  'INTER SE',
#  'INTER SESE',
#  'INTER VIVOS',
#  'INTERCEPTION',
#  'INTEREST',
#  'INTEREST.P',
#  'INTERIM FINANCING',
#  'INTERIM ORDER',
#  'INTERLOCKING DIRECTORATE',
#  'INTERLOCUTORY',
#  'INTERLOCUTORY DECREE',
#  'INTERLOCUTORY DECREES',
#  'INTERLOCUTORY ORDER',
#  'INTERLOCUTORY SENTENCE',
#  'INTERMEDDLER',
#  'INTERNAL REVENUE CODE',
#  'INTERNAL REVENUE SERVICE',
#  'INTERNATIONAL AGREEMENTS',
#  'INTERNATIONAL COURT OF JUSTICE',
#  'INTERNATIONAL LAW',
#  'INTERPLEADER',
#  'INTERROGATION',
#  'INTERROGATORIES',
#  'INTERSTATE COMMERCE',
#  'INTERSTATE COMMERCE COMMISSION',
#  'INTERSTATE COMPACT',
#  'INTERSTATE COMPACTS',
#  'INTERVAL OWNERSHIP',
#  'INTERVENING',
#  'INTERVENING CAUSE',
#  'INTERVENOR',
#  'INTERVENTION',
#  'INTESTACY',
#  'INTESTATE',
#  'INTESTATE SUCCESSION',
#  'INTOXICATION',
#  'INTRINSIC EVIDENCE',
#  'INTRINSIC FRAUD',
#  'INURE',
#  'INVALID ON ITS FACE',
#  'INVASION OF',
#  'INVASION OF PRIVACY',
#  'INVENTION',
#  'INVENTORY',
#  'INVERSE ORDER OF ALIENATION',
#  'INVEST',
#  'INVESTIGATORY POWERS',
#  'INVESTITURE',
#  'INVESTMENT',
#  'INVESTMENT BANKER',
#  'INVESTMENT COMPANY',
#  'INVESTMENT COMPANY ACT OF',
#  'INVESTMENT STOCK',
#  'INVESTMENT TAX CREDIT',
#  'INVESTORS ADVISORS ACT OF',
#  'INVITEE',
#  'INVOLUNTARY',
#  'INVOLUNTARY BAILMENT',
#  'INVOLUNTARY MANSLAUGHTER',
#  'INVOLUNTARY NONSUIT',
#  'INVOLUNTARY PROCEEDING',
#  'INVOLUNTARY TRUST',
#  'IOLTA',
#  'IPSE DIXIT',
#  'IPSO FACTO',
#  'IPSO JURE',
#  'IRA',
#  'IRRELEVANT',
#  'IRREPARABLE INJURY',
#  'IRS',
#  'IRS.',
#  'ISSUE',
#  'ISSUE PRECLUSION',
#  'ISSUED',
#  'ITEMIZED DEDUCTIONS',
#  'J.A.G.',
#  'J.D.',
#  'J.D.J',
#  'J.P.',
#  'JAIL',
#  'JAILHOUSE LAWYER',
#  'JANE DOE',
#  'JEOPARDY',
#  'JEOPARDY ASSESSMENT',
#  'JJ.',
#  'JOBBER',
#  'JOBS CREDIT',
#  'JOHN',
#  'JOINDER',
#  'JOINDER OF ISSUE',
#  'JOINT',
#  'JOINT ACCOUNT',
#  'JOINT AND SEVERAL',
#  'JOINT CUSTODY',
#  'JOINT ENTERPRISE',
#  'JOINT LIABILITY',
#  'JOINT LIVES',
#  'JOINT OWNERSHIP',
#  'JOINT RETURN',
#  'JOINT STOCK COMPANY',
#  'JOINT TENANCY',
#  'JOINT TENANTS',
#  'JOINT TORTFEASORS',
#  'JOINT VENTURE',
#  'JOINTTENANCY',
#  'JOINTURE',
#  'JONES ACT',
#  'JOURNALIST',
#  'JOYRIDING',
#  'JUDGE',
#  'JUDGMENT',
#  'JUDGMENT BY DEFAULT',
#  'JUDGMENT CREDITOR',
#  'JUDGMENT DEBTOR',
#  'JUDGMENT IN REM',
#  'JUDGMENT N.O.V.',
#  'JUDGMENT OF CONVICTION',
#  'JUDGMENT ON THE MERITS',
#  'JUDGMENT PROOF',
#  'JUDICATURE',
#  'JUDICIAL',
#  'JUDICIAL ACTIVISM',
#  'JUDICIAL DISCRETION',
#  'JUDICIAL ECONOMY',
#  'JUDICIAL ERROR',
#  'JUDICIAL IMMUNITY',
#  'JUDICIAL NOTICE',
#  'JUDICIAL RESTRAINT',
#  'JUDICIAL REVIEW',
#  'JUDICIAL SALE',
#  'JUDICIALADMISSION',
#  'JUDICIARY',
#  'JUMP BAIL',
#  'JURAL',
#  'JURAT L',
#  'JURE UXORIS',
#  'JURIS DOCTOR',
#  'JURIS IGNORANTIA EST CUM NOSTRUM IGNORAMUS',
#  'JURIS L',
#  'JURISDICTION',
#  'JURISDICTIONAL AMOUNT',
#  'JURISPRUDENCE',
#  'JURIST',
#  'JUROR',
#  'JURY',
#  'JURY OF THE VICINAGE',
#  'JURY TRIAL',
#  'JURY VOIR DIRE',
#  'JURYTAMPERING. S',
#  'JUS ACCRESCENDI',
#  'JUS TERTII',
#  'JUST COMPENSATION',
#  'JUSTICE OF THE PEACE',
#  'JUSTICIABLE',
#  'JUSTICIABLE CONTROVERSY',
#  'JUSTIFIABLE HOMICIDE',
#  'JUSTIFICATION',
#  'JUVENILE',
#  'JUVENILE COURTS',
#  'JUVENILE DELINQUENT',
#  'KEOGH PLAN',
#  'KEY NUMBERS',
#  'KICKBACK',
#  'KIDNAPPING',
#  'KIN',
#  'KIND',
#  'KIND EXCHANGE',
#  'KING',
#  'KINSHIP',
#  'KKANGAROO COURT',
#  'L.J.',
#  'L.S.',
#  'L.S. C',
#  'L.S. S',
#  'LABOR PRACTICE',
#  'LABOR UNION',
#  'LACHES',
#  'LACHES.EXAMPLE',
#  'LADING',
#  'LAME DUCK',
#  'LAND',
#  'LAND TRUST',
#  'LANDLORD',
#  'LANDMARK CASE',
#  'LANDRUM',
#  'LAPSE',
#  'LARCENY',
#  'LAST',
#  'LAST ANTECEDENT DOCTRINE',
#  'LAST CLEAR CHANCE',
#  'LAST WILL AND TESTAMENT',
#  'LATENT AMBIGUITY',
#  'LATENT DEFECT',
#  'LATERAL SUPPORT',
#  'LAW',
#  'LAW CLERK',
#  'LAW COPYRIGHT',
#  'LAW MARRIAGE',
#  'LAW MERCHANT',
#  'LAW OF ADMIRALTY',
#  'LAW OF CAPTURE',
#  'LAW OF THE CASE',
#  'LAW OF THE LAND',
#  'LAW REPORTS',
#  'LAWCOPYRIGHT',
#  'LAWFUL',
#  'LAWS',
#  'LAWSUIT',
#  'LAWTRUST',
#  'LAY',
#  'LAYWITNESS',
#  'LEADING',
#  'LEADING CASE',
#  'LEADING QUESTION',
#  'LEASE',
#  'LEASE AND RELEASE',
#  'LEASEHOLD',
#  'LEAVE OF COURT',
#  'LEGACY',
#  'LEGAL',
#  'LEGAL AGE',
#  'LEGAL AID SOCIETY',
#  'LEGAL ASSISTANT',
#  'LEGAL CAPACITY TO SUE',
#  'LEGAL CONSIDERATION',
#  'LEGAL DETRIMENT',
#  'LEGAL DISCRETION',
#  'LEGAL DUTY',
#  'LEGAL ESTATE',
#  'LEGAL FICTION',
#  'LEGAL HEIRS',
#  'LEGAL IMPOSSIBILITY',
#  'LEGAL INJURY',
#  'LEGAL NOTICE',
#  'LEGAL SECRETARY',
#  'LEGAL SEPARATION',
#  'LEGAL SERVICES CORPORATION',
#  'LEGAL TENDER',
#  'LEGATEE',
#  'LEGISLATION',
#  'LEGISLATIVE HISTORY',
#  'LEGISLATIVE INTENT',
#  'LEND',
#  'LESSEE',
#  'LESSER',
#  'LESSOR',
#  'LET',
#  'LETTER OF CREDIT',
#  'LETTER OF INTENT',
#  'LETTER RULING',
#  'LETTER STOCK',
#  'LETTERS OF',
#  'LETTERS OF ADMINISTRATION',
#  'LETTERS OF ADMINISTRATION CTA',
#  'LETTERS ROGATORY',
#  'LETTERS TESTAMENTARY',
#  'LEVARI FACIAS',
#  'LEVERAGE',
#  'LEVY',
#  'LEWDNESS',
#  'LEX LOCI CONTRACTUS',
#  'LEX LOCI DELICTI',
#  'LEXIS',
#  'LIABILITY',
#  'LIABILITY ACT',
#  'LIABILITY WITHOUT FAULT',
#  'LIABILITY.EXAMPLE',
#  'LIABLE',
#  'LIBEL',
#  'LIBERTIES',
#  'LIBERTY',
#  'LICENSE',
#  'LICENSE TAX',
#  'LICENSEE',
#  'LICENSOR',
#  'LIE DETECTOR TEST',
#  'LIEN',
#  'LIEN JURISDICTION',
#  'LIEN THEORY',
#  'LIEN THEORY OF MORTGAGE',
#  'LIFE ESTATE',
#  'LIFE EXPECTANCY',
#  'LIFE INTEREST',
#  'LIFE TENANT',
#  'LIFO',
#  'LIKE',
#  'LIMINE',
#  'LIMITATION',
#  'LIMITATIONS',
#  'LIMITATIONS PERIOD',
#  'LIMITED JURISDICTION',
#  'LIMITED LIABILITY',
#  'LIMITED PARTNERS',
#  'LIMITED PARTNERSHIP',
#  'LINE',
#  'LINE METHOD',
#  'LINEAGE',
#  'LINEAL',
#  'LINEAL CONSANGUINITY',
#  'LINEUP',
#  'LIQUIDATE',
# ...
#  'SECURITIES INVESTOR PROTECTION CORPORATION',
#  'SECURITY',
#  'SECURITY DEPOSIT',
#  'SECURITY INTEREST',
#  'SEDITION',
#  'SEDITIOUS LIBEL',
#  'SEDUCTION',
#  'SEGREGATION',
#  'SEIGNEUR',
#  'SEIGNIOR',
#  'SEISED',
#  'SEISIN',
#  'SEIZURE',
#  'SELECTIVE',
#  'SELECTIVE ALLOCATION',
#  'SELECTIVE INCORPORATION',
#  'SELECTIVE SERVICE SYSTEM',
#  'SELF',
#  'SELL AGREEMENT',
#  'SELLER',
#  'SELLING SHORT',
#  'SENILE DEMENTIA',
#  'SENTENCE',
#  'SENTENCE REPORT',
#  'SEPARABLE CONTROVERSY',
#  'SEPARATE BUT EQUAL',
#  'SEPARATE PROPERTY',
#  'SEPARATION',
#  'SEPARATION AGREEMENT',
#  'SEPARATION OF POWER',
#  'SEQUESTER',
#  'SEQUESTRATION',
#  'SERIAL',
#  'SERIAL BOND',
#  'SERIATIM L',
#  'SERIES',
#  'SERVANT',
#  'SERVE',
#  'SERVICE (OF PROCESS',
#  'SERVICE BY',
#  'SERVICE BY PUBLICATION',
#  'SERVICES',
#  'SERVIENT ESTATE',
#  'SERVIENT TENEMENT',
#  'SERVITUDE',
#  'SERVITUDES',
#  'SESSION LAWS',
#  'SET ASIDE',
#  'SETBACK',
#  'SETOFF',
#  'SETTLEMENT',
#  'SETTLOR',
#  'SEVENTH AMENDMENT',
#  'SEVER',
#  'SEVERABILITY CLAUSE',
#  'SEVERABLE CONTRACT',
#  'SEVERABLE STATUTE',
#  'SEVERAL',
#  'SEVERALTY',
#  'SEVERANCE',
#  'SEVERE',
#  'SEX OFFENDER',
#  'SEXUAL ASSAULT',
#  'SEXUAL CONTACT',
#  'SEXUAL HARASSMENT',
#  'SHAM PLEADING',
#  'SHAM TRANSACTION',
#  'SHARE',
#  'SHARE AND SHARE ALIKE',
#  'SHAREHOLDER',
#  'SHAREHOLDERS',
#  'SHARING PLAN',
#  'SHELLEY',
#  'SHELTER',
#  'SHERIFF',
#  'SHERMAN ACT',
#  'SHERMAN ANTITRUST ACT',
#  'SHIELD LAWS',
#  'SHIFTING INTEREST',
#  'SHIFTING THE BURDEN OF PROOF',
#  'SHIFTING USE',
#  'SHIPMENT CONTRACT',
#  'SHOP',
#  'SHORT',
#  'SHORT AGAINST THE BOX',
#  'SHORT RATE',
#  'SHORT SELLING',
#  'SHORT SWING PROFITS',
#  'SHORT YEAR',
#  'SHOW CAUSE ORDER',
#  'SHOW UP',
#  'SIAC',
#  'SICK PAY',
#  'SIDE',
#  'SIGHT DRAFT',
#  'SIGNATURE',
#  'SILENT PARTNER',
#  'SILVER PLATTER DOCTRINE',
#  'SIMPLE CONTRACT',
#  'SIMPLE NEGLIGENCE',
#  'SIMPLE TRUST',
#  'SIMPLICITER',
#  'SIMULTANEOUS DEATH ACT',
#  'SINE DIE',
#  'SINE QUA NON',
#  'SINKING FUND',
#  'SIPC',
#  'SISTERN',
#  'SITUS',
#  'SIXTH AMENDMENT',
#  'SKY LAWS',
#  'SKYJACKING',
#  'SLANDER',
#  'SLANDER OF GOODS',
#  'SLANDEROUS PER QUOD',
#  'SLANDEROUS PER SE',
#  'SLIGHT CARE',
#  'SLIGHT NEGLIGENCE',
#  'SLIP OPINION',
#  'SMALL CLAIMS COURT',
#  'SOCAGE',
#  'SOCIAL GUEST',
#  'SOCIAL SECURITY',
#  'SODOMY',
#  'SOLDIER',
#  'SOLE PROPRIETORSHIP',
#  'SOLEMNITY OF CONTRACT',
#  'SOLICITATION',
#  'SOLICITOR',
#  'SOLICITOR GENERAL',
#  'SOLVENCY',
#  'SOUND',
#  'SOUND AND DISPOSING MIND AND MEMORY',
#  'SOUND BODY',
#  'SOUND MIND',
#  'SOUNDS IN',
#  'SOVEREIGN',
#  'SOVEREIGN IMMUNITY',
#  'SPACE ARBITRAGE',
#  'SPECIAL',
#  'SPECIAL APPEARANCE',
#  'SPECIAL ASSUMPSIT',
#  'SPECIAL CONTRACT',
#  'SPECIAL COURT',
#  'SPECIAL DAMAGES',
#  'SPECIAL DEMURRER',
#  'SPECIAL INDORSEMENT',
#  'SPECIAL JURISDICTION',
#  'SPECIAL LEGISLATION',
#  'SPECIAL MASTER',
#  'SPECIAL POWER',
#  'SPECIAL POWER OF APPOINTMENT',
#  'SPECIAL PROSECUTOR',
#  'SPECIAL TRAVERSE',
#  'SPECIAL VERDICT',
#  'SPECIALAPPEARANCE',
#  'SPECIALTY',
#  'SPECIE',
#  'SPECIFIC BEQUEST',
#  'SPECIFIC DENIAL',
#  'SPECIFIC INTENT',
#  'SPECIFIC MENS REA',
#  'SPECIFIC PERFORMANCE',
#  'SPECIFIC RELIEF',
#  'SPECULATION',
#  'SPEECH',
#  'SPEECH OR DEBATE CLAUSE',
#  'SPEED',
#  'SPEEDY TRIAL',
#  'SPENDING POWER',
#  'SPENDTHRIFT TRUST',
#  'SPLIT GIFT',
#  'SPLIT SENTENCE',
#  'SPLITTING A CAUSE OF ACTION',
#  'SPOT ZONING',
#  'SPOUSAL DISQUALIFICATION',
#  'SPOUSE',
#  'SPRINGING INTEREST',
#  'SPRINGING USE',
#  'SQUEEZE',
#  'SSAILOR',
#  'STAKEHOLDER',
#  'STALKING',
#  'STANDARD DEDUCTION',
#  'STANDARD DEDUCTIONS',
#  'STANDARD OF CARE',
#  'STANDING',
#  'STANDING MUTE',
#  'STANDING ORDER',
#  'STAR CHAMBER',
#  'STARE DECISIS',
#  'STATE ACTION',
#  'STATE OR MUNICIPAL BONDS',
#  'STATE REMEDIES',
#  'STATEMENT',
#  'STATU QUO',
#  'STATUS CRIME',
#  'STATUS QUO',
#  'STATUS QUO ANTE',
#  'STATUTE',
#  'STATUTE OF',
#  'STATUTE OF DESCENT AND',
#  'STATUTE OF DESCENT AND DISTRIBUTION',
#  'STATUTE OF FRAUDS',
#  'STATUTE OF LIMITATIONS',
#  'STATUTE OF QUIA EMPTORES',
#  'STATUTE OF USES',
#  'STATUTE OF WILLS',
#  'STATUTORY ARSON',
#  'STATUTORY CONSTRUCTION',
#  'STATUTORY EXCEPTIONS',
#  'STATUTORY OFFENSE',
#  'STATUTORY OFFENSES',
#  'STATUTORY RAPE',
#  'STAY',
#  'STAY OF EXECUTION',
#  'STEP',
#  'STEP TRANSACTION',
#  'STIMULANTS',
#  'STIPULATION',
#  'STIRPES',
#  'STOCK',
#  'STOCK CERTIFICATE',
#  'STOCK CLEARING',
#  'STOCK CORPORATION',
#  'STOCK DIVIDEND',
#  'STOCK EXCHANGE',
#  'STOCK ISSUE',
#  'STOCK MARKET',
#  'STOCK OPTION',
#  'STOCK RIGHTS',
#  'STOCK SPLIT',
#  'STOCK WARRANT',
#  'STOCKBROKER',
#  'STOCKHOLDER',
#  'STOCKHOLDERS',
#  'STOLEN PROPERTY',
#  'STOP AND FRISK',
#  'STRADDLE',
#  'STRAIGHT',
#  'STRAIGHT BILL OF LADING',
#  'STRAIGHT LINE DEPRECIATION',
#  'STRAW MAN',
#  'STREET NAME',
#  'STRICT CONSTRUCTION',
#  'STRICT LIABILITY',
#  'STRICT SCRUTINY',
#  'STRIKE',
#  'STRIKE SUIT',
#  'SUA SPONTE',
#  'SUB JUDICE',
#  'SUB MODO',
#  'SUB NOMINE',
#  'SUB ROSA',
#  'SUB SILENTIO',
#  'SUBCHAPTER S',
#  'SUBCHAPTER S CORPORATION',
#  'SUBCONTRACTOR',
#  'SUBDIVISION',
#  'SUBINFEUDATION',
#  'SUBJACENT SUPPORT',
#  'SUBJECT MATTER',
#  'SUBJECT MATTER JURISDICTION',
#  'SUBJECT TO MORTGAGE',
#  'SUBJECT TO OPEN',
#  'SUBJECT TO PARTIAL DEFEASANCE',
#  'SUBLEASE',
#  'SUBLET',
#  'SUBMIT',
#  'SUBORDINATION',
#  'SUBORDINATION AGREEMENT',
#  'SUBORNATION OF PERJURY',
#  'SUBPOENA AD TESTIFICANDUM',
#  'SUBPOENA DUCES TECUM',
#  'SUBPOENA L',
#  'SUBROGATION',
#  'SUBROGEE',
#  'SUBROGOR',
#  'SUBSCRIBER',
#  'SUBSCRIPTION RIGHTS',
#  'SUBSEQUENT CONDITION',
#  'SUBSIDIARY',
#  'SUBSIDIARY CORPORATION',
#  'SUBSTANTIAL COMPLIANCE',
#  'SUBSTANTIAL PERFORMANCE',
#  'SUBSTANTIVE',
#  'SUBSTANTIVE DUE PROCESS',
#  'SUBSTANTIVE LAW',
#  'SUBSTITUTED BASIS',
#  'SUBSTITUTED SERVICE',
#  'SUBSTITUTION',
#  'SUBTENANT',
#  'SUCCESSION',
#  'SUCCESSIVE TERMS',
#  'SUCCESSOR',
#  'SUCCESSOR ADMINISTRATOR',
#  'SUE OUT',
#  'SUFFERANCE',
#  'SUI GENERIS',
#  'SUI JURIS',
#  'SUICIDE',
#  'SUIT',
#  'SUITOR',
#  'SUM ALIMONY PAYMENT',
#  'SUM CERTAIN',
#  'SUM DISTRIBUTION',
#  'SUM PAYMENT',
#  'SUMMARY COURT',
#  'SUMMARY JUDGMENT',
#  'SUMMARY PROCEEDING',
#  'SUMMATION',
#  'SUMMING UP',
#  'SUMMONS',
#  'SUNDAY CLOSING LAWS',
#  'SUNSHINE LAWS',
#  'SUO NOMINE',
#  'SUPERIOR COURT',
#  'SUPERSEDEAS L',
#  'SUPERSEDING CAUSE',
#  'SUPERVENING',
#  'SUPERVENING CAUSE',
#  'SUPPLEMENTAL',
#  'SUPPLEMENTAL ACT',
#  'SUPPLEMENTAL AFFIDAVIT',
#  'SUPPLEMENTAL ANSWER',
#  'SUPPLEMENTAL BILL',
#  'SUPPLEMENTAL CLAIM',
#  'SUPPLEMENTAL PLEADING',
#  'SUPPLEMENTAL PROCEEDING',
#  'SUPPLEMENTARY SECURITY INCOME',
#  'SUPPORT',
#  'SUPPRESS',
#  'SUPPRESSION OF EVIDENCE',
#  'SUPRA L',
#  'SUPREMACY CLAUSE',
#  'SUPREME COURT',
#  'SUPREME COURT OF APPEALS',
#  'SUPREME COURT OF ERRORS',
#  'SUPREME JUDICIAL COURT',
#  'SURCHARGE',
#  'SURETY',
#  'SURETY BOND',
#  'SURPLUS',
#  'SURREBUTTER',
#  'SURREJOINDER',
#  'SURRENDER',
#  'SURROGATE',
#  'SURROGATE MOTHER',
#  'SURROGATE PARENT',
#  'SURTAX',
#  'SURVEILLANCE',
#  'SURVIVAL STATUTE',
#  'SURVIVORSHIP',
#  'SUSPECT',
#  'SUSPECT CLASSIFICATION',
#  'SUSPENDED SENTENCE',
#  'SUSTAIN',
#  'SWEARING',
#  'SWEEPSTAKES',
#  'SWITCH',
#  'SYLLABUS',
#  'SYMBOLIC',
#  'SYMBOLIC DELIVERY',
#  'SYMBOLIC SPEECH',
#  'SYNDICATE',
#  'T.R.O.',
#  'T.RO.',
#  'TACKING',
#  'TAFT',
#  'TAIL',
#  'TAINT',
#  'TAINTED',
#  'TAINTED EVIDENCE',
#  'TAKING THE FIFTH',
#  'TANGIBLE PROPERTY',
#  'TARGET CORPORATION',
#  'TARGETED JOBS CREDIT',
#  'TAX',
#  'TAX BENEFIT DOCTRINE',
#  'TAX COURT',
#  'TAX CREDIT',
#  'TAX DEDUCTION',
#  'TAX EVASION',
#  'TAX EXEMPT',
#  'TAX EXPENDITURE',
#  'TAX EXPENDITURE BUDGET',
#  'TAX PREFERENCE ITEMS',
#  'TAX RATE',
#  'TAX REFUND',
#  'TAX RETURN',
#  'TAX SALE',
#  'TAX SHELTER',
#  'TAXABLE ESTATE',
#  'TAXABLE GIFT',
#  'TAXABLE INCOME',
#  'TAXABLE YEAR',
#  'TAXABLEINCOME',
#  'TAXING POWER',
#  'TAXPAYER',
#  'TEMPORARY',
#  'TEMPORARY INJUNCTION',
#  'TEMPORARY RESTRAINING ORDER',
#  'TEMPORE L',
#  'TENANCY',
#  'TENANCY AT',
#  'TENANCY AT SUFFERANCE',
#  'TENANCY AT WILL',
#  'TENANCY BY THE ENTIRETY',
#  'TENANCY FOR',
#  'TENANCY FOR YEARS',
#  'TENANCY FROM MONTH TO MTH',
#  'TENANCY FROM YEAR TO YEAR',
#  'TENANCY IN',
#  'TENANCY IN COMMON',
#  'TENANCYAT SUFFERANCE',
#  'TENANT',
#  'TENANT FOR',
#  'TENANT FOR LIFE',
#  'TENANT IN FEE (SIMPLE',
#  'TENANTABLE REPAIR',
#  'TENANTS BY THE',
#  'TENANTS IN',
#  'TENANTS IN COMMON',
#  'TENANTS IN TAIL',
#  'TENDER',
#  'TENDER OF DELIVERY',
#  'TENDER OFFER',
#  'TENEMENT',
#  'TENTH AMENDMENT',
#  'TENURE',
#  'TENURIAL OWNERSHIP',
#  'TERM CAPITAL GAIN',
#  'TERM CAPITAL GAIN OR LOSS',
#  'TERM CAPITAL GAINS OR LOSSES',
#  'TERM INSURANCE',
#  'TERM LIABILITIES',
#  'TERM LIABILITY',
#  'TERM OF ART',
#  'TERM OF COURT',
#  'TERMINABLE INTEREST',
#  'TERMINER',
#  'TERRITORIAL COURT',
#  'TERRITORIAL JURISDICTION',
#  'TERRITORIAL WATERS',
#  'TERROREM',
#  'TEST CASE',
#  'TESTACY',
#  'TESTAMENT',
#  'TESTAMENTARY CAPACITY',
#  'TESTAMENTARY DISPOSITION',
#  'TESTAMENTARY INTENT',
#  'TESTAMENTARY TRUST',
#  'TESTATOR',
#  'TESTATRIX',
#  'TESTIFY',
#  'TESTIMONIAL',
#  'TESTIMONIAL IMMUNITY',
#  'TESTIMONY',
#  'THE',
#  'THE COURT OF EXCHEQUER CHAMBER',
#  'THEFT',
#  'THING IN ACTION',
#  'THIRD PARTY',
#  'THIRD PARTY BENEFICIARY',
#  'THIRD PARTY PLAINTIFF',
#  'THIRD PARTYPLAINTIFF',
#  'THIRTEENTH AMENDMENT',
#  'THREAT',
#  'THRIFT INSTITUTIONS',
#  'TIDE LAND',
#  'TIME',
#  'TIME ARBITRAGE',
#  'TIME DRAFT',
#  'TIME IS OF THE ESSENCE',
#  'TIME SHARING',
#  'TITHE',
#  'TITLE',
#  'TITLE (OF A STATUTE',
#  'TITLE JURISDICTION',
#  'TITLE OF A',
#  'TITLE SEARCH',
#  'TITLE THEORY',
#  'TO WIT',
#  'TOLL',
#  'TOMBSTONE AD',
#  'TONNAGE',
#  'TONNAGE DUTY',
#  'TORT',
#  'TORT CLAIMS ACT',
#  'TORTFEASOR',
#  'TORTIOUS',
#  'TOTAL DISABILITY',
#  'TOTAL INCORPORATION',
#  'TOTAL INCORPORATION APPROACH',
#  'TOTAL LOSS',
#  'TOTALITY OF THE CIRCUMSTANCES TEST',
#  'TOTO',
#  'TOUCH AND CONCERN',
#  'TRACT',
#  'TRACT INDEX',
#  'TRADE',
#  'TRADE FIXTURE',
#  'TRADE NAME',
#  'TRADE SECRETS',
#  'TRADE USAGE',
#  'TRADEMARK',
#  'TRADITIONARY EVIDENCE',
#  'TRANSACTION',
#  'TRANSACTIONAL IMMUNITY',
#  'TRANSACTIONS OR OCCURRENCE TEST',
#  'TRANSCRIPT',
#  'TRANSFER',
#  'TRANSFER AGENT',
#  'TRANSFER IN CONTEMPLATION OF DEATH',
#  'TRANSFER TAX',
#  'TRANSFEREE LIABILITY',
#  'TRANSFERRED INTENT',
#  'TRAVERSE',
#  'TREASON',
#  'TREASURE TROVE',
#  'TREASURY',
#  'TREASURY BILL',
#  'TREASURY BOND',
#  'TREASURY NOTE',
#  'TREASURY STOCK',
#  'TREATY',
#  'TREATY CLAUSE',
#  'TREBLE',
#  'TREBLE DAMAGES',
#  'TREBLE) DAMAGES',
#  'TRESPASS',
#  'TRESPASS DE BONIS ASPORTATIS',
#  'TRESPASS ON THE CASE',
#  'TRESPASS QUARE CLAUSUM FREGIT',
#  'TRESPASS VI ET ARMIS',
#  'TRESPASSER',
#  'TRESSPASS ON THE CASE',
#  'TRIAL',
#  'TRIAL BY THE RECORD',
#  'TRIAL COURT',
#  'TRIAL DE NOVO',
#  'TRIAL LIST',
#  'TRIBUNAL',
#  'TRIER OF',
#  'TRIER OF FACT',
#  'TRIPARTITE',
#  'TROVER',
#  'TRUE BILL',
#  'TRUST',
#  'TRUST CERTIFICATE',
#  'TRUST COMPANY',
#  'TRUST DEED',
#  'TRUST FUND',
#  'TRUST INDENTURE',
#  'TRUST INDENTURE ACT OF',
#  'TRUSTEE',
#  'TRUSTEE IN BANKRUPTCY',
#  'TRUSTOR',
#  'TRUTH IN LENDING ACT',
#  'TRY TITLE',
#  'TTACIT',
#  'TUCKER ACT',
#  'TURNTABLE DOCTRINE',
#  'TURPITUDE',
#  'TWO FUNDS DOCTRINE',
#  'TWO PARTY CONSENT',
#  'TYING ARRANGEMENT',
#  'U. S.',
#  'U.C.C.',
#  'U.C.C.C.',
#  'U.G.M.A.',
#  'U.N. S',
#  'U.S.',
#  'U.S. C',
#  'U.S. D',
#  'U.S. G',
#  'U.S. N',
#  'U.S. S',
#  'U.S. T',
#  'U.S.C.A.',
#  'UBI SUPRA',
#  'UCC',
#  'ULTIMATE FACTS',
#  'ULTRAHAZARDOUS ACTIVITY',
#  'ULTRAVIRES L',
#  'UNAVOIDABLE ACCIDENT',
#  'UNCLEAN HANDS',
#  'UNCONDITIONAL DISCHARGE',
#  'UNCONSCIONABLE',
#  'UNCONSTITUTIONAL',
#  'UNDER COLOR OF LAW',
#  'UNDER COLOR OF TITLE',
#  'UNDER PROTEST',
#  'UNDER SEAL',
#  'UNDER THE INFLUENCE',
#  'UNDER THE WILL',
#  'UNDERLEASE',
#  'UNDERWRITE',
#  'UNDISCLOSED PRINCIPAL',
#  'UNDIVIDED INTEREST',
#  'UNDUE',
#  'UNDUE INFLUENCE',
#  'UNEARNED SURPLUS',
#  'UNETHICAL',
#  'UNEXECUTED USE',
#  'UNFAIR COMPETITION',
#  'UNFAIR LABOR PRACTICE',
#  'UNFIT',
#  'UNIFIED ESTATE AND GIFT TAX',
#  'UNIFORM',
#  'UNIFORM ARBITRATION ACT',
#  'UNIFORM CODE OF MILITARY JUSTICE',
#  'UNIFORM COMMERCIAL CODE',
#  'UNIFORM CONSUMER CREDIT CODE',
#  'UNIFORM GIFTS TO MINORS ACT',
#  'UNIFORM LAWS',
#  'UNIFORM SYSTEM OF CITATION',
#  'UNIFORM) CODE OF MILITARY JUSTICE',
#  'UNILATERAL CONTRACT',
#  'UNILATERAL MISTAKE',
#  'UNION',
#  'UNION SHOP',
#  'UNIT',
#  'UNIT INVESTMENT TRUST',
#  'UNITED STATES',
#  'UNITED STATES ATTORNEY',
#  'UNITED STATES ATTORNEYS',
#  'UNITED STATES CLAIMS COURT',
#  'UNITED STATES CODE',
#  'UNITED STATES CODE ANNOTATED',
#  'UNITED STATES COURTS',
#  'UNITED STATES MAGISTRATE',
#  'UNITED STATES TRUSTEE',
#  'UNITIES',
#  'UNITY OF',
#  'UNITY OF INTEREST',
#  'UNITY OF PERSON',
#  'UNITY OF POSSESSION',
#  'UNITY OF TIME',
#  'UNITY OF TITLE',
#  'UNIVERSAL AGENT',
#  'UNJUST ENRICHMENT',
#  'UNLAWFUL',
#  'UNLAWFUL ACT MANSLAUGHTER',
#  'UNLAWFUL ASSEMBLY',
#  'UNLAWFUL DETAINER',
#  'UNLAWFUL ENTRY',
#  'UNLAWFUL FORCE',
#  'UNLAWFULDETAINER STATUTES',
#  'UNLIQUIDATED',
#  'UNLISTED SECURITY',
#  'UNLISTED STOCK',
#  'UNNATURAL ACT',
#  'UNNECESSARY',
#  'UNNECESSARY HARDSHIP',
#  'UNREALIZED APPRECIATION',
#  'UNREASONABLE',
#  'UNREASONABLE PUNISHMENT',
#  'UNREASONABLE RESTRAINT OF TRADE',
#  'UNREASONABLE SEARCH AND SEIZURE',
#  'UNUSUAL PUNISHMENT',
#  'UP BASIS',
#  'UP TICK',
#  'USAGE OF',
#  'USAGE OF TRADE',
#  'USE',
#  'USE IMMUNITY',
#  'USE TAX',
#  'USEFUL LIFE',
#  'USUFRUCT',
#  'USURIOUS CONTRACT',
#  'USURY',
#  'UTILITY',
#  'UTMOST CARE',
#  'UTMOST RESISTANCE',
#  'UTTER',
#  'UUBI L',
#  'UXOR',
#  'VAGRANCY',
#  'VAGUENESS',
#  'VALUABLE CONSIDERATION',
#  'VALUATION',
#  'VALUE',
#  'VALUE ADDED TAX',
#  'VALUE. S',
#  'VANDALISM',
#  'VARIANCE',
#  'VASSAL',
#  'VEIL',
#  'VEL NON',
#  'VENAL',
#  'VEND',
#  'VENDEE',
#  'VENDOR',
#  'VENIRE DE NOVO',
#  'VENIRE L',
#  'VENUE',
#  'VERACITY',
#  'VERDICT',
#  'VERIFICATION',
#  'VERTICAL PRICE FIXING',
#  'VERTICAL PRIVITY',
#  'VESTED',
#  'VESTED ESTATE',
#  'VESTED INTEREST',
#  'VESTED REMAINDER',
#  'VESTED RIGHTS',
#  'VETO',
#  'VEXATIOUS LITIGATION',
#  'VI  ET ARMIS',
#  'VICARIOUS LIABILITY',
#  'VICE CRIMES',
#  'VICINAGE',
#  'VICTUALER',
#  'VICTUALLER',
#  'VICTUALS',
#  'VIDELICET',
#  'VIDUITATE',
#  'VIDUITY',
#  'VIEW',
#  'VII',
#  'VILLEIN SOCAGE',
#  'VILLENAGE',
#  'VIOLATION OF PROBATION',
#  'VIOLENCE',
#  'VIOLENT',
#  'VIR L',
#  'VIRTUAL REPRESENTATION',
#  'VIS MAJOR',
#  'VISA',
#  'VISITATION',
#  'VISITATION RIGHTS',
#  'VITALIZED',
#  'VITIATE',
#  'VIZ L',
#  'VOICE EXEMPLAR',
#  'VOID',
#  'VOID FOR VAGUENESS',
#  'VOID ON ITS FACE',
#  'VOIDABLE',
#  'VOIDABLE PREFERENCE',
#  'VOIR DIRE',
#  'VOIR DIRE EXAMINATION',
#  'VOLENTI NON FIT INJURIA',
#  'VOLUNTARY APPEARANCE',
#  'VOLUNTARY DISABLEMENT',
#  'VOLUNTARY DISSOLUTION',
#  'VOLUNTARY MANSLAUGHTER',
#  'VOLUNTARY NONSUIT',
#  'VOLUNTARY PROCEEDING',
#  'VOLUNTARY WASTE',
#  'VOLUNTARYDISABLEMENT.ANTI',
#  'VOTING',
#  'VOTING RIGHT',
#  'VOTING RIGHTS ACT',
#  'VOTING TRUST',
#  'VVACATE',
#  'WAGE',
#  'WAGE EARNER',
#  'WAGER OF LAW',
#  'WAGNER ACT',
#  'WAIT',
#  'WAITING PERIOD',
#  'WAIVER',
#  'WANT OF CONSIDERATION',
#  'WANT OF PROSECUTION',
#  'WANTON',
#  'WANTON NEGLIGENCE',
#  'WARD',
#  'WARDSHIP',
#  'WAREHOUSE RECEIPT',
#  'WAREHOUSEMAN',
#  'WARRANT',
#  'WARRANT TO SATISFY JUDGMENT',
#  'WARRANTY',
#  'WARRANTY ACT',
#  'WARRANTY DEED',
#  'WARRANTY OF',
#  'WARRANTY OF FITNESS',
#  'WARRANTY OF HABITABILITY',
#  'WARRANTY OF MERCHANTABILITY',
#  'WARRENTLESS ARREST',
#  'WASH SALE',
#  'WASH SALES',
#  'WASTE',
#  'WASTING ASSET',
#  'WATERED STOCK',
#  'WATERS',
#  'WAY',
#  'WEAPON',
#  'WEIGHT OF THE',
#  'WEIGHT OF THE EVIDENCE',
#  'WESTLAW',
#  'WESTLAW. B',
#  'WHEN ISSUED',
#  'WHEN ISSUED SECURITIES',
#  'WHIPLASH INJURY',
#  'WHITE',
#  'WHITE SLAVE TRAFFIC ACT',
#  'WHOLE LIFE INSURANCE',
#  'WHOLESALER',
#  'WIDOW',
#  'WIDOWER',
#  'WIFE PRIVILEGE',
#  'WILD',
#  'WILDCAT STRIKE',
#  'WILL',
#  'WILLFUL',
#  'WILLFUL NEGLIGENCE',
#  'WILLIAMS ACT',
#  'WILLS',
#  'WINDING UP',
#  'WIRETAP',
#  'WITH PREJUDICE',
#  'WITH RESERVATION',
#  'WITHDRAWAL',
#  'WITHHOLDING',
#  'WITHHOLDING TAX',
#  'WITHIN THE',
#  'WITHOUT FAULT',
#  'WITHOUT PREJUDICE',
#  'WITHOUT RECOURSE',
#  'WITNESS',
#  'WITNESS AGAINST ONESELF',
#  'WORDS OF',
#  'WORDS OF ART',
#  'WORDS OF FIGHTING',
#  'WORDS OF LIMITATION',
#  'WORDS OF PURCHASE',
#  'WORK PRODUCT',
#  'WORK RELEASE PROGRAM',
#  'WORKERS',
#  'WORKHOUSE',
#  'WORKHOUSE. M',
#  'WORTH',
#  'WORTHIER TITLE',
#  'WRAPAROUND MORTGAGE',
#  'WRIT',
#  'WRIT OF',
#  'WRIT OF ASSISTANCE',
#  'WRIT OF CAPIAS',
#  'WRIT OF CERTIORARI',
#  'WRIT OF CORAM NOBIS',
#  'WRIT OF ERROR',
#  'WRIT OF ERROR CORAMNOBIS',
#  'WRIT OF EXECUTION',
#  'WRIT OF HABEAS CORPUS',
#  'WRIT OF MANDAMUS',
#  'WRIT OF NE EXEAT',
#  'WRIT OF POSSESSION',
#  'WRIT OF PROHIBITION',
#  'WRIT OF RIGHT',
#  'WRIT OF SUPERSEDEAS',
#  'WRITTEN INSTRUMENT',
#  'WRONG',
#  'WRONGFUL ACT',
#  'WRONGFUL DEATH STATUTE',
#  'WRONGFUL LIFE',
#  'WWAGE EARNER',
#  'XYZ',
#  'YEARLY',
#  'YEARS',
#  'YELLOW DOG CONTRACT',
#  'YIELD',
#  'YOUTHFUL OFFENDERS',
#  'YTM',
#  'YYEAR AND A DAY RULE',
#  'ZERO',
#  'ZERO BRACKET AMOUNT',
#  'ZERO BRACKET AMOUNT DEDUCTION',
#  'ZONING',
#  'ZZONE OF EMPLOYMENT'}

# %%
len(words)
# Out:
# 7290

# %% [markdown]
# #見出し語抽出できた！次はアルファベット順に並べる

# %%
dicWords = sorted(words)
pprint.pprint(dicWords)


dicfile=open("/content/drive/My Drive/Colab Notebooks/0_dicWords.txt","w")
for i in range(len(dicWords)):  #for i in dicWords: ->TypeError:"list indices must be integers or slices, not str" WHY?
  dicfile.write(dicWords[i]+"\n")
dicfile.close()
# Out:
# ['A COURSE OF DEALING',
#  'A COVENANT OF WARRANTY',
#  'A FORTIORI',
#  'A JOINT TENANCY',
#  'A MENSA ET THORO',
#  'A POSTERIORI',
#  'A PRIORI',
#  'A RIGHTOF ACTION',
#  'A U.S.',
#  'A.) S',
#  'A.B.A.',
#  'A.B.A.',
#  'A.C.L.U.',
#  'A.F.D.C.',
#  'A.F.D.C.',
#  'A.J.',
#  'A.J.',
#  'A.K.A.',
#  'A.L.R.',
#  'A.L.R.',
#  'A.L.R. F',
#  'AA.B.A.',
#  'AB INITIO',
#  'ABANDONED CHILD',
#  'ABANDONMENT',
#  'ABATABLE NUISANCE',
#  'ABATABLE NUISANCE',
#  'ABATEMENT',
#  'ABATEMENT OF A LEGACY',
#  'ABATEMENT OF A NUISANCE',
#  'ABATEMENT OF TAXES',
#  'ABDUCTION',
#  'ABET',
#  'ABEYANCE',
#  'ABILITY TO STAND TRIAL',
#  'ABNORMALLY DANGEROUS ACTIVITY',
#  'ABOLISH',
#  'ABORIGINAL TITLE',
#  'ABORIGINAL TITLE',
#  'ABORTION',
#  'ABRIDGE',
#  'ABROGATE',
#  'ABSCOND',
#  'ABSENT WITHOUT LEAVE',
#  'ABSENT WITHOUT LEAVE',
#  'ABSENTIA',
#  'ABSOLUTE LIABILITY',
#  'ABSOLUTE SALE',
#  'ABSQUE HOC',
#  'ABSTENTION',
#  'ABSTRACT OF RECORD',
#  'ABSTRACT OF TITLE',
#  'ABUSE OF DISCRETION',
#  'ABUSE OF DISCRETION',
#  'ABUSE OF PROCESS',
#  'ABUT',
#  'ACCELERATED DEPRECIATION',
#  'ACCELERATION',
#  'ACCELERATION CLAUSE',
#  'ACCELERATION DEPRECIATION',
#  'ACCEPTANCE',
#  'ACCESS',
#  'ACCESSION',
#  'ACCESSORY',
#  'ACCESSORY AFTER',
#  'ACCESSORY AFTER THE FACT',
#  'ACCESSORY BEFORE',
#  'ACCESSORY BEFORE THE FACT',
#  'ACCIDENT',
#  'ACCOMMODATION INDORSEMENT',
#  'ACCOMMODATION INDORSEMENT',
#  'ACCOMMODATION MAKER',
#  'ACCOMPLICE',
#  'ACCORD',
#  'ACCORD AND SATISFACTION',
#  'ACCOUNT',
#  'ACCOUNT DEBTOR',
#  'ACCOUNT PAYABLE',
#  'ACCOUNTING',
#  'ACCOUNTING METHOD',
#  'ACCOUNTS PAYABLE',
#  'ACCOUNTS RECEIVABLE',
#  'ACCOUNTS RECEIVABLE',
#  'ACCREDITED INVESTOR',
#  'ACCREDITED INVESTORS',
#  'ACCRETION',
#  'ACCRUAL METHOD',
#  'ACCRUE',
#  'ACCRUED INTEREST',
#  'ACCUMULATED DEPRECIATION',
#  'ACCUMULATED EARNINGS AND PROFITS',
#  'ACCUSATION',
#  'ACCUSATORY INSTRUMENT',
#  'ACCUSE',
#  'ACCUSED',
#  'ACKNOWLEDGMENT',
#  'ACLU',
#  'ACQUIESCENCE',
#  'ACQUIRE',
#  'ACQUIRED PROPERTY',
#  'ACQUIRED TITLE',
#  'ACQUIT',
#  'ACQUITTAL',
#  'ACT',
#  'ACT OF GOD',
#  'ACTIO L',
#  'ACTIO NON',
#  'ACTION',
#  'ACTION',
#  'ACTION',
#  'ACTION EX CONTRACTU',
#  'ACTION EX DELICTO',
#  'ACTION EX DELICTO',
#  'ACTION FOR',
#  'ACTION FOR ACCOUNTING',
#  'ACTION FOR POSSESSION',
#  'ACTION IN CASE',
#  'ACTIONABLE',
#  'ACTIONABLE TORT',
#  'ACTIONS IN PERSONAM',
#  'ACTIONS IN REM',
#  'ACTIONS IN REM',
#  'ACTIONS QUASI IN REM',
#  'ACTIONS QUASI IN REM',
#  'ACTIVE EUTHANASIA',
#  'ACTIVE EUTHANASIA',
#  'ACTIVE EUTHANASIA',
#  'ACTIVE EUTHANASIA',
#  'ACTIVISM',
#  'ACTUAL',
#  'ACTUAL AUTHORITY',
#  'ACTUAL AUTHORITY',
#  'ACTUAL CASH VALUE',
#  'ACTUAL DAMAGES',
#  'ACTUAL DAMAGES',
#  'ACTUAL DAMAGES',
#  'ACTUAL DAMAGES',
#  'ACTUAL EVICTION',
#  'ACTUAL EVICTION',
#  'ACTUAL NOTICE',
#  'ACTUAL NOTICE',
#  'ACTUAL POSSESSION',
#  'ACTUAL POSSESSION',
#  'ACTUAL POSSESSION',
#  'ACTUAL VALUE',
#  'ACTUAL VALUE',
#  'ACTUAL VALUE',
#  'ACTUARY',
#  'ACTUS REUS',
#  'AD ALOREM TAX',
#  'AD DAMNUM',
#  'AD HOC',
#  'AD LITEM',
#  'AD TESTIFICANDUM',
#  'AD TESTIFICANDUM',
#  'AD VALOREM',
#  'AD VALOREM TAX',
#  'AD VALOREM TAX',
#  'AD VALOREM TAX',
#  'ADDENDUM',
#  'ADDITUR L',
#  'ADEEM',
#  'ADEMPTION',
#  'ADHESION CONTRACT',
#  'ADJECTIVE LAW',
#  'ADJOURN',
#  'ADJOURNMENT SINE DIE',
#  'ADJUDICATION',
#  'ADJUSTED BASIS',
#  'ADJUSTED BASIS',
#  'ADJUSTED BASIS',
#  'ADJUSTED GROSS INCOME',
#  'ADJUSTEDGROSS INCOME',
#  'ADJUSTER',
#  'ADMINISTRATION DBN',
#  'ADMINISTRATION FOR NATIVE',
#  'ADMINISTRATION FOR NATIVE AMERICANS',
#  'ADMINISTRATION FOR NATIVE AMERICANS',
#  'ADMINISTRATIVE AGENCIES',
#  'ADMINISTRATIVE AGENCY',
#  'ADMINISTRATIVE HEARING',
#  'ADMINISTRATIVE HEARING',
#  'ADMINISTRATIVE LAW',
#  'ADMINISTRATIVE LAW JUDGE',
#  'ADMINISTRATIVE PROCEDURE ACT',
#  'ADMINISTRATOR',
#  'ADMIRALTY AND MARITIME JURISDICTION',
#  'ADMIRALTY COURTS',
#  'ADMIRALTY LAW',
#  'ADMISSIBLE EVIDENCE',
#  'ADMISSION',
#  'ADMISSION BY A PARTY',
#  'ADMISSIONS BY A PARTY',
#  'ADMIT',
#  'ADMIT TO BAIL',
#  'ADMIT TO PRACTICE',
#  'ADMIT TO PRACTICE',
#  'ADMIT TO THE BAR',
#  'ADOPT',
#  'ADOPTION',
#  'ADR',
#  'ADR',
#  'ADR',
#  'ADR',
#  'ADR',
#  'ADULT',
#  'ADULTERY',
#  'ADVANCE',
#  'ADVANCE SHEETS',
#  'ADVANCEMENT',
#  'ADVERSARY',
#  'ADVERSARY PROCEEDING',
#  'ADVERSE',
#  'ADVERSE',
#  'ADVERSE',
#  'ADVERSE INTEREST',
#  'ADVERSE PARTY',
#  'ADVERSE POSSESSION',
#  'ADVERSE TITLE',
#  'ADVERSE WITNESS',
#  'ADVICE AND CONSENT',
#  'ADVISORY OPINION',
#  'ADVOCACY',
#  'AFFECTED WITH A PUBLIC INTEREST',
#  'AFFECTED WITH A PUBLIC INTEREST',
#  'AFFECTED WITH A PUBLIC INTEREST',
#  'AFFIANT',
#  'AFFIDAVIT',
#  'AFFINITY',
#  'AFFIRM',
#  'AFFIRMATION',
#  'AFFIRMATIVE ACTION',
#  'AFFIRMATIVE ACTION PROGRAMS',
#  'AFFIRMATIVE DEFENSE',
#  'AFFIRMATIVE DEFENSE',
#  'AFFIRMATIVE DEFENSE',
#  'AFFIRMATIVE DEFENSE',
#  'AFFIRMATIVE DEFENSE',
#  'AFFIRMATIVE EASEMENT',
#  'AFFIRMATIVE EASEMENT',
#  'AFFIRMATIVE RELIEF',
#  'AFFIRMATIVE RELIEF',
#  'AFFIX',
#  'AFIS',
#  'AFIS',
#  'AFIS (A',
#  'AFORETHOUGHT',
#  'AFTER',
#  'AFTER',
#  'AFTER',
#  'AGAINST GRANTOR',
#  'AGAINST PUBLIC POLICY',
#  'AGAINST PUBLIC POLICY',
#  'AGAINST PUBLIC POLICY',
#  'AGAINST THE',
#  'AGE DISCRIMINATION',
#  'AGE OF',
#  'AGE OF CONSENT',
#  'AGE OF MAJORITY',
#  'AGENCY',
#  'AGENT',
#  'AGGRAVATED ASSAULT',
#  'AGGRAVATED ASSAULT',
#  'AGGRAVATED ASSAULT',
#  'AGGRAVATING CIRCUMSTANCES',
#  'AGGREGATE',
#  'AGGRIEVED PARTY',
#  'AGREEMENT',
#  'AID AND ABET',
#  'AID TO FAMILIES WITH',
#  'AID TO FAMILIES WITH DEPENDENT CHILDREN',
#  'AID TO FAMILIES WITH DEPENDENT CHILDREN',
#  'AID TO FAMILIES WITH DEPENDENT CHILDREN',
#  'AIR PIRACY',
#  'AIR RIGHTS',
#  'AIRSPACE',
#  'AKA',
#  'ALEATORY',
#  'ALEATORY CONTRACT',
#  'ALEATORY CONTRACT',
#  'ALI TEST',
#  'ALI TEST',
#  'ALIAS',
#  'ALIBI',
#  'ALIBI',
#  'ALIEN',
#  'ALIEN REGISTRATION',
#  'ALIENATION',
#  'ALIENATION',
#  'ALIENATION OF AFFECTIONS',
#  'ALIMONY',
#  'ALIQUOT L',
#  'ALIUNDE L',
#  'ALIUNDE RULE',
#  'ALLEGATION',
#  'ALLEN CHARGE',
#  'ALLOCUTION',
#  'ALLODIAL',
#  'ALLODIAL OWNERSHIP',
#  'ALLOWANCE',
#  'ALLOWANCE',
#  'ALLUVION',
#  'ALTER EGO',
#  'ALTERATION',
#  'ALTERNATE PAYEE',
#  'ALTERNATIVE DISPUTE RESOLUTION',
#  'ALTERNATIVE PLEADING',
#  'ALTERNATIVE WRIT OF MANDAMUS',
#  'AMELIORATING WASTE',
#  'AMELIORATING WASTE',
#  'AMELIORATING WASTE',
#  'AMEND',
#  'AMENDED RETURN',
#  'AMENDMENTS',
#  'AMERICAN BAR ASSOCIATION',
#  'AMERICAN BAR FOUNDATION',
#  'AMERICAN BAR FOUNDATION',
#  'AMERICAN BAR FOUNDATION',
#  'AMERICAN CIVIL LIBERTIES UNION',
#  'AMERICAN DEPOSITORY RECEIPT',
#  'AMERICAN INDIAN LAW',
#  'AMERICAN STOCK EXCHANGE',
#  'AMERICANS',
#  'AMEX',
#  'AMICUS BRIEF',
#  'AMICUS CURIAE',
#  'AMICUS CURIAE BRIEF',
#  'AMINO REVERTENDI',
#  'AMINO REVOCANDI',
#  'AMINO TESTANDI',
#  'AMNESTY',
#  'AMORTIZATION',
#  'AMOUNT REALIZED',
#  'ANCIENT DEMESNE',
#  'ANCILLARY JURISDICTION',
#  'AND',
#  'AND',
#  'AND FREIGHT',
#  'AND HIS HEIRS',
#  'AND HIS HEIRS',
#  'AND QUARTERED',
#  'ANIMO L',
#  'ANIMUS',
#  'ANNOTATION',
#  'ANNUAL REPORT',
#  'ANNUITANT',
#  'ANNUITY',
#  'ANNUL',
#  'ANSWER',
#  'ANTENUPTIAL AGREEMENT',
#  'ANTENUPTIAL AGREEMENT',
#  'ANTI',
#  'ANTICIPATORY BREACH',
#  'ANTICIPATORY BREACH',
#  'ANTIDISCRIMINATION ACT',
#  'ANTIDUMPING LAW',
#  'ANTILAPSE STATUTES',
#  'ANTITRUST LAWS',
#  'APA',
#  'APA',
#  'APPARENT AUTHORITY',
#  'APPEAL',
#  'APPEALS COURT',
#  'APPEARANCE',
#  'APPEARANCE DE BENE ESSE',
#  'APPEARANCE DE BENE ESSE',
#  'APPELLANT',
#  'APPELLATE COURT',
#  'APPELLATE JURISDICTION',
#  'APPELLATE JURISDICTION',
#  'APPELLATEJURISDICTION',
#  'APPELLEE',
#  'APPOINTED COUNSEL',
#  'APPOINTMENT',
#  'APPOINTMENT OF RECEIVER',
#  'APPORTION',
#  'APPRAISAL RIGHTS',
#  'APPRAISE',
#  'APPRECIATE',
#  'APPRECIATION',
#  'APPROPRIATE',
#  'APPROPRIATION',
#  'APPURTENANT',
#  'ARBITER L',
#  'ARBITRAGE',
#  'ARBITRARY AND CAPRICIOUS',
#  'ARBITRATION',
#  'ARBITRATION CLAUSE',
#  'ARBITRATOR',
#  'ARGUENDO L',
#  'ARGUMENT',
#  'ARM',
#  'ARM STATUTES',
#  'ARMED ROBBERY',
#  'ARRAIGN',
#  'ARRAIGNMENT',
#  'ARRANGEMENTS',
#  'ARRAY',
#  'ARREARS',
#  'ARREST',
#  'ARREST OF JUDGMENT',
#  'ARREST RECORD',
#  'ARREST WARRANT',
#  'ARSON',
#  'ART',
#  'ARTICLES OF IMPEACHMENT',
#  'ARTICLES OF INCORPORATION',
#  'ARTIFICAL PERSON',
#  'ARTIFICE',
#  'ARTIFICIAL PERSON',
#  'AS A MATTER OF LAW',
#  'AS IS',
#  'ASE',
#  'ASE.AMEX',
#  'ASPORTATION',
#  'ASPORTATION',
#  'ASSAULT',
#  'ASSEMBLY',
#  'ASSESS',
#  'ASSESSABLE STOCK',
#  'ASSESSMENT OF DEFICIENCY',
#  'ASSET',
#  'ASSET',
#  'ASSET VALUE',
#  'ASSIGN',
#  'ASSIGNED COUNSEL',
#  'ASSIGNED RISK',
#  'ASSIGNEES',
#  'ASSIGNMENT',
#  'ASSIGNMENT FOR BENEFIT OF CREDITORS',
#  'ASSIGNMENT OF A LEASE',
#  'ASSIGNMENT OF A LEASE',
#  'ASSIGNMENT OF A LEASE',
#  'ASSIGNMENT OF ERROR',
#  'ASSIGNMENT OF INCOME',
#  'ASSIGNS',
#  'ASSISTED SUICIDE',
#  'ASSIZE',
#  'ASSOCIATE JUSTICE',
#  'ASSOCIATION',
#  'ASSOCIATION',
#  'ASSOCIATION',
#  'ASSUMPSIT L',
#  'ASSUMPTION OF MORTGAGE',
#  'ASSUMPTION OF MORTGAGE',
#  'ASSUMPTION OF RISK',
#  'ASSURANCE',
#  'ASSURED',
#  'ASYLUM',
#  'AT BAR',
#  'AT BAR',
#  'AT EQUITY',
#  'AT ISSUE',
#  'AT LAW',
#  'AT LAW',
#  'ATROCIOUS',
#  'ATTACHMENT',
#  'ATTAINDER',
#  'ATTAINDER',
#  'ATTAINT',
#  'ATTEMPT',
#  'ATTENDANT CIRCUMSTANCES',
#  'ATTEST',
#  'ATTESTATION',
#  'ATTORNEY',
#  'ATTORNEY',
#  'ATTORNEY',
#  'ATTORNEY',
#  'ATTORNEY',
#  'ATTORNEY AT LAW',
#  'ATTORNEY GENERAL',
#  'ATTORNEY IN FACT',
#  'ATTORNEY OF RECORD',
#  'ATTORNEY OF RECORD',
#  'ATTORNEY OF RECORD',
#  'ATTRACTIVE NUISANCE',
#  'ATTRACTIVE NUISANCE',
#  'AUCTION',
#  'AUCTION SALE',
#  'AUCTION SALE',
#  'AUDIT',
#  'AUDIT OF RETURN',
#  'AUDITOR',
#  'AUTHENTICATE',
#  'AUTHORITY',
#  'AUTHORITY',
#  'AUTHORITY',
#  'AUTHORITY BY ESTOPPEL',
#  'AUTHORITY COUPLED WITH AN INTEREST',
#  'AUTHORITY COUPLED WITH AN INTEREST',
#  'AUTHORIZED ISSUE',
#  'AUTOMOBILE',
#  'AUTOMOBILE GUEST',
#  'AUTOMOBILE GUEST STATUTE',
#  'AUTOPSY',
#  'AUTRE VIE',
#  'AVERMENT',
#  'AVERMENT OF NOTICE',
#  'AVOID',
#  'AVOIDANCE',
#  'AVOIDANCE OF TAX',
#  'AVULSION',
#  'AWOL',
#  'AWOL',
#  'B. T',
#  'B.F.O.Q.',
#  'B.F.O.Q.',
#  'B.F.O.Q.',
#  'B.F.O.Q.',
#  'B.F.O.Q.',
#  'B.F.O.Q.',
#  'B.F.O.Q.',
#  'B.F.O.Q. S',
#  'B.F.P.',
#  'B.F.P.',
#  'BAD DEBT',
#  'BAD DEBT RESERVE',
#  'BAD FAITH',
#  'BAD TITLE',
#  'BADGES OF FRAUD',
#  'BAIL',
#  'BAIL BOND',
#  'BAIL BONDSMAN',
#  'BAIL JUMPING',
#  'BAILEE',
#  'BAILIFF',
#  'BAILMENT',
#  'BAILOR',
#  'BAIT AND SWITCH',
#  'BALANCE SHEET',
#  'BALANCING (TEST',
#  'BALANCING OF EQUITIES',
#  'BALANCING OF INTERESTS',
#  'BALLOON NOTE',
#  'BALM STATUTE',
#  'BANC',
#  'BANK',
#  'BANKER',
#  'BANKRUPTCY',
#  'BANKRUPTCY COURT',
#  'BANKRUPTCY PETITION',
#  'BAR',
#  'BAR',
#  'BARGAIN',
#  'BARGAIN AND SALE',
#  'BARGAINING UNIT',
#  'BARRATRY',
#  'BARRISTER',
#  'BARTER',
#  'BARTER',
#  'BARTER.EXCHANGE',
#  'BASIS',
#  'BASTARD',
#  'BASTARDY PROCEEDING',
#  'BASTARDY PROCEEDINGS',
#  'BATTERY',
#  'BBAD CHECK',
#  'BEARER',
#  'BEARER BOND',
#  'BEARER BOND',
#  'BEARER BOND',
#  'BEARER BONDS',
#  'BEARER PAPER',
#  'BED AND BOARD',
#  'BEFORE',
#  'BELIEF',
#  'BENCH',
#  'BENCH',
#  'BENCH TRIAL',
#  'BENCH TRIAL',
#  'BENCH WARRANT',
#  'BENEFICIAL INTEREST',
#  'BENEFICIAL USE',
#  'BENEFICIARY',
#  'BENEFIT',
#  'BENEFIT OF THE BARGAIN (RULE',
#  'BEQUEATH',
#  'BEQUEST',
#  'BEST EVIDENCE RULE',
#  'BESTIALITY',
#  'BEYOND A REASONABLE DOUBT',
#  'BIA',
#  'BIA',
#  'BIAS',
#  'BIAS CRIME',
#  'BID',
#  'BID SHOPPING',
#  'BIGAMY',
#  'BILATERAL',
#  'BILATERAL',
#  'BILATERAL CONTRACT',
#  'BILATERAL CONTRACT',
#  'BILATERAL MISTAKE',
#  'BILL',
#  'BILL',
#  'BILL',
#  'BILL FOR A NEW TRIAL',
#  'BILL OF',
#  'BILL OF',
#  'BILL OF',
#  'BILL OF ATTAINDER',
#  'BILL OF CERTIORARI',
#  'BILL OF DISCOVERY',
#  'BILL OF EXCEPTIONS',
#  'BILL OF EXCHANGE',
#  'BILL OF EXCHANGE',
#  'BILL OF EXCHANGE',
#  'BILL OF EXCHANGE',
#  'BILL OF EXCHANGE',
#  'BILL OF INTERPLEADER',
#  'BILL OF LADING',
#  'BILL OF PARTICULARS',
#  'BILL OF REVIEW',
#  'BILL OF REVIEW',
#  'BILL OF RIGHTS',
#  'BILL OF SALE',
#  'BILL OF SALE',
#  'BIND',
#  'BIND OVER',
#  'BINDER',
#  'BINDER RECEIPT',
#  'BINDING',
#  'BINDING AGREEMENT',
#  'BINDING ARBITRATION',
#  'BINDING INSTRUCTION',
#  'BLACK LETTER LAW',
#  'BLACKACRE',
#  'BLACKMAIL',
#  'BLACKMAIL SUITS',
#  'BLACKMAIL SUITS',
#  'BLANK INDORSEMENT',
#  'BLANK INDORSEMENT',
#  'BLASPHEMY',
#  'BLIND TRUST',
#  'BLIND TRUST',
#  'BLOOD',
#  'BLUE BOOK',
#  'BLUE BOOK',
#  'BLUE CHIP STOCK',
#  'BLUE CHIP STOCK',
#  'BLUE LAWS',
#  'BLUE RIBBON JURY',
#  'BLUE RIBBON JURY',
#  'BLUE RIBBON JURY',
#  'BLUE SKY LAWS',
#  'BLUEBOOK',
#  'BOARD OF DIRECTORS',
#  'BOARD ROOM',
#  'BOILER ROOM',
#  'BOILERPLATE',
#  'BONA FIDE',
#  'BONA FIDE OCCUPATIONAL QUALIFICATION',
#  'BONA FIDE PURCHASER',
#  'BONA L',
#  'BOND',
#  'BOND',
#  'BOND DISCOUNT',
#  'BOND DISCOUNT',
#  'BOND FOR DEED',
#  'BOND FOR GENERAL PURPOSES',
#  'BOND ISSUE',
#  'BOND PREMIUM',
#  'BOND YIELD',
#  'BONDED DEBT',
#  'BONDS',
#  'BONDSMAN',
#  'BONUS STOCK',
#  'BONUS STOCK',
#  'BONUS STOCK',
#  'BOOK VALUE',
#  'BOOT',
#  'BORDELLO',
#  'BORDELLO',
#  'BOROUGH ENGLISH',
#  'BOROUGH ENGLISH',
#  'BOYCOTT',
#  'BRAIN DEATH',
#  'BREACH',
#  'BREACH',
#  'BREACH OF',
#  'BREACH OF',
#  'BREACH OF CONTRACT',
#  'BREACH OF CONTRACT',
#  'BREACH OF CONTRACT',
#  'BREACH OF CONTRACT',
#  'BREACH OF PROMISE',
#  'BREACH OF PROMISE',
#  'BREACH OF PROMISE',
#  'BREACH OF PROMISE',
#  'BREACH OF THE PEACE',
#  'BREACH OF THE PEACE',
#  'BREACH OF TRUST',
#  'BREACH OF WARRANTY',
#  'BREAKING A CLOSE',
#  'BREAKING A CLOSE',
#  'BREAKING AND ENTERING',
#  'BREAKING BULK',
#  'BREATHALYZER',
#  'BRETHREN',
#  'BRIBERY',
#  'BRIEF',
#  'BROKER',
#  'BRUTUM FULMEN',
#  'BUGGERY',
#  'BUGGING',
#  'BUILDING AND LOAN ASSOCIATION',
#  'BUILDING AND LOAN ASSOCIATION',
#  'BUILDING PERMIT',
#  'BULK SALES ACTS',
#  'BULK TRANSFER',
#  'BUNCHING',
#  'BURDEN',
#  'BURDEN OF EVIDENCE',
#  'BURDEN OF PROOF',
#  'BUREAU OF INDIAN AFFAIRS',
#  'BUREAU OF INDIAN AFFAIRS',
#  'BUREAU OF INDIAN AFFAIRS',
#  'BURGLARY',
#  'BUSINESS',
#  'BUSINESS CYCLE',
#  'BUSINESS GUEST',
#  'BUSINESS INVITEE',
#  'BUSINESS JUDGMENT RULE',
#  'BUSINESS RECORDS EXCEPTION',
#  'BUSINESS RECORDS EXCEPTION',
#  'BUSINESS RECORDS EXCEPTION',
#  'BUSINESS TRUST',
#  'BUT FOR',
#  'BUY',
#  'BUYER IN ORDINARY COURSE OF BUSINESS',
#  'BY ESTOPPEL',
#  'BY OPERATION OF LAW',
#  'BY THE ENTIRETY',
#  'BYLAWS',
#  'C. C',
#  'C.F.I.',
#  'C.F.I. I',
#  'C.I.F.',
#  'C.I.F.',
#  'C.I.F.',
#  'C.I.F.',
#  'C.J.',
#  'C.J.',
#  'CA. RESP.',
#  'CA. SA',
#  'CAB',
#  'CAB',
#  'CADAVER',
#  'CALENDAR CALL',
#  'CALL',
#  'CALL OPTION',
#  'CALL OPTION',
#  'CALL OPTION',
#  'CALLABLE BOND',
#  'CALUMNY',
#  'CAMERA',
#  'CANNABIS',
#  'CANNABIS',
#  'CANNABIS',
#  'CANNABIS',
#  'CANON',
#  'CAPACITY',
#  'CAPACITY TO SUE',
#  'CAPIAS AD AUDIENDUM JUDICIUM',
#  'CAPIAS AD RESPONDENDUM',
#  'CAPIAS AD RESPONDENDUM',
#  'CAPIAS AD SATISFACIENDUM',
#  'CAPIAS AD SATISFACIENDUM',
#  'CAPIAS L',
#  'CAPITA',
#  'CAPITAL',
#  'CAPITAL',
#  'CAPITAL ACCOUNT',
#  'CAPITAL ASSET',
#  'CAPITAL ASSETS',
#  'CAPITAL ASSETS',
#  'CAPITAL ASSETS',
#  'CAPITAL ASSETS',
#  'CAPITAL EXPENDITURE',
#  'CAPITAL EXPENDITURE',
#  'CAPITAL EXPENDITURE',
#  'CAPITAL EXPENDITURE',
#  'CAPITAL EXPENDITURES',
#  'CAPITAL GAINS OR LOSSES',
#  'CAPITAL GAINS OR LOSSES',
#  'CAPITAL GAINS OR LOSSES',
#  'CAPITAL GAINS OR LOSSES',
#  'CAPITAL GAINS TAX',
#  'CAPITAL INTENSIVE',
#  'CAPITAL INVESTMENT',
#  'CAPITAL INVESTMENT',
#  'CAPITAL INVESTMENT',
#  'CAPITAL MARKET',
#  'CAPITAL OFFENSE',
#  'CAPITAL PUNISHMENT',
#  'CAPITAL STOCK',
#  'CAPITAL STOCK',
#  'CAPITAL STOCK',
#  'CAPITAL STOCK',
#  'CAPITAL STOCK',
#  'CAPITAL STOCK',
#  'CAPITAL STOCK',
#  'CAPITAL SURPLUS',
#  'CAPITAL SURPLUS',
#  'CAPITAL. S',
#  'CAPITALIZATION',
#  'CAPITALIZED VALUE',
#  'CAPITE',
#  'CAPTION',
#  'CAPTURE',
#  'CARE',
#  'CARE',
#  'CARJACKING',
#  'CARJACKING',
#  'CARJACKING',
#  'CARNAL KNOWLEDGE',
#  'CARNAL KNOWLEDGE',
#  'CARRIER',
#  'CARRYBACK',
#  'CARRYOVER',
#  'CARRYOVER BASIS',
#  'CARRYOVER OR SUBSTITUTED BASIS',
#  'CARRYOVER SUBSTITUTED BASIS',
#  'CARTEL',
#  'CARVE OUT',
#  'CASE',
#  'CASE',
#  'CASE',
#  'CASE AT BAR',
#  'CASE AT BAR',
#  'CASE LAW',
#  'CASE OF FIRST IMPRESSION',
#  'CASE OR CONTROVERSY',
#  'CASE OR CONTROVERSY',
#  'CASE REPORTS',
#  'CASH EQUIVALENT DOCTRINE',
#  'CASH EQUIVALENT DOCTRINE',
#  'CASH EQUIVALENT DOCTRINE',
#  'CASH METHOD',
#  'CASH SALE',
#  'CASH SALE DOCTRINE',
#  'CASH SURRENDER VALUE',
#  'CASH VALUE',
#  'CASH VALUE',
#  'CASHIER',
#  'CASHIER',
#  'CASUALTY LOSS',
#  'CAUSA L',
#  'CAUSA MORTIS',
#  'CAUSA MORTIS',
#  'CAUSA MORTIS',
#  'CAUSA MORTIS',
#  'CAUSA MORTIS',
#  'CAUSA PROXIMA',
#  'CAUSA SINE QUA NON',
#  'CAUSA SINE QUA NON',
#  'CAUSAMORTIS',
#  'CAUSE',
#  'CAUSE',
#  'CAUSE',
#  'CAUSE OF ACTION',
#  'CAUTIONARY INSTRUCTION',
#  'CAVEAT EMPTOR',
#  'CAVEAT L',
#  'CCAB',
#  'CEASE AND DESIST ORDER',
#  'CELL PARDE',
#  'CELL PAROLE',
#  'CELL PAROLE',
#  'CENSURE',
#  'CENTER OF GRAVITY',
#  'CERTIFICATE OF DEPOSIT',
#  'CERTIFICATE OF INCORPORATION',
#  'CERTIFICATE OF OCCUPANCY',
#  'CERTIFICATE OF TITLE',
#  'CERTIFICATION',
#  'CERTIFIED CHECK',
#  'CERTIFIED CHECK',
#  'CERTIORARI L',
#  'CESTUI QUE',
#  'CESTUI QUE TRUST',
#  'CESTUI QUE TRUST',
#  'CESTUI QUE USE',
#  'CESTUI QUE VIE',
#  'CESTUIS QUE) O',
#  'CHAIN OF TITLE',
#  'CHALLENGE',
#  'CHALLENGE FOR CAUSE',
#  'CHALLENGE TO JURY ARRAY',
#  'CHALLENGED FOR CAUSE',
#  'CHAMBERS',
#  'CHAMPERTY',
#  'CHANCELLOR',
#  'CHANCERY',
#  'CHANGE OF VENUE',
#  'CHAPTER',
#  'CHAPTER',
#  'CHAPTER',
#  'CHAPTER',
#  'CHARACTER WITNESS',
#  'CHARACTER WITNESS',
#  'CHARACTER WITNESS',
#  'CHARACTER WITNESS',
#  'CHARGE',
#  'CHARITABLE CONTRIBUTION',
#  'CHARITABLE CONTRIBUTION',
#  'CHARITABLE DEDUCTION',
#  'CHARITABLE TRUST',
#  'CHARITABLE TRUST',
#  'CHARITY',
#  'CHARTER',
#  'CHATTEL',
#  'CHATTEL MORTGAGE',
#  'CHATTEL MORTGAGE',
#  'CHATTEL PAPER',
#  'CHECK',
#  'CHECK KITING',
#  'CHECK.NON SUI JURIS',
#  'CHECKS AND BALANCES',
#  'CHIEF JUSTICE',
#  'CHILD AND DEPENDENT CARE CREDIT',
#  'CHILD CUSTODY',
#  'CHILD SUPPORT',
#  'CHILD SUPPORT',
#  'CHILL',
#  'CHILLING EFFECT',
#  'CHILLING EFFECT',
#  'CHOATE',
#  'CHOICE OF',
#  'CHOICE OF LAW',
#  'CHOICE OF LAW',
#  'CHOICE OF LAW',
#  'CHOICE OF LAW',
#  'CHOSE F',
#  'CHOSE IN',
#  'CHOSE IN ACTION',
#  'CHOSE IN ACTION',
#  'CHOSE IN ACTION',
#  'CHOSE IN POSSESSION',
#  'CHURNING',
#  'CIRCUIT',
#  'CIRCUIT COURT',
#  'CIRCUMSTANTIAL EVIDENCE',
#  'CITATION',
#  'CITE',
#  'CITIZEN',
#  'CITIZEN',
#  'CIVIL',
#  'CIVIL',
#  'CIVIL',
#  'CIVIL ACTION',
#  'CIVIL AERONAUTICS BOARD',
#  'CIVIL CONTEMPT',
#  'CIVIL CONTEMPT',
#  'CIVIL DAMAGE ACTS',
#  'CIVIL DEATH',
#  'CIVIL DISOBEDIENCE',
#  'CIVIL DISORDER',
#  'CIVIL LAW',
#  'CIVIL LIABILITY',
#  'CIVIL LIBERTIES',
#  'CIVIL PENALTIES',
#  'CIVIL PROCEDURE',
#  'CIVIL RIGHTS',
#  'CIVIL RIGHTS ACT OF',
#  'CIVIL SERVICE COMMISSIONS',
#  'CIVIL SERVICE COMMISSIONS',
#  'CIVIL SERVICE COMMISSIONS',
#  'CIVITAS L',
#  'CLA',
#  'CLA',
#  'CLA (C',
#  'CLAIM',
#  'CLAIM',
#  'CLAIM FOR REFUND',
#  'CLAIM OF RIGHT',
#  'CLAIMANT',
#  'CLASS ACTION',
#  'CLASS GIFT',
#  'CLASS SUIT',
#  'CLASSIFIED STOCK',
#  'CLASSIFIED STOCK',
#  'CLAUSE',
#  'CLAYTON ACT',
#  'CLAYTON ACT',
#  'CLEAN HANDS',
#  'CLEAR',
#  'CLEAR AND CONVINCING',
#  'CLEAR AND PRESENT DANGER',
#  'CLEAR TITLE',
#  'CLEAR TITLE',
#  'CLEAR TITLE OF RECORD',
#  'CLEARINGHOUSE',
#  'CLEMENCY',
#  'CLERGYMEN',
#  'CLERIC',
#  'CLERICAL ERROR',
#  'CLERK',
#  'CLIENT PRIVILEGE',
#  'CLIENT PRIVILEGE',
#  'CLOSE',
#  'CLOSE CORPORATION',
#  'CLOSE CORPORATIONS',
#  'CLOSE CORPORATIONS',
#  'CLOSE.ENCROACH',
#  'CLOSED',
#  'CLOSED',
#  'CLOSED END FUNDS',
#  'CLOSED SHOP',
#  'CLOSED TRANSACTION',
#  'CLOSELY HELD CORPORATION',
#  'CLOSING',
#  'CLOSING AGREEMENT',
#  'CLOSING ARGUMENTS',
#  'CLOSING LAWS',
#  'CLOSING STATEMENT',
#  'CLOSING STATEMENT',
#  'CLOSING STATEMENT',
#  'CLOTURE',
#  'CLOUD ON TITLE',
#  'COCONSPIRATOR',
#  'CODE',
#  'CODE OF MILITARY JUSTICE',
#  'CODE OF MILITARY JUSTICE',
#  'CODE OF MILITARY JUSTICE',
#  'CODE OF MILITARY JUSTICE',
#  'CODE OF MILITARY JUSTICE',
#  'CODE OF PROFESSIONAL RESPONSIBILITY',
#  'CODE PLEADING',
#  'CODEFENDANT',
#  'CODICIL',
#  'COERCION',
#  'COGENT',
#  'COGNIZABLE',
#  'COGNOVIT JUDGMENT',
#  'COGNOVIT NOTE',
#  'COHABITATION',
#  'COHEIR',
#  'COIF',
#  'COINSURANCE',
#  'COLLAR CRIME',
#  'COLLATERAL',
#  'COLLATERAL',
#  'COLLATERAL',
#  'COLLATERAL AFFINITY',
#  'COLLATERAL AFFINITY',
#  'COLLATERAL AFFINITY',
#  'COLLATERAL ATTACK',
#  'COLLATERAL ATTACK',
#  'COLLATERAL ATTACK',
#  'COLLATERAL ATTACK',
#  'COLLATERAL CONSANGUINITY',
#  'COLLATERAL CONSANGUINITY',
#  'COLLATERAL CONSANGUINITY',
#  'COLLATERAL ESTOPPEL',
#  'COLLATERAL ESTOPPEL',
#  'COLLATERAL ESTOPPEL',
#  'COLLATERAL ESTOPPEL',
#  'COLLATERAL ESTOPPEL',
#  'COLLATERAL ESTOPPEL',
#  'COLLATERAL FRAUD',
#  'COLLATERAL LINE',
#  'COLLATERAL PROMISE',
#  'COLLATERAL SOURCE RULE',
#  'COLLATION',
#  'COLLECTIVE BARGAINING',
#  'COLLOQUIUM',
#  'COLLUSION',
#  'COLLUSIVE ACTION',
#  'COLOR',
#  'COLOR OF LAW',
#  'COLOR OF TITLE',
#  'COLOR OF TITLE',
#  'COLORABLE',
#  'COMITAS',
#  'COMITY',
#  'COMMENT',
#  'COMMERCE',
#  'COMMERCE CLAUSE',
#  'COMMERCE POWER',
#  'COMMERCE POWER',
#  'COMMERCE POWER',
#  'COMMERCE POWER',
#  'COMMERCIAL BANK',
#  'COMMERCIAL BANK',
#  'COMMERCIAL BANK',
#  'COMMERCIAL BRIBERY',
#  'COMMERCIAL BRIBERY',
#  'COMMERCIAL FRUSTRATION',
#  'COMMERCIAL FRUSTRATION',
#  'COMMERCIAL LAW',
#  'COMMERCIAL NAME',
#  'COMMERCIAL PAPER',
#  'COMMERCIAL PREFERENCE',
#  'COMMERCIAL UNIT',
#  'COMMINGLING OF FUNDS',
#  'COMMISSION',
#  'COMMISSION',
#  'COMMITMENT',
#  'COMMITTEE',
#  'COMMODITY',
#  'COMMODITY SHORT SALES',
#  'COMMON',
#  'COMMON',
#  'COMMON',
#  'COMMON',
#  'COMMON',
#  'COMMON',
#  'COMMON',
#  'COMMON',
#  'COMMON AREA',
#  'COMMON CARRIER',
#  'COMMON CARRIER',
#  'COMMON CARRIER',
#  'COMMON CARRIER',
#  'COMMON LAW',
#  'COMMON NUISANCE',
#  'COMMON NUISANCE',
#  'COMMON PROPERTY',
#  'COMMON PROPERTY',
#  'COMMON SEAL',
#  'COMMON STOCK',
#  'COMMON STOCK',
#  'COMMON STOCK',
#  'COMMON STOCK',
#  'COMMONS',
#  'COMMUNITY NOTIFICATION',
#  'COMMUNITY NOTIFICATION',
#  'COMMUNITY NOTIFICATION',
#  'COMMUNITY PROPERTY',
#  'COMMUTATION',
#  'COMPACT CLAUSE',
#  'COMPANY',
#  'COMPANY ACT OF',
#  'COMPARATIVE NEGLIGENCE',
#  'COMPARATIVE NEGLIGENCE',
#  'COMPELLING INTEREST',
#  'COMPENSATION',
#  'COMPENSATION ACTS',
#  'COMPENSATORY DAMAGES',
#  'COMPETENT',
#  'COMPETENT COURT',
#  'COMPETENT EVIDENCE',
#  'COMPLAINANT',
#  'COMPLAINT',
#  'COMPLAINT',
#  'COMPLEX TRUST',
#  'COMPLIANCE',
#  'COMPOS MENTIS',
#  'COMPOUND CONCLUSION',
#  'COMPOUND CONCLUSION',
#  'COMPOUND INTEREST',
#  'COMPOUND INTEREST',
#  'COMPOUNDING A FELONY',
#  'COMPROMISE VERDICT',
#  'COMPROMISE VERDICT',
#  'COMPROMISE VERDICT',
#  'COMPULSORY APPEARANCE',
#  'COMPULSORY APPEARANCE',
#  'COMPULSORY APPEARANCE',
#  'COMPULSORY ARBITRATION',
#  'COMPULSORY ARBITRATION',
#  'COMPULSORY ARBITRATION',
#  'COMPULSORY COUNTERCLAIM',
#  'COMPULSORY COUNTERCLAIM',
#  'COMPULSORY COUNTERCLAIM',
#  'COMPULSORY COUNTERCLAIM',
#  'COMPULSORY JOINDER',
#  'COMPULSORY JOINDER',
#  'COMPULSORY JOINDER',
#  'COMPULSORY PROCESS',
#  'COMPURAGATOR',
#  'COMPURGATORS',
#  'CONCEALMENT',
#  'CONCERT OF ACTION',
#  'CONCERTED ACTION',
#  'CONCILIATION',
#  'CONCILIATOR',
#  'CONCILIATOR',
#  'CONCILIATOR',
#  'CONCLUSION OF FACT',
#  'CONCLUSION OF LAW',
#  'CONCLUSIVE',
#  'CONCLUSIVE EVIDENCE',
#  'CONCLUSIVE PRESUMPTION',
#  'CONCUR',
#  'CONCURRENT',
#  'CONCURRENT CONDITION',
#  'CONCURRENT CONDITION',
#  'CONCURRENT CONDITION',
#  'CONCURRENT COVENANTS',
#  'CONCURRENT COVENANTS',
#  'CONCURRENT COVENANTS',
#  'CONCURRENT JURISDICTION',
#  'CONCURRENT JURISDICTION',
#  'CONCURRENT JURISDICTION',
#  'CONCURRENT JURISDICTION',
#  'CONCURRENT NEGLIGENCE',
#  'CONCURRENT NEGLIGENCE',
#  'CONCURRENT NEGLIGENCE',
#  'CONCURRENT SENTENCE',
#  'CONCURRENT SENTENCE',
#  'CONCURRENT SENTENCES',
#  'CONCURRENT SENTENCES',
#  'CONCURRING OPINION',
#  'CONCURRING OPINION',
#  'CONCURRING OPINION',
#  'CONDEMN',
#  'CONDITION',
#  'CONDITION PRECEDENT',
#  'CONDITION PRECEDENT',
#  'CONDITION PRECEDENT',
#  'CONDITION PRECEDENT',
#  'CONDITION PRECEDENT',
#  'CONDITION PRECEDENT',
#  'CONDITION SUBSEQUENT',
#  'CONDITION SUBSEQUENT',
#  'CONDITION SUBSEQUENT',
#  'CONDITION SUBSEQUENT',
#  'CONDITION SUBSEQUENT',
#  'CONDITIONAL',
#  'CONDITIONAL BEQUEST',
#  'CONDITIONAL BEQUEST',
#  'CONDITIONAL BEQUEST',
#  'CONDITIONAL CONTRACT',
#  'CONDITIONAL CONTRACT',
#  'CONDITIONAL CONTRACT',
#  'CONDITIONAL DISCHARGE',
#  'CONDITIONAL DISCHARGE',
#  'CONDITIONAL DISCHARGE SENTENCE',
#  'CONDITIONAL FEE',
#  'CONDITIONAL PARDON',
#  'CONDITIONAL SALE',
#  'CONDITIONALDISCHARGE',
#  'CONDOMINIUM',
#  'CONFERENCE',
#  'CONFESSION',
#  'CONFESSION AND AVOIDANCE',
#  'CONFESSION OF JUDGMENT',
#  'CONFIDENCE GAME',
#  'CONFIDENTIAL COMMUNICATION',
#  'CONFIRMATION',
#  'CONFIRMATION',
#  'CONFISCATE',
#  'CONFLICT OF INTERESTS',
#  'CONFLICT OF LAW',
#  'CONFORMED',
#  'CONFORMED COPY',
#  'CONFORMING USE',
#  'CONFRONTATION CLAUSE',
#  'CONFUSION OF GOODS',
#  'CONGLOMERATE',
#  'CONGRESS',
#  'CONGRESSIONAL REFERENCE CASES',
#  'CONJECTURE',
#  'CONJUGAL',
#  'CONJUGAL',
#  'CONJUGAL RIGHTS',
#  'CONJUGAL VISITATION',
#  'CONJUNCTIVE DENIAL',
#  'CONJUNCTIVE DENIAL',
#  'CONJUNCTIVE DENIAL',
#  'CONJUNCTIVE DENIAL',
#  'CONSANGUINITY',
#  'CONSCIENCE OF THE COURT',
#  'CONSCIENTIOUS OBJECTOR',
#  'CONSCIOUS PARALLELISM',
#  'CONSECUTIVE',
#  'CONSECUTIVE',
#  'CONSECUTIVE',
#  'CONSECUTIVE SENTENCE',
#  'CONSENT',
#  'CONSENT',
#  'CONSENT DECREE',
#  'CONSENT DECREE',
#  'CONSENT DECREE',
#  'CONSENT FOR',
#  'CONSENT JUDGMENT',
#  'CONSENT ORDER',
#  'CONSENT ORDER',
#  'CONSENT ORDER',
#  'CONSENT SEARCH',
#  'CONSEQUENTIAL',
#  'CONSEQUENTIAL DAMAGES',
#  'CONSEQUENTIAL DAMAGES',
#  'CONSERVATOR',
#  'CONSIDERATION',
#  'CONSIDERATION',
#  'CONSIDERED DICTUM',
#  'CONSIDERED DICTUM',
#  'CONSIDERED DICTUM',
#  'CONSIGNEE',
#  'CONSIGNMENT',
#  'CONSIGNMENT.SALE OR EXCHANGE',
#  'CONSIGNOR',
#  'CONSOLIDATED APPEAL',
#  'CONSOLIDATION',
#  'CONSOLIDATION',
#  'CONSORTIUM',
#  'CONSPIRACY',
#  'CONSPIRATOR',
#  'CONSTITUTION',
#  'CONSTITUTIONAL',
#  'CONSTITUTIONAL RIGHTS',
#  'CONSTRUCTION',
#  'CONSTRUCTIVE',
#  'CONSTRUCTIVE',
#  'CONSTRUCTIVE',
#  'CONSTRUCTIVE',
#  'CONSTRUCTIVE BAILMENT',
#  'CONSTRUCTIVE BAILMENT',
#  'CONSTRUCTIVE BAILMENT',
#  'CONSTRUCTIVE CONTEMPT',
#  'CONSTRUCTIVE CONTEMPT',
#  'CONSTRUCTIVE CONTEMPT',
#  'CONSTRUCTIVE DELIVERY',
#  'CONSTRUCTIVE DELIVERY',
#  'CONSTRUCTIVE EVICTION',
#  'CONSTRUCTIVE EVICTION',
#  'CONSTRUCTIVE EVICTION',
#  'CONSTRUCTIVE EVICTION',
#  'CONSTRUCTIVE FRAUD',
#  'CONSTRUCTIVE FRAUD',
#  'CONSTRUCTIVE FRAUD',
#  'CONSTRUCTIVE FRAUD',
#  'CONSTRUCTIVE NOTICE',
#  'CONSTRUCTIVE NOTICE',
#  'CONSTRUCTIVE NOTICE',
#  'CONSTRUCTIVE NOTICE',
#  'CONSTRUCTIVE NOTICE',
#  'CONSTRUCTIVE POSSESSION',
#  'CONSTRUCTIVE POSSESSION',
#  'CONSTRUCTIVE POSSESSION',
#  'CONSTRUCTIVE RECEIPT OF INCOME',
#  'CONSTRUCTIVE SERVICE',
#  'CONSTRUCTIVE TRUST',
#  'CONSTRUCTIVE TRUST',
#  'CONSTRUCTIVE TRUST',
#  'CONSTRUE',
#  'CONSUMER',
#  'CONSUMER GOODS',
#  'CONSUMER PROTECTION',
#  'CONTACTS APPROACH',
#  'CONTEMPLATION OF DEATH',
#  'CONTEMPLATION OF DEATH',
#  'CONTEMPT OF COURT',
#  'CONTIGUOUS',
#  'CONTINGENT',
#  'CONTINGENT BENEFICIARY',
#  'CONTINGENT ESTATE',
#  'CONTINGENT ESTATE',
#  'CONTINGENT FEE',
#  'CONTINGENT LIABILITY',
#  'CONTINUANCE',
#  'CONTINUING TRESPASS',
#  'CONTRA BONOS MORES',
#  'CONTRA L',
#  'CONTRA PACEM',
#  'CONTRABAND',
#  'CONTRACT',
#  'CONTRACT',
#  'CONTRACT',
#  'CONTRACT OF HAZARD',
#  'CONTRACT OF HAZARD',
#  'CONTRACT OFADHESION',
#  'CONTRACT UNDER SEAL',
#  'CONTRACT UNDER SEAL',
#  'CONTRACT. T',
#  'CONTRACTOR',
#  'CONTRACTOR',
#  'CONTRACTUAL BREACH',
#  'CONTRIBUTION',
#  'CONTRIBUTORY NEGLIGENCE',
#  'CONTRIBUTORY NEGLIGENCE',
#  'CONTRIBUTORY NEGLIGENCE',
#  'CONTROLLED SUBSTANCE',
#  'CONTROVERSY',
#  'CONTUMACY',
#  'CONVERSATION',
#  'CONVERSATION. H',
#  'CONVERSION',
#  'CONVERTIBLE SECURITIES',
#  'CONVERTIBLE SECURITY',
#  'CONVEY',
#  'CONVEYANCE',
#  'CONVICT',
#  'CONVICTION',
#  'COOPERATIVE',
#  'COOPERATIVE',
#  'COOPERATIVE ASSOCIATION',
#  'COORDINATE JURISDICTION',
#  'COPARCENARY',
#  'COPARCENERS',
#  'COPARTNER',
#  'COPY',
#  'COPYHOLD',
#  'COPYRIGHT',
#  'CORAM NOBIS',
#  'CORAM NOBIS',
#  'CORESPONDENT',
#  'CORONER',
#  'CORPORAL PUNISHMENT',
#  'CORPORATE',
#  'CORPORATE OPPORTUNITY',
#  'CORPORATE POWER',
#  'CORPORATION',
#  'CORPORATION',
#  'CORPORATIONS',
#  'CORPOREAL',
#  'CORPOREAL HEREDITAMENT',
#  'CORPOREALHEREDITAMENTS',
#  'CORPUS DELICTI',
#  'CORPUS JURIS',
#  'CORPUS L',
#  'CORRECTIONAL FACILITY',
#  'CORRECTIONAL INSTITUTION',
#  'CORRESPONDENT',
#  'CORRESPONDENT',
#  'CORROBORATING EVIDENCE',
#  'CORRUPTION OF THE',
#  'CORRUPTION OF THE BLOOD',
#  'COSIGN',
#  'COST',
#  'COST',
#  'COST',
#  'COST OF COMPLETION',
#  'COST OF COMPLETION',
#  'COST OF LIVING CLAUSE',
#  'COSTS',
#  'COSTS TO ABIDE THE EVENT',
#  'COUNSEL',
#  'COUNSELLOR',
#  'COUNT',
#  'COUNTER MARKET',
#  'COUNTERCLAIM',
#  'COUNTERFEIT',
#  'COUPLED WITH AN INTEREST',
#  'COUPONS',
#  'COURSE OF',
#  'COURSE OF BUSINESS',
#  'COURSE OF DEALING',
#  'COURSE OF DEALING',
#  'COURT',
#  'COURT',
#  'COURT',
#  'COURT',
#  'COURT',
#  'COURT',
#  'COURT CALENDAR',
#  'COURT CLERK',
#  'COURT OF',
#  'COURT OF APPEALS',
#  'COURT OF ASSIZE AND NISI PRIUS',
#  'COURT OF CLAIMS',
#  'COURT OF CUSTOMS AND PATENT APPEALS',
#  'COURT OF CUSTOMS AND PATENT APPEALS',
#  'COURT OF EQUITY',
#  'COURT OF EXCHEQUER',
#  'COURT OF INQUIRY',
#  'COURT OF KING',
#  'COURT OF LAW',
#  'COURT OF MILITARY APPEAL',
#  'COURT OF MILITARY APPEAL',
#  'COURT OF MILITARY APPEAL',
#  'COURT OF MILITARY REVIEW',
#  'COURT OF MILITARY REVIEW',
#  'COURT OF MILITARY REVIEW',
#  'COURT OF RECORD',
#  'COURT OF STAR CHAMBER',
#  'COURT REPORTERS',
#  'COURT REPORTS',
#  'COURT SETTLEMENT',
#  'COURTDOCKET.COURT EN BANC',
#  'COVENANT',
#  'COVENANT',
#  'COVENANT AGAINST ACTS OF THE GRANTOR',
#  'COVENANT AGAINST ENCUMBRANCES',
#  'COVENANT NOT TO COMPETE',
#  'COVENANT NOT TO COMPETE',
#  'COVENANT NOT TO COMPETE',
#  'COVENANT OF',
#  'COVENANT OF FURTHER ASSURANCE',
#  'COVENANT OF FURTHER ASSURANCE',
#  'COVENANT OF QUIET ENJOYMENT',
#  'COVENANT OF QUIET ENJOYMENT',
#  'COVENANT OF QUIET ENJOYMENT',
#  'COVENANT OF SEISIN AND RIGHT TO CONVEY',
#  'COVENANT OF SEISIN AND RIGHT TO CONVEY',
#  'COVENANT OF SEISIN AND RIGHT TO CONVEY',
#  'COVENANT OF WARRANTY AND QUIET ENJOYMENT',
#  'COVENANTEE',
#  'COVENANTOR',
#  'COVENANTS',
#  'COVENANTS OF TITLE',
#  'COVER',
#  'COVERTURE',
#  'CREDIBILITY',
#  'CREDIT',
#  'CREDIT CARD',
#  'CREDITOR',
#  'CREDITOR',
#  'CREDITOR BENEFICIARY',
#  'CREDITOR BENEFICIARY',
#  'CREDITOR BENEFICIARY',
#  'CRIME',
#  'CRIME',
#  'CRIME AGAINST NATURE',
#  'CRIME OF PASSION',
#  'CRIMEN FALSI',
#  'CRIMINAL',
#  'CRIMINAL',
#  'CRIMINAL',
#  'CRIMINAL',
#  'CRIMINAL',
#  'CRIMINAL',
#  'CRIMINAL',
#  'CRIMINAL CODE',
#  'CRIMINAL COERCION',
#  'CRIMINAL CONTEMPT',
#  'CRIMINAL CONTEMPT',
#  'CRIMINAL CONVERSATION',
#  'CRIMINAL MAINTENANCE',
#  'CRIMINAL MISCHIEF',
#  'CRIMINAL NEGLIGENCE',
#  'CRIMINAL POSSESSION',
#  'CRIMINAL POSSESSION',
#  'CRIMINAL PROCEDURE',
#  'CRIMINAL PROCEDURE',
#  'CRIMINAL RECORD',
#  'CROSS',
#  'CROSS',
#  'CROSS',
#  'CROSS',
#  'CROSS BILL',
#  'CRUEL AND UNUSUAL PUNISHMENT',
#  'CTA',
#  'CTA',
#  'CTA',
#  'CUCKOLD',
#  'CULPA L',
#  'CULPABLE',
#  'CULPABLE',
#  'CULPABLE',
#  'CULPABLE MENTAL STATE',
#  'CUM TESTAMENTO ANNEXO',
#  'CUM TESTAMENTO ANNEXO',
#  'CUM TESTAMENTO ANNEXO',
#  'CUMULATIVE',
#  'CUMULATIVE',
#  'CUMULATIVE',
#  'CUMULATIVE DIVIDEND',
#  'CUMULATIVE DIVIDEND',
#  'CUMULATIVE DIVIDEND',
#  'CUMULATIVE SENTENCE',
#  'CUMULATIVE VOTING',
#  'CURATIVE',
#  'CURIA REGIS',
#  'CURRENT ASSETS',
#  'CURRENT ASSETS',
#  'CURRENT EARNINGS AND PROFITS',
#  'CURRENT LIABILITIES',
#  'CURRENT LIABILITIES',
#  'CURTESY',
#  'CURTILAGE',
#  'CUSTODIAL SENTENCE',
#  'CUSTODY',
#  'CUSTODY OF CHILDREN',
#  'CUSTOM DUTIES',
#  'CUSTOMS AND PATENT APPEALS',
#  'CUSTOMS COURT',
#  'CUSTOMS COURT',
#  'D.B.A.',
#  'D.B.A. S',
#  'D.C.',
#  'D.U.I.',
#  'D.W.I.',
#  'D.W.I.',
#  'D.W.I.',
#  'D.W.I.',
#  'DAILY',
#  'DAMAGE',
#  'DAMAGE',
#  'DAMAGES',
#  'DAMAGES',
#  'DAMAGES',
#  'DAMAGES',
#  'DAMAGES',
#  'DAMAGES',
#  'DAMNUM ABSQUE INJURIA',
#  'DANGEROUS WEAPON',
#  'DATE',
#  'DATE',
#  'DAY IN COURT',
#  'DBN',
#  'DBN',
#  'DBN',
#  'DD.A.',
#  'DE BENE ESSE',
#  'DE BONIS NON',
#  'DE BONIS NON',
#  'DE BONIS NON',
#  'DE FACTO',
#  'DE FACTO',
#  'DE FACTO',
#  'DE FACTO CORPORATION',
#  'DE FACTO INCUMBENT',
#  'DE JURE',
#  'DE MINIMIS',
#  'DE MINIMIS NON CURAT LEX',
#  'DE NOVO',
#  'DE NOVO HEARING',
#  'DE NOVO HEARING',
#  'DEAD HAND',
#  'DEADLY FORCE',
#  'DEADLY FORCE',
#  'DEADLY FORCE',
#  'DEADLY WEAPON',
#  'DEALER',
#  'DEALING',
#  'DEATH',
#  'DEATH BY',
#  'DEATH BY AUTOMOBILE',
#  'DEATH BY AUTOMOBILE',
#  'DEATH BY AUTOMOBILE',
#  'DEATH PENALTY',
#  'DEBAUCHERY',
#  'DEBENTURE',
#  'DEBIT',
#  'DEBT',
#  'DEBT',
#  'DEBT CAPITAL',
#  'DEBT CAPITAL',
#  'DEBT CAPITAL',
#  'DEBTOR',
#  'DECEASED',
#  'DECEDENT',
#  'DECEDENT',
#  'DECEIT',
#  'DECISION',
#  'DECISION',
#  'DECISION ON THE MERITS',
#  'DECLARANT',
#  'DECLARATION',
#  'DECLARATION AGAINST INTEREST',
#  'DECLARATION OF ESTIMATED TAX',
#  'DECLARATION OF ESTIMATED TAX',
#  'DECLARATION OF ESTIMATED TAX',
#  'DECLARATION OF TRUST',
#  'DECLARATION OF TRUST',
#  'DECLARATORY JUDGMENT',
#  'DECLARATORY STATUTE',
#  'DECREE',
#  'DECREE NISI',
#  'DECREE NISI',
#  'DECREE NISI',
#  'DECREE NISI',
#  'DECRIMINALIZATION',
#  'DEDICATION',
#  'DEDICATION',
#  'DEDUCTIONS',
#  'DEED',
#  'DEED OF TRUST',
#  'DEED POLL',
#  'DEEP ROCK DOCTRINE',
#  'DEFALCATION',
#  'DEFAMATION',
#  'DEFAULT',
#  'DEFAULT JUDGMENT',
#  'DEFEASANCE',
#  'DEFEASIBLE',
#  'DEFEASIBLE FEE',
#  'DEFEASIBLE FEE',
#  'DEFECT',
#  'DEFECTIVE',
#  'DEFECTIVE PLEADING',
#  'DEFECTIVE TITLE',
#  'DEFENDANT',
#  'DEFENDANT IN ERROR',
#  'DEFENDENT IN ERROR',
#  'DEFENSE',
#  'DEFENSE',
#  'DEFENSE OF',
#  'DEFERMENT',
#  'DEFERRED COMPENSATION',
#  'DEFERRED COMPENSATION',
#  'DEFERRED COMPENSATION',
#  'DEFERRED PAYMENTS',
#  'DEFICIENCY',
#  'DEFICIT',
#  'DEFINITE FAILURE OF ISSUE',
#  'DEFINITE FAILURE OF ISSUE',
#  'DEFRAUD',
#  'DEGREE',
#  'DEGREE',
#  'DEGREE',
#  'DEGREE',
#  'DEGREE MURDER',
#  'DEGREE MURDER',
#  'DEGREE MURDER',
#  'DEGREE OF CONSANGUINITY',
#  'DEGREE OF CRIME',
#  'DEGREE OF NEGLIGENCE',
#  'DEGREE OF PROOF',
#  'DEHORS',
#  'DELEGABLE DUTY',
#  'DELEGABLE DUTY',
#  'DELEGATE',
#  'DELEGATED POWER',
#  'DELIBERATE',
#  'DELIBERATE',
#  'DELIBERATE SPEED',
#  'DELIBERATION',
#  'DELICT',
#  'DELICTUM',
#  'DELICTUML',
#  'DELINQUENCY. S',
#  'DELINQUENT',
#  'DELISTING',
#  'DELIVERY',
#  'DELIVERY. C',
#  'DELUSION',
#  'DEMAND',
#  'DEMAND NOTE',
#  'DEMESNE F',
#  'DEMISE',
#  'DEMONSTRATIVE EVIDENCE',
#  'DEMUR',
#  'DEMURRER',
#  'DENIAL',
#  'DEODAND',
#  'DEPENDENCY',
#  'DEPENDENT',
#  'DEPENDENT CARE',
#  'DEPENDENT CHILDREN',
#  'DEPENDENT COVENANTS',
#  'DEPENDENT COVENANTS',
#  'DEPENDENT COVENANTS',
#  'DEPENDENT RELATIVE REVOCATION',
#  'DEPLETION',
#  'DEPLETION ALLOWANCE',
#  'DEPLETION ALLOWANCE',
#  'DEPONENT',
#  'DEPORTATION',
#  'DEPOSE',
#  'DEPOSITION',
#  'DEPOSITION DE BENE ESSE',
#  'DEPOSITIONS DE BENE ESSE',
#  'DEPRECIATION',
#  'DEPRECIATION RESERVE',
#  'DEPREDATION',
#  'DEPRESSANTS',
#  'DERELICTION',
#  'DERIVATIVE ACTION',
#  'DERIVATIVE ACTION',
#  'DERIVATIVE ACTION',
#  'DERIVATIVE SUIT',
#  'DERIVATIVE TORT',
#  'DEROGATION',
#  'DESCENT',
#  'DESCENT AND DISTRIBUTION',
#  'DESEGREGATION',
#  'DESERTION',
#  'DESIST',
#  'DESTINATION CONTRACT',
#  'DESTRUCTIBILITY',
#  'DESUETUDE',
#  'DETAINER',
#  'DETENTION',
#  'DETERMINABLE FEE',
#  'DETERMINATION',
#  'DETINUE',
#  'DETRIMENTAL RELIANCE',
#  'DEVISE',
#  'DEVOLVE',
#  'DICTA',
#  'DICTUM',
#  'DIE WITHOUT ISSUE',
#  'DIFFERENTIAL.ODIOUS',
#  'DILATORY PLEA',
#  'DILATORY PLEA',
#  'DILIGENCE',
#  'DILUTING THE SHARES',
#  'DIMINISHED',
#  'DIMINISHED CAPACITY',
#  'DIMINISHED RESPONSIBILITY',
#  'DIMINUTION IN VALUE',
#  'DIRECT AFFINITY',
#  'DIRECT AFFINITY',
#  'DIRECT AFFINITY',
#  'DIRECT ATTACK',
#  'DIRECT CAUSE',
#  'DIRECT CAUSE',
#  'DIRECT CAUSE',
#  'DIRECT CAUSE',
#  'DIRECT CONTEMPT',
#  'DIRECT CONTEMPT',
#  'DIRECT ESTOPPEL',
#  'DIRECT ESTOPPEL',
#  'DIRECT ESTOPPEL',
#  'DIRECT EXAMINATION',
#  'DIRECT EXAMINATION',
#  'DIRECT EXAMINATION',
#  'DIRECT EXAMINATION',
#  'DIRECT EXAMINATION',
#  'DIRECT EXAMINATION',
#  'DIRECT ORDER OF ALIENATION',
#  'DIRECT ORDER OF ALIENATION',
#  'DIRECT TRUST',
#  'DIRECTED VERDICT',
#  'DIRECTED VERDICT',
#  'DIRECTOR',
#  'DISABILITY',
#  'DISBAR',
#  'DISCHARGE',
#  'DISCHARGE IN BANKRUPTCY',
#  'DISCLAIMER',
#  'DISCLAIMER OF LIABILITY',
#  'DISCLOSED PRINCIPAL',
#  'DISCONTINUANCE',
#  'DISCOUNT',
#  'DISCOUNT BOND',
#  'DISCOUNTED CASH FLOW',
#  'DISCOVERY',
#  'DISCRETION',
#  'DISCRETIONARY ACCOUNT',
#  'DISCRIMINATION',
#  'DISCRIMINATION ACT',
#  'DISHONOR',
#  'DISINHERITANCE',
#  'DISINTERMEDIATION',
#  'DISJUNCTIVE ALLEGATIONS',
#  'DISJUNCTIVE DENIAL',
#  'DISMISS',
#  'DISMISSAL',
#  'DISMISSAL WITH PREJUDICE',
#  'DISMISSAL WITH PREJUDICE',
#  'DISMISSAL WITH PREJUDICE',
#  'DISMISSAL WITHOUT PREJUDICE',
#  'DISMISSAL WITHOUT PREJUDICE',
#  'DISMISSAL WITHOUT PREJUDICE',
#  'DISORDERLY CONDUCT',
#  'DISPARAGEMENT',
#  'DISPARAGEMENT. S',
#  'DISPOSITION',
#  'DISPOSSESS',
#  'DISPUTABLE PRESUMPTION',
#  'DISQUALIFICATION',
#  'DISSEISIN',
#  'DISSENT',
#  'DISSENTING OPINION',
#  'DISSENTING OPINION',
#  'DISSENTING OPINION',
#  'DISSOLUTION',
#  'DISTINGUISH',
#  'DISTRAINER',
#  'DISTRAINT',
#  'DISTRAINT',
#  'DISTRESS',
#  'DISTRESS',
#  'DISTRESS',
#  'DISTRIBUTION',
#  'DISTRIBUTION',
#  'DISTRICT ATTORNEY',
#  'DISTRICT COURT',
#  'DISTURBANCE OF THE PEACE',
#  'DIVERS',
#  'DIVERSIONARY PROGRAMS',
#  'DIVERSIONARY PROGRAMS',
#  'DIVERSIONARY PROGRAMS.PREVAILING PARTY',
#  'DIVERSITY JURISDICTION',
#  'DIVERSITY JURISDICTION',
#  'DIVERSITY OF CITIZENSHIP',
#  'DIVESTITURE',
#  'DIVIDEND',
#  'DIVIDEND',
#  'DIVIDEND',
#  'DIVIDEND ADDITION',
#  'DIVIDEND DATE',
#  'DIVIDEND DATE',
#  'DIVISIBLE CONTRACT',
#  'DIVISIBLE CONTRACTS',
#  'DIVORCE',
#  'DIVORCE A MENSA ET THORO',
#  'DNA',
#  'DNA',
#  'DNA',
#  'DNA',
#  'DNA',
#  'DNA',
#  'DNA',
#  'DNA',
#  'DNA',
#  'DNA',
#  'DNA',
#  'DNA',
#  'DNA',
#  'DNA',
#  'DNA',
#  'DNA',
#  'DNA',
#  'DNA',
#  'DNA',
#  'DNA',
#  'DNA TESTING',
#  'DNA. DNA',
#  'DOB',
#  'DOCKET',
#  'DOCTOR',
#  'DOCTRINE',
#  'DOCTRINE OF',
#  'DOCTRINE OF WORTHIER TITLE',
#  'DOCUMENT',
#  'DOCUMENT',
#  'DOCUMENT OF TITLE',
#  'DOCUMENTARY EVIDENCE',
#  'DOLUS',
#  'DOLUS',
#  'DOMAIN',
#  'DOMESDAY BOOK',
#  'DOMICILE',
#  'DOMICILIARY',
#  'DOMINANT ESTATE',
#  'DOMINANT ESTATE',
#  'DOMINION',
#  'DONATED SURPLUS',
#  'DONATED SURPLUS',
#  'DONATED SURPLUS',
#  'DONATIO L',
#  'DONATION',
#  'DONATION.',
#  'DONATIVE INTENT',
#  'DONEE',
#  'DONEE BENEFICIARY',
#  'DONEE BENEFICIARY',
#  'DONEE BENEFICIARY',
#  'DONOR',
#  'DONOR',
#  'DOUBLE',
#  'DOUBLE',
#  'DOUBLE',
#  'DOUBLE DAMAGES',
#  'DOUBLE JEOPARDY',
#  'DOUBT',
#  'DOWAGER',
#  'DOWER',
#  'DOWRY',
#  'DQ A',
#  'DQ A',
#  'DQ ALPHA',
#  'DRAFT',
#  'DRAM SHOPACT',
#  'DRAW',
#  'DRAWEE',
#  'DRAWER',
#  'DRAWING',
#  'DRAWN',
#  'DRIVING WHILE INTOXICATED',
#  'DROIT F',
#  'DRUG ABUSE',
#  'DRUG LAW',
#  'DRUGS',
#  'DTC',
#  'DUAL CITIZENSHIP',
#  'DUCES TECUM',
#  'DUE CARE',
#  'DUE COURSE',
#  'DUE DATE',
#  'DUE DILIGENCE',
#  'DUE PROCESS',
#  'DUE PROCESS OF LAW',
#  'DUMMY',
#  'DUMMY CORPORATION',
#  'DUMMY DIRECTOR',
#  'DUMMY SHAREHOLDER',
#  'DUMPING',
#  'DUMPING LAW',
#  'DUPLICITOUS',
#  'DUPLICITY',
#  'DURESS',
#  'DURHAM RULE',
#  'DUTY',
#  'DUTY',
#  'DUTY OF',
#  'DUTY OF CARE',
#  'DUTY OF PRODUCING EVIDENCE',
#  'DUTY OF PRODUCING EVIDENCE',
#  'DUTY TO',
#  'DUTY TO MITIGATE DAMAGES',
#  'DUTY TO MITIGATE DAMAGES',
#  'DWELLING HOUSE',
#  'DYING DECLARATIONS',
#  'DYING DECLARATIONS',
#  'DYINGDECLARATIONS. U',
#  'E.E.O.C.',
#  'E.R.A.',
#  'E.R.A.',
#  'E.R.A.',
#  'EARNED SURPLUS',
#  'EARNINGS AND PROFITS',
#  'EARNINGS REPORT',
#  'EASEMENT',
#  'EASEMENT APPURTENANT',
#  'EASEMENT APPURTENANT',
#  'EASEMENT BY',
#  'EASEMENT BY PRESCRIPTION',
#  'EASEMENT IN',
#  'EASEMENT IN GROSS',
#  'EASEMENT IN GROSS',
#  'EASEMENT IN GROSS',
#  'EASEMENT OF NECESSITY',
#  'EAVESDROPPING',
#  'ECCLESIASTICAL LAW',
#  'ECONOMIC WASTE',
#  'ECU',
#  'EEARNEST',
#  'EEOC',
#  'EEOC',
#  'EEOC). T',
#  'EFFECTIVE TAX RATE',
#  'EFFECTS',
#  'EGRESS',
#  'EIGHTH AMENDMENT',
#  'EIR',
#  'EIS',
#  'EJECTMENT',
#  'EJUSDEM GENERIS',
#  'ELECTION',
#  'ELECTION',
#  'ELECTION',
#  'ELECTION',
#  'ELECTION OF REMEDIES',
#  'ELECTION UNDER THE WILL',
#  'ELECTIVE',
#  'ELECTIVE FRANCHISE',
#  'ELECTIVE FRANCHISE',
#  'ELECTIVE FRANCHISE',
#  'ELECTIVE SHARE',
#  'ELEGIT',
#  'ELEGIT',
#  'ELEGIT L',
#  'ELEMENT',
#  'ELEMENTS',
#  'ELEVENTH AMENDMENT',
#  'EMANCIPATION',
#  'EMBEZZLEMENT',
#  'EMBLEMENTS',
#  'EMBRACERY',
#  'EMINENT DOMAIN',
#  'EMOLUMENT',
#  'EMOTIONAL',
#  'EMOTIONAL DISTRESS',
#  'EMPLOYEE SHARE OWNERSHIP PLAN',
#  'EMPLOYEE STOCK OPTION',
#  'EMPLOYEE STOCK OPTION',
#  'EMPLOYER',
#  'EMPLOYMENT RETIREMENT INCOME SECURITY ACT OF',
#  'EMPLOYMENT RETIREMENT INCOME SECURITYACT OF',
#  'EN BANC',
#  'EN GROS',
#  'EN VENTRE SA MERE',
#  'ENABLING CLAUSE',
#  'ENACTING CLAUSE',
#  'ENCLOSURE',
#  'ENCUMBRANCE',
#  'END LOAD PLAN',
#  'END MANAGEMENT COMPANY',
#  'END MUTUAL FUNDS',
#  'END MUTUAL FUNDS',
#  'ENDORSEMENT',
#  'ENDOWMENT',
#  'ENDOWMENT INSURANCE',
#  'ENFEOFF',
#  'ENJOIN',
#  'ENJOYMENT',
#  'ENLARGEMENT',
#  'ENRICHMENT',
#  'ENTAIL',
#  'ENTIRETY',
#  'ENTIRETY',
#  'ENTITY',
#  'ENTRAPMENT',
#  'ENTRY',
#  'ENTRY',
#  'ENUMERATED',
#  'ENUMERATED POWERS',
#  'ENURE',
#  'ENVIRONMENTAL IMPACT STATEMENT',
#  'ENVIRONMENTAL PROTECTION AGENCY',
#  'EO INSTANTI',
#  'EPA',
#  'EPA',
#  'EQUAL EMPLOYMENT OPPORTUNITY COMMISSION',
#  'EQUAL EMPLOYMENT OPPORTUNITY COMMISSION',
#  'EQUAL OPPORTUNITY',
#  'EQUAL PROTECTION OF THE LAWS',
#  'EQUAL RIGHTS AMENDMENT',
#  'EQUAL TIME ACT',
#  'EQUALITY',
#  'EQUIPMENT',
#  'EQUITABLE',
#  'EQUITABLE',
#  'EQUITABLE',
#  'EQUITABLE DEFENSE',
#  'EQUITABLE DEFENSE',
#  'EQUITABLE DEFENSE',
#  'EQUITABLE DISTRIBUTION',
#  'EQUITABLE DISTRIBUTION',
#  'EQUITABLE DISTRIBUTION',
#  'EQUITABLE DISTRIBUTION',
#  'EQUITABLE EASEMENT',
#  'EQUITABLE ESTATE',
#  'EQUITABLE ESTATE',
#  'EQUITABLE ESTATES',
#  'EQUITABLE ESTOPPEL',
#  'EQUITABLE ESTOPPEL',
#  'EQUITABLE LIEN',
#  'EQUITABLE MORTGAGE',
#  'EQUITABLE RECOUPMENT',
#  'EQUITABLE RELIEF',
#  'EQUITABLE SALVAGE',
#  'EQUITABLE SEISIN',
#  'EQUITABLE SERVITUDE',
#  'EQUITABLE TITLE',
#  'EQUITABLE TITLE',
#  'EQUITABLE TITLE',
#  'EQUITABLE WASTE',
#  'EQUITY',
#  'EQUITY CAPITAL',
#  'EQUITY CAPITAL',
#  'EQUITY CAPITAL',
#  'EQUITY MARKET',
#  'EQUITY MARKET',
#  'EQUITY OF REDEMPTION',
#  'EREMPTORYCHALLENGES',
#  'ERGO L',
#  'ERISA',
#  'ERISA',
#  'ERISA.',
#  'ERISA.',
#  'ERRONEOUS',
#  'ERRONEOUS JUDGMENT',
#  'ERROR',
#  'ERROROF LAW',
#  'ESCALATOR CLAUSE',
#  'ESCAPE CLAUSE',
#  'ESCHEAT',
#  'ESCROW',
#  'ESCROW AGENT',
#  'ESOP',
#  'ESOP',
#  'ESOP',
#  'ESQ.',
#  'ESQUIRE',
#  'ESSENCE',
#  'ESTABLISHMENT CLAUSE',
#  'ESTATE',
#  'ESTATE',
#  'ESTATE AT SUFFERANCE',
#  'ESTATE AT WILL',
#  'ESTATE BY THE ENTIRETY',
#  'ESTATE FOR LIFE',
#  'ESTATE FOR YEARS',
#  'ESTATE FROM YEAR TO YEAR',
#  'ESTATE IN',
#  'ESTATE IN COMMON',
#  'ESTATE IN COPARCENARY',
#  'ESTATE OF INHERITANCE',
#  'ESTATE PER AUTRE VIE',
#  'ESTATE TAX',
#  'ESTATE TAX',
#  'ESTATE TAX',
#  'ESTATE TAX',
#  'ESTATE TAX',
#  'ESTIMATED TAX',
#  'ESTOPPEL',
#  'ESTOPPEL BY',
#  'ESTOPPEL BY DEED',
#  'ESTOPPEL BY JUDGMENT',
#  'ESTOPPEL BY JUDGMENT',
#  'ESTOPPEL BY JUDGMENT',
#  'ESTOPPEL BY LACHES',
#  'ESTOPPEL IN PAIS',
#  'ESTOPPEL IN PAIS',
#  'ESTOVERS',
#  'ET AL.',
#  'ET NON',
#  'ET SEQ.',
#  'ET UX.',
#  'ETHICAL',
#  'EURODOLLAR',
#  'EUTHANASIA',
#  'EVASION OF TAX',
#  'EVASIVE ANSWER',
#  'EVICTION',
#  'EVIDENCE',
#  'EVIDENCE',
#  'EVIDENCE ALIUNDE',
#  'EVIDENCE DE BENE ESSE',
#  'EVIDENCE DE BENE ESSE',
#  'EX AEQUO ET BONO',
#  'EX CONTRACTU',
#  'EX CONTRACTU',
#  'EX DELICTO',
#  'EX DELICTO',
#  'EX GRATIA',
#  'EX OFFICIO',
#  'EX OFFICIO MEMBER',
#  'EX OFFICIO SERVICES',
#  'EX PARTE',
#  'EX POST FACTO',
#  'EX REL',
#  'EX TURPI CAUSA NON ORITUR ACTIO',
#  'EXAMINATION',
#  'EXAMINATION',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE',
#  'EXAMPLE. T',
#  'EXCEPTION',
#  'EXCESSIVE BAIL',
#  'EXCHANGE',
#  'EXCHEQUER',
#  'EXCISE',
#  'EXCISE TAX',
#  'EXCLUSION',
#  'EXCLUSIONARY RULE',
#  'EXCLUSIVE USE',
#  'EXCLUSIVE USE',
#  'EXCONTRACTU',
#  'EXCULPATORY',
#  'EXCULPATORY CLAUSE',
#  'EXCUSABLE NEGLECT',
#  'EXECUTE',
#  'EXECUTED',
#  'EXECUTED INTEREST',
#  'EXECUTED INTEREST',
#  'EXECUTED INTEREST',
#  'EXECUTED REMAINDER',
#  'EXECUTED SALE',
#  'EXECUTED SALE',
#  'EXECUTION',
#  'EXECUTION OF INSTRUMENT',
#  'EXECUTION SALE',
#  'EXECUTION SALE',
#  'EXECUTIVE AGREEMENT',
#  'EXECUTIVE AGREEMENT',
#  'EXECUTIVE CLEMENCY',
#  'EXECUTIVE ORDER',
#  'EXECUTIVE PARDON',
#  'EXECUTIVE PRIVILEGE',
#  'EXECUTIVE PROCLAMATION',
#  'EXECUTOR',
#  'EXECUTORY',
#  'EXECUTORY',
#  'EXECUTORY BEQUEST',
#  'EXECUTORY BEQUEST',
#  'EXECUTORY BEQUEST',
#  'EXECUTORY CONTRACT',
#  'EXECUTORY CONTRACTS',
#  'EXECUTORY INTEREST',
#  'EXECUTORY INTEREST',
#  'EXECUTORY INTEREST',
#  'EXECUTORY INTEREST',
#  'EXECUTORY INTEREST',
#  'EXECUTORY SALE',
#  'EXECUTORY SALE',
#  'EXECUTORY WAIVER',
#  'EXECUTORY WAIVER',
#  'EXECUTORY WAIVER',
#  'EXEMPLAR',
#  'EXEMPLARY',
#  'EXEMPLARY',
#  'EXEMPLARY DAMAGES',
#  'EXEMPLARY DAMAGES',
#  'EXEMPT',
#  'EXEMPTION',
#  'EXHAUSTION OF ADMINISTRATIVE REMEDIES',
#  'EXHAUSTION OF REMEDIES',
#  'EXHAUSTION OF STATE REMEDIES',
#  'EXHAUSTION OF STATE REMEDIES',
#  'EXHIBIT',
#  'EXIGENCY',
#  'EXIGENT CIRCUMSTANCES',
#  'EXIGIBLE',
#  'EXILE',
#  'EXPECTANCY',
#  'EXPECTATION DAMAGES',
#  'EXPECTATION DAMAGES',
#  'EXPECTATION DAMAGES',
#  'EXPECTATION DAMAGES',
#  'EXPENSE',
#  'EXPERT EVIDENCE',
#  'EXPERT TESTIMONY',
#  'EXPERT TESTIMONY',
#  'EXPERT WITNESS',
#  'EXPERT WITNESS',
#  'EXPORT',
#  'EXPRESS',
#  'EXPRESS AUTHORITY',
#  'EXPRESS POWERS',
#  'EXPRESS TRUST',
#  'EXPRESS TRUST',
#  'EXPRESS TRUST',
#  'EXPRESS WARRANTIES',
#  'EXPRESS WARRANTIES',
#  'EXPRESS WARRANTY',
#  'EXPRESSIO UNIUS EST EXCLUSIO ALTERIUS',
#  'EXPROPRIATION',
#  'EXPULSION',
#  'EXPULSION',
#  'EXPUNGEMENT OF RECORDS',
#  'EXTENDI FACIAS',
#  'EXTENSION',
#  'EXTENUATING CIRCUMSTANCES',
#  'EXTINGUISHMENT',
#  'EXTORTION',
#  'EXTRADITION',
#  'EXTRAJUDICIAL',
#  'EXTRAORDINARY DIVIDENDS',
#  'EXTRAORDINARY DIVIDENDS',
#  'EXTRAORDINARY DIVIDENDS',
#  'EXTRAORDINARY REMEDY',
#  'EXTRAORDINARY REMEDY',
#  'EXTRAORDINARY REMEDY',
#  'EXTREMIS',
#  'EXTRINSIC',
# ...
#  'SUBSTANTIAL PERFORMANCE',
#  'SUBSTANTIVE',
#  'SUBSTANTIVE DUE PROCESS',
#  'SUBSTANTIVE LAW',
#  'SUBSTITUTED BASIS',
#  'SUBSTITUTED BASIS',
#  'SUBSTITUTED SERVICE',
#  'SUBSTITUTED SERVICE',
#  'SUBSTITUTED SERVICE',
#  'SUBSTITUTION',
#  'SUBTENANT',
#  'SUCCESSION',
#  'SUCCESSIVE TERMS',
#  'SUCCESSOR',
#  'SUCCESSOR ADMINISTRATOR',
#  'SUCCESSOR ADMINISTRATOR',
#  'SUCCESSOR ADMINISTRATOR',
#  'SUE OUT',
#  'SUFFERANCE',
#  'SUI GENERIS',
#  'SUI JURIS',
#  'SUICIDE',
#  'SUIT',
#  'SUITOR',
#  'SUM ALIMONY PAYMENT',
#  'SUM CERTAIN',
#  'SUM DISTRIBUTION',
#  'SUM PAYMENT',
#  'SUMMARY COURT',
#  'SUMMARY COURT',
#  'SUMMARY JUDGMENT',
#  'SUMMARY JUDGMENT',
#  'SUMMARY PROCEEDING',
#  'SUMMATION',
#  'SUMMING UP',
#  'SUMMONS',
#  'SUNDAY CLOSING LAWS',
#  'SUNSHINE LAWS',
#  'SUO NOMINE',
#  'SUPERIOR COURT',
#  'SUPERIOR COURT',
#  'SUPERIOR COURT',
#  'SUPERSEDEAS L',
#  'SUPERSEDING CAUSE',
#  'SUPERSEDING CAUSE',
#  'SUPERSEDING CAUSE',
#  'SUPERVENING',
#  'SUPERVENING',
#  'SUPERVENING CAUSE',
#  'SUPERVENING CAUSE',
#  'SUPPLEMENTAL',
#  'SUPPLEMENTAL ACT',
#  'SUPPLEMENTAL AFFIDAVIT',
#  'SUPPLEMENTAL ANSWER',
#  'SUPPLEMENTAL BILL',
#  'SUPPLEMENTAL CLAIM',
#  'SUPPLEMENTAL PLEADING',
#  'SUPPLEMENTAL PLEADING',
#  'SUPPLEMENTAL PROCEEDING',
#  'SUPPLEMENTARY SECURITY INCOME',
#  'SUPPLEMENTARY SECURITY INCOME',
#  'SUPPLEMENTARY SECURITY INCOME',
#  'SUPPLEMENTARY SECURITY INCOME',
#  'SUPPORT',
#  'SUPPRESS',
#  'SUPPRESSION OF EVIDENCE',
#  'SUPRA L',
#  'SUPREMACY CLAUSE',
#  'SUPREME COURT',
#  'SUPREME COURT OF APPEALS',
#  'SUPREME COURT OF ERRORS',
#  'SUPREME JUDICIAL COURT',
#  'SURCHARGE',
#  'SURETY',
#  'SURETY BOND',
#  'SURETY BOND',
#  'SURETY BOND',
#  'SURPLUS',
#  'SURPLUS',
#  'SURREBUTTER',
#  'SURREJOINDER',
#  'SURRENDER',
#  'SURROGATE',
#  'SURROGATE',
#  'SURROGATE',
#  'SURROGATE MOTHER',
#  'SURROGATE PARENT',
#  'SURTAX',
#  'SURTAX',
#  'SURVEILLANCE',
#  'SURVIVAL STATUTE',
#  'SURVIVORSHIP',
#  'SUSPECT',
#  'SUSPECT CLASSIFICATION',
#  'SUSPENDED SENTENCE',
#  'SUSPENDED SENTENCE',
#  'SUSPENDED SENTENCE',
#  'SUSPENDED SENTENCE',
#  'SUSPENDED SENTENCE',
#  'SUSPENDED SENTENCE',
#  'SUSTAIN',
#  'SWEARING',
#  'SWEEPSTAKES',
#  'SWEEPSTAKES',
#  'SWEEPSTAKES',
#  'SWITCH',
#  'SYLLABUS',
#  'SYMBOLIC',
#  'SYMBOLIC DELIVERY',
#  'SYMBOLIC DELIVERY',
#  'SYMBOLIC SPEECH',
#  'SYNDICATE',
#  'T.R.O.',
#  'T.RO.',
#  'TACKING',
#  'TAFT',
#  'TAIL',
#  'TAIL',
#  'TAINT',
#  'TAINTED',
#  'TAINTED EVIDENCE',
#  'TAKING THE FIFTH',
#  'TANGIBLE PROPERTY',
#  'TARGET CORPORATION',
#  'TARGET CORPORATION',
#  'TARGETED JOBS CREDIT',
#  'TARGETED JOBS CREDIT',
#  'TARGETED JOBS CREDIT',
#  'TAX',
#  'TAX BENEFIT DOCTRINE',
#  'TAX COURT',
#  'TAX CREDIT',
#  'TAX DEDUCTION',
#  'TAX EVASION',
#  'TAX EXEMPT',
#  'TAX EXPENDITURE',
#  'TAX EXPENDITURE BUDGET',
#  'TAX PREFERENCE ITEMS',
#  'TAX RATE',
#  'TAX REFUND',
#  'TAX RETURN',
#  'TAX SALE',
#  'TAX SALE',
#  'TAX SALE',
#  'TAX SHELTER',
#  'TAXABLE ESTATE',
#  'TAXABLE GIFT',
#  'TAXABLE INCOME',
#  'TAXABLE INCOME',
#  'TAXABLE INCOME',
#  'TAXABLE INCOME',
#  'TAXABLE INCOME',
#  'TAXABLE YEAR',
#  'TAXABLEINCOME',
#  'TAXING POWER',
#  'TAXPAYER',
#  'TEMPORARY',
#  'TEMPORARY',
#  'TEMPORARY INJUNCTION',
#  'TEMPORARY RESTRAINING ORDER',
#  'TEMPORE L',
#  'TENANCY',
#  'TENANCY',
#  'TENANCY AT',
#  'TENANCY AT',
#  'TENANCY AT SUFFERANCE',
#  'TENANCY AT SUFFERANCE',
#  'TENANCY AT SUFFERANCE',
#  'TENANCY AT SUFFERANCE',
#  'TENANCY AT SUFFERANCE',
#  'TENANCY AT SUFFERANCE',
#  'TENANCY AT SUFFERANCE',
#  'TENANCY AT WILL',
#  'TENANCY AT WILL',
#  'TENANCY AT WILL',
#  'TENANCY AT WILL',
#  'TENANCY BY THE ENTIRETY',
#  'TENANCY BY THE ENTIRETY',
#  'TENANCY BY THE ENTIRETY',
#  'TENANCY BY THE ENTIRETY',
#  'TENANCY BY THE ENTIRETY',
#  'TENANCY BY THE ENTIRETY',
#  'TENANCY BY THE ENTIRETY',
#  'TENANCY BY THE ENTIRETY',
#  'TENANCY BY THE ENTIRETY',
#  'TENANCY FOR',
#  'TENANCY FOR YEARS',
#  'TENANCY FOR YEARS',
#  'TENANCY FOR YEARS',
#  'TENANCY FROM MONTH TO MTH',
#  'TENANCY FROM YEAR TO YEAR',
#  'TENANCY IN',
#  'TENANCY IN COMMON',
#  'TENANCY IN COMMON',
#  'TENANCY IN COMMON',
#  'TENANCY IN COMMON',
#  'TENANCY IN COMMON',
#  'TENANCYAT SUFFERANCE',
#  'TENANT',
#  'TENANT FOR',
#  'TENANT FOR LIFE',
#  'TENANT IN FEE (SIMPLE',
#  'TENANTABLE REPAIR',
#  'TENANTS BY THE',
#  'TENANTS IN',
#  'TENANTS IN COMMON',
#  'TENANTS IN COMMON',
#  'TENANTS IN COMMON',
#  'TENANTS IN TAIL',
#  'TENANTS IN TAIL',
#  'TENDER',
#  'TENDER OF DELIVERY',
#  'TENDER OF DELIVERY',
#  'TENDER OF DELIVERY',
#  'TENDER OFFER',
#  'TENDER OFFER',
#  'TENEMENT',
#  'TENTH AMENDMENT',
#  'TENURE',
#  'TENURIAL OWNERSHIP',
#  'TENURIAL OWNERSHIP',
#  'TERM CAPITAL GAIN',
#  'TERM CAPITAL GAIN',
#  'TERM CAPITAL GAIN OR LOSS',
#  'TERM CAPITAL GAIN OR LOSS',
#  'TERM CAPITAL GAINS OR LOSSES',
#  'TERM INSURANCE',
#  'TERM INSURANCE',
#  'TERM INSURANCE',
#  'TERM LIABILITIES',
#  'TERM LIABILITIES',
#  'TERM LIABILITY',
#  'TERM OF ART',
#  'TERM OF COURT',
#  'TERMINABLE INTEREST',
#  'TERMINER',
#  'TERRITORIAL COURT',
#  'TERRITORIAL JURISDICTION',
#  'TERRITORIAL WATERS',
#  'TERROREM',
#  'TEST CASE',
#  'TESTACY',
#  'TESTAMENT',
#  'TESTAMENTARY CAPACITY',
#  'TESTAMENTARY DISPOSITION',
#  'TESTAMENTARY INTENT',
#  'TESTAMENTARY TRUST',
#  'TESTAMENTARY TRUST',
#  'TESTAMENTARY TRUST',
#  'TESTATOR',
#  'TESTATRIX',
#  'TESTATRIX',
#  'TESTIFY',
#  'TESTIMONIAL',
#  'TESTIMONIAL IMMUNITY',
#  'TESTIMONY',
#  'THE',
#  'THE',
#  'THE',
#  'THE',
#  'THE',
#  'THE COURT OF EXCHEQUER CHAMBER',
#  'THEFT',
#  'THING IN ACTION',
#  'THIRD PARTY',
#  'THIRD PARTY',
#  'THIRD PARTY',
#  'THIRD PARTY BENEFICIARY',
#  'THIRD PARTY PLAINTIFF',
#  'THIRD PARTY PLAINTIFF',
#  'THIRD PARTYPLAINTIFF',
#  'THIRTEENTH AMENDMENT',
#  'THREAT',
#  'THRIFT INSTITUTIONS',
#  'TIDE LAND',
#  'TIME',
#  'TIME',
#  'TIME ARBITRAGE',
#  'TIME ARBITRAGE',
#  'TIME DRAFT',
#  'TIME DRAFT',
#  'TIME IS OF THE ESSENCE',
#  'TIME SHARING',
#  'TITHE',
#  'TITLE',
#  'TITLE',
#  'TITLE',
#  'TITLE',
#  'TITLE (OF A STATUTE',
#  'TITLE JURISDICTION',
#  'TITLE OF A',
#  'TITLE SEARCH',
#  'TITLE THEORY',
#  'TITLE THEORY',
#  'TO WIT',
#  'TOLL',
#  'TOMBSTONE AD',
#  'TONNAGE',
#  'TONNAGE DUTY',
#  'TORT',
#  'TORT CLAIMS ACT',
#  'TORTFEASOR',
#  'TORTIOUS',
#  'TOTAL DISABILITY',
#  'TOTAL INCORPORATION',
#  'TOTAL INCORPORATION APPROACH',
#  'TOTAL INCORPORATION APPROACH',
#  'TOTAL LOSS',
#  'TOTALITY OF THE CIRCUMSTANCES TEST',
#  'TOTO',
#  'TOUCH AND CONCERN',
#  'TRACT',
#  'TRACT INDEX',
#  'TRADE',
#  'TRADE',
#  'TRADE',
#  'TRADE FIXTURE',
#  'TRADE FIXTURE',
#  'TRADE NAME',
#  'TRADE SECRETS',
#  'TRADE USAGE',
#  'TRADEMARK',
#  'TRADITIONARY EVIDENCE',
#  'TRANSACTION',
#  'TRANSACTIONAL IMMUNITY',
#  'TRANSACTIONAL IMMUNITY',
#  'TRANSACTIONS OR OCCURRENCE TEST',
#  'TRANSCRIPT',
#  'TRANSFER',
#  'TRANSFER AGENT',
#  'TRANSFER IN CONTEMPLATION OF DEATH',
#  'TRANSFER TAX',
#  'TRANSFEREE LIABILITY',
#  'TRANSFERRED INTENT',
#  'TRAVERSE',
#  'TREASON',
#  'TREASURE TROVE',
#  'TREASURY',
#  'TREASURY BILL',
#  'TREASURY BILL',
#  'TREASURY BOND',
#  'TREASURY NOTE',
#  'TREASURY STOCK',
#  'TREASURY STOCK',
#  'TREATY',
#  'TREATY CLAUSE',
#  'TREBLE',
#  'TREBLE',
#  'TREBLE DAMAGES',
#  'TREBLE) DAMAGES',
#  'TRESPASS',
#  'TRESPASS DE BONIS ASPORTATIS',
#  'TRESPASS DE BONIS ASPORTATIS',
#  'TRESPASS ON THE CASE',
#  'TRESPASS ON THE CASE',
#  'TRESPASS ON THE CASE',
#  'TRESPASS ON THE CASE',
#  'TRESPASS QUARE CLAUSUM FREGIT',
#  'TRESPASS VI ET ARMIS',
#  'TRESPASS VI ET ARMIS',
#  'TRESPASSER',
#  'TRESSPASS ON THE CASE',
#  'TRIAL',
#  'TRIAL',
#  'TRIAL BY THE RECORD',
#  'TRIAL COURT',
#  'TRIAL DE NOVO',
#  'TRIAL LIST',
#  'TRIBUNAL',
#  'TRIER OF',
#  'TRIER OF',
#  'TRIER OF FACT',
#  'TRIER OF FACT',
#  'TRIER OF FACT',
#  'TRIPARTITE',
#  'TROVER',
#  'TRUE BILL',
#  'TRUE BILL',
#  'TRUST',
#  'TRUST',
#  'TRUST',
#  'TRUST',
#  'TRUST CERTIFICATE',
#  'TRUST COMPANY',
#  'TRUST DEED',
#  'TRUST FUND',
#  'TRUST FUND',
#  'TRUST INDENTURE',
#  'TRUST INDENTURE ACT OF',
#  'TRUST INDENTURE ACT OF',
#  'TRUSTEE',
#  'TRUSTEE IN BANKRUPTCY',
#  'TRUSTEE IN BANKRUPTCY',
#  'TRUSTOR',
#  'TRUSTOR',
#  'TRUTH IN LENDING ACT',
#  'TRY TITLE',
#  'TTACIT',
#  'TUCKER ACT',
#  'TURNTABLE DOCTRINE',
#  'TURPITUDE',
#  'TWO FUNDS DOCTRINE',
#  'TWO FUNDS DOCTRINE',
#  'TWO PARTY CONSENT',
#  'TWO PARTY CONSENT',
#  'TYING ARRANGEMENT',
#  'U. S.',
#  'U.C.C.',
#  'U.C.C.',
#  'U.C.C.',
#  'U.C.C.',
#  'U.C.C.C.',
#  'U.C.C.C.',
#  'U.C.C.C.',
#  'U.C.C.C.',
#  'U.G.M.A.',
#  'U.N. S',
#  'U.S.',
#  'U.S.',
#  'U.S.',
#  'U.S.',
#  'U.S.',
#  'U.S.',
#  'U.S.',
#  'U.S.',
#  'U.S.',
#  'U.S.',
#  'U.S.',
#  'U.S.',
#  'U.S.',
#  'U.S.',
#  'U.S.',
#  'U.S.',
#  'U.S.',
#  'U.S.',
#  'U.S.',
#  'U.S.',
#  'U.S.',
#  'U.S. C',
#  'U.S. C',
#  'U.S. C',
#  'U.S. C',
#  'U.S. C',
#  'U.S. C',
#  'U.S. C',
#  'U.S. C',
#  'U.S. C',
#  'U.S. C',
#  'U.S. C',
#  'U.S. C',
#  'U.S. C',
#  'U.S. C',
#  'U.S. C',
#  'U.S. C',
#  'U.S. C',
#  'U.S. C',
#  'U.S. C',
#  'U.S. D',
#  'U.S. D',
#  'U.S. G',
#  'U.S. G',
#  'U.S. G',
#  'U.S. G',
#  'U.S. N',
#  'U.S. S',
#  'U.S. S',
#  'U.S. S',
#  'U.S. S',
#  'U.S. S',
#  'U.S. S',
#  'U.S. T',
#  'U.S.C.A.',
#  'U.S.C.A.',
#  'UBI SUPRA',
#  'UCC',
#  'ULTIMATE FACTS',
#  'ULTRAHAZARDOUS ACTIVITY',
#  'ULTRAVIRES L',
#  'UNAVOIDABLE ACCIDENT',
#  'UNAVOIDABLE ACCIDENT',
#  'UNAVOIDABLE ACCIDENT',
#  'UNCLEAN HANDS',
#  'UNCONDITIONAL DISCHARGE',
#  'UNCONDITIONAL DISCHARGE',
#  'UNCONDITIONAL DISCHARGE',
#  'UNCONSCIONABLE',
#  'UNCONSTITUTIONAL',
#  'UNDER COLOR OF LAW',
#  'UNDER COLOR OF TITLE',
#  'UNDER PROTEST',
#  'UNDER SEAL',
#  'UNDER THE INFLUENCE',
#  'UNDER THE WILL',
#  'UNDERLEASE',
#  'UNDERWRITE',
#  'UNDISCLOSED PRINCIPAL',
#  'UNDISCLOSED PRINCIPAL',
#  'UNDISCLOSED PRINCIPAL',
#  'UNDIVIDED INTEREST',
#  'UNDUE',
#  'UNDUE INFLUENCE',
#  'UNEARNED SURPLUS',
#  'UNETHICAL',
#  'UNEXECUTED USE',
#  'UNEXECUTED USE',
#  'UNFAIR COMPETITION',
#  'UNFAIR LABOR PRACTICE',
#  'UNFIT',
#  'UNIFIED ESTATE AND GIFT TAX',
#  'UNIFIED ESTATE AND GIFT TAX',
#  'UNIFIED ESTATE AND GIFT TAX',
#  'UNIFIED ESTATE AND GIFT TAX',
#  'UNIFIED ESTATE AND GIFT TAX',
#  'UNIFIED ESTATE AND GIFT TAX',
#  'UNIFORM',
#  'UNIFORM',
#  'UNIFORM ARBITRATION ACT',
#  'UNIFORM ARBITRATION ACT',
#  'UNIFORM CODE OF MILITARY JUSTICE',
#  'UNIFORM COMMERCIAL CODE',
#  'UNIFORM CONSUMER CREDIT CODE',
#  'UNIFORM GIFTS TO MINORS ACT',
#  'UNIFORM LAWS',
#  'UNIFORM SYSTEM OF CITATION',
#  'UNIFORM) CODE OF MILITARY JUSTICE',
#  'UNILATERAL CONTRACT',
#  'UNILATERAL CONTRACT',
#  'UNILATERAL MISTAKE',
#  'UNILATERAL MISTAKE',
#  'UNION',
#  'UNION',
#  'UNION',
#  'UNION SHOP',
#  'UNIT',
#  'UNIT INVESTMENT TRUST',
#  'UNIT INVESTMENT TRUST',
#  'UNITED STATES',
#  'UNITED STATES',
#  'UNITED STATES ATTORNEY',
#  'UNITED STATES ATTORNEYS',
#  'UNITED STATES CLAIMS COURT',
#  'UNITED STATES CODE',
#  'UNITED STATES CODE ANNOTATED',
#  'UNITED STATES COURTS',
#  'UNITED STATES MAGISTRATE',
#  'UNITED STATES TRUSTEE',
#  'UNITED STATES TRUSTEE',
#  'UNITIES',
#  'UNITY OF',
#  'UNITY OF INTEREST',
#  'UNITY OF PERSON',
#  'UNITY OF POSSESSION',
#  'UNITY OF TIME',
#  'UNITY OF TIME',
#  'UNITY OF TITLE',
#  'UNIVERSAL AGENT',
#  'UNJUST ENRICHMENT',
#  'UNLAWFUL',
#  'UNLAWFUL',
#  'UNLAWFUL ACT MANSLAUGHTER',
#  'UNLAWFUL ACT MANSLAUGHTER',
#  'UNLAWFUL ASSEMBLY',
#  'UNLAWFUL DETAINER',
#  'UNLAWFUL DETAINER',
#  'UNLAWFUL DETAINER',
#  'UNLAWFUL DETAINER',
#  'UNLAWFUL DETAINER',
#  'UNLAWFUL ENTRY',
#  'UNLAWFUL FORCE',
#  'UNLAWFUL FORCE',
#  'UNLAWFUL FORCE',
#  'UNLAWFULDETAINER STATUTES',
#  'UNLIQUIDATED',
#  'UNLIQUIDATED',
#  'UNLISTED SECURITY',
#  'UNLISTED STOCK',
#  'UNNATURAL ACT',
#  'UNNECESSARY',
#  'UNNECESSARY HARDSHIP',
#  'UNREALIZED APPRECIATION',
#  'UNREALIZED APPRECIATION',
#  'UNREALIZED APPRECIATION',
#  'UNREASONABLE',
#  'UNREASONABLE PUNISHMENT',
#  'UNREASONABLE RESTRAINT OF TRADE',
#  'UNREASONABLE SEARCH AND SEIZURE',
#  'UNUSUAL PUNISHMENT',
#  'UP BASIS',
#  'UP BASIS',
#  'UP BASIS',
#  'UP TICK',
#  'USAGE OF',
#  'USAGE OF TRADE',
#  'USE',
#  'USE',
#  'USE',
#  'USE IMMUNITY',
#  'USE IMMUNITY',
#  'USE TAX',
#  'USEFUL LIFE',
#  'USEFUL LIFE',
#  'USEFUL LIFE',
#  'USUFRUCT',
#  'USURIOUS CONTRACT',
#  'USURY',
#  'UTILITY',
#  'UTMOST CARE',
#  'UTMOST RESISTANCE',
#  'UTTER',
#  'UUBI L',
#  'UXOR',
#  'VAGRANCY',
#  'VAGUENESS',
#  'VALUABLE CONSIDERATION',
#  'VALUABLE CONSIDERATION',
#  'VALUATION',
#  'VALUATION',
#  'VALUE',
#  'VALUE ADDED TAX',
#  'VALUE ADDED TAX',
#  'VALUE ADDED TAX',
#  'VALUE ADDED TAX',
#  'VALUE. S',
#  'VANDALISM',
#  'VARIANCE',
#  'VASSAL',
#  'VEIL',
#  'VEL NON',
#  'VENAL',
#  'VEND',
#  'VENDEE',
#  'VENDOR',
#  'VENDOR',
#  'VENIRE DE NOVO',
#  'VENIRE L',
#  'VENUE',
#  'VERACITY',
#  'VERDICT',
#  'VERIFICATION',
#  'VERTICAL PRICE FIXING',
#  'VERTICAL PRICE FIXING',
#  'VERTICAL PRICE FIXING',
#  'VERTICAL PRIVITY',
#  'VERTICAL PRIVITY',
#  'VERTICAL PRIVITY',
#  'VESTED',
#  'VESTED ESTATE',
#  'VESTED ESTATE',
#  'VESTED INTEREST',
#  'VESTED INTEREST',
#  'VESTED REMAINDER',
#  'VESTED REMAINDER',
#  'VESTED RIGHTS',
#  'VESTED RIGHTS',
#  'VETO',
#  'VEXATIOUS LITIGATION',
#  'VI  ET ARMIS',
#  'VICARIOUS LIABILITY',
#  'VICE CRIMES',
#  'VICINAGE',
#  'VICTUALER',
#  'VICTUALLER',
#  'VICTUALS',
#  'VIDELICET',
#  'VIDUITATE',
#  'VIDUITY',
#  'VIEW',
#  'VII',
#  'VII',
#  'VILLEIN SOCAGE',
#  'VILLEIN SOCAGE',
#  'VILLENAGE',
#  'VIOLATION OF PROBATION',
#  'VIOLATION OF PROBATION',
#  'VIOLENCE',
#  'VIOLENT',
#  'VIR L',
#  'VIRTUAL REPRESENTATION',
#  'VIS MAJOR',
#  'VISA',
#  'VISITATION',
#  'VISITATION',
#  'VISITATION RIGHTS',
#  'VITALIZED',
#  'VITALIZED',
#  'VITIATE',
#  'VIZ L',
#  'VOICE EXEMPLAR',
#  'VOID',
#  'VOID',
#  'VOID FOR VAGUENESS',
#  'VOID ON ITS FACE',
#  'VOIDABLE',
#  'VOIDABLE PREFERENCE',
#  'VOIDABLE PREFERENCE',
#  'VOIR DIRE',
#  'VOIR DIRE EXAMINATION',
#  'VOLENTI NON FIT INJURIA',
#  'VOLUNTARY APPEARANCE',
#  'VOLUNTARY APPEARANCE',
#  'VOLUNTARY DISABLEMENT',
#  'VOLUNTARY DISSOLUTION',
#  'VOLUNTARY DISSOLUTION',
#  'VOLUNTARY MANSLAUGHTER',
#  'VOLUNTARY MANSLAUGHTER',
#  'VOLUNTARY MANSLAUGHTER',
#  'VOLUNTARY NONSUIT',
#  'VOLUNTARY NONSUIT',
#  'VOLUNTARY PROCEEDING',
#  'VOLUNTARY WASTE',
#  'VOLUNTARY WASTE',
#  'VOLUNTARY WASTE',
#  'VOLUNTARYDISABLEMENT.ANTI',
#  'VOTING',
#  'VOTING RIGHT',
#  'VOTING RIGHTS ACT',
#  'VOTING TRUST',
#  'VOTING TRUST',
#  'VVACATE',
#  'WAGE',
#  'WAGE EARNER',
#  'WAGER OF LAW',
#  'WAGNER ACT',
#  'WAIT',
#  'WAITING PERIOD',
#  'WAITING PERIOD',
#  'WAITING PERIOD',
#  'WAIVER',
#  'WANT OF CONSIDERATION',
#  'WANT OF CONSIDERATION',
#  'WANT OF PROSECUTION',
#  'WANT OF PROSECUTION',
#  'WANT OF PROSECUTION',
#  'WANTON',
#  'WANTON NEGLIGENCE',
#  'WANTON NEGLIGENCE',
#  'WARD',
#  'WARDSHIP',
#  'WAREHOUSE RECEIPT',
#  'WAREHOUSEMAN',
#  'WAREHOUSEMAN',
#  'WARRANT',
#  'WARRANT TO SATISFY JUDGMENT',
#  'WARRANTY',
#  'WARRANTY ACT',
#  'WARRANTY DEED',
#  'WARRANTY OF',
#  'WARRANTY OF',
#  'WARRANTY OF FITNESS',
#  'WARRANTY OF FITNESS',
#  'WARRANTY OF HABITABILITY',
#  'WARRANTY OF HABITABILITY',
#  'WARRANTY OF HABITABILITY',
#  'WARRANTY OF MERCHANTABILITY',
#  'WARRANTY OF MERCHANTABILITY',
#  'WARRENTLESS ARREST',
#  'WASH SALE',
#  'WASH SALE',
#  'WASH SALES',
#  'WASTE',
#  'WASTING ASSET',
#  'WATERED STOCK',
#  'WATERED STOCK',
#  'WATERS',
#  'WAY',
#  'WEAPON',
#  'WEIGHT OF THE',
#  'WEIGHT OF THE EVIDENCE',
#  'WESTLAW',
#  'WESTLAW. B',
#  'WHEN ISSUED',
#  'WHEN ISSUED SECURITIES',
#  'WHEN ISSUED SECURITIES',
#  'WHIPLASH INJURY',
#  'WHITE',
#  'WHITE SLAVE TRAFFIC ACT',
#  'WHITE SLAVE TRAFFIC ACT',
#  'WHOLE LIFE INSURANCE',
#  'WHOLE LIFE INSURANCE',
#  'WHOLE LIFE INSURANCE',
#  'WHOLESALER',
#  'WIDOW',
#  'WIDOW',
#  'WIDOW',
#  'WIDOW',
#  'WIDOWER',
#  'WIFE PRIVILEGE',
#  'WIFE PRIVILEGE',
#  'WILD',
#  'WILDCAT STRIKE',
#  'WILL',
#  'WILL',
#  'WILLFUL',
#  'WILLFUL NEGLIGENCE',
#  'WILLIAMS ACT',
#  'WILLS',
#  'WINDING UP',
#  'WIRETAP',
#  'WIRETAP',
#  'WITH PREJUDICE',
#  'WITH RESERVATION',
#  'WITHDRAWAL',
#  'WITHHOLDING',
#  'WITHHOLDING TAX',
#  'WITHHOLDING TAX',
#  'WITHHOLDING TAX',
#  'WITHHOLDING TAX',
#  'WITHIN THE',
#  'WITHOUT FAULT',
#  'WITHOUT PREJUDICE',
#  'WITHOUT RECOURSE',
#  'WITNESS',
#  'WITNESS',
#  'WITNESS',
#  'WITNESS AGAINST ONESELF',
#  'WORDS OF',
#  'WORDS OF',
#  'WORDS OF',
#  'WORDS OF ART',
#  'WORDS OF FIGHTING',
#  'WORDS OF LIMITATION',
#  'WORDS OF PURCHASE',
#  'WORK PRODUCT',
#  'WORK RELEASE PROGRAM',
#  'WORKERS',
#  'WORKHOUSE',
#  'WORKHOUSE',
#  'WORKHOUSE. M',
#  'WORTH',
#  'WORTHIER TITLE',
#  'WRAPAROUND MORTGAGE',
#  'WRIT',
#  'WRIT',
#  'WRIT',
#  'WRIT OF',
#  'WRIT OF',
#  'WRIT OF ASSISTANCE',
#  'WRIT OF CAPIAS',
#  'WRIT OF CERTIORARI',
#  'WRIT OF CORAM NOBIS',
#  'WRIT OF ERROR',
#  'WRIT OF ERROR CORAMNOBIS',
#  'WRIT OF EXECUTION',
#  'WRIT OF HABEAS CORPUS',
#  'WRIT OF MANDAMUS',
#  'WRIT OF NE EXEAT',
#  'WRIT OF POSSESSION',
#  'WRIT OF PROHIBITION',
#  'WRIT OF RIGHT',
#  'WRIT OF SUPERSEDEAS',
#  'WRITTEN INSTRUMENT',
#  'WRONG',
#  'WRONGFUL ACT',
#  'WRONGFUL DEATH STATUTE',
#  'WRONGFUL DEATH STATUTE',
#  'WRONGFUL LIFE',
#  'WWAGE EARNER',
#  'XYZ',
#  'YEARLY',
#  'YEARS',
#  'YEARS',
#  'YELLOW DOG CONTRACT',
#  'YIELD',
#  'YIELD',
#  'YOUTHFUL OFFENDERS',
#  'YTM',
#  'YTM',
#  'YYEAR AND A DAY RULE',
#  'ZERO',
#  'ZERO BRACKET AMOUNT',
#  'ZERO BRACKET AMOUNT',
#  'ZERO BRACKET AMOUNT',
#  'ZERO BRACKET AMOUNT DEDUCTION',
#  'ZONING',
#  'ZZONE OF EMPLOYMENT']

# %%
print("yippee!")
# Out:
# yippee!

# %% [markdown]
# #並べ替えできた（dicWords）！次は、テキストブックから文字を抽出する。
# テキストがネット上に散らばっていてめんどくさい<br>
# スクレイピングをする

# %%
#!pip install requests
#!pip install beautifulsoup4
#import requests
#from bs4 import BeautifulSoup as bs

# %%
#civ1=requests.get("https://www.themisbar.com/learners/index.php?service=subjectoutline&id_task=286231")
#sciv1=bs(civ1.content,"html.parser")
#print(sciv1.find_all("li"))

# %% [markdown]
# #スクレイピングは挫折した。txtの単語を科目別にリスト化する。

# %%
toWords=[]
rpWords=[]
evWords=[]
crWords=[]
crpWords=[]
contWords=[]
consWords=[]
cipWords=[]

toDic=[]
rpDic=[]
evDic=[]
crDic=[]
crpDic=[]
contDic=[]
consDic=[]
cipDic=[]

torts =["/content/drive/My Drive/Colab Notebooks/torts_outline.txt", toWords,toDic,"/content/drive/My Drive/Colab Notebooks/0_toWords.txt"]
realpro =["/content/drive/My Drive/Colab Notebooks/realpro_outline.txt", rpWords,rpDic,"/content/drive/My Drive/Colab Notebooks/0_rpWords.txt"]
evidence =["/content/drive/My Drive/Colab Notebooks/evidence_outline.txt", evWords,evDic,"/content/drive/My Drive/Colab Notebooks/0_evWords.txt"]
criminal =["/content/drive/My Drive/Colab Notebooks/criminal_outline.txt", crWords,crDic,"/content/drive/My Drive/Colab Notebooks/0_crWords.txt"]
crimpro =["/content/drive/My Drive/Colab Notebooks/crimpro_outline.txt", crpWords,crpDic,"/content/drive/My Drive/Colab Notebooks/0_crpWords.txt"]
contract =["/content/drive/My Drive/Colab Notebooks/contract_outline.txt", contWords,contDic,"/content/drive/My Drive/Colab Notebooks/0_contWords.txt"]
constitusion =["/content/drive/My Drive/Colab Notebooks/constitution_outline.txt", consWords,consDic,"/content/drive/My Drive/Colab Notebooks/0_consWords.txt"]
civpro =["/content/drive/My Drive/Colab Notebooks/civpro_outline.txt", cipWords,cipDic,"/content/drive/My Drive/Colab Notebooks/0_cipWords.txt"]

subjects = [torts, realpro, evidence, criminal, crimpro, contract, constitusion,civpro]

# %%
# op=open("/content/drive/My Drive/Colab Notebooks/torts_outline.txt","r") #open()->str
# read=op.read() #str.read()->list? no, str

# read=read.replace("'"," ")
# read=read.replace("."," ")
# read=read.replace(","," ")
# read=read.replace(r"!\#$%&''’(())*+,-./:;<=>?@[]^_{|}~"""," ") #not perfectly deleted. maybe need escaping?
# read=read.replace(r"[0-9]"," ")
# read=read.upper() #ここまでtype(read)=str
# read=read.split() #ここでリスト化!type(read)=list
# tofile=sorted(read) #tofile as a list 
# tofile=list(set(tofile))
# op.close()

# for i in tofile:
#   toWords.append(i)

# %% [markdown]
# #できた。これを関数化＝般化する。

# %%
def clean(i): #i: subjects[i][0]  
  op = open(subjects[i][0],"r") #type(open())=str 
  read=op.read() #type(str.read())=str
  read=re.sub(r"\W"," ", read)
  read=re.sub(r"[0-9]"," ", read)
  read=read.upper() #ここまでtype(read)=str
  read=read.split() #ここで  type(read)=list 
  
  wordset={}
  wordset=set(read) #to remove redundant words
  for ii in wordset:
    subjects[i][1].append(ii) #add cleaned words from wordset #i=index number here!!    
  op.close()


# clean(realpro[0]) ->works
# len(realpro[1])
# print(realpro[1][100:110])

#   wordset={}
#   wordset=set(read) #to remove redundant words
  
#   for ii in range(len(wordset)):
#     subjects[i][1].append(wordset[ii]) #add cleaned words from wordlist    
#   op.close()

# %% [markdown]
# #各subjectに対して実行

# %%
for i in range(len(subjects)):
  clean(i)
  
  print(str(i)+"length") # how can I spell "torts" out from the list?
  print(len(subjects[i][1]))
  print(str(i)+"subset")
  print(subjects[i][1][1:10])
# Out:
# 0length
# 2981
# 0subset
# ['MEANING', 'SOCIAL', 'SURGICAL', 'HAPPENS', 'TAKE', 'SCOPE', 'AVAILABLE', 'TURN', 'CROSSING']
# 1length
# 3369
# 1subset
# ['MEANING', 'SOCIAL', 'TAKE', 'SCOPE', 'AVAILABLE', 'TURN', 'RESTRICTION', 'VIRTUALLY', 'LATENT']
# 2length
# 2341
# 2subset
# ['SOCIAL', 'MEANING', 'HAPPENS', 'TAKE', 'SCOPE', 'AVAILABLE', 'TURN', 'RESTRICTION', 'HAS']
# 3length
# 4252
# 3subset
# ['REMOVE', 'MEANING', 'SURGICAL', 'BURGLARIES', 'WEAPONS', 'SCOPE', 'TAKE', 'AVAILABLE', 'LEGITIMATELY']
# 4length
# 3276
# 4subset
# ['MEANING', 'SURGICAL', 'TAKE', 'SCOPE', 'WEAPONS', 'AVAILABLE', 'TURN', 'BULLCOMING', 'STANDARDIZED']
# 5length
# 2589
# 5subset
# ['REMOVE', 'MEANING', 'ARRIVED', 'SOCIAL', 'HAPPENS', 'TAKE', 'AVAILABLE', 'TURN', 'RESTRICTION']
# 6length
# 4613
# 6subset
# ['SOCIAL', 'MEANING', 'HAPPENS', 'TAKE', 'SCOPE', 'CHICAGO', 'WEAPONS', 'AVAILABLE', 'TURN']
# 7length
# 3184
# 7subset
# ['SOCIAL', 'CONNER', 'MEANING', 'TAKE', 'SCOPE', 'INFERENCES', 'AVAILABLE', 'LEGITIMATELY', 'HAS']

# %% [markdown]
# #subjects[i][1]に各subjectの全単語リストができた！

# %%
subjects[0][0]==torts[0]
# Out:
# True

# %%
print(len(subjects))
# Out:
# 8

# %%
a=["aa","ab","ac"]
b=["ba","bb","bc"]
c=["ca","cb","cc"]
list=[a,b,c]

# how to print "a"

print(list[0])
print(str(list[0]))

print(str(list))
# Out:
# ['aa', 'ab', 'ac']
# ['aa', 'ab', 'ac']
# [['aa', 'ab', 'ac'], ['ba', 'bb', 'bc'], ['ca', 'cb', 'cc']]

# %%
test_list = ['a1', 'b2', 'c3']
print('simple list into string')
print('_'.join(test_list))


test_nest = [test_list, ['x1', 'y2', 'z3']]
print('_'.join(test_nest[0]))
print('$'.join(['_'.join(i) for i in test_nest]))

#"test_list"
# Out:
# simple list into string
# a1_b2_c3
# a1_b2_c3
# a1_b2_c3$x1_y2_z3

# %%
set(globals())==set(locals())
# Out:
# True

# %% [markdown]
# * reserved names: list, print, def, for, str
# * variable names: hotharuna, a, b, c

# %%
# def clean(ii):
#   op=open(ii)
#   read=op.read()
#   read=read.replace("'"," ")
#   read=read.replace("."," ")
#   read=read.replace(","," ")
#   read=read.replace("("," ")
#   read=read.replace(")"," ")  
#   read=read.split()
#   return sorted(read) #clean(テキストファイル)で句読点削除済テキスト（リスト）を入手->リストになっていない？

# for iii in subjects:
#   cl=clean(iii[0])
#   for cli in cl:
#     iii[1].append(cli) #これで膨大な一つの単語がsubjects[iii][1][0]にだけ登録されている。subjects[iii][1]がリストにならない。

# tofile=open("/content/drive/My Drive/Colab Notebooks/0_toWords.txt","w")
# for to in range(len(toWords)):
#   tofile.write(toWords[to]+"\n")
# tofile.close()


# #clean(torts[0])
# #type(torts[1])
# #print(torts[1])
# #type(subjects[0])

# %%
# #print(subjects[0][1][0:10])



# print("===")
# #subject[0][1][0]が多すぎるらしい。

# len(clean(torts[0]))

# %% [markdown]
# #重複する単語をリスト化する。

# %%
for i in range(len(subjects)):
  wordlist={}
  wordlist=set(subjects[i][1])&set(dicWords)
  for ii in wordlist:
    subjects[i][2].append(ii)
    subjects[i][2]=sorted(subjects[i][2])
  print("======="+str(i)+"=======")
  print(subjects[i][2]) #"なんでリストの要素がセットになってるんや！！！"
# Out:
# =======0=======
# ['ABATEMENT', 'ACCESS', 'ACCIDENT', 'ACCOUNT', 'ACCUSATION', 'ACCUSE', 'ACT', 'ACTION', 'ACTIONABLE', 'ACTUAL', 'ADOPT', 'ADULT', 'ADVANCE', 'ADVERSE', 'AFFIRMATION', 'AFTER', 'AGENCY', 'AGENT', 'AGREEMENT', 'ALTERATION', 'AND', 'ANSWER', 'APPORTION', 'APPRECIATE', 'APPROPRIATE', 'APPROPRIATION', 'ARREST', 'ART', 'ASSAULT', 'ASSOCIATION', 'ATTEMPT', 'ATTORNEY', 'AUTHORITY', 'AUTOMOBILE', 'AVOID', 'BAILEE', 'BAILMENT', 'BAILOR', 'BANK', 'BAR', 'BARGAIN', 'BASIS', 'BATTERY', 'BEFORE', 'BELIEF', 'BENEFICIARY', 'BENEFIT', 'BREACH', 'BURDEN', 'BUSINESS', 'CALL', 'CAPACITY', 'CARE', 'CARRIER', 'CASE', 'CAUSE', 'CHARGE', 'CHATTEL', 'CHECK', 'CITIZEN', 'CIVIL', 'CLAIM', 'CLAUSE', 'CLEAR', 'CLOSE', 'CLOSED', 'CODE', 'COLLATERAL', 'COMMENT', 'COMMISSION', 'COMMON', 'COMPANY', 'COMPENSATION', 'COMPETENT', 'COMPLIANCE', 'CONCEALMENT', 'CONCLUSIVE', 'CONCURRENT', 'CONDITION', 'CONDITIONAL', 'CONFORMED', 'CONGRESS', 'CONSENT', 'CONSEQUENTIAL', 'CONSIDERATION', 'CONSORTIUM', 'CONSTITUTIONAL', 'CONSTRUCTION', 'CONSTRUCTIVE', 'CONSUMER', 'CONTRACT', 'CONTRACTOR', 'CONTRIBUTION', 'CONTROVERSY', 'CONVERSATION', 'CONVERSION', 'CONVICTION', 'CORPORATION', 'CORPORATIONS', 'COST', 'COSTS', 'COURT', 'CREDIT', 'CRIME', 'CRIMINAL', 'CROSS', 'CULPABLE', 'CURTILAGE', 'DAMAGE', 'DAMAGES', 'DATE', 'DEALING', 'DEATH', 'DECEASED', 'DECEDENT', 'DECEIT', 'DECISION', 'DEFAMATION', 'DEFECT', 'DEFECTIVE', 'DEFENDANT', 'DEFENSE', 'DEGREE', 'DELIBERATE', 'DEMAND', 'DEPRECIATION', 'DESIST', 'DETENTION', 'DETERMINATION', 'DILIGENCE', 'DIMINISHED', 'DISABILITY', 'DISCLAIMER', 'DISMISS', 'DISMISSAL', 'DISTINGUISH', 'DISTRESS', 'DISTRIBUTION', 'DOCTOR', 'DOCTRINE', 'DOMINION', 'DOUBLE', 'DRUGS', 'DURESS', 'DUTY', 'EASEMENT', 'EAVESDROPPING', 'ELEMENT', 'ELEMENTS', 'EMOTIONAL', 'EMPLOYER', 'ENJOYMENT', 'ENTRY', 'ENUMERATED', 'EQUITY', 'ERRONEOUS', 'ESSENCE', 'ESTATE', 'EVIDENCE', 'EXAMINATION', 'EXAMPLE', 'EXCEPTION', 'EXCULPATORY', 'EXEMPT', 'EXHIBIT', 'EXPENSE', 'EXPRESS', 'EXTRINSIC', 'FACT', 'FACTOR', 'FACTS', 'FAIR', 'FALSE', 'FAMILY', 'FAULT', 'FEDERAL', 'FEE', 'FELONY', 'FIDUCIARY', 'FIGURE', 'FINDER', 'FINDING', 'FIRST', 'FIT', 'FITNESS', 'FIXED', 'FOR', 'FORCE', 'FORESEEABILITY', 'FORESEEABLE', 'FORM', 'FOUNDATION', 'FRAUD', 'FREE', 'FREEDOM', 'FRIEND', 'GAMBLING', 'GOODS', 'GOVERNMENT', 'GRANT', 'GROSS', 'GUARANTEE', 'GUARDIAN', 'GUEST', 'HARM', 'HEARING', 'HEART', 'HELP', 'HOLDING', 'HOSTILE', 'HOUSE', 'HUSBAND', 'IGNORANCE', 'III', 'ILLEGAL', 'IMMATERIAL', 'IMMUNITIES', 'IMMUNITY', 'IMPLICATION', 'IMPLIED', 'IMPRISONMENT', 'IMPUTED', 'INCAPACITY', 'INCOME', 'INCONSISTENT', 'INDEMNIFY', 'INDEMNITY', 'INDEPENDENT', 'INFERENCE', 'INFLUENCE', 'INFORMATION', 'INFORMED', 'INHERENT', 'INJUNCTION', 'INJURY', 'INNUENDO', 'INSTITUTION', 'INSTRUMENTALITY', 'INSURANCE', 'INTEGRATION', 'INTENT', 'INTEREST', 'INTERVENING', 'INTERVENTION', 'INTOXICATION', 'INVITEE', 'INVOLUNTARY', 'IRRELEVANT', 'ISSUE', 'JOHN', 'JOINT', 'JUDGE', 'JUDGMENT', 'JUDICIAL', 'JURISDICTION', 'JURY', 'JUSTIFICATION', 'KIN', 'KIND', 'LAND', 'LANDLORD', 'LAST', 'LAW', 'LAWFUL', 'LAWS', 'LAY', 'LEGAL', 'LEGISLATION', 'LEND', 'LESSEE', 'LESSER', 'LESSOR', 'LIABILITY', 'LIABLE', 'LIBEL', 'LICENSE', 'LICENSEE', 'LIKE', 'LIMITATION', 'LIMITATIONS', 'LINE', 'LITIGATION', 'LOCATION', 'LONG', 'LOSS', 'MAINTAIN', 'MAINTENANCE', 'MAJORITY', 'MALICE', 'MALPRACTICE', 'MANIFEST', 'MATERIAL', 'MATTER', 'MATURITY', 'MENACING', 'MERCHANT', 'MERCHANTABILITY', 'MERITS', 'MILITARY', 'MINIMUM', 'MINING', 'MINORITY', 'MISAPPROPRIATION', 'MISCONDUCT', 'MISDEMEANOR', 'MISTAKE', 'MORAL', 'MOTION', 'MOVE', 'MUTUAL', 'NECESSARY', 'NECESSITY', 'NEGLIGENCE', 'NEXT', 'NON', 'NOT', 'NOTE', 'NOTICE', 'NOW', 'NUISANCE', 'OBJECT', 'OBLIGATION', 'OFFICER', 'OFFSET', 'OMISSION', 'ONE', 'OPEN', 'OPINION', 'OPTION', 'ORDER', 'ORDINANCE', 'ORIGINAL', 'OUT', 'OVER', 'OWNER', 'OWNERSHIP', 'PACKAGE', 'PAID', 'PARTNERSHIP', 'PARTY', 'PATIENT', 'PAYMENT', 'PENALTY', 'PER', 'PERFORMANCE', 'PERIL', 'PERSON', 'PERSONAL', 'PHYSICIAN', 'PLAINTIFF' ...
# =======1=======
# ['ABANDONMENT', 'ABATEMENT', 'ACCELERATION', 'ACCEPTANCE', 'ACCESS', 'ACCORD', 'ACCOUNT', 'ACCOUNTING', 'ACKNOWLEDGMENT', 'ACQUIRE', 'ACT', 'ACTION', 'ACTIONABLE', 'ACTUAL', 'ADEMPTION', 'ADMISSION', 'ADOPT', 'ADOPTION', 'ADULT', 'ADVANCE', 'ADVERSE', 'AFTER', 'AGENCY', 'AGENT', 'AGREEMENT', 'AIRSPACE', 'ALIENATION', 'ALTERATION', 'AMEND', 'AMORTIZATION', 'AND', 'ANSWER', 'ANTI', 'APPEAL', 'APPOINTMENT', 'APPROPRIATE', 'APPROPRIATION', 'APPURTENANT', 'ART', 'ASSEMBLY', 'ASSIGN', 'ASSIGNMENT', 'ASSIGNS', 'ASSOCIATION', 'ATTACHMENT', 'ATTEMPT', 'ATTORNEY', 'AUTHORITY', 'AVOID', 'BANK', 'BANKRUPTCY', 'BAR', 'BASIS', 'BEARER', 'BEFORE', 'BELIEF', 'BENEFICIARY', 'BENEFIT', 'BIND', 'BLACKACRE', 'BLOOD', 'BREACH', 'BROKER', 'BURDEN', 'BUSINESS', 'BUY', 'BYLAWS', 'CAPACITY', 'CARE', 'CASE', 'CAUSE', 'CHALLENGE', 'CHARGE', 'CHARITY', 'CHATTEL', 'CITIZEN', 'CIVIL', 'CLAIM', 'CLAUSE', 'CLEAR', 'CLOSE', 'CLOSING', 'CODE', 'COLLATERAL', 'COLOR', 'COMMERCE', 'COMMISSION', 'COMMON', 'COMPANY', 'COMPENSATION', 'COMPLAINANT', 'COMPLAINT', 'COMPLIANCE', 'CONCEALMENT', 'CONCILIATION', 'CONCLUSIVE', 'CONCURRENT', 'CONDITION', 'CONDITIONAL', 'CONDOMINIUM', 'CONGRESS', 'CONSECUTIVE', 'CONSENT', 'CONSIDERATION', 'CONSTITUTION', 'CONSTITUTIONAL', 'CONSTRUCTION', 'CONSTRUCTIVE', 'CONTINGENT', 'CONTRACT', 'CONTRIBUTION', 'CONVERSION', 'CONVEY', 'CONVEYANCE', 'COOPERATIVE', 'CORPORATION', 'COST', 'COSTS', 'COUNSEL', 'COUNT', 'COURT', 'COVENANT', 'COVENANTS', 'COVER', 'CREDIT', 'CREDITOR', 'CRIME', 'CRIMINAL', 'CROSS', 'CUMULATIVE', 'CURTESY', 'CUSTODY', 'DAMAGE', 'DAMAGES', 'DATE', 'DEALING', 'DEATH', 'DEBT', 'DEBTOR', 'DECEASED', 'DECEDENT', 'DECISION', 'DECLARATION', 'DECREE', 'DEDICATION', 'DEED', 'DEFAULT', 'DEFEASIBLE', 'DEFECT', 'DEFECTIVE', 'DEFENDANT', 'DEFENSE', 'DEFICIENCY', 'DEGREE', 'DELEGATE', 'DELIVERY', 'DEMAND', 'DENIAL', 'DEPRECIATION', 'DESCENT', 'DETAINER', 'DEVISE', 'DIMINISHED', 'DIRECTOR', 'DISABILITY', 'DISCHARGE', 'DISCLAIMER', 'DISCOVERY', 'DISCRETION', 'DISCRIMINATION', 'DISPOSITION', 'DISTINGUISH', 'DISTRIBUTION', 'DIVORCE', 'DOCTRINE', 'DOCUMENT', 'DOMAIN', 'DOMICILE', 'DONEE', 'DONOR', 'DOWER', 'DRAFT', 'DRAW', 'DURESS', 'DUTY', 'EASEMENT', 'EFFECTS', 'EJECTMENT', 'ELECTION', 'ELEMENTS', 'EMBLEMENTS', 'ENCUMBRANCE', 'ENJOYMENT', 'ENRICHMENT', 'ENTIRETY', 'ENTITY', 'ENTRY', 'EQUIPMENT', 'EQUITABLE', 'EQUITY', 'ESCROW', 'ESSENCE', 'ESTATE', 'ESTOPPEL', 'EVICTION', 'EVIDENCE', 'EXAMPLE', 'EXCEPTION', 'EXCHANGE', 'EXCLUSION', 'EXECUTE', 'EXECUTED', 'EXECUTION', 'EXECUTOR', 'EXECUTORY', 'EXEMPT', 'EXEMPTION', 'EXPENSE', 'EXPRESS', 'EXPULSION', 'EXTENSION', 'EXTINGUISHMENT', 'EXTRINSIC', 'FACT', 'FACTOR', 'FACTS', 'FAIR', 'FAMILY', 'FAULT', 'FEDERAL', 'FEE', 'FELONY', 'FENCE', 'FIDUCIARY', 'FILE', 'FILING', 'FINDING', 'FIRST', 'FITNESS', 'FIXED', 'FIXTURE', 'FLOAT', 'FOR', 'FORCE', 'FORCIBLE', 'FORECLOSURE', 'FORESEEABLE', 'FORFEITURE', 'FORGERY', 'FORM', 'FORUM', 'FOUNDATION', 'FRAUD', 'FREE', 'FREEHOLD', 'FRONT', 'FUND', 'GAIN', 'GIFT', 'GOODS', 'GOVERNMENT', 'GRANT', 'GRANTOR', 'GROSS', 'GUARANTEE', 'GUARANTOR', 'HABENDUM', 'HABITABILITY', 'HARDSHIP', 'HARM', 'HEARING', 'HEIRS', 'HELP', 'HOLDER', 'HOLDING', 'HOSTILE', 'HOUSE', 'HUSBAND', 'III', 'ILLEGAL', 'IMPLICATION', 'IMPLIED', 'IMPRISONMENT', 'IMPROVEMENT', 'INCAPACITY', 'INCOME', 'INCONSISTENT', 'INCORPORATION', 'INDEPENDENT', 'INDEX', 'INDORSEMENT', 'INFANCY', 'INFLUENCE', 'INFORMATION', 'INHERITANCE', 'INJUNCTION', 'INJURY', 'INSANITY', 'INSTALLMENT', 'INSTITUTION', 'INSTRUCTION', 'INSTRUMENT', 'INSURANCE', 'INTEGRATION', 'INTENT', 'INTEREST', 'INTESTACY', 'INTESTATE', 'INVESTMENT', 'INVOLUNTARY', 'IRRELEVANT', 'ISSUE', 'ISSUED', 'JOINT', 'JUDGMENT', 'JUDICIAL', 'JUDICIARY', 'JURISDICTION', 'JUSTIFICATION', 'KIND', 'KING', 'LACHES', 'LAND', 'LANDLORD', 'LAPSE', 'LAST', 'LAW', 'LAWFUL', 'LAWS', 'LAWSUIT', 'LEADING', 'LEASE', 'LEASEHOLD', 'LEGAL', 'LEGISLATION', 'LESSEE', 'LESSER', 'LESSOR', 'LET', 'LEVY', 'LEXIS', 'LIABILITY', 'LIABLE', 'LICENSE', 'LICENSEE', 'LICENSOR',  ...
# =======2=======
# ['ACCEPTANCE', 'ACCIDENT', 'ACCOUNT', 'ACCUSED', 'ACQUITTAL', 'ACT', 'ACTION', 'ADJUDICATION', 'ADMINISTRATOR', 'ADMISSION', 'ADMIT', 'ADOPTION', 'ADULT', 'ADVANCE', 'ADVERSARY', 'ADVERSE', 'AFFIRMATION', 'AFTER', 'AGENCY', 'AGENT', 'AGREEMENT', 'ALLEGATION', 'AND', 'ANSWER', 'APPEAL', 'APPEARANCE', 'APPROPRIATE', 'ARGUMENT', 'ARRANGEMENTS', 'ARREST', 'ASSAULT', 'ASSESS', 'ATTORNEY', 'AUTHENTICATE', 'AUTHORITY', 'AVOID', 'AVOIDANCE', 'BAIL', 'BANK', 'BANKRUPTCY', 'BAR', 'BASIS', 'BATTERY', 'BEFORE', 'BELIEF', 'BIAS', 'BLOOD', 'BRIBERY', 'BURDEN', 'BUSINESS', 'CALL', 'CAMERA', 'CAPACITY', 'CAPITAL', 'CASE', 'CAUSE', 'CHALLENGE', 'CHARGE', 'CIRCUIT', 'CIVIL', 'CLAIM', 'CLAUSE', 'CLEAR', 'CLOSED', 'COHABITATION', 'COLLATERAL', 'COMMENT', 'COMMISSION', 'COMMITMENT', 'COMMITTEE', 'COMMON', 'COMPANY', 'COMPENSATION', 'COMPETENT', 'COMPLAINT', 'CONCLUSIVE', 'CONDITION', 'CONDITIONAL', 'CONFESSION', 'CONSENT', 'CONSIDERATION', 'CONSOLIDATION', 'CONSPIRACY', 'CONSPIRATOR', 'CONSTITUTIONAL', 'CONTRACT', 'CONTROVERSY', 'CONVERSATION', 'CONVICT', 'CONVICTION', 'COPY', 'CORPORATE', 'CORPORATION', 'COUNSEL', 'COURT', 'CREDIBILITY', 'CRIME', 'CRIMINAL', 'CROSS', 'CULPABLE', 'CUMULATIVE', 'CURATIVE', 'CUSTODY', 'DAMAGE', 'DATE', 'DEATH', 'DECEASED', 'DECEDENT', 'DECISION', 'DECLARANT', 'DECLARATION', 'DEFAMATION', 'DEFECTIVE', 'DEFENDANT', 'DEFENSE', 'DEFICIENCY', 'DEGREE', 'DELIBERATE', 'DEPENDENT', 'DEPOSE', 'DEPOSITION', 'DETERMINATION', 'DICTA', 'DILIGENCE', 'DISABILITY', 'DISCOVERY', 'DISCRETION', 'DISTRESS', 'DIVORCE', 'DOCTOR', 'DOCTRINE', 'DOCUMENT', 'DOUBT', 'DRAW', 'DRAWING', 'DURESS', 'DUTY', 'ELEMENT', 'ELEMENTS', 'EMBEZZLEMENT', 'EMOTIONAL', 'EMPLOYER', 'EQUIPMENT', 'ERRONEOUS', 'ERROR', 'ESTATE', 'EVIDENCE', 'EXAMINATION', 'EXAMPLE', 'EXCEPTION', 'EXCHANGE', 'EXCLUSION', 'EXECUTED', 'EXECUTION', 'EXECUTOR', 'EXEMPT', 'EXHIBIT', 'EXPRESS', 'EXTRADITION', 'EXTRINSIC', 'EYEWITNESS', 'FACT', 'FACTOR', 'FACTS', 'FAIR', 'FALSE', 'FAMILY', 'FAULT', 'FEDERAL', 'FEE', 'FELONY', 'FILE', 'FINDING', 'FINE', 'FIRST', 'FOR', 'FORCE', 'FORENSIC', 'FORFEITURE', 'FORM', 'FOUNDATION', 'FRAUD', 'FREE', 'FRIEND', 'FRONT', 'GOVERNMENT', 'GUARDIAN', 'GUILTY', 'HARASSMENT', 'HARDSHIP', 'HARM', 'HEARING', 'HELP', 'HOLDER', 'HOLDING', 'HOMICIDE', 'HOSTILE', 'HOUSE', 'III', 'ILLEGAL', 'IMMATERIAL', 'IMMUNITY', 'IMPEACH', 'IMPLIED', 'IMPRESSION', 'IMPRISONMENT', 'IMPUTED', 'INCONSISTENT', 'INCRIMINATE', 'INCRIMINATION', 'INDICTMENT', 'INFERENCE', 'INFLUENCE', 'INFORMATION', 'INHERITANCE', 'INITIATIVE', 'INJURY', 'INSTRUCTION', 'INSURANCE', 'INSURED', 'INTEGRATION', 'INTENT', 'INTEREST', 'INTERROGATION', 'INTOXICATION', 'IRRELEVANT', 'IRS', 'ISSUE', 'ISSUED', 'JOURNALIST', 'JUDGE', 'JUDGMENT', 'JUDICIAL', 'JURISDICTION', 'JUROR', 'JURY', 'JUVENILE', 'KIND', 'LAW', 'LAWFUL', 'LAWS', 'LAWSUIT', 'LAY', 'LEADING', 'LEGAL', 'LEGATEE', 'LESSER', 'LIABILITY', 'LIKE', 'LIMITATION', 'LIMITATIONS', 'LINEUP', 'LITIGATION', 'LOCK', 'LONG', 'LOTTERY', 'MAJORITY', 'MAKER', 'MALPRACTICE', 'MARRIAGE', 'MATERIAL', 'MATTER', 'MEMORANDUM', 'MINORITY', 'MISCONDUCT', 'MISDEMEANOR', 'MISTAKE', 'MISTRIAL', 'MOTION', 'MOVE', 'MURDER', 'NECESSARY', 'NECESSITY', 'NEGATIVE', 'NEGLIGENCE', 'NEGOTIATION', 'NEXT', 'NON', 'NOT', 'NOTE', 'NOTICE', 'NOW', 'OBJECT', 'OBJECTION', 'OFFENSE', 'OFFER', 'OFFERING', 'OFFICER', 'ONE', 'OPEN', 'OPINION', 'OPPONENT', 'ORAL', 'ORDER', 'ORIGINAL', 'OUT', 'OVER', 'OWNER', 'OWNERSHIP', 'PAID', 'PAPER', 'PARDON', 'PARTICULARS', 'PARTY', 'PATIENT', 'PAYMENT', 'PECUNIARY', 'PENALTY', 'PERJURY', 'PERSON', 'PERSONAL', 'PHYSICIAN', 'PLAINTIFF', 'PLAN', 'PLEA', 'PLEAD', 'POSSESSION', 'PRACTICE', 'PRE', 'PREFERENCE', 'PREJUDICE', 'PRESUMPTION', 'PRIOR', 'PRIVACY', 'PRIVILEGE', 'PROBATION', 'PROBATIVE', 'PROCEDURE', 'PROCEEDING', 'PROCESS', 'PRODUCT', 'PROHIBITION', 'PROMISE', 'PROOF', 'PROPER', 'PROPERTY', 'PROPRIETARY', 'PROSECUTION', 'PROSECUTOR', 'PROTECT', 'PROTECTION', 'PSYCHOTHERAPIST', 'PUBLIC', 'PUBLICATION', 'PUNISHMENT', 'QUEEN', 'QUESTION', 'RAPE',  ...
# =======3=======
# ['ABANDONMENT', 'ACCESS', 'ACCESSORY', 'ACCIDENT', 'ACCOMPLICE', 'ACCOUNT', 'ACCUSATION', 'ACCUSED', 'ACQUIESCENCE', 'ACQUIRE', 'ACQUITTAL', 'ACT', 'ACTION', 'ACTUAL', 'ADMISSION', 'ADMIT', 'ADOPT', 'ADULT', 'ADULTERY', 'ADVERSARY', 'ADVERSE', 'AFFIANT', 'AFFIDAVIT', 'AFFIRMATION', 'AFORETHOUGHT', 'AFTER', 'AGENCY', 'AGENT', 'AGREEMENT', 'ALIBI', 'ALTERATION', 'AMEND', 'AMENDMENTS', 'AND', 'ANSWER', 'APPEAL', 'APPEARANCE', 'APPELLANT', 'APPOINTMENT', 'APPRECIATE', 'APPROPRIATE', 'ARRAIGNMENT', 'ARRAY', 'ARREST', 'ARSON', 'ASPORTATION', 'ASSAULT', 'ASSESS', 'ASSURED', 'ATROCIOUS', 'ATTACHMENT', 'ATTAINDER', 'ATTEMPT', 'ATTORNEY', 'AUTHORITY', 'AUTOMOBILE', 'AVOID', 'BAIL', 'BAILEE', 'BAILOR', 'BANK', 'BAR', 'BARGAIN', 'BASIS', 'BATTERY', 'BEFORE', 'BELIEF', 'BENCH', 'BENEFIT', 'BESTIALITY', 'BIAS', 'BIGAMY', 'BILATERAL', 'BILL', 'BLOOD', 'BOND', 'BONDS', 'BREACH', 'BREATHALYZER', 'BRIBERY', 'BRIEF', 'BURDEN', 'BURGLARY', 'BUSINESS', 'BUY', 'CALL', 'CAPACITY', 'CAPITAL', 'CAPTION', 'CARE', 'CASE', 'CAUSE', 'CHALLENGE', 'CHARGE', 'CHECK', 'CITATION', 'CITIZEN', 'CIVIL', 'CLAIM', 'CLAIMANT', 'CLAUSE', 'CLEAR', 'CLERK', 'CLOSE', 'CLOSED', 'CODE', 'COERCION', 'COHABITATION', 'COLLATERAL', 'COMMENT', 'COMMISSION', 'COMMON', 'COMPANY', 'COMPETENT', 'COMPLIANCE', 'CONCLUSIVE', 'CONCURRENT', 'CONDITION', 'CONFESSION', 'CONGRESS', 'CONSECUTIVE', 'CONSENT', 'CONSIDERATION', 'CONSPIRACY', 'CONSPIRATOR', 'CONSTITUTION', 'CONSTITUTIONAL', 'CONSTRUCTIVE', 'CONTRABAND', 'CONTRACT', 'CONVERSATION', 'CONVERSION', 'CONVEY', 'CONVICT', 'CONVICTION', 'CORPORATE', 'CORPORATION', 'CORPORATIONS', 'CORPOREAL', 'COUNSEL', 'COURT', 'COVER', 'CREDIBILITY', 'CRIME', 'CRIMINAL', 'CROSS', 'CULPABLE', 'CUMULATIVE', 'CURTILAGE', 'CUSTODY', 'DAILY', 'DAMAGE', 'DATE', 'DEALING', 'DEATH', 'DEBT', 'DECEIT', 'DECISION', 'DECLARANT', 'DECLARATION', 'DEED', 'DEFECT', 'DEFECTIVE', 'DEFENDANT', 'DEFENSE', 'DEFRAUD', 'DEGREE', 'DELIBERATE', 'DEMAND', 'DEMURRER', 'DENIAL', 'DEPENDENT', 'DETENTION', 'DETERMINATION', 'DISABILITY', 'DISCHARGE', 'DISCOVERY', 'DISCRETION', 'DISCRIMINATION', 'DISMISS', 'DISMISSAL', 'DISQUALIFICATION', 'DIVORCE', 'DNA', 'DOCTOR', 'DOCTRINE', 'DOCUMENT', 'DOMINION', 'DOUBLE', 'DOUBT', 'DRAW', 'DRAWER', 'DRAWN', 'DRUGS', 'DURESS', 'DUTY', 'EFFECTS', 'ELEMENT', 'ELEMENTS', 'EMBEZZLEMENT', 'EMPLOYER', 'ENCLOSURE', 'ENTIRETY', 'ENTITY', 'ENTRAPMENT', 'ENTRY', 'ENUMERATED', 'EQUIPMENT', 'ERRONEOUS', 'ERROR', 'ESSENCE', 'ESTOPPEL', 'EUTHANASIA', 'EVIDENCE', 'EXAMINATION', 'EXAMPLE', 'EXCEPTION', 'EXCHANGE', 'EXCLUSION', 'EXCULPATORY', 'EXECUTE', 'EXECUTED', 'EXECUTION', 'EXEMPLAR', 'EXIGENCY', 'EXPRESS', 'EXTENSION', 'EXTORTION', 'EXTRAJUDICIAL', 'EYEWITNESS', 'FACILITATION', 'FACT', 'FACTOR', 'FACTS', 'FAIR', 'FALSE', 'FAMILY', 'FAULT', 'FEDERAL', 'FELONY', 'FENCE', 'FIDUCIARY', 'FILE', 'FILING', 'FINDER', 'FINDING', 'FINE', 'FIRST', 'FIT', 'FIXED', 'FIXTURE', 'FLIGHT', 'FOR', 'FORCE', 'FORCIBLE', 'FORESEEABLE', 'FORFEITURE', 'FORGERY', 'FORM', 'FORNICATION', 'FRAUD', 'FREE', 'FREEDOM', 'FRIEND', 'FRISK', 'FRIVOLOUS', 'GAIN', 'GOODS', 'GOVERNMENT', 'GRANT', 'GROSS', 'GUARANTEE', 'GUARDIAN', 'GUEST', 'GUILTY', 'HARASSMENT', 'HARM', 'HEARING', 'HEART', 'HELP', 'HIT', 'HOLDING', 'HOMICIDE', 'HOSTILE', 'HOUSE', 'HUSBAND', 'HYPNOSIS', 'IGNORANCE', 'III', 'ILLEGAL', 'IMMATERIAL', 'IMMIGRATION', 'IMMUNITY', 'IMPEACH', 'IMPLIED', 'IMPOSSIBILITY', 'IMPRISONMENT', 'INCARCERATION', 'INCEST', 'INCHOATE', 'INCOMPETENCY', 'INCONSISTENT', 'INCRIMINATE', 'INCRIMINATION', 'INCULPATORY', 'INDEPENDENT', 'INDICTMENT', 'INDIGENT', 'INFANCY', 'INFERENCE', 'INFORMATION', 'INFORMED', 'INHERENT', 'INJURY', 'INMATE', 'INSANITY', 'INSIDER', 'INSTRUCTION', 'INSTRUMENT', 'INSTRUMENTALITY', 'INSURANCE', 'INTENT', 'INTEREST', 'INTERROGATION', 'INTERVENING', 'INTOXICATION', 'INVENTORY', 'INVOLUNTARY', 'IRRELEVANT', 'ISSUE', 'ISSUED', 'JAIL', 'JEOPARDY', 'JOINT', 'JUDGE', 'JUDGMENT', 'JUDICIAL', 'JURISDICTION', 'JUROR', 'JURY', 'JUSTIFICATION', 'JUVENILE', 'KIDNAPPING', 'KING', 'LAN ...
# =======4=======
# ['ACCESS', 'ACCIDENT', 'ACCOMPLICE', 'ACCUSATION', 'ACCUSED', 'ACQUIESCENCE', 'ACQUITTAL', 'ACT', 'ACTION', 'ACTUAL', 'ADMISSION', 'ADMIT', 'ADOPT', 'ADULT', 'ADVERSARY', 'ADVERSE', 'AFFIANT', 'AFFIDAVIT', 'AFFIRMATION', 'AFTER', 'AGENCY', 'AGENT', 'AGREEMENT', 'AMEND', 'AMENDMENTS', 'AND', 'ANSWER', 'APPEAL', 'APPEARANCE', 'APPELLANT', 'APPOINTMENT', 'APPROPRIATE', 'ARRAIGNMENT', 'ARRAY', 'ARREST', 'ARSON', 'ASSESS', 'ASSURED', 'ATROCIOUS', 'ATTACHMENT', 'ATTEMPT', 'ATTORNEY', 'AUTHORITY', 'AUTOMOBILE', 'AVOID', 'BAIL', 'BANK', 'BAR', 'BARGAIN', 'BASIS', 'BATTERY', 'BEFORE', 'BELIEF', 'BENCH', 'BIAS', 'BILL', 'BLOOD', 'BOND', 'BREATHALYZER', 'BRIEF', 'BURDEN', 'BURGLARY', 'BUSINESS', 'CALL', 'CAPITAL', 'CARE', 'CASE', 'CAUSE', 'CHALLENGE', 'CHARGE', 'CHECK', 'CITATION', 'CITIZEN', 'CIVIL', 'CLAIM', 'CLAIMANT', 'CLAUSE', 'CLEAR', 'CLERK', 'CLOSE', 'CLOSED', 'COERCION', 'COLLATERAL', 'COMMENT', 'COMMISSION', 'COMMON', 'COMPETENT', 'COMPLIANCE', 'CONCLUSIVE', 'CONCURRENT', 'CONDITION', 'CONFESSION', 'CONSECUTIVE', 'CONSENT', 'CONSIDERATION', 'CONSPIRACY', 'CONSPIRATOR', 'CONSTITUTION', 'CONSTITUTIONAL', 'CONTRABAND', 'CONTRACT', 'CONVERSATION', 'CONVEY', 'CONVICT', 'CONVICTION', 'CORPORATE', 'CORPORATIONS', 'CORPOREAL', 'COUNSEL', 'COURT', 'CREDIBILITY', 'CRIME', 'CRIMINAL', 'CROSS', 'CUMULATIVE', 'CURTILAGE', 'CUSTODY', 'DAILY', 'DATE', 'DEALING', 'DEATH', 'DECEIT', 'DECISION', 'DECLARANT', 'DECLARATION', 'DEFECT', 'DEFECTIVE', 'DEFENDANT', 'DEFENSE', 'DEGREE', 'DELIBERATE', 'DEMAND', 'DEMURRER', 'DENIAL', 'DETENTION', 'DETERMINATION', 'DISABILITY', 'DISCOVERY', 'DISCRETION', 'DISCRIMINATION', 'DISMISS', 'DISMISSAL', 'DISQUALIFICATION', 'DNA', 'DOCTRINE', 'DOCUMENT', 'DOUBLE', 'DOUBT', 'DRAWN', 'DRUGS', 'DURESS', 'DUTY', 'EFFECTS', 'ELEMENT', 'ELEMENTS', 'ENCLOSURE', 'ENTITY', 'ENTRAPMENT', 'ENTRY', 'EQUIPMENT', 'ERRONEOUS', 'ERROR', 'ESTOPPEL', 'EVIDENCE', 'EXAMINATION', 'EXAMPLE', 'EXCEPTION', 'EXCHANGE', 'EXCLUSION', 'EXCULPATORY', 'EXECUTE', 'EXECUTED', 'EXECUTION', 'EXEMPLAR', 'EXIGENCY', 'EXPRESS', 'EXTENSION', 'EXTRAJUDICIAL', 'EYEWITNESS', 'FACT', 'FACTOR', 'FACTS', 'FAIR', 'FALSE', 'FEDERAL', 'FELONY', 'FENCE', 'FILE', 'FILING', 'FINDER', 'FINDING', 'FINE', 'FIRST', 'FIT', 'FIXED', 'FOR', 'FORCE', 'FORCIBLE', 'FORFEITURE', 'FORM', 'FRAUD', 'FREE', 'FREEDOM', 'FRIEND', 'FRISK', 'FRIVOLOUS', 'GAIN', 'GOVERNMENT', 'GRANT', 'GUARANTEE', 'GUEST', 'GUILTY', 'HARASSMENT', 'HARM', 'HEARING', 'HELP', 'HOLDING', 'HOMICIDE', 'HOSTILE', 'HOUSE', 'HUSBAND', 'III', 'ILLEGAL', 'IMMIGRATION', 'IMMUNITY', 'IMPEACH', 'IMPRISONMENT', 'INCARCERATION', 'INCOMPETENCY', 'INCONSISTENT', 'INCRIMINATE', 'INCRIMINATION', 'INCULPATORY', 'INDEPENDENT', 'INDICTMENT', 'INDIGENT', 'INFERENCE', 'INFORMATION', 'INFORMED', 'INHERENT', 'INJURY', 'INMATE', 'INSANITY', 'INSIDER', 'INSTRUCTION', 'INSTRUMENT', 'INTENT', 'INTEREST', 'INTERROGATION', 'INTERVENING', 'INTOXICATION', 'INVENTORY', 'INVOLUNTARY', 'IRRELEVANT', 'ISSUE', 'ISSUED', 'JAIL', 'JEOPARDY', 'JOINT', 'JUDGE', 'JUDICIAL', 'JURISDICTION', 'JUROR', 'JURY', 'JUSTIFICATION', 'JUVENILE', 'KING', 'LAND', 'LANDLORD', 'LARCENY', 'LAST', 'LAW', 'LAWFUL', 'LAWS', 'LAY', 'LEGAL', 'LESSER', 'LIBERTIES', 'LIBERTY', 'LICENSE', 'LIKE', 'LIMITATION', 'LIMITATIONS', 'LINEUP', 'LOCATION', 'LONG', 'LOSS', 'LOT', 'MAGISTRATE', 'MAINTAIN', 'MANDATE', 'MANIFEST', 'MANIPULATION', 'MANSLAUGHTER', 'MARIJUANA', 'MATERIAL', 'MATTER', 'MINIMUM', 'MINING', 'MINORITY', 'MINUTES', 'MISCONDUCT', 'MISDEMEANOR', 'MISTAKE', 'MISTRIAL', 'MORAL', 'MOTION', 'MURDER', 'NARCOTICS', 'NECESSARY', 'NECESSITY', 'NEGLIGENCE', 'NEXT', 'NON', 'NOT', 'NOTE', 'NOTICE', 'NOW', 'OBJECT', 'OBJECTION', 'OBLIGATION', 'OCCUPANT', 'OFFENSE', 'OFFER', 'OFFICER', 'OMNIBUS', 'ONE', 'OPEN', 'OPPONENT', 'ORAL', 'ORDER', 'ORDINANCE', 'ORIGINAL', 'OUT', 'OVER', 'OWNER', 'OWNERSHIP', 'PAPER', 'PAROLE', 'PARTY', 'PASSIVE', 'PENALTIES', 'PENALTY', 'PER', 'PEREMPTORY', 'PERFORMANCE', 'PERJURY', 'PERSON', 'PERSONAL', 'PETITION', 'PETITIONER', 'PETTY', 'PLACEM ...
# =======5=======
# ['ACCELERATION', 'ACCEPTANCE', 'ACCIDENT', 'ACCORD', 'ACCOUNT', 'ACCRUE', 'ACKNOWLEDGMENT', 'ACQUIESCENCE', 'ACT', 'ACTION', 'ACTUAL', 'ADJUDICATION', 'ADMINISTRATOR', 'ADMISSION', 'ADULT', 'ADVANCE', 'AFFIRMATION', 'AFTER', 'AGENT', 'AGREEMENT', 'AND', 'ANSWER', 'APPROPRIATE', 'ARBITRATION', 'ASSIGN', 'ASSIGNMENT', 'ASSURANCE', 'ATTEMPT', 'ATTORNEY', 'AUCTION', 'AVOID', 'AVOIDANCE', 'BAILEE', 'BANK', 'BANKER', 'BANKRUPTCY', 'BAR', 'BARGAIN', 'BASIS', 'BEFORE', 'BELIEF', 'BENEFICIARY', 'BENEFIT', 'BID', 'BILATERAL', 'BILL', 'BINDING', 'BOILERPLATE', 'BREACH', 'BURDEN', 'BUSINESS', 'BUY', 'CALL', 'CAPACITY', 'CARRIER', 'CASE', 'CAUSE', 'CHALLENGE', 'CHARGE', 'CHARITY', 'CHECK', 'CIVIL', 'CLAIM', 'CLAIMANT', 'CLAUSE', 'CLEAR', 'CLERK', 'CODE', 'COMMENT', 'COMMISSION', 'COMMITMENT', 'COMMON', 'COMPANY', 'COMPENSATION', 'COMPETENT', 'COMPLAINT', 'CONCURRENT', 'CONDITION', 'CONDITIONAL', 'CONFERENCE', 'CONFIRMATION', 'CONSENT', 'CONSEQUENTIAL', 'CONSIDERATION', 'CONSTRUCTION', 'CONSTRUCTIVE', 'CONSUMER', 'CONTINGENT', 'CONTRACT', 'CONTRACTOR', 'CONTRIBUTION', 'CONVERSATION', 'CONVERSION', 'CONVEY', 'CONVEYANCE', 'CORPORATE', 'CORPORATION', 'COST', 'COSTS', 'COURT', 'COVENANT', 'COVER', 'CREDIT', 'CREDITOR', 'CRIME', 'CRIMINAL', 'CUSTODY', 'DAMAGE', 'DAMAGES', 'DATE', 'DEALER', 'DEALING', 'DEATH', 'DEBT', 'DEBTOR', 'DECEDENT', 'DECISION', 'DEFAULT', 'DEFECT', 'DEFECTIVE', 'DEFENDANT', 'DEFENSE', 'DEGREE', 'DELEGATE', 'DELIVERY', 'DEMAND', 'DEPENDENT', 'DILIGENCE', 'DIMINISHED', 'DISCHARGE', 'DISCLAIMER', 'DISCOVERY', 'DISCRETION', 'DISCRIMINATION', 'DISPOSITION', 'DISTINGUISH', 'DOCTOR', 'DOCTRINE', 'DOCUMENT', 'DONATION', 'DONEE', 'DONOR', 'DOUBT', 'DRAFT', 'DRUGS', 'DURESS', 'DUTY', 'EASEMENT', 'ELECTION', 'ELEMENT', 'ELEMENTS', 'EMPLOYER', 'ENRICHMENT', 'EQUITABLE', 'ESSENCE', 'ESTATE', 'ESTOPPEL', 'EVIDENCE', 'EXAMINATION', 'EXAMPLE', 'EXCEPTION', 'EXCHANGE', 'EXCLUSION', 'EXCULPATORY', 'EXECUTION', 'EXECUTOR', 'EXPENSE', 'EXPORT', 'EXPRESS', 'EXTENSION', 'EXTRINSIC', 'FACT', 'FACTS', 'FAIR', 'FALSE', 'FAMILY', 'FAULT', 'FEDERAL', 'FEE', 'FIDUCIARY', 'FILING', 'FINDING', 'FIRST', 'FIT', 'FITNESS', 'FIXED', 'FIXING', 'FOR', 'FORBEARANCE', 'FORESEEABILITY', 'FORESEEABLE', 'FORM', 'FRAUD', 'FREE', 'GIFT', 'GOODS', 'GRANT', 'GROSS', 'GUILTY', 'HARDSHIP', 'HARM', 'HOLDER', 'HOLDING', 'HOUSE', 'IGNORANCE', 'III', 'ILLEGAL', 'IMMATERIAL', 'IMPLICATION', 'IMPLIED', 'IMPOSSIBILITY', 'IMPRESSION', 'IMPROVEMENT', 'INCAPACITY', 'INCOMPETENCY', 'INCONSISTENT', 'INDEMNITY', 'INDEPENDENT', 'INDORSEMENT', 'INFANCY', 'INFIRM', 'INFLUENCE', 'INFORMATION', 'INHERENT', 'INJUNCTION', 'INJURY', 'INSOLVENCY', 'INSTALLMENT', 'INSTRUMENT', 'INSURANCE', 'INTEGRATION', 'INTENT', 'INTEREST', 'INTOXICATION', 'INVENTORY', 'ISSUE', 'JUDGMENT', 'JUDICIAL', 'JURISDICTION', 'JURY', 'KIND', 'LACHES', 'LADING', 'LAND', 'LAPSE', 'LAST', 'LAW', 'LAWSUIT', 'LEASE', 'LEGAL', 'LEND', 'LESSER', 'LET', 'LIABILITY', 'LIABLE', 'LICENSE', 'LIEN', 'LIKE', 'LIMITATION', 'LIMITATIONS', 'LOAN', 'LOCATION', 'LONG', 'LOSS', 'LOT', 'MAINTAIN', 'MAJORITY', 'MAKER', 'MARRIAGE', 'MASTER', 'MATERIAL', 'MATTER', 'MECHANIC', 'MEMORANDUM', 'MERCHANT', 'MERCHANTABILITY', 'MERCHANTABLE', 'MERGER', 'MILITARY', 'MINING', 'MINORITY', 'MISCONDUCT', 'MISTAKE', 'MONTH', 'MORAL', 'MORTGAGE', 'MUTUAL', 'NARCOTICS', 'NECESSARY', 'NEGLIGENCE', 'NEGOTIATION', 'NEXT', 'NON', 'NONPERFORMANCE', 'NOT', 'NOTE', 'NOTICE', 'NOVATION', 'NULLITY', 'OBJECT', 'OBJECTION', 'OBLIGATION', 'OBLIGEE', 'OBLIGOR', 'OFFER', 'OFFERING', 'OMISSION', 'ONE', 'OPEN', 'OPINION', 'OPTION', 'ORAL', 'ORDER', 'ORIGINAL', 'OUT', 'OVER', 'OWNER', 'OWNERSHIP', 'PAID', 'PAPER', 'PAROLE', 'PARTY', 'PATIENT', 'PAYMENT', 'PENALTIES', 'PENALTY', 'PER', 'PERFORMANCE', 'PERSON', 'PERSONAL', 'PLAINTIFF', 'PLEADINGS', 'POSSESSION', 'POWER', 'PRACTICE', 'PRE', 'PRECEDENT', 'PREJUDICE', 'PRESUMPTION', 'PRICE', 'PRINCIPAL', 'PRIOR', 'PRIORITY', 'PRIVACY', 'PROCESS', 'PRODUCT', 'PROFIT', 'PROMISE', 'PROOF', 'PROPER', 'PROPERTY', 'PROSECUTION',  ...
# =======6=======
# ['ABOLISH', 'ABORTION', 'ABRIDGE', 'ABROGATE', 'ABSTENTION', 'ACCEPTANCE', 'ACCESS', 'ACCIDENT', 'ACCORD', 'ACCOUNT', 'ACCOUNTING', 'ACLU', 'ACT', 'ACTION', 'ACTUAL', 'ADJUDICATION', 'ADMINISTRATOR', 'ADMISSION', 'ADMIT', 'ADOPT', 'ADOPTION', 'ADULT', 'ADVANCE', 'ADVANCEMENT', 'ADVERSE', 'ADVOCACY', 'AFFIDAVIT', 'AFFIRMATION', 'AFTER', 'AGENCY', 'AGGREGATE', 'AGREEMENT', 'AIRSPACE', 'ALIEN', 'AMEND', 'AMENDMENTS', 'AMERICANS', 'AMNESTY', 'AND', 'ANIMUS', 'ANSWER', 'ANTI', 'APPEAL', 'APPEARANCE', 'APPOINTMENT', 'APPROPRIATE', 'APPROPRIATION', 'ART', 'ASSEMBLY', 'ASSESS', 'ASSIGN', 'ASSIGNMENT', 'ASSOCIATION', 'ASSURED', 'ATTACHMENT', 'ATTAINDER', 'ATTEMPT', 'ATTORNEY', 'AUTHORITY', 'AVOID', 'BAIL', 'BAILEE', 'BANK', 'BANKRUPTCY', 'BAR', 'BASIS', 'BATTERY', 'BEFORE', 'BELIEF', 'BENEFIT', 'BIAS', 'BILL', 'BINDING', 'BLOOD', 'BOND', 'BONDS', 'BREACH', 'BRIBERY', 'BURDEN', 'BUSINESS', 'BUY', 'CALL', 'CAMERA', 'CAPACITY', 'CARE', 'CARRIER', 'CASE', 'CAUSE', 'CHALLENGE', 'CHAPTER', 'CHARTER', 'CHECK', 'CITIZEN', 'CIVIL', 'CLAIM', 'CLAUSE', 'CLEAR', 'CLERIC', 'CLERK', 'CLOSE', 'CLOSED', 'CLOSING', 'CODE', 'COERCION', 'COGNIZABLE', 'COLOR', 'COMITY', 'COMMERCE', 'COMMISSION', 'COMMITMENT', 'COMMITTEE', 'COMMON', 'COMMUTATION', 'COMPANY', 'COMPENSATION', 'COMPLAINT', 'CONCUR', 'CONCURRENT', 'CONDITION', 'CONGRESS', 'CONSENT', 'CONSIDERATION', 'CONSTITUTION', 'CONSTITUTIONAL', 'CONSTRUCTION', 'CONTRACT', 'CONTRIBUTION', 'CONTROVERSY', 'CONVICTION', 'CORPORATE', 'CORPORATION', 'CORPORATIONS', 'COST', 'COSTS', 'COUNSEL', 'COURT', 'COVER', 'CREDIT', 'CRIME', 'CRIMINAL', 'CUSTODY', 'DAMAGE', 'DAMAGES', 'DEATH', 'DEBTOR', 'DECISION', 'DECLARATION', 'DEDICATION', 'DEDUCTIONS', 'DEFAMATION', 'DEFENDANT', 'DEFENSE', 'DEGREE', 'DELEGATE', 'DELINQUENT', 'DELIVERY', 'DEMAND', 'DENIAL', 'DEPENDENT', 'DEPORTATION', 'DESCENT', 'DETENTION', 'DETERMINATION', 'DEVISE', 'DIMINISHED', 'DISABILITY', 'DISCHARGE', 'DISCRETION', 'DISCRIMINATION', 'DISMISS', 'DISMISSAL', 'DISTINGUISH', 'DISTRIBUTION', 'DIVORCE', 'DOCTOR', 'DOCTRINE', 'DOMAIN', 'DONOR', 'DRAFT', 'DRAW', 'DRAWING', 'DRAWN', 'DRUGS', 'DUTY', 'EASEMENT', 'EFFECTS', 'ELECTION', 'ELEMENT', 'ELEMENTS', 'EMPLOYER', 'ENDORSEMENT', 'ENDOWMENT', 'ENJOIN', 'ENTITY', 'ENTRY', 'ENUMERATED', 'EPA', 'EQUALITY', 'EQUIPMENT', 'EQUITABLE', 'ERRONEOUS', 'ESCHEAT', 'ESSENCE', 'ESTATE', 'EVIDENCE', 'EXAMINATION', 'EXAMPLE', 'EXCEPTION', 'EXCHANGE', 'EXCISE', 'EXCLUSION', 'EXECUTE', 'EXECUTION', 'EXEMPTION', 'EXPENSE', 'EXPORT', 'EXPRESS', 'EXTENSION', 'FACT', 'FACTOR', 'FACTS', 'FAIR', 'FALSE', 'FAMILY', 'FAULT', 'FCC', 'FDA', 'FEDERAL', 'FEDERALISM', 'FEE', 'FIGURE', 'FILE', 'FILING', 'FINDING', 'FIRST', 'FISCAL', 'FIT', 'FIXING', 'FOR', 'FORCE', 'FORESEEABLE', 'FORFEITURE', 'FORM', 'FORUM', 'FOUNDATION', 'FRANCHISE', 'FRAUD', 'FREE', 'FREEDOM', 'FUND', 'GENERIC', 'GOODS', 'GOVERNMENT', 'GRANT', 'GRIEVANCE', 'GUARANTEE', 'GUILTY', 'HARASSMENT', 'HARM', 'HEARING', 'HEART', 'HOLDER', 'HOLDING', 'HOSTILE', 'HOUSE', 'HUSBAND', 'III', 'ILLEGAL', 'ILLEGITIMATE', 'IMMUNITIES', 'IMMUNITY', 'IMPEACH', 'IMPLIED', 'IMPORT', 'IMPORTATION', 'IMPOUND', 'IMPOUNDMENT', 'INCARCERATION', 'INCOME', 'INCONSISTENT', 'INCORPORATE', 'INCRIMINATION', 'INCUMBENT', 'INDECENT', 'INDEPENDENT', 'INDICTMENT', 'INDIGENT', 'INFIRM', 'INFLUENCE', 'INFORMATION', 'INFORMED', 'INFRINGEMENT', 'INHERENT', 'INHERITANCE', 'INJUNCTION', 'INJURY', 'INSTITUTION', 'INSTRUCTION', 'INSTRUMENTALITY', 'INSURANCE', 'INTEGRATION', 'INTENT', 'INTEREST', 'INTERPLEADER', 'INTERVENTION', 'INTESTATE', 'INVESTMENT', 'INVOLUNTARY', 'IRS', 'ISSUE', 'ISSUED', 'JOINT', 'JOURNALIST', 'JUDGE', 'JUDGMENT', 'JUDICIAL', 'JUDICIARY', 'JURISDICTION', 'JURY', 'JUSTIFICATION', 'LAND', 'LANDLORD', 'LAST', 'LAW', 'LAWFUL', 'LAWS', 'LAWSUIT', 'LAY', 'LEASEHOLD', 'LEGAL', 'LEGISLATION', 'LEND', 'LESSEE', 'LESSER', 'LESSOR', 'LEVY', 'LIABILITY', 'LIABLE', 'LIBERTIES', 'LIBERTY', 'LICENSE', 'LIEN', 'LIKE', 'LIMITATION', 'LIMITATIONS', 'LINE', 'LISTING', 'LITIGANTS', 'LITIGATION', 'LOAN',  ...
# =======7=======
# ['ABRIDGE', 'ABSTENTION', 'ACCESS', 'ACCIDENT', 'ACCORD', 'ACCOUNT', 'ACQUIRE', 'ACT', 'ACTION', 'ACTUAL', 'ADJUDICATION', 'ADMISSION', 'ADMIT', 'ADOPT', 'ADVANCE', 'ADVERSARY', 'ADVERSE', 'AFFIANT', 'AFFIDAVIT', 'AFTER', 'AGENCY', 'AGENT', 'AGGREGATE', 'AGREEMENT', 'ALIEN', 'ALIMONY', 'ALLEGATION', 'ALTERATION', 'AMEND', 'AMENDMENTS', 'AND', 'ANIMUS', 'ANSWER', 'APPEAL', 'APPEARANCE', 'APPOINTMENT', 'APPORTION', 'APPROPRIATE', 'ARBITRATION', 'ARGUMENT', 'ARM', 'ARREST', 'ASSAULT', 'ASSESS', 'ASSIGNMENT', 'ASSOCIATION', 'ATTACHMENT', 'ATTEMPT', 'ATTORNEY', 'AUTHORITY', 'AUTOMOBILE', 'AVOID', 'AVOIDANCE', 'BAILEE', 'BAILOR', 'BANK', 'BANKRUPTCY', 'BAR', 'BASIS', 'BATTERY', 'BEFORE', 'BELIEF', 'BENEFICIARY', 'BENEFIT', 'BIAS', 'BIND', 'BINDING', 'BLOOD', 'BOND', 'BREACH', 'BRIEF', 'BURDEN', 'BUSINESS', 'CAB', 'CALL', 'CAPACITY', 'CAPITAL', 'CASE', 'CAUSE', 'CERTIFICATION', 'CHALLENGE', 'CHAMBERS', 'CHAPTER', 'CHECK', 'CIRCUIT', 'CITIZEN', 'CIVIL', 'CLAIM', 'CLAIMANT', 'CLAUSE', 'CLEAR', 'CLERK', 'CLOSE', 'CLOSED', 'CLOSING', 'CODE', 'COGNIZABLE', 'COLLATERAL', 'COLOR', 'COMMERCE', 'COMMITTEE', 'COMMON', 'COMPANY', 'COMPENSATION', 'COMPETENT', 'COMPLAINT', 'CONCLUSIVE', 'CONCURRENT', 'CONDITION', 'CONDITIONAL', 'CONFERENCE', 'CONGRESS', 'CONSENT', 'CONSIDERATION', 'CONSTITUTION', 'CONSTITUTIONAL', 'CONSTRUE', 'CONSUMER', 'CONTINGENT', 'CONTRACT', 'CONTRACTOR', 'CONTROVERSY', 'CONVEYANCE', 'CONVICTION', 'COPY', 'COPYRIGHT', 'CORPORATE', 'CORPORATION', 'CORPORATIONS', 'COST', 'COSTS', 'COUNSEL', 'COUNTERCLAIM', 'COURT', 'CREDIBILITY', 'CREDIT', 'CRIMINAL', 'CROSS', 'CUMULATIVE', 'CUSTODY', 'DAMAGE', 'DAMAGES', 'DATE', 'DEATH', 'DECEDENT', 'DECISION', 'DECLARATION', 'DECREE', 'DEFAULT', 'DEFECT', 'DEFECTIVE', 'DEFENDANT', 'DEFENSE', 'DEFICIENCY', 'DEGREE', 'DELIBERATION', 'DELIVERY', 'DEMAND', 'DENIAL', 'DEPENDENT', 'DEPONENT', 'DEPOSE', 'DEPOSITION', 'DETERMINATION', 'DILIGENCE', 'DIRECTOR', 'DISCOVERY', 'DISCRETION', 'DISCRIMINATION', 'DISMISS', 'DISMISSAL', 'DISPOSITION', 'DISSOLUTION', 'DIVORCE', 'DOCTRINE', 'DOCUMENT', 'DOMAIN', 'DOMICILE', 'DOMICILIARY', 'DOUBLE', 'DOUBT', 'DRAFT', 'DRAW', 'DURESS', 'DUTY', 'EFFECTS', 'ELEMENT', 'ELEMENTS', 'EMPLOYER', 'ENJOIN', 'ENTIRETY', 'ENTITY', 'ENTRY', 'EQUIPMENT', 'EQUITABLE', 'EQUITY', 'ERRONEOUS', 'ERROR', 'ESTATE', 'ESTOPPEL', 'EVIDENCE', 'EXAMINATION', 'EXAMPLE', 'EXCEPTION', 'EXCHANGE', 'EXCLUSION', 'EXECUTE', 'EXECUTED', 'EXHIBIT', 'EXPENSE', 'EXPRESS', 'EXTRINSIC', 'FACT', 'FACTOR', 'FACTS', 'FAIR', 'FALSE', 'FAMILY', 'FAULT', 'FEDERAL', 'FILE', 'FILING', 'FINDER', 'FINDING', 'FINE', 'FIRST', 'FIT', 'FOR', 'FORCE', 'FORECLOSURE', 'FORESEEABILITY', 'FORFEITURE', 'FORM', 'FORUM', 'FRAUD', 'FREE', 'FRIEND', 'FUND', 'GAIN', 'GARNISHMENT', 'GOODS', 'GOVERNMENT', 'GRANT', 'GROSS', 'GUILTY', 'HARDSHIP', 'HARM', 'HEARING', 'HIT', 'HOLDER', 'HOLDING', 'HUSBAND', 'III', 'IMMATERIAL', 'IMMUNITIES', 'IMMUNITY', 'IMPEACH', 'IMPLEADER', 'IMPLIED', 'IMPRISONMENT', 'IMPUTED', 'INCARCERATION', 'INCONSISTENT', 'INCORPORATION', 'INDEFINITE', 'INDEMNIFY', 'INDEPENDENT', 'INFLUENCE', 'INFORMATION', 'INFRINGEMENT', 'INHERENT', 'INHERITANCE', 'INITIATIVE', 'INJUNCTION', 'INJURY', 'INSTRUCTION', 'INSTRUMENTALITY', 'INSURANCE', 'INSURED', 'INTENT', 'INTEREST', 'INTERLOCUTORY', 'INTERPLEADER', 'INTERROGATORIES', 'INTERVENING', 'INTERVENOR', 'INTERVENTION', 'INVOLUNTARY', 'IRRELEVANT', 'IRS', 'ISSUE', 'ISSUED', 'JOHN', 'JOINDER', 'JOINT', 'JUDGE', 'JUDGMENT', 'JUDICIAL', 'JUDICIARY', 'JURISDICTION', 'JUROR', 'JURY', 'JUSTIFICATION', 'KING', 'LACHES', 'LAND', 'LAST', 'LAW', 'LAWS', 'LAWSUIT', 'LEGAL', 'LESSER', 'LEXIS', 'LIABILITY', 'LIABLE', 'LIBERTY', 'LICENSE', 'LIEN', 'LIMITATION', 'LIMITATIONS', 'LINE', 'LISTING', 'LITIGANTS', 'LITIGATION', 'LOAN', 'LOCATION', 'LONG', 'LOSS', 'MAINTAIN', 'MAINTENANCE', 'MAJORITY', 'MALICE', 'MANIFEST', 'MASTER', 'MATERIAL', 'MATTER', 'MEMORANDUM', 'MERITS', 'MILITARY', 'MINIMUM', 'MISCONDUCT', 'MISTAKE', 'MORTGAGE', 'MOTION', 'MOVANT', 'MOVE', 'NECESSARY', 'NEGLECT',  ...

# %%
# print(subjects[1][1][1:10])
# print(set(subjects[1][1][1:10]))

# %%
# print(dicWords[1:10])
# print(set(dicWords[1:10]))

# %%
# test=set(subjects[1][1][1:10])&set(dicWords[1:10])
# print(test)

# %% [markdown]
# #各subjectDicを出力

# %%
for i in range(len(subjects)):
  dicfile=open(subjects[i][3],"w")
  for ii in range(len(subjects[i][2])):
    dicfile.write(subjects[i][2][ii]+"\n")
dicfile.close()
